# %%
import torch
import torch.nn as nn
import math
import pandas as pd
import string
import numpy as np
from tqdm import tqdm

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")


# --- Vocabulary Class ---
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        all_chars = list(string.printable)
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        if isinstance(text, float):  # Handle NaN values
            text = str(text)
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# --- Transformer Model ---
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))
        attn_probs = torch.softmax(scores, dim=-1)
        return torch.matmul(attn_probs, V)

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        return self.W_o(self.combine_heads(attn_output))

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super().__init__()
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm2(x + self.dropout(ff_output))

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm3(x + self.dropout(ff_output))

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask
        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        return self.fc(dec_output)

# --- Inference Functions ---
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        return vocab.decode(target[0].cpu().numpy())

def process_and_print_results(model, test_file, vocab, max_length, device, num_samples=4000):
    try:
        df = pd.read_excel(test_file) if test_file.endswith('.xlsx') else pd.read_csv(test_file)
    except Exception as e:
        print(f"Error loading test file: {e}")
        return None

    if len(df) > num_samples:
        df = df.sample(n=num_samples, random_state=42)

    results = []
    total_correct = 0
    total_chars_correct = 0
    total_chars = 0

    print("\n=== Starting Inference ===")
    print(f"Processing {len(df)} test cases...\n")

    for idx, row in df.iterrows():
        try:
            input_text = str(row['input'])
            expected = str(row['output'])

            # Decrypt the text
            decrypted = decrypt_text(model, input_text, vocab, max_length, device)
            decrypted_clean = decrypted.replace('<SOS>', '').replace('<EOS>', '').strip()

            # Calculate metrics
            full_match = decrypted_clean == expected
            total_correct += int(full_match)

            min_len = min(len(decrypted_clean), len(expected))
            char_matches = sum(1 for a, b in zip(decrypted_clean[:min_len], expected[:min_len]) if a == b)
            total_chars_correct += char_matches
            total_chars += max(len(decrypted_clean), len(expected))

            # Print detailed results for each case
            print(f"\n--- Case {idx+1} ---")
            print(f"Input:     {input_text}")
            print(f"Decrypted: {decrypted_clean}")
            print(f"Expected:  {expected}")
            print(f"Match:     {'✅' if full_match else '❌'}")
            print(f"Char Accuracy: {char_matches}/{max(len(decrypted_clean), len(expected))} ({(char_matches/max(len(decrypted_clean), len(expected)))*100:.1f}%)")

            results.append({
                'Case #': idx+1,
                'Input': input_text,
                'Decrypted': decrypted_clean,
                'Expected': expected,
                'Full Match': 'Yes' if full_match else 'No',
                'Char Matches': f"{char_matches}/{max(len(decrypted_clean), len(expected))}",
                'Char Accuracy': f"{(char_matches/max(len(decrypted_clean), len(expected)))*100:.2f}%"
            })

        except Exception as e:
            print(f"\nError processing case {idx+1}: {e}")
            continue

    # Create results DataFrame
    results_df = pd.DataFrame(results)

    # Add summary
    full_acc = (total_correct/len(results))*100 if results else 0
    char_acc = (total_chars_correct/total_chars)*100 if total_chars > 0 else 0

    summary = pd.DataFrame([{
        'Case #': 'SUMMARY',
        'Input': f"Total Cases: {len(results)}",
        'Decrypted': f"Full Accuracy: {full_acc:.2f}%",
        'Expected': f"Char Accuracy: {char_acc:.2f}%",
        'Full Match': f"{total_correct}/{len(results)}",
        'Char Matches': f"{total_chars_correct}/{total_chars}",
        'Char Accuracy': f"{char_acc:.2f}%"
    }])

    return pd.concat([results_df, summary], ignore_index=True)

# --- Main Execution ---
if __name__ == "__main__":
    # Configuration - UPDATE THESE PATHS
    MODEL_PATH = '/content/drive/MyDrive/vigenere_vanilla_100.pth'
    TEST_FILE = '/content/Full_testing_vigenere_100.xlsx'
    OUTPUT_FILE = '/content/drive/MyDrive/inference_vigenere_100_vanilla.xlsx'
    MAX_LENGTH = 256

    # Initialize vocabulary and model
    vocab = Vocabulary()
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=8,
        num_layers=8,
        d_ff=1024,
        max_seq_length=MAX_LENGTH,
        dropout=0.1018942343827998
    ).to(device)


    # Load trained model
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
        model.eval()
        print("Model loaded successfully")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    # Process test cases and print all results
    results = process_and_print_results(model, TEST_FILE, vocab, MAX_LENGTH, device)

    # Save to Excel
    if results is not None:
        try:
            results.to_excel(OUTPUT_FILE, index=False)
            print(f"\nFull results saved to {OUTPUT_FILE}")

            # Print final summary
            print("\n=== Final Summary ===")
            print(f"Full-match accuracy: {results.iloc[-1]['Full Match']}")
            print(f"Character-level accuracy: {results.iloc[-1]['Char Matches']} ({results.iloc[-1]['Char Accuracy']})")
        except Exception as e:
            print(f"\nError saving results: {e}")
    else:
        print("\nNo results were generated")
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected:  ALLOWS
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 60201 ---
# Input:     TTBWIXV
# Decrypted: FITNESS
# Expected:  HORIZON
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 211840 ---
# Input:     LQ LTBQ ZMZ TMHT XEWQ RNIR M SLO.
# Decrypted: WE HAVE THE BOOK THAT THIS I KEY.
# Expected:  HE WILL NOT LIVE MORE THAN A DAY.
# Match:     ❌
# Char Accuracy: 12/33 (36.4%)
#
# --- Case 175638 ---
# Input:     JFS IWYIJPM OA GJLCFKL ADJF GTWA.
# Decrypted: THE LITTEER IS CROSPO THE I DEAD.
# Expected:  THE COUNTRY IS COVERED WITH SNOW.
# Match:     ❌
# Char Accuracy: 11/33 (33.3%)
#
# --- Case 125002 ---
# Input:     B RJMOWX RJ T WVIO.
# Decrypted: I BOUGHT TO A SONG.
# Expected:  I WORKED AT A BANK.
# Match:     ❌
# Char Accuracy: 9/19 (47.4%)
#
# --- Case 221664 ---
# Input:     VTWYJ
# Decrypted: BADGE
# Expected:  LOGAN
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 21226 ---
# Input:     HRUG
# Decrypted: STAT
# Expected:  ARAB
# Match:     ❌
# Char Accuracy: 1/4 (25.0%)
#
# --- Case 181450 ---
# Input:     YEN UG OZAZFWS HGJ JNFUPFDS AU YNP.
# Decrypted: SHE IS STUDIED FOR QUIETING IN DNA.
# Expected:  SHE IS PUTTING THE CHILDREN TO BED.
# Match:     ❌
# Char Accuracy: 14/35 (40.0%)
#
# --- Case 229136 ---
# Input:     YMDEHWT
# Decrypted: FARMERS
# Expected:  WARRIOR
# Match:     ❌
# Char Accuracy: 2/7 (28.6%)
#
# --- Case 70348 ---
# Input:     PAP PRYL XTRNWCSFYWHL JNX ROL.
# Decrypted: THE TEST CONVERSITING THE LEWT.
# Expected:  THE BEST HAIRDRESSERS ARE GAY.
# Match:     ❌
# Char Accuracy: 12/31 (38.7%)
#
# --- Case 361325 ---
# Input:     RRLP ZWTLAYZ HMV QRY IMV IERN TEY NND PEYN NDB KI UU IMRN.
# Decrypted: ZIRI STARTED THE WAY THE ORD OFF THE DIST AFT THE WAS BY.
# Expected:  MARY THOUGHT SHE WAS THE ONLY ONE WHO KNEW HOW TO DO THAT.
# Match:     ❌
# Char Accuracy: 15/58 (25.9%)
#
# --- Case 278528 ---
# Input:     JQJF PWU BMFERU ADZERUD UBWI OAS MWL.
# Decrypted: SAMI HAD PLANED OVERLY THERE FOR YOU.
# Expected:  TELL THE POLICE OFFICER WHAT YOU SAW.
# Match:     ❌
# Char Accuracy: 9/37 (24.3%)
#
# --- Case 175333 ---
# Input:     FBM JMOD QYNZA TTXY MFY TTKFP.
# Decrypted: YOU SAID THANK MARY WAS FUSST.
# Expected:  LET MARY WATCH WHAT SHE WANTS.
# Match:     ❌
# Char Accuracy: 7/30 (23.3%)
#
# --- Case 116810 ---
# Input:     YT DUWN QJJ XJVKIWP MRHT AZ UQG RGASMKCSFF BAHLQN XH IAYF JPS EAONA.
# Decrypted: WE HAVE NEW THINKED TOM AND MAR EXUSTABLED CANSED TO LEAST OF THER.
# Expected:  WE LIVE OUR LIMITED LIFE IN THE COORDINATE SYSTEM OF TIME AND MONEY.
# Match:     ❌
# Char Accuracy: 17/68 (25.0%)
#
# --- Case 342480 ---
# Input:     NGT
# Decrypted: RAM
# Expected:  WEB
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 364485 ---
# Input:     K TYUDP NPXGXMSNMW VBKY.
# Decrypted: I HAVE A FORGOTING TOMA.
# Expected:  I NEVER UNDERSTOOD THIS.
# Match:     ❌
# Char Accuracy: 8/24 (33.3%)
#
# --- Case 26214 ---
# Input:     MKUV LOBDVOYN EBKMO BUTH DPNM.
# Decrypted: SAMI STARTEDY TALKE THIS SHOW.
# Expected:  SAMI SURVIVED WORSE THAN THAT.
# Match:     ❌
# Char Accuracy: 14/30 (46.7%)
#
# --- Case 43739 ---
# Input:     COOJQMSSRS
# Decrypted: RESISTANCE
# Expected:  DELEGATION
# Match:     ❌
# Char Accuracy: 1/10 (10.0%)
#
# --- Case 70316 ---
# Input:     BIS JWLB IOQJWZFGAWKA BFM YTG.
# Decrypted: THE TEST CONVERSITING THE LEWT.
# Expected:  THE BEST HAIRDRESSERS ARE GAY.
# Match:     ❌
# Char Accuracy: 12/31 (38.7%)
#
# --- Case 175912 ---
# Input:     NNE VQAX HITTHPDRI OTTHN CUJ YBEMKWT.
# Decrypted: THE WILL PROBABLED TEACH THE MORNING.
# Expected:  THE WORK CONTINUED UNTIL THE EVENING.
# Match:     ❌
# Char Accuracy: 19/37 (51.4%)
#
# --- Case 148147 ---
# Input:     BIGP
# Decrypted: IRAQ
# Expected:  PENN
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 39055 ---
# Input:     HZAK UTBOOX P LWNEXNBCBGD.
# Decrypted: SAMI WANTED A PREVILLATED.
# Expected:  SAMI BECAME A MILLIONAIRE.
# Match:     ❌
# Char Accuracy: 11/26 (42.3%)
#
# --- Case 2880 ---
# Input:     JCO
# Decrypted: EXP
# Expected:  SAW
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 347090 ---
# Input:     KEH JFI JJVAIYEW VG YXV RVE BXVD D JFBBUY VSJF JCR HBLR.
# Decrypted: TOM WAS ARRIVING IN THE ONE THAN I ASLEEP AND THE STUD.
# Expected:  TOM WAS STANDING AT THE BAR WHEN I WALKED INTO THE CLUB.
# Match:     ❌
# Char Accuracy: 27/56 (48.2%)
#
# --- Case 376427 ---
# Input:     YDZ ETX ABPM FAY PXSHR LY WTNIBYN.
# Decrypted: TOM AND MARY ARE READY TO HEARTHE.
# Expected:  TOM HAS LOST ALL SENSE OF REALITY.
# Match:     ❌
# Char Accuracy: 14/34 (41.2%)
#
# --- Case 89124 ---
# Input:     BWFB LS UVVUS PVOLGDA.
# Decrypted: PAUL IS HEAVY DIFFICE.
# Expected:  BAYA IS YOURS TONIGHT.
# Match:     ❌
# Char Accuracy: 7/22 (31.8%)
#
# --- Case 215022 ---
# Input:     TRAGWJP
# Decrypted: WRAPPED
# Expected:  WEAPONS
# Match:     ❌
# Char Accuracy: 3/7 (42.9%)
#
# --- Case 169278 ---
# Input:     NWTG BTTM XD GOS.
# Decrypted: THAT MIDS BE TOM.
# Expected:  THIS NEWS IS SAD.
# Match:     ❌
# Char Accuracy: 7/17 (41.2%)
#
# --- Case 153971 ---
# Input:     Z JSJ CP KWWUEOO F BFO.
# Decrypted: I HAD TO SCUMING A DOG.
# Expected:  I OWE MY PARENTS A LOT.
# Match:     ❌
# Char Accuracy: 9/23 (39.1%)
#
# --- Case 397903 ---
# Input:     PCXA PVCX VJK YXN YUWKTI.
# Decrypted: MARY WENT OFF BY BIKENON.
# Expected:  MARY SAID SHE WAS EATING.
# Match:     ❌
# Char Accuracy: 8/25 (32.0%)
#
# --- Case 174331 ---
# Input:     RGMLFIE
# Decrypted: PRESTON
# Expected:  THROUGH
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 101592 ---
# Input:     XJZ OVUKIM JONSV E BEKL TXMO BB QBUO WYER TXMO GY JPUO ZIOEZ GET.
# Decrypted: TOM ALWAYS USELS A COOK FIND A WEEKS BETO DOWN A LONG FOR WITH.
# Expected:  TOM EITHER WEARS A GRAY SUIT OR DARK BLUE SUIT TO WORK EVERY DAY.
# Match:     ❌
# Char Accuracy: 15/65 (23.1%)
#
# --- Case 111326 ---
# Input:     TY GTBFNP HXAEM XCKVCR ELAN.
# Decrypted: WE SHOULD DECID COULDE DOCT.
# Expected:  MY MOTHER HATES SUMMER HEAT.
# Match:     ❌
# Char Accuracy: 6/28 (21.4%)
#
# --- Case 353134 ---
# Input:     ZKXF DVBNIHZLDA LK LNMSN UTZHEQDMHTJ.
# Decrypted: THIS DISTANCELE IS LIKEL INWASINING.
# Expected:  THIS ADMONITION IS WORTH REMEMBERING.
# Match:     ❌
# Char Accuracy: 10/37 (27.0%)
#
# --- Case 233559 ---
# Input:     HFDWJMIGB
# Decrypted: COMPOUTED
# Expected:  SIGNATURE
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 387735 ---
# Input:     R PAB EYRP RX LTJJ KCMW OKOV EYS.
# Decrypted: I WAS KIND OF THIS PLAN STOM WAS.
# Expected:  I WAS TOLD TO STAY AWAY FROM TOM.
# Match:     ❌
# Char Accuracy: 16/33 (48.5%)
#
# --- Case 264941 ---
# Input:     BGE AGGJA LG PQOK PWJR.
# Decrypted: TOM TRIED TO SCAR SOUT.
# Expected:  TOM NEEDS TO COME HERE.
# Match:     ❌
# Char Accuracy: 10/23 (43.5%)
#
# --- Case 201330 ---
# Input:     IWZZTO QX LW XABMDP EAVLTC.
# Decrypted: THANKS IS NO THINK TOGETHE.
# Expected:  ARABIC IS MY MOTHER TONGUE.
# Match:     ❌
# Char Accuracy: 8/27 (29.6%)
#
# --- Case 263519 ---
# Input:     ZX DVD H QAJX EWTG GWJKLMD.
# Decrypted: HE AND I HAVE NEED FOUGHTS.
# Expected:  HE AND I WERE BOTH MARRIED.
# Match:     ❌
# Char Accuracy: 13/27 (48.1%)
#
# --- Case 297024 ---
# Input:     BALO
# Decrypted: THIS
# Expected:  BEEN
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 11476 ---
# Input:     KXKXB LICDJ SGS IJIN SF WRTYFT GZICOSD.
# Decrypted: MAYBE THEIR YOU KNOW TO APPEAR ROTINER.
# Expected:  THESE GASES CAN LEAD TO GLOBAL WARMING.
# Match:     ❌
# Char Accuracy: 11/39 (28.2%)
#
# --- Case 34317 ---
# Input:     WYXW YWNKV.
# Decrypted: THEY WROME.
# Expected:  THEY STUDY.
# Match:     ❌
# Char Accuracy: 6/11 (54.5%)
#
# --- Case 200524 ---
# Input:     HA BTXAHSZ JEPZ VS AP ZJA.
# Decrypted: HE REHIESE BACK TO GO MEE.
# Expected:  HE USUALLY GETS UP AT SIX.
# Match:     ❌
# Char Accuracy: 8/26 (30.8%)
#
# --- Case 379466 ---
# Input:     NJIMUC
# Decrypted: FLEECE
# Expected:  EARNED
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 160362 ---
# Input:     EUPBGNBWTS
# Decrypted: APPARENTLY
# Expected:  MULTIMEDIA
# Match:     ❌
# Char Accuracy: 0/10 (0.0%)
#
# --- Case 175365 ---
# Input:     DDF PERQ VMWGH OGMW WHW VMQXS.
# Decrypted: TOM ONLY LOVED MARY FOR MONEY.
# Expected:  LET MARY WATCH WHAT SHE WANTS.
# Match:     ❌
# Char Accuracy: 8/30 (26.7%)
#
# --- Case 90594 ---
# Input:     L PSBFI OOI GXQ IOOHLKY LWWE WLE PBG ELP XGWHKGP.
# Decrypted: I THINK TOM AND MARRIED JUST WOR HER WAS LARGEL.
# Expected:  I SPENT ALL DAY TALKING WITH TOM AND HIS FRIENDS.
# Match:     ❌
# Char Accuracy: 15/49 (30.6%)
#
# --- Case 133967 ---
# Input:     UF IXHWP MPVT NUHN LM BUF MMX RQ MEROFE.
# Decrypted: HE WAITS JAPA THAT I WANT TOM WAS THING.
# Expected:  HE WROTE THIS BOOK AT THE AGE OF TWENTY.
# Match:     ❌
# Char Accuracy: 11/40 (27.5%)
#
# --- Case 80183 ---
# Input:     QMXK XCB M MCRA DMNG.
# Decrypted: SAMI HAD A HORS TOD.
# Expected:  SAMI HAD A BABY FACE.
# Match:     ❌
# Char Accuracy: 12/21 (57.1%)
#
# --- Case 59968 ---
# Input:     QSSRX
# Decrypted: INDEX
# Expected:  ALLAN
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 115985 ---
# Input:     VNUS QCLVUWXUMS GL RLQHUAKW T DCV KRODLLKPG.
# Decrypted: THIS WATCHANGED TO SELLAXEL IN MY GRATCHES.
# Expected:  THAT RESTAURANT IS PROBABLY A BIT EXPENSIVE.
# Match:     ❌
# Char Accuracy: 8/44 (18.2%)
#
# --- Case 171159 ---
# Input:     ILJ UXOSH QEN BHICA LO QBG DTK EXBQT.
# Decrypted: TOM COULD GET HAPPY TO SEE WHA NOUNT.
# Expected:  TOM LOVES THE SOUND OF HIS OWN VOICE.
# Match:     ❌
# Char Accuracy: 13/37 (35.1%)
#
# --- Case 303658 ---
# Input:     M TXMCTBY BLAJ RWZ BFL E CXYVPY YW AID.
# Decrypted: I THOUGHT THAT YOU CAN E FRIEND TO REA.
# Expected:  I THOUGHT THAT TOM HAD A CHANCE TO WIN.
# Match:     ❌
# Char Accuracy: 25/39 (64.1%)
#
# --- Case 394868 ---
# Input:     HLZKYHL
# Decrypted: RETURNS
# Expected:  RESTORE
# Match:     ❌
# Char Accuracy: 2/7 (28.6%)
#
# --- Case 1850 ---
# Input:     XRLTSK NZ G MXXWRM QKT.
# Decrypted: JASMIN IS A GERMAN GYP.
# Expected:  RUCHEL IS A POLISH JEW.
# Match:     ❌
# Char Accuracy: 8/23 (34.8%)
#
# --- Case 27407 ---
# Input:     ETO AHEIFX XJMB A BWNNRJ VQT BCHAKW.
# Decrypted: SHE PREFER NEXT A SPAIRA THE MORNIN.
# Expected:  YOU SHOULD REST A LITTLE BIT LONGER.
# Match:     ❌
# Char Accuracy: 11/36 (30.6%)
#
# --- Case 122965 ---
# Input:     AM FKI WAMFHV IL FQWW VWQK FSLV GQUI.
# Decrypted: IT WAS EASILY TO SHOW THAT YOU BETTER.
# Expected:  IN THE WINTER IT GETS VERY COLD HERE.
# Match:     ❌
# Char Accuracy: 9/38 (23.7%)
#
# --- Case 94042 ---
# Input:     L GEL YGLWOR UV Y YQKX.
# Decrypted: I WAS AMAZED TO D THAT.
# Expected:  I WAS BITTEN BY A GNAT.
# Match:     ❌
# Char Accuracy: 13/23 (56.5%)
#
# --- Case 355644 ---
# Input:     AMHVN PMLT NRBGQ FE WQA XVWFX QMKI.
# Decrypted: YANNI WENT THAT TO PUT SHOULD CARE.
# Expected:  LAYLA GAVE BIRTH TO HER NINTH BABY.
# Match:     ❌
# Char Accuracy: 7/35 (20.0%)
#
# --- Case 181109 ---
# Input:     WJT QEJ DIXTA IRJIP XW QP XSWHN.
# Decrypted: SHE HAD BURNS ALIED ON THE WORD.
# Expected:  SHE HAS NEVER EATEN IN MY HOUSE.
# Match:     ❌
# Char Accuracy: 13/32 (40.6%)
#
# --- Case 376780 ---
# Input:     XCRKRVZ
# Decrypted: THREATS
# Expected:  GAZETTE
# Match:     ❌
# Char Accuracy: 2/7 (28.6%)
#
# --- Case 332493 ---
# Input:     D XCDAJL AK VVY.
# Decrypted: I BUSSED TO KEO.
# Expected:  I FORGOT MY BAG.
# Match:     ❌
# Char Accuracy: 5/16 (31.2%)
#
# --- Case 60963 ---
# Input:     NSU CZRGS EEVJ WWLZKQN WWY XEFOH LUD WBKDI.
# Decrypted: THE TRAIN LEAD DORMINE HIS PLACE OF CHADE.
# Expected:  THE STORY TOLD THROUGH THE MOVIE WAS GREAT.
# Match:     ❌
# Char Accuracy: 12/43 (27.9%)
#
# --- Case 380257 ---
# Input:     VAH QGDQL FGFOKK IBTR VTVZ UN HHA.
# Decrypted: TOM SAID EVERYON FELT THAT BE HIM.
# Expected:  TOM KNOWS BETTER THAN THAT BY NOW.
# Match:     ❌
# Char Accuracy: 15/34 (44.1%)
#
# --- Case 227046 ---
# Input:     VSLZADPVB
# Decrypted: EXCESSIVE
# Expected:  POSITIONS
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 280485 ---
# Input:     VNILZQ WQYU TIS DYM HCUN.
# Decrypted: PLEASE LEFT THE DOB OVEN.
# Expected:  THOMAS DOES NOT EAT FISH.
# Match:     ❌
# Char Accuracy: 5/25 (20.0%)
#
# --- Case 111281 ---
# Input:     ORAAHIMVIJ
# Decrypted: RESISTANCE
# Expected:  VEGETATION
# Match:     ❌
# Char Accuracy: 1/10 (10.0%)
#
# --- Case 245861 ---
# Input:     U MCIIU ZE YTVE JIOUZWD.
# Decrypted: I BAKED TO LEAR SOMETH.
# Expected:  I TRIED TO MAKE FRIENDS.
# Match:     ❌
# Char Accuracy: 10/24 (41.7%)
#
# --- Case 329179 ---
# Input:     YIFTFK
# Decrypted: ELIGHT
# Expected:  FATHER
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 157201 ---
# Input:     FTW KNWB QZ YQY EG BXUBEZUSQ HX NIQ.
# Decrypted: TOM TOLD ME HE WE THOUGHT NOT A WAS.
# Expected:  TOM WENT TO GET US SOMETHING TO EAT.
# Match:     ❌
# Char Accuracy: 12/36 (33.3%)
#
# --- Case 8650 ---
# Input:     ILWFFNQSKOB
# Decrypted: CONJUNCTION
# Expected:  CONTROLLERS
# Match:     ❌
# Char Accuracy: 3/11 (27.3%)
#
# --- Case 82458 ---
# Input:     XOC UQYF GM PEQTQAA YPMS QDBRLSWSN.
# Decrypted: TOM CAME TO BOSTONE LIED TOGETHERS.
# Expected:  TOM WILL BE LEAVING THIS AFTERNOON.
# Match:     ❌
# Char Accuracy: 11/35 (31.4%)
#
# --- Case 250415 ---
# Input:     A DAWP X YKOE QOAANE HEGOE OLQARE MLKYQAHP FK IAMLVSHAN.
# Decrypted: I HAVE A SPIT THINKI ABOUT THROOM TOUGHING MY BATHMORY.
# Expected:  I HAVE A GOOD FRIEND WHOSE NATIVE LANGUAGE IS MALAYALAM.
# Match:     ❌
# Char Accuracy: 19/56 (33.9%)
#
# --- Case 202543 ---
# Input:     HVU
# Decrypted: SEX
# Expected:  SAO
# Match:     ❌
# Char Accuracy: 1/3 (33.3%)
#
# --- Case 285997 ---
# Input:     NWKNIQTVD
# Decrypted: THICKNESS
# Expected:  PRACTICAL
# Match:     ❌
# Char Accuracy: 1/9 (11.1%)
#
# --- Case 360057 ---
# Input:     VAH CTCNL QG FJ CTXN YST YVXR.
# Decrypted: TOM PLANS TO DO THAT AST WELL.
# Expected:  TOM WANTS ME TO WAIT FOR MARY.
# Match:     ❌
# Char Accuracy: 13/30 (43.3%)
#
# --- Case 351552 ---
# Input:     FWS KWE EGWPUVM OP FPK PQE AZCL.
# Decrypted: TOM HAD BOUGHED AT HIS PAY FINE.
# Expected:  TOM WAS WAITING AT THE BUS STOP.
# Match:     ❌
# Char Accuracy: 13/32 (40.6%)
#
# --- Case 13886 ---
# Input:     CLA
# Decrypted: WED
# Expected:  AUD
# Match:     ❌
# Char Accuracy: 1/3 (33.3%)
#
# --- Case 368982 ---
# Input:     FUAHS
# Decrypted: LADEN
# Expected:  CATCH
# Match:     ❌
# Char Accuracy: 1/5 (20.0%)
#
# --- Case 339373 ---
# Input:     SZXL PEMTLU RHQR WXC JSNGXY YSEIB.
# Decrypted: THIS TIFFER LAST FOR WATCH TOGENT.
# Expected:  MARY LOOKED LIKE SHE ALWAYS LOOKS.
# Match:     ❌
# Char Accuracy: 7/34 (20.6%)
#
# --- Case 21502 ---
# Input:     MCZ YSUNFH IMZNGJCSUW NJHI EYUYVDIZ.
# Decrypted: THE WHOLES GOVERNMENT HERE STREEKED.
# Expected:  THE DOCTOR PRESCRIBED SOME MEDICINE.
# Match:     ❌
# Char Accuracy: 9/36 (25.0%)
#
# --- Case 250424 ---
# Input:     I DHWH A CVPG FNPFQD SOPVE JHULVA SBQGQHHH IO TBOAUHMDM.
# Decrypted: I HAVE A SPIT THINKS THIS I BETTER MODIED TO PERFORMANT.
# Expected:  I HAVE A GOOD FRIEND WHOSE NATIVE LANGUAGE IS MALAYALAM.
# Match:     ❌
# Char Accuracy: 16/56 (28.6%)
#
# --- Case 52355 ---
# Input:     INA ONHS PG HKDF VAXQHA.
# Decrypted: TOM SAID HE COOS LAURDS.
# Expected:  TOM MUST BE OVER THIRTY.
# Match:     ❌
# Char Accuracy: 10/24 (41.7%)
#
# --- Case 36782 ---
# Input:     PWKTYNOX
# Decrypted: SURROUND
# Expected:  MCDONALD
# Match:     ❌
# Char Accuracy: 1/8 (12.5%)
#
# --- Case 281524 ---
# Input:     TKT BVKAK NH IB OF FOQSE JO DVNH EWYMB TKKBB.
# Decrypted: TOM ASKED ME IF I WANTED TO SEET LEAVE TODAY.
# Expected:  TOM ASKED ME IF HE COULD GO HOME EARLY TODAY.
# Match:     ❌
# Char Accuracy: 28/45 (62.2%)
#
# --- Case 75971 ---
# Input:     Z ODNDB ZEYXVM KK JYZOJ SFPHI FFNONRCT XJ Q MVHNT KMWSICVPNEE DJYE AVLFDVNA.
# Decrypted: I THINK PEOPLE SO FINISH THES RESTAURANT TO LEAVE FREECTION OUT THER OF THEM.
# Expected:  I THINK EITHER OF THESE COULD POSSIBLY BE A VALID TRANSLATION INTO JAPANESE.
# Match:     ❌
# Char Accuracy: 17/77 (22.1%)
#
# --- Case 312848 ---
# Input:     LXZDYK SSARAOP ABXW MANJ MSSL IGEINNTES.
# Decrypted: MENNAD STARTED WITH THEI WAS ABROUNDTON.
# Expected:  PEOPLE ACHIEVE MORE WHEN THEY COOPERATE.
# Match:     ❌
# Char Accuracy: 9/40 (22.5%)
#
# --- Case 509 ---
# Input:     MV LJW KXI DDBW NXS EPUPVT XJXB QFHRKCP.
# Decrypted: WE ARE NEW DOUT OFF GEOING SOME KILDNER.
# Expected:  IT WAS THE BOSS WHO CALLED THIS MORNING.
# Match:     ❌
# Char Accuracy: 9/40 (22.5%)
#
# --- Case 126213 ---
# Input:     AQO ZIR.
# Decrypted: GET TOM.
# Expected:  NOT BAD.
# Match:     ❌
# Char Accuracy: 3/8 (37.5%)
#
# --- Case 390875 ---
# Input:     HHA BMYBX BTSG VD CUXLI FVTH Z HERHYMWG ZHJD EUI WWEZDY XFM IAU.
# Decrypted: TOM ASKED MARY TO PULLS OVER A STRAWAIN FTER AND KING AT HOME.
# Expected:  TOM CRIED WHEN HE HEARD THAT A MOUNTAIN LION HAD KILLED HIS DOG.
# Match:     ❌
# Char Accuracy: 22/64 (34.4%)
#
# --- Case 275977 ---
# Input:     BUFWBKYI
# Decrypted: ENTRANCE
# Expected:  ENROLLED
# Match:     ❌
# Char Accuracy: 2/8 (25.0%)
#
# --- Case 132681 ---
# Input:     WHXA
# Decrypted: BITE
# Expected:  DUDE
# Match:     ❌
# Char Accuracy: 1/4 (25.0%)
#
# --- Case 303101 ---
# Input:     US DVJC KXDW KTE CWUG ELNQ YY DJH PXWX FMO DARKB.
# Decrypted: IT FELL THAT TOM AND MARY ARE NEW WAST FOR DINNE.
# Expected:  IN THAT CASE YOU ONLY HAVE TO PAY HALF THE PRICE.
# Match:     ❌
# Char Accuracy: 14/49 (28.6%)
#
# --- Case 78501 ---
# Input:     US KZU XN QSW SFBRNWA FY EK HSHH RB FD AXQOUJU BL EJMRZZN CPB QDABOF KNLP.
# Decrypted: IT WAS FOR IN APPROVE TO DO THAT IS A SELUCTED TO SETTING THE DOOR THAT.
# Expected:  IN ALL OF THE GARDENS IN MY CITY IT IS ILLEGAL TO TRAMPLE THE FLOWER BEDS.
# Match:     ❌
# Char Accuracy: 21/74 (28.4%)
#
# --- Case 31631 ---
# Input:     KDVKD
# Decrypted: START
# Expected:  MEANS
# Match:     ❌
# Char Accuracy: 1/5 (20.0%)
#
# --- Case 191900 ---
# Input:     FPUZI
# Decrypted: SEATS
# Expected:  BELOW
# Match:     ❌
# Char Accuracy: 1/5 (20.0%)
#
# --- Case 201446 ---
# Input:     NI PRZ VDBRTK NEKZS LDXILJ.
# Decrypted: HE ATE BREADY WORKS THINGS.
# Expected:  HE WAS ACTING UNDER DURESS.
# Match:     ❌
# Char Accuracy: 8/27 (29.6%)
#
# --- Case 228287 ---
# Input:     K UII QKD UPC EXL GDIQPIJBG SNG PWEJ.
# Decrypted: I TOO LD MAY YOU ALTERREADY DID THAT.
# Expected:  I WAS THE ONE WHO DECORATED THE ROOM.
# Match:     ❌
# Char Accuracy: 7/37 (18.9%)
#
# --- Case 337982 ---
# Input:     OIYJYMR QHX EEBCUL EB SUF RPYLMZF.
# Decrypted: WILLIAM AND SANDRA BY THE ALGIERS.
# Expected:  LORENZO WAS TRYING TO PAY MELISSA.
# Match:     ❌
# Char Accuracy: 7/34 (20.6%)
#
# --- Case 22644 ---
# Input:     LQ QKIN ZE EXJXF CA TD FQKG.
# Decrypted: HE TOLD HE HOUSE OF HE WOUL.
# Expected:  WE HAVE NO PLANS TO DO THAT.
# Match:     ❌
# Char Accuracy: 8/28 (28.6%)
#
# --- Case 87731 ---
# Input:     RNH QZNA LC GZ ZLNIDB XJR.
# Decrypted: TOM WENT TO TO SILERS ARM.
# Expected:  TOM TOLD ME HE CALLED YOU.
# Match:     ❌
# Char Accuracy: 10/26 (38.5%)
#
# --- Case 117346 ---
# Input:     ZLX GVIE PJY JKFGZO WEKV.
# Decrypted: THE KEEP ALL THEIRS DAYS.
# Expected:  THE POND HAS FROZEN OVER.
# Match:     ❌
# Char Accuracy: 8/25 (32.0%)
#
# --- Case 62213 ---
# Input:     ZA KMKYRTF CMC NIYL.
# Decrypted: HE CLIMBED THE FEET.
# Expected:  MY POCKETS ARE FULL.
# Match:     ❌
# Char Accuracy: 6/20 (30.0%)
#
# --- Case 319907 ---
# Input:     ZMYG WUFY CT YBMIH HBCXYCMS.
# Decrypted: THEY WANT TO TALK ATTRACTION.
# Expected:  THEY WERE IN THEIR THIRTIES.
# Match:     ❌
# Char Accuracy: 10/29 (34.5%)
#
# --- Case 133292 ---
# Input:     XCR MEFDXPEO JBOOZQ EC UR DDES GP FLZPU UJP SPG.
# Decrypted: THE PRINCESS CORNED TO US WITH AT TRADE TO DAY.
# Expected:  THE CREATURE WALKED UP TO ZIRI TO CHECK HIM OUT.
# Match:     ❌
# Char Accuracy: 15/48 (31.2%)
#
# --- Case 221687 ---
# Input:     NMOQK
# Decrypted: PACKS
# Expected:  LOGAN
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 103712 ---
# Input:     NUM LGJAY NNE VQAYI NU MD.
# Decrypted: TOM COULD GET TRIED TO DO.
# Expected:  TOM MEANT THE WORLD TO ME.
# Match:     ❌
# Char Accuracy: 12/26 (46.2%)
#
# --- Case 152851 ---
# Input:     XNJE
# Decrypted: BETH
# Expected:  CHEM
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 187180 ---
# Input:     ZPLKLV
# Decrypted: SENSOR
# Expected:  INTENT
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 58735 ---
# Input:     CAE LLCZXC RL NXH ST DSRGS.
# Decrypted: THE DEEPED OF THE A SYMBER.
# Expected:  THE CASTLE IS NOW IN RUINS.
# Match:     ❌
# Char Accuracy: 8/27 (29.6%)
#
# --- Case 200330 ---
# Input:     PJ SMWP UJ SFLF PJ VYD RZNFFEQVJC.
# Decrypted: WE NEED TO FIND BE OFF EVERYTHING.
# Expected:  HE TOLD ME THAT HE WAS FRIGHTENED.
# Match:     ❌
# Char Accuracy: 11/34 (32.4%)
#
# --- Case 57663 ---
# Input:     NZC MGPT SPIDKUSUJ JY YHT SZK.
# Decrypted: TOM WILL PRETILLED TO THE NOW.
# Expected:  TOM CAME YESTERDAY TO SEE YOU.
# Match:     ❌
# Char Accuracy: 14/30 (46.7%)
#
# --- Case 22582 ---
# Input:     BIB HLA XML F EROYZHZCH NV QZBN UA YSR VNHWD.
# Decrypted: YOU MUST BE I WORRIEVED TO LEAR TO DO THATER.
# Expected:  YOU CAN USE A TELESCOPE TO LOOK AT THE STARS.
# Match:     ❌
# Char Accuracy: 15/45 (33.3%)
#
# --- Case 167696 ---
# Input:     VBHRPFQ WKIGT DNLZUF ODJHUVLD VCTHPHFF GK JBA TPJVEC.
# Decrypted: MIROSLAV WERE OTHERS FISHING HIS SOULD BE THE EXPECT.
# Expected:  ALGERIA COULD CANCEL SPORTING FIXTURES IN THE FUTURE.
# Match:     ❌
# Char Accuracy: 10/53 (18.9%)
#
# --- Case 41734 ---
# Input:     OW LNV JDTBG.
# Decrypted: HE WAS CRAZY.
# Expected:  IT WAS ROUGH.
# Match:     ❌
# Char Accuracy: 6/13 (46.2%)
#
# --- Case 71257 ---
# Input:     UTZ RBZYL XGM HUKT NAEP OJLYTY.
# Decrypted: SHE SENTS HER ALST THEM STAYED.
# Expected:  SHE LIKES TEA MORE THAN COFFEE.
# Match:     ❌
# Char Accuracy: 14/31 (45.2%)
#
# --- Case 18993 ---
# Input:     NZS TUOWG SYOLWZA PH SMLGQ WZ NCW AALIABS.
# Decrypted: SHE BAKED DOLAWED AT HAPPY BY MED QUESTER.
# Expected:  SHE HATES GETTING UP EARLY IN THE MORNING.
# Match:     ❌
# Char Accuracy: 15/42 (35.7%)
#
# --- Case 247679 ---
# Input:     RWG ZFXL FA EBAMBQXID NFYWDQ UAMK RJGL KAV.
# Decrypted: YOU HAVE TO ANSWREING AROTED THAN MARY WE.
# Expected:  YOU NEED TO DISAPPEAR BEFORE THEY FIND YOU.
# Match:     ❌
# Char Accuracy: 15/43 (34.9%)
#
# --- Case 41144 ---
# Input:     WUB PVWSUGE KBHBTUS MPKVWEJ WQA VRP.
# Decrypted: OUR INSIDES THINKIN ADVOIDE HIS WAR.
# Expected:  HIS FINGERS BRUSHED AGAINST HER LEG.
# Match:     ❌
# Char Accuracy: 9/36 (25.0%)
#
# --- Case 325100 ---
# Input:     GPWEGKP
# Decrypted: CURIOUS
# Expected:  CENTURY
# Match:     ❌
# Char Accuracy: 1/7 (14.3%)
#
# --- Case 93937 ---
# Input:     MAY ADLZDGCXXK TZY RLYREMNID.
# Decrypted: TOM PRETENDEDS THE BULLESQUE.
# Expected:  TOM DEFINITELY WAS AVAILABLE.
# Match:     ❌
# Char Accuracy: 9/29 (31.0%)
#
# --- Case 350077 ---
# Input:     YBYSQJY
# Decrypted: RETURNS
# Expected:  BUKKAKE
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 185304 ---
# Input:     E JJHN GKC VJN ZWHT PRNP JCAI FDEPHN OQO ODO PDUVLOE KDZ.
# Decrypted: I TOLD TOM AND MARY WETH THEY WERE TO GO THE BOLD OF WILL.
# Expected:  I TOLD TOM AND MARY THAT THEY SHOULD BUY THE CHEAPER ONE.
# Match:     ❌
# Char Accuracy: 32/58 (55.2%)
#
# --- Case 374965 ---
# Input:     UNZVXRMBFHH
# Decrypted: CONJUNCTION
# Expected:  CONSTRUCTED
# Match:     ❌
# Char Accuracy: 3/11 (27.3%)
#
# --- Case 339229 ---
# Input:     WLR GMSKQ GY MZ DRXNVMOFF HIJW JTHHMB.
# Decrypted: TOM WANTS TO DO EVERYTHING BAD WEEKEN.
# Expected:  TOM MIGHT BE IN AUSTRALIA NEXT MONDAY.
# Match:     ❌
# Char Accuracy: 10/38 (26.3%)
#
# --- Case 306623 ---
# Input:     HNF MQMVGH VTB MCDS FUEBQIQNG HHBXR PCGQCAXL KIVA AGQM.
# Decrypted: TOM WALKED INT THAT DESTIMIST APPEA THINGST ABOUT WITH.
# Expected:  OUR MOTHER CAN MAKE DELICIOUS FRIED PANCAKES WITH MEAT.
# Match:     ❌
# Char Accuracy: 12/55 (21.8%)
#
# --- Case 25579 ---
# Input:     TAEADBIFQ
# Decrypted: THICKNESS
# Expected:  ASSOCIATE
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 175731 ---
# Input:     UD IBPF QN ZTT QZO PNKDOETPD.
# Decrypted: WE HAVE TO GET OUR SOMEBODY.
# Expected:  WE NEED TO BUY TOM SOMETHING.
# Match:     ❌
# Char Accuracy: 13/29 (44.8%)
#
# --- Case 215416 ---
# Input:     ABAQ OTA PPDAHCTZG LHW EFCFD BP RZAOM ICUW.
# Decrypted: SAMI GOT PROBABLED HER THANK AN LAYLA WELL.
# Expected:  SAMI WAS OBVIOUSLY TOO DRUNK TO DRIVE HOME.
# Match:     ❌
# Char Accuracy: 14/43 (32.6%)
#
# --- Case 397120 ---
# Input:     QKJZKLM
# Decrypted: ARRIVES
# Expected:  WEBPAGE
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 177281 ---
# Input:     YRFEL NXYN OCUXGBEBO UEOOV PBF FAU.
# Decrypted: YANNI SAID CONTINUED ELONG THE WAS.
# Expected:  FELIX FELT SOMETHING BRUSH HIS LEG.
# Match:     ❌
# Char Accuracy: 7/35 (20.0%)
#
# --- Case 233528 ---
# Input:     IUEHWIKDC
# Decrypted: RENDERING
# Expected:  SIGNATURE
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 152048 ---
# Input:     E YZFTUL JH FATC AL NSJ TWZ FJ TNIW WHC XTOZL YMDUDNGPR.
# Decrypted: I WONDER IF WHAT TO SAY OUT OF THES WAS BEDTDY THROUSD.
# Expected:  I FORGOT TO WEAR MY HAT AND MY FACE GOT BADLY SUNBURNED.
# Match:     ❌
# Char Accuracy: 17/56 (30.4%)
#
# --- Case 256526 ---
# Input:     IOLNA YBIEA YIGF EFH QHB JAFQMB QGM.
# Decrypted: PENER HOUSE BOYS WAS THE LOOKED BEE.
# Expected:  BORIS ASKED RIMA WHY SHE CALLED HIM.
# Match:     ❌
# Char Accuracy: 12/36 (33.3%)
#
# --- Case 197039 ---
# Input:     QYGWSSN NUTZBDN RSO AE DKJ CP BKUIC.
# Decrypted: SOMEONE STRPPED THE BO AND RE START.
# Expected:  RODRIGO DROPPED ONE OF THE SD CARDS.
# Match:     ❌
# Char Accuracy: 13/36 (36.1%)
#
# --- Case 303173 ---
# Input:     OM ZUEJ AJZV ENA BRBW QHMK SU CEO FJSW ZGK CVYAN.
# Decrypted: IT FELL THAT TOM ANDO MARY TO SEE WITH FOR THEM.
# Expected:  IN THAT CASE YOU ONLY HAVE TO PAY HALF THE PRICE.
# Match:     ❌
# Char Accuracy: 16/49 (32.7%)
#
# --- Case 81219 ---
# Input:     LHP AAHX ISKB PAR VAWG WZYHHC LH EM CNILWKDBIUY.
# Decrypted: TOM SAID THAT HIS FEET THIRTY TO BE DESPERATED.
# Expected:  TOM SAID MARY HAS BEEN TRYING TO BE COOPERATIVE.
# Match:     ❌
# Char Accuracy: 29/48 (60.4%)
#
# --- Case 304711 ---
# Input:     SFG ESLUR LCLGNG HXB FOEJ GP JPA.
# Decrypted: THE RESTE GRAGES THE BAGE OF TOM.
# Expected:  THE WHOLE FAMILY WAS SICK IN BED.
# Match:     ❌
# Char Accuracy: 11/33 (33.3%)
#
# --- Case 356324 ---
# Input:     MWUBJEILOW
# Decrypted: PRESENTING
# Expected:  MANAGEMENT
# Match:     ❌
# Char Accuracy: 1/10 (10.0%)
#
# --- Case 227716 ---
# Input:     AIS BGEL NS BZX XSCRWVB IOL TXMO O NSBTVFM.
# Decrypted: SHE WENT TO BED AFTERED THE ENDS A MARRIED.
# Expected:  SHE TOLD ME THE PROJECT HAD BEEN A FAILURE.
# Match:     ❌
# Char Accuracy: 14/43 (32.6%)
#
# --- Case 171149 ---
# Input:     MTS ETZXL YNX XSNGI UY MML HBT OTMVX.
# Decrypted: TOM COULD GET HAPPY TO SEE WHA NORDAY.
# Expected:  TOM LOVES THE SOUND OF HIS OWN VOICE.
# Match:     ❌
# Char Accuracy: 12/38 (31.6%)
#
# --- Case 302557 ---
# Input:     YQ RKKT LXEN TPXM.
# Decrypted: WE USED THAT BACK.
# Expected:  WE WERE REAL HURT.
# Match:     ❌
# Char Accuracy: 7/18 (38.9%)
#
# --- Case 98799 ---
# Input:     WSUI
# Decrypted: PASO
# Expected:  LIKE
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 198423 ---
# Input:     YXZIZ AOF Q UXSR KG VKI ATBD.
# Decrypted: GOING FOR A WALK IS THE MOVE.
# Expected:  FELIX HAD A BEER IN HIS HAND.
# Match:     ❌
# Char Accuracy: 9/29 (31.0%)
#
# --- Case 111850 ---
# Input:     YLVQCMJ IXLTQ WMYV SV QAIRJ SGPC ZWFMA GKM EHNQL SV BTCSLBT.
# Decrypted: ENGISTS THING TOOK IS MORET THAN NEEDS TO BEAVE FEW FASTER.
# Expected:  SOMEONE BROKE INTO MY HOUSE LAST NIGHT AND STOLE MY SHOTGUN.
# Match:     ❌
# Char Accuracy: 11/60 (18.3%)
#
# --- Case 387421 ---
# Input:     MPV WGOFMU TCUMMCR GQ IKKAZHL.
# Decrypted: SHE SEEMED UNDERED ME HELBBACK.
# Expected:  SHE KILLED HERSELF IN OCTOBER.
# Match:     ❌
# Char Accuracy: 10/31 (32.3%)
#
# --- Case 195236 ---
# Input:     UMYV HA C EUPJ QPPUIHLWMX.
# Decrypted: SAMI HAD ALREA WORKINGERS.
# Expected:  SAMI IS A SICK INDIVIDUAL.
# Match:     ❌
# Char Accuracy: 7/26 (26.9%)
#
# --- Case 16973 ---
# Input:     SX CVJU AXTGRZOAW Q JXA.
# Decrypted: IT WILL UNLIKELYED TOME.
# Expected:  MY WIFE COMPLAINS A LOT.
# Match:     ❌
# Char Accuracy: 5/24 (20.8%)
#
# --- Case 358851 ---
# Input:     CK XWXZXU OU JFCBR YDSXWES TK ONJ HTEMP GGXL GVZYO.
# Decrypted: MY BROTHE IS INTER SHOULD TOM AND MARYED WERE CYEL.
# Expected:  HE SEEMED TO ENJOY HIMSELF AT THE PARTY LAST NIGHT.
# Match:     ❌
# Char Accuracy: 10/51 (19.6%)
#
# --- Case 88079 ---
# Input:     B EME UHTP KPN EAGMW JQ MMHVQ.
# Decrypted: I WAS KNOW TOM LOSES TO STRYM.
# Expected:  I WAS TOLD YOU WOULD BE ALONE.
# Match:     ❌
# Char Accuracy: 13/30 (43.3%)
#
# --- Case 106643 ---
# Input:     X CGZS VF FTCTIMXV BF YIQI ONMG AKBNP.
# Decrypted: I WANT TO COMPUTER TO KNOW THAT YOUSH.
# Expected:  I HAVE NO STRENGTH TO LIFT THIS STONE.
# Match:     ❌
# Char Accuracy: 15/38 (39.5%)
#
# --- Case 107059 ---
# Input:     X TXWC MC WBXA FAOI QLV QTG IL PJH.
# Decrypted: I WANT TO KNOW WHAT YOU TOM DO THAT.
# Expected:  I WANT TO HEAR WHAT TOM HAS TO SAY.
# Match:     ❌
# Char Accuracy: 21/36 (58.3%)
#
# --- Case 111160 ---
# Input:     PP IJZ QL T MEJZ.
# Decrypted: WE RAN TO DO THAT.
# Expected:  WE SAT IN A BOAT.
# Match:     ❌
# Char Accuracy: 6/18 (33.3%)
#
# --- Case 190062 ---
# Input:     VEXIGMBW
# Decrypted: SHIPPING
# Expected:  DETAILED
# Match:     ❌
# Char Accuracy: 0/8 (0.0%)
#
# --- Case 74882 ---
# Input:     WBLD DNLX AMPVU VHHVF ZYYJ DBUY.
# Decrypted: THIS MILK COMES FROM THEIR FARM.
# Expected:  THEY SAID THEIR BACKS WERE SORE.
# Match:     ❌
# Char Accuracy: 9/32 (28.1%)
#
# --- Case 297972 ---
# Input:     PXK BEID PQYC LE EJSMHID TDN QQSW.
# Decrypted: TOM SAID THAT HE WANTEDED TO PLAY.
# Expected:  TOM SAID THAT HE ENJOYED THE SHOW.
# Match:     ❌
# Char Accuracy: 19/34 (55.9%)
#
# --- Case 316083 ---
# Input:     G TPNFGB YJ OEVFQC YQUF GA.
# Decrypted: I FIGURE IT WOULD LIKE TO.
# Expected:  I HELPED MY MOTHER WASH UP.
# Match:     ❌
# Char Accuracy: 5/27 (18.5%)
#
# --- Case 18580 ---
# Input:     KJWGRTZ
# Decrypted: THOUGHT
# Expected:  THEATRE
# Match:     ❌
# Char Accuracy: 2/7 (28.6%)
#
# --- Case 152794 ---
# Input:     PXUV LDZG BYBJNPRAB PZT KDP VXXT.
# Decrypted: THEY WERE UNBREATED THE TRAPSTIC.
# Expected:  MARY TOLD EVERYBODY SHE WAS SAFE.
# Match:     ❌
# Char Accuracy: 10/33 (30.3%)
#
# --- Case 65272 ---
# Input:     FNDO
# Decrypted: MISC
# Expected:  JEFF
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 307941 ---
# Input:     BGE FCKJ BZSG JG YWDV UKU NWMKR NCYB OWRM.
# Decrypted: TOM SAID THAT HE HOPE TOM THREE FELT LAST.
# Expected:  TOM SAID THAT HE SOLD HIS HOUSE LAST WEEK.
# Match:     ❌
# Char Accuracy: 25/42 (59.5%)
#
# --- Case 317151 ---
# Input:     NNJETYX
# Decrypted: SHERIFF
# Expected:  SHEMALE
# Match:     ❌
# Char Accuracy: 3/7 (42.9%)
#
# --- Case 325350 ---
# Input:     ZLV TOR F AKOAUPKJ JUIM MBC HYUXTE ZHPL G OJHSM.
# Decrypted: TOM HAS A MARRIELY NEED TOM LAUGED NEWT TO PAIN.
# Expected:  TOM HAS A TERRIBLE COLD AND CROAKS LIKE A RAVEN.
# Match:     ❌
# Char Accuracy: 22/48 (45.8%)
#
# --- Case 10292 ---
# Input:     XJZ QBU YIML GRBN.
# Decrypted: TOM WAS VERY COLD.
# Expected:  TOM GOT VERY WEAK.
# Match:     ❌
# Char Accuracy: 11/18 (61.1%)
#
# --- Case 279815 ---
# Input:     S HOU ZC HAOQWB SNE TEXJPIOR QG JOUTZW ET.
# Decrypted: I HAD TO CROSER THE NEIGHORE OF MAN IN ME.
# Expected:  A LOT OF PEOPLE ARE STARTING TO NOTICE IT.
# Match:     ❌
# Char Accuracy: 11/42 (26.2%)
#
# --- Case 182407 ---
# Input:     ZTG QS Q HLUVJTM AHHCMZ.
# Decrypted: TOM IS A SINCERE PERSON.
# Expected:  TOM IS A TRAPEZE ARTIST.
# Match:     ❌
# Char Accuracy: 13/24 (54.2%)
#
# --- Case 199824 ---
# Input:     I SPMO OJSZ OIRL GRR IF DKIHK JQ TDL GXTQYF.
# Decrypted: I KNOW THAT TOM HAD TO DESPED DO THE RADIO.
# Expected:  I WILL ONLY LIVE FOR MY CHILD IN THE FUTURE.
# Match:     ❌
# Char Accuracy: 11/44 (25.0%)
#
# --- Case 172866 ---
# Input:     XAZFYMFF
# Decrypted: EVIDENCE
# Expected:  ORIGINAL
# Match:     ❌
# Char Accuracy: 2/8 (25.0%)
#
# --- Case 273348 ---
# Input:     PATBTY IKBLGEJ QUGFWXM.
# Decrypted: MENNAD ORDERED SHOPING.
# Expected:  THINGS QUICKLY CHANGED.
# Match:     ❌
# Char Accuracy: 5/23 (21.7%)
#
# --- Case 340123 ---
# Input:     MHA HQISU CTKM KPHKU MATH TQ LOA.
# Decrypted: TOM ASKED MARY WAITS THEY TO SEE.
# Expected:  TOM HOPES MARY KNOWS WHAT TO SAY.
# Match:     ❌
# Char Accuracy: 20/33 (60.6%)
#
# --- Case 203985 ---
# Input:     VUG GZQ KGATKNR.
# Decrypted: TOM HAS RETIRED.
# Expected:  TOM HAS REGRETS.
# Match:     ❌
# Char Accuracy: 11/16 (68.8%)
#
# --- Case 66166 ---
# Input:     KXLKTDW
# Decrypted: THOUGHT
# Expected:  BOULDER
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 85786 ---
# Input:     VYB PKIYGEQ WKH JTVXTOS VQI X FBPSVLOEN BQPUFBVT.
# Decrypted: THE ALPHABS ARE LANDRED THE A SYMITTATE MOSQUENT.
# Expected:  THE PATIENT WAS TREATED FOR A FRACTURED MANDIBLE.
# Match:     ❌
# Char Accuracy: 16/49 (32.7%)
#
# --- Case 74063 ---
# Input:     QP UHVHRN L BYZ IGIX JYS.
# Decrypted: WE EXPECT A LOT FROM HIM.
# Expected:  WE EXPECT A LOT FROM TOM.
# Match:     ❌
# Char Accuracy: 23/25 (92.0%)
#
# --- Case 255333 ---
# Input:     MXFF MKI FYSIT TQOJ BYPFGD EBC CL NEX ZDLBX.
# Decrypted: SAMI AND LAYLA WERE CHILLY AND TO THE LIFE.
# Expected:  SAMI AND LAYLA WERE HAVING SEX IN THE CROWD.
# Match:     ❌
# Char Accuracy: 27/44 (61.4%)
#
# --- Case 90144 ---
# Input:     BMAI UJE DTHNB IXFUS UW RRA XYUQ.
# Decrypted: ZIRI WAS ALWAY GETER TO EAT FAIL.
# Expected:  MARY HAS NEVER VOTED IN HER LIFE.
# Match:     ❌
# Char Accuracy: 12/33 (36.4%)
#
# --- Case 181122 ---
# Input:     PUE YIO KRVVZ AXGEE QJ JL HFCOB.
# Decrypted: SHE HAD BURNS ALIED TO DO THAT.
# Expected:  SHE HAS NEVER EATEN IN MY HOUSE.
# Match:     ❌
# Char Accuracy: 12/32 (37.5%)
#
# --- Case 128830 ---
# Input:     BTL GD IINSGYS QS SFP ABMDP CAWR.
# Decrypted: TOM IS SITTING IN THE BATLE SING.
# Expected:  TOM IS WAITING IN THE OTHER ROOM.
# Match:     ❌
# Char Accuracy: 21/33 (63.6%)
#
# --- Case 95952 ---
# Input:     LQXW CMDK VEE QBM AZWAUD XQMVP.
# Decrypted: ZIRI TOOK THE WAS STAILL STEAL.
# Expected:  ZIRI GAVE HIS IVY ENOUGH LIGHT.
# Match:     ❌
# Char Accuracy: 10/31 (32.3%)
#
# --- Case 145281 ---
# Input:     ABFISA
# Decrypted: SENSOR
# Expected:  HOLMES
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 364242 ---
# Input:     PKVR ZMMON FNV CNHBCMEGFJ CLX KCWGOH.
# Decrypted: THEY WANTS TOM EVERYTHING TWAS EVERY.
# Expected:  MARY COULD BUY EVERYTHING SHE NEEDED.
# Match:     ❌
# Char Accuracy: 17/37 (45.9%)
#
# --- Case 317985 ---
# Input:     UNCMD
# Decrypted: BADGE
# Expected:  SHINE
# Match:     ❌
# Char Accuracy: 1/5 (20.0%)
#
# --- Case 200347 ---
# Input:     TI MQFI YI MJUY TI PCM KDMZJNJZIW.
# Decrypted: WE NEED TO FIND BE OFF EVERYTHING.
# Expected:  HE TOLD ME THAT HE WAS FRIGHTENED.
# Match:     ❌
# Char Accuracy: 11/34 (32.4%)
#
# --- Case 371564 ---
# Input:     EPHYEZR
# Decrypted: SAMSUNG
# Expected:  UKRAINE
# Match:     ❌
# Char Accuracy: 1/7 (14.3%)
#
# --- Case 206091 ---
# Input:     VFVF ENS OMJM VJ CVLZG KC LFY.
# Decrypted: SAMI WAS SURE HE WOULD GO HER.
# Expected:  ZIRI SAW RIMA IN FRONT OF HIM.
# Match:     ❌
# Char Accuracy: 10/30 (33.3%)
#
# --- Case 194034 ---
# Input:     NH HHSWGUDRKG HGXVTMOR JXGVQY GDXDYV.
# Decrypted: HE PERSONALLY PREPARED REALLY SUCCES.
# Expected:  HE SUPERVISED STUDENTS DURING RECESS.
# Match:     ❌
# Char Accuracy: 9/37 (24.3%)
#
# --- Case 337388 ---
# Input:     KP HBPC UWOB.
# Decrypted: WE PAID CASH.
# Expected:  WE NEED GLUE.
# Match:     ❌
# Char Accuracy: 6/13 (46.2%)
#
# --- Case 201238 ---
# Input:     IFS CIW NYNDOVK CUP AGZKVHGHG.
# Decrypted: SHE HAS NOTHING THE CENTRAILS.
# Expected:  SHE WAS SIPPING HER MARGARITA.
# Match:     ❌
# Char Accuracy: 14/30 (46.7%)
#
# --- Case 297768 ---
# Input:     XL KZN DVA IOJBYE RETL KSBS TZNDPNYD.
# Decrypted: WE SAW THE SPOLES HERE KNOW TIMENTS.
# Expected:  HE DID NOT RETURN HOME TILL MIDNIGHT.
# Match:     ❌
# Char Accuracy: 10/37 (27.0%)
#
# --- Case 50182 ---
# Input:     VBL KPYW NOJ DGUYULEU RZ AMPVU ZYNPAGMONA.
# Decrypted: SHE WERE AT ANYTHING HER ANTES SHORPERISM.
# Expected:  SHE FELT THE STRENGTH OF THEIR FRIENDSHIP.
# Match:     ❌
# Char Accuracy: 9/42 (21.4%)
#
# --- Case 46939 ---
# Input:     H GDX RGLSONKFDN LS PDNXW TP QUOUDYZD LB YYY.
# Decrypted: I WAS TRANSFERRED A GLASS SO WATCHING TO SAY.
# Expected:  I WAS HUMILIATED IN FRONT OF EVERYONE BY TOM.
# Match:     ❌
# Char Accuracy: 13/45 (28.9%)
#
# --- Case 399870 ---
# Input:     IZ YXYLUDU PO OAN CROD.
# Decrypted: HE DUMBED ME YEAR BOOK.
# Expected:  HE FOCUSED ON THE GAME.
# Match:     ❌
# Char Accuracy: 5/23 (21.7%)
#
# --- Case 335505 ---
# Input:     FFRJJRTAS
# Decrypted: PICHUNTER
# Expected:  PROTOTYPE
# Match:     ❌
# Char Accuracy: 1/9 (11.1%)
#
# --- Case 270567 ---
# Input:     BH
# Decrypted: PD
# Expected:  OG
# Match:     ❌
# Char Accuracy: 0/2 (0.0%)
#
# --- Case 193514 ---
# Input:     NYU EXUVTL WCN BUTN GMYE.
# Decrypted: TOM LEAPED FOR YEAR OPEN.
# Expected:  TOM REALLY DID THAT WELL.
# Match:     ❌
# Char Accuracy: 11/25 (44.0%)
#
# --- Case 260937 ---
# Input:     PQ MOD VIQACBOMIKE WQKREK.
# Decrypted: IT WAS SPRESSIBLED UNIVED.
# Expected:  WE ARE PRACTICALLY FAMILY.
# Match:     ❌
# Char Accuracy: 5/26 (19.2%)
#
# --- Case 217107 ---
# Input:     CJ QMNJ HI NNJ ZCNVOCL EJMBEHRUS GSX PAT O AI US NPE RWA QNJYT.
# Decrypted: WE HAVE TO SAI MIXTAKE BETTERFUL WHO WAS A BE ON THE COOD TFAT.
# Expected:  WE WENT TO THE FUNFAIR YESTERDAY AND HAD A GO ON THE BIG WHEEL.
# Match:     ❌
# Char Accuracy: 29/63 (46.0%)
#
# --- Case 102432 ---
# Input:     HZTTCUO
# Decrypted: SITEMAP
# Expected:  APPLIES
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 372987 ---
# Input:     UYUY TRTRF BW JEH RGOC NEO PD.
# Decrypted: SAMI TRIED TO GET HIMI AS YOU.
# Expected:  SAMI WOULD DO THE SAME FOR ME.
# Match:     ❌
# Char Accuracy: 13/30 (43.3%)
#
# --- Case 227053 ---
# Input:     MTUUHTCHE
# Decrypted: TEMPORARY
# Expected:  POSITIONS
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 43125 ---
# Input:     ULTQRTX
# Decrypted: ASSAULT
# Expected:  PUZZLES
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 298423 ---
# Input:     B MVIPD HJUKX ORG T ZQJ HY PECNHKVNE KOOXB KD TNGTTTZKQ.
# Decrypted: I WOULD RAPER YOU COULD GO BETTERDAY AGARD THE PARTMENT.
# Expected:  I THINK THERE ARE A LOT OF BEAUTIFUL WOMEN IN AUSTRALIA.
# Match:     ❌
# Char Accuracy: 12/56 (21.4%)
#
# --- Case 198055 ---
# Input:     HGS HXPQG UAT ROAL HNAGMWHBI TQNIV BI.
# Decrypted: SHE ENDED HER HARD IMPRESSED THAT IT.
# Expected:  SHE FEARS SHE SAYS SOMETHING ABOUT IT.
# Match:     ❌
# Char Accuracy: 9/38 (23.7%)
#
# --- Case 346455 ---
# Input:     INA UETOH QG IGS DXPBV.
# Decrypted: TOM TRIED TO GET AWAY.
# Expected:  TOM SLEPT ON THE BEACH.
# Match:     ❌
# Char Accuracy: 8/23 (34.8%)
#
# --- Case 392982 ---
# Input:     FIUXFYWCUL
# Decrypted: CONSTRAINT
# Expected:  CONSULTING
# Match:     ❌
# Char Accuracy: 6/10 (60.0%)
#
# --- Case 80711 ---
# Input:     CYXQO QAVKF SM JCR XVNTFZ.
# Decrypted: AVOID GOING TO THE MOSQUE.
# Expected:  DAVID TRIED TO HUG AMANDA.
# Match:     ❌
# Char Accuracy: 10/26 (38.5%)
#
# --- Case 142349 ---
# Input:     LFSB NW YENXMNRZ PNZA TXAXW MBWPL.
# Decrypted: SAMI IS JUFFERED THAN LAYLA FLAGE.
# Expected:  SAMI IS FLIRTING WITH OTHER GIRLS.
# Match:     ❌
# Char Accuracy: 12/34 (35.3%)
#
# --- Case 227148 ---
# Input:     OAP GNOV IAN STD HBU KXR CK WZ HUGL.
# Decrypted: SHE GAVE HIS TOM DOG WAS AN IN BERB.
# Expected:  SHE SAID SHE WAS TOO SHY TO DO THAT.
# Match:     ❌
# Char Accuracy: 14/36 (38.9%)
#
# --- Case 79509 ---
# Input:     XJT FEKUV KH LECC.
# Decrypted: THE PASS IS MBERS.
# Expected:  THE WATER IS CALM.
# Match:     ❌
# Char Accuracy: 6/18 (33.3%)
#
# --- Case 374817 ---
# Input:     PVGLGG TUA ERRY IRGUBFKXB XLZOQ DNTW.
# Decrypted: FYODOR HAS BEEN TRANSURRE THIST MONT.
# Expected:  MENNAD AND BAYA CONNECTED RIGHT AWAY.
# Match:     ❌
# Char Accuracy: 9/37 (24.3%)
#
# --- Case 83023 ---
# Input:     ITGSKOS
# Decrypted: THREATS
# Expected:  PASSIVE
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 364334 ---
# Input:     KYTEBTDCT VGV LBUJXDY ZHRJG WGB.
# Decrypted: EVERYBODY WAS ENTRALY LOOKE TOM.
# Expected:  EVERYBODY WAS WORRIED ABOUT TOM.
# Match:     ❌
# Char Accuracy: 22/32 (68.8%)
#
# --- Case 189717 ---
# Input:     GVLGXH
# Decrypted: CAUSES
# Expected:  DESIRE
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 223805 ---
# Input:     VCXDYYOTCBI
# Decrypted: EXPLORATION
# Expected:  FOUNDATIONS
# Match:     ❌
# Char Accuracy: 0/11 (0.0%)
#
# --- Case 215721 ---
# Input:     WPLOI
# Decrypted: SAINT
# Expected:  CHUCK
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 294758 ---
# Input:     XOC QIG VD PMMICTS.
# Decrypted: TOM WAS AN ADDICT.
# Expected:  TOM SAT BY HIMSELF.
# Match:     ❌
# Char Accuracy: 7/19 (36.8%)
#
# --- Case 362526 ---
# Input:     AOG QQINQ HRTIFNIRRLG MLOJQM.
# Decrypted: TOM STAYED ABSOLUTELY SILENT.
# Expected:  TOM LIKES HUMILIATING PEOPLE.
# Match:     ❌
# Char Accuracy: 7/29 (24.1%)
#
# --- Case 42186 ---
# Input:     FVPCBXRG
# Decrypted: STANFORD
# Expected:  DESCRIBE
# Match:     ❌
# Char Accuracy: 0/8 (0.0%)
#
# --- Case 204797 ---
# Input:     ATWAAQTVLMB
# Decrypted: COMPARISONS
# Expected:  COMPLICATED
# Match:     ❌
# Char Accuracy: 4/11 (36.4%)
#
# --- Case 171194 ---
# Input:     WLP IGKSV QKB KDIQA RC ZXG RTQ SGXQH.
# Decrypted: TOM COULD GET HAPPY TO SEE WHO A BOE.
# Expected:  TOM LOVES THE SOUND OF HIS OWN VOICE.
# Match:     ❌
# Char Accuracy: 13/37 (35.1%)
#
# --- Case 28968 ---
# Input:     CHYP CQPK JRU OHU CETLKRYUN ZWFVYKKDA AF NE.
# Decrypted: MARY WILL SAT BEFO DELIMENT APPROMING IN UP.
# Expected:  MARY SAID SHE HAD SOMETHING IMPORTANT TO DO.
# Match:     ❌
# Char Accuracy: 15/44 (34.1%)
#
# --- Case 346516 ---
# Input:     Q DCVYKIUITSMM ZCC THBI.
# Decrypted: I ALREADYONNED TOM SOME.
# Expected:  I CONGRATULATE YOU BOTH.
# Match:     ❌
# Char Accuracy: 7/24 (29.2%)
#
# --- Case 135567 ---
# Input:     V LZUP WSTB GPY ALHO MW OF M ITVSBME BF G ZUZVMEZ EZHUP.
# Decrypted: I KNOW THAT TOM WILL BE AT A PICPARE OF HI PARTY DALK.
# Expected:  I KNOW THAT TOM USED TO BE A CASHIER AT A GROCERY STORE.
# Match:     ❌
# Char Accuracy: 23/56 (41.1%)
#
# --- Case 313233 ---
# Input:     NLF TUIQ XGY.
# Decrypted: TOM TOOK OFF.
# Expected:  TOM WILL DIE.
# Match:     ❌
# Char Accuracy: 6/13 (46.2%)
#
# --- Case 44232 ---
# Input:     AYQ SHUS VHKL DLIH XA FTL SOXBCDC XG.
# Decrypted: TOM SAID MARY WILL BE WAS FRIENDS TO.
# Expected:  TOM KNEW MORE THAN HE WAS LETTING ON.
# Match:     ❌
# Char Accuracy: 17/37 (45.9%)
#
# --- Case 276799 ---
# Input:     GSBKSY
# Decrypted: CURTIS
# Expected:  VIRGIN
# Match:     ❌
# Char Accuracy: 2/6 (33.3%)
#
# --- Case 187603 ---
# Input:     KG OU ZGYUQKTI QCY NRKRGQN.
# Decrypted: IT IS DHIFFISH TOM SOMEONE.
# Expected:  HE IS CLEANING THE TOILETS.
# Match:     ❌
# Char Accuracy: 10/27 (37.0%)
#
# --- Case 179442 ---
# Input:     JERMBP VUYZX XKWOSE ML RZH MIFBRWUI.
# Decrypted: DANIEL FOUND HEOPHY TO SAM MOTIVING.
# Expected:  GUNTER DROVE AMELIA TO THE CEMETERY.
# Match:     ❌
# Char Accuracy: 10/36 (27.8%)
#
# --- Case 132111 ---
# Input:     SMO ELP JYXGZBA IDINRV YGCP Q RLC UUOD.
# Decrypted: TOM WAS ARGUING ALMOST EASY I WAS ANG.
# Expected:  TOM WAS ALREADY ASLEEP WHEN I GOT HOME.
# Match:     ❌
# Char Accuracy: 16/39 (41.0%)
#
# --- Case 26236 ---
# Input:     UMYV RCTHUIDL YADFD BJMZ GGIV.
# Decrypted: SAMI STARTEDY TALKE STORY WAS.
# Expected:  SAMI SURVIVED WORSE THAN THAT.
# Match:     ❌
# Char Accuracy: 11/30 (36.7%)
#
# --- Case 298103 ---
# Input:     QCMQVV CM ICSQRN ZIU KZU ZVMNOG.
# Decrypted: PLEASE PUT THESE DOG OFF BEFORE.
# Expected:  NAGOYA IS FAMOUS FOR ITS CASTLE.
# Match:     ❌
# Char Accuracy: 7/32 (21.9%)
#
# --- Case 133745 ---
# Input:     X ILBBP YDJ GPC WISFP UOICRL.
# Decrypted: I NEVER SAW TOM BABAN STATER.
# Expected:  I THINK TOM CAN SPEAK FRENCH.
# Match:     ❌
# Char Accuracy: 8/29 (27.6%)
#
# --- Case 161864 ---
# Input:     S MQTA M YXHO GNDE JQVZJWYW.
# Decrypted: I LIKE T THIS YEAR MORNINGS.
# Expected:  I HAVE A LEFT WING NEIGHBOR.
# Match:     ❌
# Char Accuracy: 8/28 (28.6%)
#
# --- Case 75825 ---
# Input:     MV BRY QJVH ZT EWRWKORJ RM R RPBPYI LDW DIIK IMRH KKC DVUIY.
# Decrypted: IT WAS THIN IN ENVERING TO BE THING YOU WANT TO DO THAT.
# Expected:  HE HAS BEEN IN PRACTICE AS A LAWYER FOR MORE THAN TEN YEARS.
# Match:     ❌
# Char Accuracy: 17/60 (28.3%)
#
# --- Case 204996 ---
# Input:     OXF FSYTCRWNYPA YIBISSY JPZ RL ROEZY Q TRALDX DCPIF BL EYM LFJFFERV.
# Decrypted: THE HANDEREPED OLICING. OUT OF SAFUL A PERCE APPLY AND LEAVE SUM.
# Expected:  THE SUBDIVISION ALLOWED TOM TO BUILD A SECOND HOUSE ON HIS PROPERTY.
# Match:     ❌
# Char Accuracy: 13/68 (19.1%)
#
# --- Case 279563 ---
# Input:     C QEBIHS GJ UIKV DJPD.
# Decrypted: I AGREED TO HELP THEM.
# Expected:  I FORCED MY EYES OPEN.
# Match:     ❌
# Char Accuracy: 10/22 (45.5%)
#
# --- Case 394189 ---
# Input:     YDGCEZDS
# Decrypted: EXPLICIT
# Expected:  OPPOSITE
# Match:     ❌
# Char Accuracy: 1/8 (12.5%)
#
# --- Case 217966 ---
# Input:     R FFMTDW QZNCYDH STG SWM DZHX BYJN NDAQQWUKBNU.
# Decrypted: I WONDER WHETHER TOM AND MARY ARED INSTRANGERS.
# Expected:  I WONDER WHETHER TOM AND MARY WERE EMBARRASSED.
# Match:     ❌
# Char Accuracy: 33/47 (70.2%)
#
# --- Case 97452 ---
# Input:     FWS OOWMJ AA FW IOHX GUI.
# Decrypted: TOM COULD BE OF THIS EYE.
# Expected:  TOM ASKED ME TO CALL YOU.
# Match:     ❌
# Char Accuracy: 11/25 (44.0%)
#
# --- Case 257496 ---
# Input:     ZLFEW JYHQHZ SPHLQUX.
# Decrypted: LAYLA LOOKED SILENCE.
# Expected:  EVERY MINUTE COUNTED.
# Match:     ❌
# Char Accuracy: 3/21 (14.3%)
#
# --- Case 247866 ---
# Input:     QXGDVTQFQ
# Decrypted: INITIALLY
# Expected:  HOPEFULLY
# Match:     ❌
# Char Accuracy: 3/9 (33.3%)
#
# --- Case 186130 ---
# Input:     HNQG SQTUDB CUUF DQNMXJ VGET BMD ZLNG.
# Decrypted: MARY THOUGH SHOT REVERY WOULD BE TREE.
# Expected:  ZIRI HELPED RIMA ESCAPE WITH THE BABY.
# Match:     ❌
# Char Accuracy: 9/38 (23.7%)
#
# --- Case 363684 ---
# Input:     PZU XECNJ CT AGMMOBJOML DP PVT BQ JN.
# Decrypted: TOM WAITED A MILITAROUT OF THE BOY TO.
# Expected:  TOM COULD DO EVERYTHING HE HAD TO DO.
# Match:     ❌
# Char Accuracy: 9/38 (23.7%)
#
# --- Case 275593 ---
# Input:     D LVAOBZH FBVL W OIPDR OBVFUQ SJMF YCIV.
# Decrypted: I THOUGHT THAT I WOULD EVERY DREAD BACK.
# Expected:  I THOUGHT THAT I COULD CHANGE YOUR MIND.
# Match:     ❌
# Char Accuracy: 24/40 (60.0%)
#
# --- Case 302049 ---
# Input:     B YNBSO MHR IHZPW UJ OG GSLMTT GTA.
# Decrypted: I THINK THE MIGHT BE AT SEERVE TOM.
# Expected:  I THINK TOM COULD BE IN BOSTON NOW.
# Match:     ❌
# Char Accuracy: 18/35 (51.4%)
#
# --- Case 144504 ---
# Input:     CKNPKIK IVEN VP MVO KA ECKKCFERGA DNOA.
# Decrypted: GUSTAVO TOLD ME THE BY ENVERYBODY LEFT.
# Expected:  GUSTAVO SAID IT WAS AN IMPOSSIBLE TASK.
# Match:     ❌
# Char Accuracy: 15/39 (38.5%)
#
# --- Case 393610 ---
# Input:     VWW OJCA XK CVRVT DUWNNN.
# Decrypted: THE PAIN IS MADER EVERY.
# Expected:  THE CITY IS QUITE LIVELY.
# Match:     ❌
# Char Accuracy: 9/25 (36.0%)
#
# --- Case 45861 ---
# Input:     FHX FMXAHQW ZUX R CQK MZ DS KNQF.
# Decrypted: TOM PUNCHED THE A LOT OF TO STAY.
# Expected:  TOM FIGURED OUT A WAY TO DO THAT.
# Match:     ❌
# Char Accuracy: 16/33 (48.5%)
#
# --- Case 87025 ---
# Input:     YFG RTS RRLP ZDQU GV ZWJP XZJ IMRN NXDSX.
# Decrypted: TOM AND MARY TOLD ME THAT THE FELT BOST.
# Expected:  TOM AND MARY TOLD ME THEY DID THAT WRONG.
# Match:     ❌
# Char Accuracy: 27/41 (65.9%)
#
# --- Case 8529 ---
# Input:     VQTJ QAYFSA.
# Decrypted: STOP FILMAM.
# Expected:  STOP MOVING.
# Match:     ❌
# Char Accuracy: 6/12 (50.0%)
#
# --- Case 54991 ---
# Input:     LBSMXRO
# Decrypted: RETURNS
# Expected:  PEOPLES
# Match:     ❌
# Char Accuracy: 2/7 (28.6%)
#
# --- Case 307405 ---
# Input:     QDSUVPVYQS
# Decrypted: APPARENTLY
# Expected:  APPEARANCE
# Match:     ❌
# Char Accuracy: 3/10 (30.0%)
#
# --- Case 365419 ---
# Input:     ETUG SZCZ LADB SGY YGNOL HDFL ML.
# Decrypted: ZIRI CAME RIGHT AN OLDER AFER ME.
# Expected:  MARY SAID THAT SHE COULD HELP US.
# Match:     ❌
# Char Accuracy: 8/33 (24.2%)
#
# --- Case 174154 ---
# Input:     VJKDN FDI YLRAX MJWU GGDH RK QQLYJXT ADOYSL JMK TRVJUW GHJGL.
# Decrypted: BEGAN AND LAYLA WERE KNOW I A SPAPER SALONG WAS FAMILY GET.
# Expected:  YANNI AND SKURA WERE BACK IN ALGIERS DURING THE SUMMER BREAK.
# Match:     ❌
# Char Accuracy: 21/61 (34.4%)
#
# --- Case 238839 ---
# Input:     RSPUVUBSWD SE LKNNXS SRH OYGQXHD YR SRLX VUEO ZNDT IEVY LMFQDLO QMYXLR.
# Decrypted: CAPRICABLE IS ALWAYS TESH OPINED IS THAT BEEN UPOO THE COULD ECOUNTRY.
# Expected:  SIMPLICITY IS MAKING THE JOURNEY OF THIS LIFE WITH JUST BAGGAGE ENOUGH.
# Match:     ❌
# Char Accuracy: 17/71 (23.9%)
#
# --- Case 331140 ---
# Input:     VQUPHWMJY
# Decrypted: PRESIDENT
# Expected:  REFERRALS
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 158227 ---
# Input:     YWROX NH N PVMDBI BS IUFL GJVIWNCT.
# Decrypted: THERE IS A MBROAD BY THIS FAMILYLY.
# Expected:  THERE IS A SCHOOL IN THIS BUILDING.
# Match:     ❌
# Char Accuracy: 20/35 (57.1%)
#
# --- Case 312015 ---
# Input:     KWMJ QBDP HF HXK NEBOV XKR USXL.
# Decrypted: YOUR PLAY IS THE MILL FOOT TIME.
# Expected:  SAMI FELT HE WAS READY FOR THAT.
# Match:     ❌
# Char Accuracy: 8/32 (25.0%)
#
# --- Case 88096 ---
# Input:     D MBF RLBX UCP MPHJA RY WZJDF.
# Decrypted: I WAS KNOW TOM LOUDS DO STRYE.
# Expected:  I WAS TOLD YOU WOULD BE ALONE.
# Match:     ❌
# Char Accuracy: 15/30 (50.0%)
#
# --- Case 317313 ---
# Input:     ZCMW IGXEQ VJK BC MIC WK FMF QRRUN.
# Decrypted: ZIRI ASKED HIS TO REA NO THE STAIRS.
# Expected:  MARY ASKED TOM TO ZIP UP HER DRESS.
# Match:     ❌
# Char Accuracy: 15/36 (41.7%)
#
# --- Case 193863 ---
# Input:     GLHI YKDOWT LK DQFP JY ZDZY NQBK RU BPHCKOU.
# Decrypted: SAMI WANTED TO HAVE HE WAS TRYED TO HAPPEN.
# Expected:  MARY SHOULD BE ABLE TO TAKE CARE OF HERSELF.
# Match:     ❌
# Char Accuracy: 13/44 (29.5%)
#
# --- Case 258461 ---
# Input:     U NDEH KU MAKV WMKN XQK.
# Decrypted: I MUST BE VERY DRAY TOM.
# Expected:  I USED TO WORK WITH HER.
# Match:     ❌
# Char Accuracy: 8/24 (33.3%)
#
# --- Case 346546 ---
# Input:     O GHENMBBDREMV FJV JXZL.
# Decrypted: I ALREADYONNED TOM SOME.
# Expected:  I CONGRATULATE YOU BOTH.
# Match:     ❌
# Char Accuracy: 7/24 (29.2%)
#
# --- Case 154150 ---
# Input:     ZEN TWFM AKJYQFZYBXBB UB RTBZENDB HYHRV QMJD UYUJYFSC MLGICT AHSPYQAK CEKPIFJXG ST WAQ BAAD FYKXB AT SML ILDZHQD VT ONP OKJYZ.
# Decrypted: THE POET EVERYTHINGED TO ELECTION DATES WAS THE OLER WORE WE FORE TREED THAT THE SOUND THE PROFORT THE SNOF THE SE TRAIS SACTORACTS.
# Expected:  THE HIGH TEMPERATURES IN SOUTHERN ITALY HAVE PROMPTED HEALTH MINISTRY OFFICIALS TO PUT SOME AREAS OF THE COUNTRY ON RED ALERT.
# Match:     ❌
# Char Accuracy: 18/132 (13.6%)
#
# --- Case 159838 ---
# ...
# Expected:  THIS IS MY FAVORITE BEER.
# Match:     ❌
# Char Accuracy: 13/25 (52.0%)
#
# --- Case 68118 ---
# Input:     BAZ KBOOS DV MCZ HGUD XA VCDQVFC PVW AGBQJMV.
# Decrypted: THE SHIRT IS THE EXT IS SEERIOUS SHE CONTEXT.
# Expected:  THE PAINT ON THE GATE IS CHIPPED AND FLAKING.
# Match:     ❌
# Char Accuracy: 16/45 (35.6%)
#
# --- Case 57402 ---
# Input:     YJMPQK
# Decrypted: SHARES
# Expected:  FORUMS
# Match:     ❌
# Char Accuracy: 1/6 (16.7%)
#
# --- Case 43697 ---
# Input:     RTW NGWJNWL RT DST EZIVWU.
# Decrypted: TOM FUMBLED IN HIS POCKET.
# Expected:  TOM CROSSED TO THE WINDOW.
# Match:     ❌
# Char Accuracy: 10/26 (38.5%)
#
# --- Case 9375 ---
# Input:     ATMAZ OLO RUGNBCZHPNTAR FS.
# Decrypted: YANNI WAS SMILISTARIONS ON.
# Expected:  MAYBE YOU MISUNDERSTOOD ME.
# Match:     ❌
# Char Accuracy: 6/27 (22.2%)
#
# --- Case 182010 ---
# Input:     UWW UT FCIUTJWI.
# Decrypted: SHE IS POISONED.
# Expected:  SHE IS WATCHING.
# Match:     ❌
# Char Accuracy: 8/16 (50.0%)
#
# --- Case 285868 ---
# Input:     PPYZ SI H ZRWKYHZ.
# Decrypted: ZIRI IS A MINISIN.
# Expected:  ZIRI IS A SAMURAI.
# Match:     ❌
# Char Accuracy: 11/18 (61.1%)
#
# --- Case 166842 ---
# Input:     WYQ MEMMJRX MEYL KO ATP QEDBXXO RZDX EGVZGGI IEPC.
# Decrypted: TOM QUICKLY WENT TO THE FRASHED STRE SEATING BED.
# Expected:  TOM THOUGHT THAT HE WAS SMARTER THAN ANYBODY ELSE.
# Match:     ❌
# Char Accuracy: 14/50 (28.0%)
#
# --- Case 199023 ---
# Input:     AX TRCFSF JAX DIEMITU AX VAF UCWWAM CN VAS UJKXST.
# Decrypted: MY MOTHER WAS LIVINGE IN THE GOESEN TO HER SLEEPIN.
# Expected:  HE FRAMED THE PICTURE HE HAD BOUGHT ON THE STREET.
# Match:     ❌
# Char Accuracy: 15/51 (29.4%)
#
# --- Case 183379 ---
# Input:     EMF FPF OA IJMP GE.
# Decrypted: GET HIM TO CALL ME.
# Expected:  LET TOM GO WITH US.
# Match:     ❌
# Char Accuracy: 9/19 (47.4%)
#
# --- Case 210151 ---
# Input:     DZ QGHXL CDQJ QHH TIZ LWGF VGUDG.
# Decrypted: WE HAVE ALWAY NOT TO HELPE SOULD.
# Expected:  IT LOOKS LIKE YOU ARE FROM INDIA.
# Match:     ❌
# Char Accuracy: 7/33 (21.2%)
#
# --- Case 349797 ---
# Input:     G BKD ACIZV BM YRP HBFMW JW YRP PLMZJBGXOXTVK.
# Decrypted: I WAS LIKED TO THE STILL BE AMA PRESENAUSANT.
# Expected:  I WAS LURED TO THE STORE BY THE ADVERTISEMENT.
# Match:     ❌
# Char Accuracy: 23/46 (50.0%)
#
# --- Case 135976 ---
# Input:     XE LQV F SSSV.
# Decrypted: HE SET A TRAP.
# Expected:  GO FLY A KITE.
# Match:     ❌
# Char Accuracy: 5/14 (35.7%)
#
# --- Case 176332 ---
# Input:     KOWQAD
# Decrypted: DEEMED
# Expected:  DESIGN
# Match:     ❌
# Char Accuracy: 2/6 (33.3%)
#
# --- Case 383851 ---
# Input:     HGWQ EBHBZJ IGPA TK CKW TKBDVI RJY.
# Decrypted: SAMI PAINTS LARE IS THE LIGHT NOW.
# Expected:  MARY LOOKED DOWN AT HER BROKEN LEG.
# Match:     ❌
# Char Accuracy: 6/35 (17.1%)
#
# --- Case 130459 ---
# Input:     WFP KAHHWBOB PHH PKDAH PWIE BJLA CIEBA.
# Decrypted: DAT EVERYONE HAD BEENO OVER THEY WRONG.
# Expected:  HIS BROTHERS GOT ANGRY WITH EACH OTHER.
# Match:     ❌
# Char Accuracy: 7/39 (17.9%)
#
# --- Case 100223 ---
# Input:     B CISV EOWWAXR IV HTH.
# Decrypted: I LIKE THINKED BY TOM.
# Expected:  I JUST LAUGHED IT OFF.
# Match:     ❌
# Char Accuracy: 8/22 (36.4%)
#
# --- Case 232438 ---
# Input:     Y IBUE E GER.
# Decrypted: I WALK A LOT.
# Expected:  I KNOW A LOT.
# Match:     ❌
# Char Accuracy: 9/13 (69.2%)
#
# --- Case 20753 ---
# Input:     EZDNZP VUE VRSFMAPBNMBID ETOYUYP ERW WZRPFMFQKIKZU ZT NTU ZTUYCD.
# Decrypted: MOVING THE LINJORRESTING COMPAAY FOR SMITIATIONAL TO LE TESTEAKIN.
# Expected:  HUBBLE HAS FUNDAMENTALLY CHANGED OUR UNDERSTANDING OF THE COSMOS.
# Match:     ❌
# Char Accuracy: 10/66 (15.2%)
#
# --- Case 272928 ---
# Input:     JTCS WSCURNAS JTYN PWUK UYNT TUQNNTIECX.
# Decrypted: THEY ADMITTED THAT THEI WELL UNIPRESSED.
# Expected:  THEY ADMITTED THAT THEY WERE DISTRESSED.
# Match:     ❌
# Char Accuracy: 33/40 (82.5%)
#
# --- Case 25669 ---
# Input:     WO MSUZT BO IHKO Y COQDOY.
# Decrypted: HE WANTS TO TALK A FAILSH.
# Expected:  HE ASKED ME WHAT I NEEDED.
# Match:     ❌
# Char Accuracy: 8/26 (30.8%)
#
# --- Case 225735 ---
# Input:     R LHXFVJ TYEX NNGOX XCC MOV RY YIGVFIWR LE TGVLEUQ.
# Decrypted: I SPEND ABOUT THREE HAR AND IT MYSELVES I BEDROWNE.
# Expected:  I SHOULD HAVE NEVER LET TOM GO SWIMMING BY HIMSELF.
# Match:     ❌
# Char Accuracy: 11/51 (21.6%)
#
# --- Case 90690 ---
# Input:     PEP FMQIFZAJT KXZ XSYMUN.
# Decrypted: YOU RECEIVEDED TO LEARNS.
# Expected:  YOU SHARPENED THE KNIVES.
# Match:     ❌
# Char Accuracy: 7/25 (28.0%)
#
# --- Case 209362 ---
# Input:     KAQQ UPODPV AX BFF LNEVOSZ NPLE.
# Decrypted: SAMI WATCHE TO GET LAYLOONG WIT.
# Expected:  SAMI WORKED AT THE OUTDOOR POOL.
# Match:     ❌
# Char Accuracy: 12/32 (37.5%)
#
# --- Case 272709 ---
# Input:     XJTH ARDX VD BIV KW CAXRV.
# Decrypted: THEY TOLD ME THE GO ABOUT.
# Expected:  THEY WANT TO SEE US ALONE.
# Match:     ❌
# Char Accuracy: 13/26 (50.0%)
#
# --- Case 203159 ---
# Input:     PIFLN BG P JBVKXF DC QQN LOIXKRL MSBMIN.
# Decrypted: YANNI IS A SPEAKS OF THE MOMENTS POOLES.
# Expected:  ALICE IS A MEMBER OF THE SATANIC TEMPLE.
# Match:     ❌
# Char Accuracy: 17/40 (42.5%)
#
# --- Case 351803 ---
# Input:     VCSK XIX FDARC EVX U FQTXBMMUWKUP XO U XLPKT.
# Decrypted: SAMI AND LAYLA USE A CHILLIBRABLE TO BE LATE.
# Expected:  SAMI AND LAYLA HAD A CONVERSATION AT A DINER.
# Match:     ❌
# Char Accuracy: 22/45 (48.9%)
#
# --- Case 376019 ---
# Input:     LHP QS ZFIGLW VEUYN DTWM FNL WHIRQNSGAFMV.
# Decrypted: TOM IS BECAMY TWROT WITH THE SUMMIRRIQUES.
# Expected:  TOM IS ALMOST NEVER LATE FOR APPOINTMENTS.
# Match:     ❌
# Char Accuracy: 15/42 (35.7%)
#
# --- Case 130177 ---
# Input:     F NODU GYW S RFMH BE SIBF.
# Decrypted: I WANT YOU TO LET ME WITH.
# Expected:  I GAVE HER A LIFT TO TOWN.
# Match:     ❌
# Char Accuracy: 9/26 (34.6%)
#
# --- Case 21796 ---
# Input:     RU CEMRWBP GJCFGFFDA.
# Decrypted: WE COUGHED VACTUREST.
# Expected:  WE BROUGHT SOMETHING.
# Match:     ❌
# Char Accuracy: 5/21 (23.8%)
#
# --- Case 46303 ---
# Input:     ITGPZDMWR
# Decrypted: COMPUTING
# Expected:  FRANCISCO
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 82736 ---
# Input:     VAY NML OMDL ZKVGMYKG HUSHQMF UF BTB DK FUDUUQXIDA.
# Decrypted: TOM SAW MUPP LITTINGS CONSIDER TO DO THE SURPRISED.
# Expected:  TOM AND MARY ACTUALLY FIGURED IT OUT BY THEMSELVES.
# Match:     ❌
# Char Accuracy: 13/51 (25.5%)
#
# --- Case 147176 ---
# Input:     KES MXI I LNRJ.
# Decrypted: TOM HAS A FLAT.
# Expected:  TOM HAD A BOAT.
# Match:     ❌
# Char Accuracy: 12/15 (80.0%)
#
# --- Case 49702 ---
# Input:     B MZBVWN BYLNDIK ZYI.
# Decrypted: I ALMOST SLAPPED TOM.
# Expected:  I REGRET KISSING HER.
# Match:     ❌
# Char Accuracy: 6/21 (28.6%)
#
# --- Case 70338 ---
# Input:     JFS HMWO XYWXLVZIQSXA EMU EOE.
# Decrypted: THE TEST CONVERSITING THE LEWT.
# Expected:  THE BEST HAIRDRESSERS ARE GAY.
# Match:     ❌
# Char Accuracy: 12/31 (38.7%)
#
# --- Case 169090 ---
# Input:     ZLVA BQJ MDGM IVLZEFB GEGVHU FVAVHUII.
# Decrypted: WHAT TOM SAID CANNIEL THEIRS MIRROROR.
# Expected:  IVAN WAS WITH SEVERAL POLICE OFFICERS.
# Match:     ❌
# Char Accuracy: 9/38 (23.7%)
#
# --- Case 114951 ---
# Input:     ONJ KDVECZJ PSRNDVM TFNBTTKZJ YZKBNXC ZMW MHKSPRJFM ETGDJX WYSHIORJKLYR.
# Decrypted: THE HOLIDAY STARTED ETTENCILE THOUSES AND CABINALY LECHANED THE ALBE.
# Expected:  THE SKILLED KAYAKER NAVIGATED THROUGH THE TURBULENT RAPIDS EFFORTLESSLY.
# Match:     ❌
# Char Accuracy: 13/72 (18.1%)
#
# --- Case 100381 ---
# Input:     B AYAR BH TYP WB FRHZSL.
# Decrypted: I HOPE TO SEE IT AGAIN.
# Expected:  I NEED TO GET IT MENDED.
# Match:     ❌
# Char Accuracy: 11/24 (45.8%)
#
# --- Case 139661 ---
# Input:     LBCI EEJ HUFL TVRTIXTEEH ZZ.
# Decrypted: ZIRI AND RIMA ALGERIFIES IT.
# Expected:  ZIRI AND RIMA TRANSLATED IT.
# Match:     ❌
# Char Accuracy: 19/28 (67.9%)
#
# --- Case 112024 ---
# Input:     MU MBWHAY URLZ TF ZHAYF WO CV.
# Decrypted: WE SHOULD TELL TO LEAVE DO IT.
# Expected:  MY FATHER TOLD ME WHERE TO GO.
# Match:     ❌
# Char Accuracy: 11/30 (36.7%)
#
# --- Case 31062 ---
# Input:     KHI NMVDAE TAGS FFO MPSRW.
# Decrypted: SHE YEARNS FARM HER ANOWS.
# Expected:  SHE FOUGHT BACK HER TEARS.
# Match:     ❌
# Char Accuracy: 13/26 (50.0%)
#
# --- Case 214811 ---
# Input:     RMOMCPNG
# Decrypted: PATIENTS
# Expected:  SOMERSET
# Match:     ❌
# Char Accuracy: 0/8 (0.0%)
#
# --- Case 97008 ---
# Input:     ZKQYYEAU
# Decrypted: DISCOUNT
# Expected:  DISEASES
# Match:     ❌
# Char Accuracy: 3/8 (37.5%)
#
# --- Case 284406 ---
# Input:     TXJG CKZG AVJ LPJP GKL DXK ADODLJPLMA.
# Decrypted: MARY TOLD TOM THAT SHE WAS DEPRESSIVE.
# Expected:  MARY TOLD TOM THAT SHE WAS SUSPICIOUS.
# Match:     ❌
# Char Accuracy: 28/38 (73.7%)
#
# --- Case 238908 ---
# Input:     NKKU YZZ UIOPM WTC MRGZAGHE FDG PYQBETYNMDU UWMRQI CR MATKQJ.
# Decrypted: SAMI AND LAYLA HAD HANDERED THE ENVISITORS TOWARS THE OUT.
# Expected:  RIMA AND SKURA ARE STUDYING THE RESPIRATORY SYSTEM AT SCHOOL.
# Match:     ❌
# Char Accuracy: 16/61 (26.2%)
#
# --- Case 299020 ---
# Input:     DKZCOD
# Decrypted: SAYING
# Expected:  JERSEY
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 311804 ---
# Input:     NXTPRZ
# Decrypted: TRAVEL
# Expected:  RHYTHM
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 140374 ---
# Input:     QPM
# Decrypted: DDR
# Expected:  ASN
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 95562 ---
# Input:     ZE WIWT EX NGOOA UFIE.
# Decrypted: HE SAID HE CHARD GIVE.
# Expected:  HE SAYS HE COOKS WELL.
# Match:     ❌
# Char Accuracy: 12/22 (54.5%)
#
# --- Case 49137 ---
# Input:     MAY XRQVT KJKK FL BUDU RX AUE ENAJU YOMQD TNXB.
# Decrypted: TOM WILLE WELL ON THEM AT YOU WANTS SAFED THEM.
# Expected:  TOM ASKED MARY TO COME TO HIS HOUSE AFTER WORK.
# Match:     ❌
# Char Accuracy: 14/47 (29.8%)
#
# --- Case 111239 ---
# Input:     UOJJDMSSRS
# Decrypted: ARTIFICIAL
# Expected:  VEGETATION
# Match:     ❌
# Char Accuracy: 1/10 (10.0%)
#
# --- Case 10148 ---
# Input:     PAPFR OK DH ZQBNY SOP.
# Decrypted: YANNI IS TO START MON.
# Expected:  THERE IS NO QUICK FIX.
# Match:     ❌
# Char Accuracy: 8/22 (36.4%)
#
# --- Case 352165 ---
# Input:     ZNYRWEPTMOMTQ HE QETMQMO.
# Decrypted: RESERVATIONS TO A STRACK.
# Expected:  HOMOSEXUALITY IS NATURAL.
# Match:     ❌
# Char Accuracy: 2/25 (8.0%)
#
# --- Case 155321 ---
# Input:     BQXT SQYUGXMBGMEF PHGIZZQ WBM DAQW MMIUMXM UROPRYKFZMPCK GDMEFMD.
# Decrypted: SOME IMMEDIATELES GIVERING TO THAT DELICES EVERYONISIONS.
# Expected:  HIGH UNEMPLOYMENT REMAINS THE MOST SERIOUS MACROECONOMIC PROBLEM.
# Match:     ❌
# Char Accuracy: 10/65 (15.4%)
#
# --- Case 83913 ---
# Input:     V VJJL HBM UG NFWIYD OWT RPOG CNT.
# Decrypted: I WANT YOU TO SHOULD LET YOUR SON.
# Expected:  I TOLD TOM HE SHOULD BUY THAT CAR.
# Match:     ❌
# Char Accuracy: 16/34 (47.1%)
#
# --- Case 71933 ---
# Input:     NEBP UP YBC VBLQ OXPY RBXM F TXAY CPBK BMQJH.
# Decrypted: THIS IS THE SETT LEFT THAT I KNOW THEI PARTY.
# Expected:  THIS IS THE BEST CAKE THAT I HAVE EVER EATEN.
# Match:     ❌
# Char Accuracy: 28/45 (62.2%)
#
# --- Case 178112 ---
# Input:     U HOX TJA TZL WHVQ FTGK MNPNL.
# Decrypted: I MET TOM WAS MARY BEING BUSY.
# Expected:  A BOY RAN OFF WITH SOME MONEY.
# Match:     ❌
# Char Accuracy: 7/30 (23.3%)
#
# --- Case 88199 ---
# Input:     WYYO GSKD XYX PYYXO EXHOC DRI LPN.
# Decrypted: THAT GIVE HIS TRAIN ALRED THE BED.
# Expected:  LOOK WHAT TOM FOUND UNDER THE BED.
# Match:     ❌
# Char Accuracy: 14/34 (41.2%)
#
# --- Case 129978 ---
# Input:     QTWQCBB ND EVS IECGESSCQB PYBIPI VDDHCC PJTWZWCD VTP.
# Decrypted: NOTHING IN THE DISTROPPER SSOLVE THOUSE ANTHONLY THEM.
# Expected:  WELCOME TO THE THIRTEENTH ANNUAL BOSTON SPELLING BEE.
# Match:     ❌
# Char Accuracy: 11/54 (20.4%)
#
# --- Case 116527 ---
# Input:     NCFQBYJGFHS
# Decrypted: INTERPRETED
# Expected:  INSTITUTION
# Match:     ❌
# Char Accuracy: 2/11 (18.2%)
#
# --- Case 40032 ---
# Input:     DO HQMSQBLXK SX TUIP WBZOD.
# Decrypted: WE SOMETIMES AN FROM SICEF.
# Expected:  WE DISCUSSED IT LAST NIGHT.
# Match:     ❌
# Char Accuracy: 9/27 (33.3%)
#
# --- Case 308511 ---
# Input:     MYVQZKB
# Decrypted: WATCHES
# Expected:  NATIONS
# Match:     ❌
# Char Accuracy: 3/7 (42.9%)
#
# --- Case 139667 ---
# Input:     MJDO TQO KQZB FXTQDEIGFP OM.
# Decrypted: ZIRI AND RIMA ALGERIFIES IT.
# Expected:  ZIRI AND RIMA TRANSLATED IT.
# Match:     ❌
# Char Accuracy: 19/28 (67.9%)
#
# --- Case 154778 ---
# Input:     NWPM KPKN IZ ZSPOH WZK HD ALXGS.
# Decrypted: THEY PAIN TO MIGHT THE DO THERS.
# Expected:  THEY WANT TO LEARN HOW TO DRIVE.
# Match:     ❌
# Char Accuracy: 15/32 (46.9%)
#
# --- Case 221527 ---
# Input:     ZCPBKYPVKMD
# Decrypted: MATHEMATICS
# Expected:  UNCERTAINTY
# Match:     ❌
# Char Accuracy: 1/11 (9.1%)
#
# --- Case 176181 ---
# Input:     MUCO UWTG QWG WYSYNSL NC UO O PHYS OOKKVZEQM MB AKR.
# Decrypted: WIT S WIMB AN ASLEEL INT THE ENDER AFTIONST TO SAI.
# Expected:  THIS GOAT WAS OFFERED UP AS A HOLY SACRIFICE TO GOD.
# Match:     ❌
# Char Accuracy: 5/52 (9.6%)
#
# --- Case 338154 ---
# Input:     DJYHNJB YXJBM QE HTDXUMB AFCF.
# Decrypted: SOMEBOD STICK TO LOURING THEM.
# Expected:  GABRIEL TRIED TO CONSOLE RIMA.
# Match:     ❌
# Char Accuracy: 9/30 (30.0%)
#
# --- Case 32167 ---
# Input:     V TGVIRCMMQ IUS.
# Decrypted: I CERTAINLY TOM.
# Expected:  I SUPPORTED HIM.
# Match:     ❌
# Char Accuracy: 5/16 (31.2%)
#
# --- Case 191223 ---
# Input:     VHAMKLGKEGL
# Decrypted: COMMUNICATE
# Expected:  COMMISSIONS
# Match:     ❌
# Char Accuracy: 4/11 (36.4%)
#
# --- Case 150709 ---
# Input:     PGS
# Decrypted: ARC
# Expected:  LED
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 105563 ---
# Input:     TTHS GQS LTCK GUT APJDOQV GLHBOHS HPND CLCNPH.
# Decrypted: MARY AND SKEP ARE SKURAGE TENDING THAT ROMILE.
# Expected:  ZIRI AND RIMA ARE GETTING MARRIED NEXT WINTER.
# Match:     ❌
# Char Accuracy: 17/46 (37.0%)
#
# --- Case 40553 ---
# Input:     WNTU KLG VDERLJF GLTYXO YFEW VZAY.
# Decrypted: ZIRI WAS ALWAYS GETTING WITH KEYS.
# Expected:  ZIRI WAS BROUGHT SAFELY BACK HOME.
# Match:     ❌
# Char Accuracy: 12/34 (35.3%)
#
# --- Case 244537 ---
# Input:     AQ ELLKKYKNL BXXXY KULWBE IFSN YUP.
# Decrypted: WE PRESSIDED ABOUT WHERES TRAY THE.
# Expected:  HE SOMETIMES PLAYS TENNIS WITH HER.
# Match:     ❌
# Char Accuracy: 10/35 (28.6%)
#
# --- Case 155187 ---
# Input:     KR QI KHBKUQIHV WN RGYZD QR NHGW QD LUCKT RW RB DARG RW SLPLGPB.
# Decrypted: IT IS POSSIBLED TO FEELS TO FEEL IN OUTSE TO DO THAT BY THE MOR.
# Expected:  IT IS NECESSARY TO LEARN TO OBEY IN ORDER TO BE ABLE TO COMMAND.
# Match:     ❌
# Char Accuracy: 29/64 (45.3%)
#
# --- Case 181991 ---
# Input:     OEI ZMA SOEM MAU JEK MEKRRA TRN CMKSRN.
# Decrypted: SHE WAS GOING TO THE UNIVE THE SHOWERE.
# Expected:  SHE CAN WRAP ANY MAN AROUND HER FINGER.
# Match:     ❌
# Char Accuracy: 11/39 (28.2%)
#
# --- Case 51239 ---
# Input:     HCW
# Decrypted: END
# Expected:  IST
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 31916 ---
# Input:     Q OSMV MW UOTC MW NM JGLA BPWMM QU.
# Decrypted: I WANT TO KNOW MY I  THAT SHORT ME.
# Expected:  I NEED TO TALK TO MY BOSS ABOUT IT.
# Match:     ❌
# Char Accuracy: 14/35 (40.0%)
#
# --- Case 262480 ---
# Input:     KKLGLU
# Decrypted: PASTOR
# Expected:  TITANS
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 204036 ---
# Input:     LGEG ZAM FAZ SW IUHR HB DMOX.
# Decrypted: SAMI HAD TOM TO WOUTH I MIND.
# Expected:  JUST ASK TOM TO GIVE IT BACK.
# Match:     ❌
# Char Accuracy: 11/29 (37.9%)
#
# --- Case 156760 ---
# Input:     GTQPGZY
# Decrypted: CYCLING
# Expected:  NIAGARA
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 52259 ---
# Input:     DSBW
# Decrypted: WIFI
# Expected:  OVEN
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 310548 ---
# Input:     PATG IOWM BB BTYHNYLYV.
# Decrypted: THIS ROAD IS TERRIBITY.
# Expected:  THIS VIEW IS FANTASTIC.
# Match:     ❌
# Char Accuracy: 10/23 (43.5%)
#
# --- Case 47327 ---
# Input:     QXGENFCVX
# Decrypted: WEBMASTER
# Expected:  LITHUANIA
# Match:     ❌
# Char Accuracy: 0/9 (0.0%)
#
# --- Case 131215 ---
# Input:     A WM UZ DG PO QLOAO.
# Decrypted: A PAY LOT OF MYNUMS.
# Expected:  I AM TO GO TO PARIS.
# Match:     ❌
# Char Accuracy: 3/20 (15.0%)
#
# --- Case 193087 ---
# Input:     IYJEO QNZKAMT QKDXG UII X JHXN GV JEH VGVCZ.
# Decrypted: FALS OTILEAND THANK YOU TO HAV TO BE MYNIES.
# Expected:  GABOR NOTICED THERE WAS A GIRL IN THE WATER.
# Match:     ❌
# Char Accuracy: 11/44 (25.0%)
#
# --- Case 283230 ---
# Input:     Q XGMFXL MZTP FWQC RSQ BWTRS.
# Decrypted: I BOUGHT THIS BOOK FOR YEARS.
# Expected:  I SHOULD HAVE TOLD THE TRUTH.
# Match:     ❌
# Char Accuracy: 8/29 (27.6%)
#
# --- Case 49723 ---
# Input:     B KSGTXH MYLLWNI AST.
# Decrypted: I ALMOST SLAPPED TOM.
# Expected:  I REGRET KISSING HER.
# Match:     ❌
# Char Accuracy: 6/21 (28.6%)
#
# Full results saved to /content/drive/MyDrive/inference_vigenere_100_vanilla.xlsx
#
# === Final Summary ===
# Full-match accuracy: 0/4000
# Character-level accuracy: 36935/113455 (32.55%)
