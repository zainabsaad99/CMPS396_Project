# %%
import torch
import torch.nn as nn
import math
import pandas as pd
import string
import numpy as np
from tqdm import tqdm

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# --- Vocabulary Class ---
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        all_chars = list(string.printable)
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        if isinstance(text, float):  # Handle NaN values
            text = str(text)
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# --- Transformer Model ---
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))
        attn_probs = torch.softmax(scores, dim=-1)
        return torch.matmul(attn_probs, V)

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        return self.W_o(self.combine_heads(attn_output))

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super().__init__()
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm2(x + self.dropout(ff_output))

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm3(x + self.dropout(ff_output))

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask
        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        return self.fc(dec_output)

# --- Inference Functions ---
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        return vocab.decode(target[0].cpu().numpy())

def process_and_print_results(model, test_file, vocab, max_length, device, num_samples=4000):
    try:
        df = pd.read_excel(test_file) if test_file.endswith('.xlsx') else pd.read_csv(test_file)
    except Exception as e:
        print(f"Error loading test file: {e}")
        return None

    if len(df) > num_samples:
        df = df.sample(n=num_samples, random_state=42)

    results = []
    total_correct = 0
    total_chars_correct = 0
    total_chars = 0

    print("\n=== Starting Inference ===")
    print(f"Processing {len(df)} test cases...\n")

    for idx, row in df.iterrows():
        try:
            input_text = str(row['input'])
            expected = str(row['output'])

            # Decrypt the text
            decrypted = decrypt_text(model, input_text, vocab, max_length, device)
            decrypted_clean = decrypted.replace('<SOS>', '').replace('<EOS>', '').strip()

            # Calculate metrics
            full_match = decrypted_clean == expected
            total_correct += int(full_match)

            min_len = min(len(decrypted_clean), len(expected))
            char_matches = sum(1 for a, b in zip(decrypted_clean[:min_len], expected[:min_len]) if a == b)
            total_chars_correct += char_matches
            total_chars += max(len(decrypted_clean), len(expected))

            # Print detailed results for each case
            print(f"\n--- Case {idx+1} ---")
            print(f"Input:     {input_text}")
            print(f"Decrypted: {decrypted_clean}")
            print(f"Expected:  {expected}")
            print(f"Match:     {'✅' if full_match else '❌'}")
            print(f"Char Accuracy: {char_matches}/{max(len(decrypted_clean), len(expected))} ({(char_matches/max(len(decrypted_clean), len(expected)))*100:.1f}%)")

            results.append({
                'Case #': idx+1,
                'Input': input_text,
                'Decrypted': decrypted_clean,
                'Expected': expected,
                'Full Match': 'Yes' if full_match else 'No',
                'Char Matches': f"{char_matches}/{max(len(decrypted_clean), len(expected))}",
                'Char Accuracy': f"{(char_matches/max(len(decrypted_clean), len(expected)))*100:.2f}%"
            })

        except Exception as e:
            print(f"\nError processing case {idx+1}: {e}")
            continue

    # Create results DataFrame
    results_df = pd.DataFrame(results)

    # Add summary
    full_acc = (total_correct/len(results))*100 if results else 0
    char_acc = (total_chars_correct/total_chars)*100 if total_chars > 0 else 0

    summary = pd.DataFrame([{
        'Case #': 'SUMMARY',
        'Input': f"Total Cases: {len(results)}",
        'Decrypted': f"Full Accuracy: {full_acc:.2f}%",
        'Expected': f"Char Accuracy: {char_acc:.2f}%",
        'Full Match': f"{total_correct}/{len(results)}",
        'Char Matches': f"{total_chars_correct}/{total_chars}",
        'Char Accuracy': f"{char_acc:.2f}%"
    }])

    return pd.concat([results_df, summary], ignore_index=True)

# --- Main Execution ---
if __name__ == "__main__":
    # Configuration - UPDATE THESE PATHS
    MODEL_PATH = '/content/drive/MyDrive/mono_vanilla_one.pth'
    TEST_FILE = '/content/Full_testing_vigenere_one.xlsx'
    OUTPUT_FILE = '/content/drive/MyDrive/inference_vigenere_one_vanilla.xlsx'
    MAX_LENGTH = 256

    # Initialize vocabulary and model
    vocab = Vocabulary()
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=8,
        num_layers=6,
        d_ff=256,
        max_seq_length=MAX_LENGTH,
        dropout=0.1125331367392462
    ).to(device)

    # Load trained model
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
        model.eval()
        print("Model loaded successfully")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    # Process test cases and print all results
    results = process_and_print_results(model, TEST_FILE, vocab, MAX_LENGTH, device)

    # Save to Excel
    if results is not None:
        try:
            results.to_excel(OUTPUT_FILE, index=False)
            print(f"\nFull results saved to {OUTPUT_FILE}")

            # Print final summary
            print("\n=== Final Summary ===")
            print(f"Full-match accuracy: {results.iloc[-1]['Full Match']}")
            print(f"Character-level accuracy: {results.iloc[-1]['Char Matches']} ({results.iloc[-1]['Char Accuracy']})")
        except Exception as e:
            print(f"\nError saving results: {e}")
    else:
        print("\nNo results were generated")
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected:  SHE SPEAKS PROPER BERBER.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3288 ---
# Input:     GZKB GM B GQEW OFAOTY RBJ SLJYOYEF.
# Decrypted: THAT IS A MERE EXCUSE FOR IDLENESS.
# Expected:  THAT IS A MERE EXCUSE FOR IDLENESS.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3289 ---
# Input:     FSWQ UUUWTRV RQQ JBLQALC OM NILAHYR I BCWIDPW.
# Decrypted: SAMI WATCHED HIS PARENTS GO THROUGH A DIVORCE.
# Expected:  SAMI WATCHED HIS PARENTS GO THROUGH A DIVORCE.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 3290 ---
# Input:     V SW EFCUY.
# Decrypted: I AM WHITE.
# Expected:  I AM WHITE.
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3291 ---
# Input:     V DSSC NIY ZRO MIPJFN.
# Decrypted: I LIKE THE NEW CARPET.
# Expected:  I LIKE THE NEW CARPET.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3292 ---
# Input:     XSLGJCF CE N KZMACBF BYSMM.
# Decrypted: KABYLIE IS A SPECIAL PLACE.
# Expected:  KABYLIE IS A SPECIAL PLACE.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3293 ---
# Input:     AGBEYS
# Decrypted: NORWAY
# Expected:  NORWAY
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3294 ---
# Input:     ASDCPY JM OHDDCPY.
# Decrypted: NATURE IS CULTURE.
# Expected:  NATURE IS CULTURE.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3295 ---
# Input:     VL SA LIU YMFQ DW KUTNQE WXOJCTB.
# Decrypted: IT IS NOT EASY TO MASTER ENGLISH.
# Expected:  IT IS NOT EASY TO MASTER ENGLISH.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3296 ---
# Input:     LGEZ YHTQQE AC MLNJLQYQ EVQUUCESSMBMLZ.
# Decrypted: YOUR ANSWER IS ENTIRELY UNSATISFACTORY.
# Expected:  YOUR ANSWER IS ENTIRELY UNSATISFACTORY.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3297 ---
# Input:     FSWQ EUWY TVK LZMNIYD FGWM AUOXK.
# Decrypted: SAMI GAVE HIS BROTHER SOME CANDY.
# Expected:  SAMI GAVE HIS BROTHER SOME CANDY.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3298 ---
# Input:     NDQMPCB UZQ URQLU GIDZWN I LYX WAZHKVW.
# Decrypted: ALGERIA AND CHINA FORMED A NEW COMPANY.
# Expected:  ALGERIA AND CHINA FORMED A NEW COMPANY.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3299 ---
# Input:     OY
# Decrypted: BG
# Expected:  BG
# Match:     ✅
# Char Accuracy: 2/2 (100.0%)
#
# --- Case 3300 ---
# Input:     QSFM
# Decrypted: DAVE
# Expected:  DAVE
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3301 ---
# Input:     RNOV
# Decrypted: EVEN
# Expected:  EVEN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3302 ---
# Input:     PMWCJUUCHR
# Decrypted: CUMULATIVE
# Expected:  CUMULATIVE
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3303 ---
# Input:     ZSDQLA
# Decrypted: MATING
# Expected:  MATING
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3304 ---
# Input:     UAC MWYTCSUL SA ZUE.
# Decrypted: HIS EYESIGHT IS BAD.
# Expected:  HIS EYESIGHT IS BAD.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 3305 ---
# Input:     MABQ EIU FAFL DPCLF.
# Decrypted: ZIRI GOT LOST THERE.
# Expected:  ZIRI GOT LOST THERE.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 3306 ---
# Input:     OSX PGG.
# Decrypted: BAN HIM.
# Expected:  BAN HIM.
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3307 ---
# Input:     GGW AYCE BQ GZYCEBU NTNL WIPS NCSUL XMCX UI PB LRIR NPXML.
# Decrypted: TOM SAID HE THOUGHT THAT MARY MIGHT NEED TO DO THAT TODAY.
# Expected:  TOM SAID HE THOUGHT THAT MARY MIGHT NEED TO DO THAT TODAY.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 3308 ---
# Input:     EWKLQ
# Decrypted: READS
# Expected:  READS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3309 ---
# Input:     FESBF
# Decrypted: SMITH
# Expected:  SMITH
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3310 ---
# Input:     V ZKBC NIY INQ S TMIL.
# Decrypted: I HATE THE WAY I LOOK.
# Expected:  I HATE THE WAY I LOOK.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3311 ---
# Input:     NHZMYLBHOR
# Decrypted: APPEARANCE
# Expected:  APPEARANCE
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3312 ---
# Input:     PDKAQYT MFNJDMB CO IOGGLMP.
# Decrypted: CLASSES STARTED IN OCTOBER.
# Expected:  CLASSES STARTED IN OCTOBER.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3313 ---
# Input:     YWD PGG EI FUSD.
# Decrypted: LET HIM DO THAT.
# Expected:  LET HIM DO THAT.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 3314 ---
# Input:     ZAQZYNJIZ
# Decrypted: MIGRATION
# Expected:  MIGRATION
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3315 ---
# Input:     EWMWPXJHSF
# Decrypted: RECORDINGS
# Expected:  RECORDINGS
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3316 ---
# Input:     UW WIBY NY RRWV TGEF MGPZ KV GXJIF.
# Decrypted: HE MADE ME FEEL LIKE SUCH AN IDIOT.
# Expected:  HE MADE ME FEEL LIKE SUCH AN IDIOT.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3317 ---
# Input:     GGW KJITYP GZO LMIS KGVWDTW.
# Decrypted: TOM CLOSED THE DOOR QUIETLY.
# Expected:  TOM CLOSED THE DOOR QUIETLY.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 3318 ---
# Input:     UW CBYLUYP JSVSGHH MXBOVG RIXUDQK DPC BPOER.
# Decrypted: HE STARTED WALKING SLOWLY TOWARDS THE HOUSE.
# Expected:  HE STARTED WALKING SLOWLY TOWARDS THE HOUSE.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3319 ---
# Input:     GGW BMFE GQ ZSBG GM TURR.
# Decrypted: TOM TOLD ME MARY IS SAFE.
# Expected:  TOM TOLD ME MARY IS SAFE.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3320 ---
# Input:     BFO WD NIY DRWNA MZ NS TNJWWLCDU TNK QWLY GFMG.
# Decrypted: ONE OF THE REEDS OF MY HARMONICA HAS GONE FLAT.
# Expected:  ONE OF THE REEDS OF MY HARMONICA HAS GONE FLAT.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 3321 ---
# Input:     FSWQ UUT MONFXQLA UBQ OSMSWUSX.
# Decrypted: SAMI WAS SCANNING THE BACKYARD.
# Expected:  SAMI WAS SCANNING THE BACKYARD.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 3322 ---
# Input:     VL SA NFVLMY.
# Decrypted: IT IS PLURAL.
# Expected:  IT IS PLURAL.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 3323 ---
# Input:     GZOAC USY FUW GWPXT NA YWKZL.
# Decrypted: THESE ARE THE WORDS TO LEARN.
# Expected:  THESE ARE THE WORDS TO LEARN.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3324 ---
# Input:     BMB UCUOM MEW VQKCUYP.
# Decrypted: OUR MEANS ARE LIMITED.
# Expected:  OUR MEANS ARE LIMITED.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3325 ---
# Input:     OGYBF
# Decrypted: BOOTH
# Expected:  BOOTH
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3326 ---
# Input:     YGBMLTP QMF LBGGHH NA CSI UCFJMEN.
# Decrypted: LORENZO WAS TRYING TO PAY MELISSA.
# Expected:  LORENZO WAS TRYING TO PAY MELISSA.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3327 ---
# Input:     JAMSCX
# Decrypted: WICKED
# Expected:  WICKED
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3328 ---
# Input:     BDOO YHE LUZS OIAB TUF VF NQDZFLQAL BWMGT.
# Decrypted: OLEG AND RIMA EACH SAT IN DIFFERENT ROOMS.
# Expected:  OLEG AND RIMA EACH SAT IN DIFFERENT ROOMS.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 3329 ---
# Input:     YWD UC XP UXY GP BFY UUXXAXO.
# Decrypted: LET ME DO ALL OF THE TALKING.
# Expected:  LET ME DO ALL OF THE TALKING.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3330 ---
# Input:     SSVTGHH
# Decrypted: FALLING
# Expected:  FALLING
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3331 ---
# Input:     GZBMYX
# Decrypted: THREAD
# Expected:  THREAD
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3332 ---
# Input:     GGW ANYON FUJOM BUZM UA LRM FITJUGSV.
# Decrypted: TOM SPENT THREE DAYS IN THE HOSPITAL.
# Expected:  TOM SPENT THREE DAYS IN THE HOSPITAL.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3333 ---
# Input:     V LRWSAIN FUSD GMO FHVBQOL QQJGYVFQ.
# Decrypted: I THOUGHT THAT YOU ENJOYED SWIMMING.
# Expected:  I THOUGHT THAT YOU ENJOYED SWIMMING.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 3334 ---
# Input:     QSX BPCFX FB VSARLBWF GZO XMFJWQ GG VMR FJHPN WCKYJF.
# Decrypted: DAN TRIED TO DISTRACT THE POLICE TO LET LINDA ESCAPE.
# Expected:  DAN TRIED TO DISTRACT THE POLICE TO LET LINDA ESCAPE.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 3335 ---
# Input:     V ZKL RLPONYW PQLXJHS PMBBYCOM FB EKBAB POD FGPI.
# Decrypted: I HAD TROUBLE FINDING CURTAINS TO MATCH OUR SOFA.
# Expected:  I HAD TROUBLE FINDING CURTAINS TO MATCH OUR SOFA.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3336 ---
# Input:     GGW QLPJNQQ KYUC ZSCQAVC WTYS ZAE VSVLYS.
# Decrypted: TOM INVITED SOME FRIENDS OVER FOR DINNER.
# Expected:  TOM INVITED SOME FRIENDS OVER FOR DINNER.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 3337 ---
# Input:     GZOAC QFLQ VFNMCX HFMQ LSLGHHM AS YBMYN KIK.
# Decrypted: THESE WERE INDEED GLAD TIDINGS OF GREAT JOY.
# Expected:  THESE WERE INDEED GLAD TIDINGS OF GREAT JOY.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3338 ---
# Input:     WSWMQ DVMF GJKVQZFLDRV KTJ BJM BBKCMQMJIZF LY IKUOXM.
# Decrypted: JAMES JUST TRANSFERRED ALL HIS POSSESSIONS TO AMANDA.
# Expected:  JAMES JUST TRANSFERRED ALL HIS POSSESSIONS TO AMANDA.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 3339 ---
# Input:     FGWMZIES ONEO.
# Decrypted: SOMEBODY CAME.
# Expected:  SOMEBODY CAME.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 3340 ---
# Input:     NEI
# Decrypted: AMY
# Expected:  AMY
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 3341 ---
# Input:     GGW VCYEM FB UYUC BFLQ.
# Decrypted: TOM NEEDS TO COME HERE.
# Expected:  TOM NEEDS TO COME HERE.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3342 ---
# Input:     NX
# Decrypted: AF
# Expected:  AF
# Match:     ✅
# Char Accuracy: 2/2 (100.0%)
#
# --- Case 3343 ---
# Input:     GGW QQ MP MQG AX PGM XUKF.
# Decrypted: TOM IS SO SET IN HIS WAYS.
# Expected:  TOM IS SO SET IN HIS WAYS.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3344 ---
# Input:     YSEVABFX
# Decrypted: LAUNCHED
# Expected:  LAUNCHED
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3345 ---
# Input:     GWMPLIMISVUKT NLPADRKC PYM NUPR BKXYH XBMG KRM GM.
# Decrypted: TECHNOLOGICAL PROGRESS HAS MADE JAPAN WHAT SHE IS.
# Expected:  TECHNOLOGICAL PROGRESS HAS MADE JAPAN WHAT SHE IS.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 3346 ---
# Input:     V LRQLE UIY ZAQPR BBPQ FGWM EIPX UQWKA.
# Decrypted: I THINK TOM MIGHT HAVE SOME GOOD IDEAS.
# Expected:  I THINK TOM MIGHT HAVE SOME GOOD IDEAS.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3347 ---
# Input:     AGLWBS FRBRUDMB UOSFUAXO DLPG YR.
# Decrypted: NOBODY EXPECTED ANYTHING FROM ME.
# Expected:  NOBODY EXPECTED ANYTHING FROM ME.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3348 ---
# Input:     GZO XPYTCPRFD WD GBFU VK DPC SPOZTWCB FYBX AS KDIRY JH FUW GWPFE.
# Decrypted: THE PRESIDENT OF MALI IS THE YOUNGEST HEAD OF STATE IN THE WORLD.
# Expected:  THE PRESIDENT OF MALI IS THE YOUNGEST HEAD OF STATE IN THE WORLD.
# Match:     ✅
# Char Accuracy: 65/65 (100.0%)
#
# --- Case 3349 ---
# Input:     FZO MLDPSE USXOGHH IGG OSBF BJG.
# Decrypted: SHE ENJOYS HANGING OUT WITH HIM.
# Expected:  SHE ENJOYS HANGING OUT WITH HIM.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3350 ---
# Input:     GZOG KCHBF JSXB WIV NA UWVX RBFG.
# Decrypted: THEY MIGHT WANT YOU TO HELP THEM.
# Expected:  THEY MIGHT WANT YOU TO HELP THEM.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3351 ---
# Input:     UMLJJY IUE SMXLYGFHFNDVG ABBHSRV YCP OOXQEKDILXJHS BX DPC WPMYBK.
# Decrypted: HUBBLE HAS FUNDAMENTALLY CHANGED OUR UNDERSTANDING OF THE COSMOS.
# Expected:  HUBBLE HAS FUNDAMENTALLY CHANGED OUR UNDERSTANDING OF THE COSMOS.
# Match:     ✅
# Char Accuracy: 65/65 (100.0%)
#
# --- Case 3352 ---
# Input:     GGW QQ U NOOU TOBRYS MMKGZPMHJMF GZKV KUSS.
# Decrypted: TOM IS A MUCH BETTER SAXOPHONIST THAN MARY.
# Expected:  TOM IS A MUCH BETTER SAXOPHONIST THAN MARY.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3353 ---
# Input:     UAC BGY HIQF OOTJ QJNT UAC ASCU.
# Decrypted: HIS TIE GOES WELL WITH HIS SUIT.
# Expected:  HIS TIE GOES WELL WITH HIS SUIT.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3354 ---
# Input:     MABQ UUT WMCLSDYNFX NL LRM ELFYZRJI WD NIUF SGBMQN.
# Decrypted: ZIRI WAS CAPTIVATED BY THE GREENERY OF THAT FOREST.
# Expected:  ZIRI WAS CAPTIVATED BY THE GREENERY OF THAT FOREST.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3355 ---
# Input:     EWKL RBF KGESX IEUJH.
# Decrypted: READ THE QURAN AGAIN.
# Expected:  READ THE QURAN AGAIN.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3356 ---
# Input:     NDWWQN BFX ZQ BMAISXE JWBM GGQIDGWN NPIN AQEEKVW.
# Decrypted: ALMOST ALL MY RECORDS WERE IMPORTED FROM GERMANY.
# Expected:  ALMOST ALL MY RECORDS WERE IMPORTED FROM GERMANY.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3357 ---
# Input:     NDYVE
# Decrypted: ALONG
# Expected:  ALONG
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3358 ---
# Input:     V VSXNYE CZGG RQQ VPIW.
# Decrypted: I DIPPED INTO HIS BOOK.
# Expected:  I DIPPED INTO HIS BOOK.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3359 ---
# Input:     GZOG FCSYP N HBWDYTMUBFKT ABPLQBYBINBFL IVLRWSN DIZFMVBGHH NTR VSZCWUID.
# Decrypted: THEY HIRED A PROFESSIONAL CHOREOGRAPHER WITHOUT CONSUDRYNG THE DIRECTOR.
# Expected:  THEY HIRED A PROFESSIONAL CHOREOGRAPHER WITHOUT CONSULTING THE DIRECTOR.
# Match:     ❌
# Char Accuracy: 69/72 (95.8%)
#
# --- Case 3360 ---
# Input:     JZKB WIV XUQ OSTJ MBPQ ZW DPC NSIGODO WD XPCZT AD.
# Decrypted: WHAT YOU DID WILL SAVE ME THE TROUBLE OF DOING IT.
# Expected:  WHAT YOU DID WILL SAVE ME THE TROUBLE OF DOING IT.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 3361 ---
# Input:     JW RIB U MIF BX CXMHUUZRGEA MZGYDF XBWK NIYY.
# Decrypted: WE HAD A LOT OF SPONTANEOUS OFFERS FROM THEM.
# Expected:  WE HAD A LOT OF SPONTANEOUS OFFERS FROM THEM.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 3362 ---
# Input:     GZSA UISX UF KZMJFFX IVLR I FSQBQA.
# Decrypted: THIS WORD IS SPELLED WITH A HYPHEN.
# Expected:  THIS WORD IS SPELLED WITH A HYPHEN.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3363 ---
# Input:     GGW KYFMYP SJYU ZITNAA.
# Decrypted: TOM CALLED FROM BOSTON.
# Expected:  TOM CALLED FROM BOSTON.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3364 ---
# Input:     ZGFM
# Decrypted: MOVE
# Expected:  MOVE
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3365 ---
# Input:     GGW BFIVATG EKZW QBM XLAXO.
# Decrypted: TOM THOUGHT MARY WAS LYING.
# Expected:  TOM THOUGHT MARY WAS LYING.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3366 ---
# Input:     CDKV
# Decrypted: PLAN
# Expected:  PLAN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3367 ---
# Input:     LGE AFIVFP BHOV YFM NTR OSVBIXM.
# Decrypted: YOU SHOULD OPEN ALL THE WINDOWS.
# Expected:  YOU SHOULD OPEN ALL THE WINDOWS.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3368 ---
# Input:     GZO KMOONDL AC KMPFLQQ OSBF MOII.
# Decrypted: THE COUNTRY IS COVERED WITH SNOW.
# Expected:  THE COUNTRY IS COVERED WITH SNOW.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3369 ---
# Input:     VNKV HOTN XVKDMLYE NA NFXI.
# Decrypted: IVAN JUST LISTENED TO ANNA.
# Expected:  IVAN JUST LISTENED TO ANNA.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3370 ---
# Input:     EWWIPET
# Decrypted: REMARKS
# Expected:  REMARKS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3371 ---
# Input:     FUYCR
# Decrypted: SCOUT
# Expected:  SCOUT
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3372 ---
# Input:     YAQPRYS
# Decrypted: LIGHTER
# Expected:  LIGHTER
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3373 ---
# Input:     V UYUKOUY FB KMPMIM VK GJKQL UOX NHK.
# Decrypted: I COMMUTE TO SCHOOL BY TRAIN AND BUS.
# Expected:  I COMMUTE TO SCHOOL BY TRAIN AND BUS.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3374 ---
# Input:     LSXVG CT HAG JOIJFZ LQYAQQMOT.
# Decrypted: YANNI IS NOT REALLY RELIGIOUS.
# Expected:  YANNI IS NOT REALLY RELIGIOUS.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3375 ---
# Input:     VL SA CUUCZT.
# Decrypted: IT IS EATING.
# Expected:  IT IS EATING.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 3376 ---
# Input:     PGMSPIBWTRK SV EYSGMAQ KZC NIIGTZD BM VF YJGAXKR.
# Decrypted: COCKROACHES IN GERMANY ARE THOUGHT TO BE EXTINCT.
# Expected:  COCKROACHES IN GERMANY ARE THOUGHT TO BE EXTINCT.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3377 ---
# Input:     YSMS
# Decrypted: LACK
# Expected:  LACK
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3378 ---
# Input:     GGW BMFE GMEQ DPYN TBQ FZYCJX ROUG HBMRYOXUAY DW ZY BHSEQ.
# Decrypted: TOM TOLD MARY THAT SHE SHOULD QUIT PRETENDING TO BE ANGRY.
# Expected:  TOM TOLD MARY THAT SHE SHOULD QUIT PRETENDING TO BE ANGRY.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 3379 ---
# Input:     FSWQ YHE FMLDK ECLF BMIAXO QYY CZ GZO KPIXX.
# Decrypted: SAMI AND LAYLA WERE HAVING SEX IN THE CROWD.
# Expected:  SAMI AND LAYLA WERE HAVING SEX IN THE CROWD.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3380 ---
# Input:     FSQMK
# Decrypted: SAGEM
# Expected:  SAGEM
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3381 ---
# Input:     GGW IQEFX YNJI EFUU MTR OKA NFBHZVFQ BM XP.
# Decrypted: TOM ASKED MARY WHAT SHE WAS PLANNING TO DO.
# Expected:  TOM ASKED MARY WHAT SHE WAS PLANNING TO DO.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3382 ---
# Input:     FZO OYPF GQ PSXLW.
# Decrypted: SHE GAVE ME CANDY.
# Expected:  SHE GAVE ME CANDY.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3383 ---
# Input:     GGW ILX NUDL SMBSUMFK SAQCPYE CF BMD JW NIYYFWVDCM.
# Decrypted: TOM AND MARY ACTUALLY FIGURED IT OUT BY THEMSELVES.
# Expected:  TOM AND MARY ACTUALLY FIGURED IT OUT BY THEMSELVES.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3384 ---
# Input:     ZQ NWE QBM EBMXL YMMYQC.
# Decrypted: MY DOG WAS SOUND ASLEEP.
# Expected:  MY DOG WAS SOUND ASLEEP.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 3385 ---
# Input:     V SW I KYNVQE GP BFY GLQAUR KMGNOZVKD XYLUS.
# Decrypted: I AM A MEMBER OF THE FRENCH COMMUNIST PARTY.
# Expected:  I AM A MEMBER OF THE FRENCH COMMUNIST PARTY.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3386 ---
# Input:     V HEB RBF EQL AX BFY EIAE SXL ROSHQQ AD.
# Decrypted: I PUT THE KEY IN THE DOOR AND TURNED IT.
# Expected:  I PUT THE KEY IN THE DOOR AND TURNED IT.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 3387 ---
# Input:     FSWQ YFXUKF ZKA YH FROHKO.
# Decrypted: SAMI ALWAYS HAS AN EXCUSE.
# Expected:  SAMI ALWAYS HAS AN EXCUSE.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3388 ---
# Input:     GZKB GM B ZMYKO LGWIIFBEI.
# Decrypted: THAT IS A FALSE DICHOTOMY.
# Expected:  THAT IS A FALSE DICHOTOMY.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3389 ---
# Input:     V LRQLE UBMG LYU UCMF NR KEANCDCAHK.
# Decrypted: I THINK THAT TOM WILL BE SUSPICIOUS.
# Expected:  I THINK THAT TOM WILL BE SUSPICIOUS.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 3390 ---
# Input:     NVCT
# Decrypted: ADSL
# Expected:  ADSL
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3391 ---
# Input:     UM
# Decrypted: HU
# Expected:  HU
# Match:     ✅
# Char Accuracy: 2/2 (100.0%)
#
# --- Case 3392 ---
# Input:     V ZYXC C IUHR LRM ABBHOR LY LM NIUF.
# Decrypted: I HOPE I HAVE THE CHANCE TO DO THAT.
# Expected:  I HOPE I HAVE THE CHANCE TO DO THAT.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 3393 ---
# Input:     V ZKL KS PHXL KYV BCF IR PSXKCL.
# Decrypted: I HAD MY ONLY SON DIE OF CANCER.
# Expected:  I HAD MY ONLY SON DIE OF CANCER.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3394 ---
# Input:     UW SA DLFY IVLR PGM NIZRQ.
# Decrypted: HE IS FREE WITH HIS MONEY.
# Expected:  HE IS FREE WITH HIS MONEY.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3395 ---
# Input:     GZSA YXNIZVLSWL CT QAELR ZCGFGNRJSVE.
# Decrypted: THIS ADMONITION IS WORTH REMEMBERING.
# Expected:  THIS ADMONITION IS WORTH REMEMBERING.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3396 ---
# Input:     AWVAMH
# Decrypted: NELSON
# Expected:  NELSON
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3397 ---
# Input:     V VSL GN GID UAW.
# Decrypted: I DID IT FOR HIM.
# Expected:  I DID IT FOR HIM.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 3398 ---
# Input:     UW GIQ U EUK YSDM.
# Decrypted: HE WAS A DAY LATE.
# Expected:  HE WAS A DAY LATE.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3399 ---
# Input:     V OYVBYS CR V UYCJX SYMYDI LM NIUF.
# Decrypted: I WONDER IF I COULD REALLY DO THAT.
# Expected:  I WONDER IF I COULD REALLY DO THAT.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3400 ---
# Input:     GWWX
# Decrypted: TEMP
# Expected:  TEMP
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3401 ---
# Input:     V ZKL RI SOZ NOKG DLPG QAJKOCX UIY.
# Decrypted: I HAD TO RUN AWAY FROM ENRAGED TOM.
# Expected:  I HAD TO RUN AWAY FROM ENRAGED TOM.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3402 ---
# Input:     FWOQLA BFX GZO NMIE IZ GZO BYVMY YNVO UC BVHSEQ.
# Decrypted: SEEING ALL THE FOOD ON THE TABLE MADE ME HUNGRY.
# Expected:  SEEING ALL THE FOOD ON THE TABLE MADE ME HUNGRY.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 3403 ---
# Input:     NEYVE NIY UANSBCX HOQFLC ECLF NAZ SXL KUSS.
# Decrypted: AMONG THE INVITED GUESTS WERE TOM AND MARY.
# Expected:  AMONG THE INVITED GUESTS WERE TOM AND MARY.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3404 ---
# Input:     XSVUYH XUE ESSACX BM M ZMCTGG.
# Decrypted: KALMAN WAS RAISED AS A MUSLIM.
# Expected:  KALMAN WAS RAISED AS A MUSLIM.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3405 ---
# Input:     QAFQQCPH
# Decrypted: DIVISION
# Expected:  DIVISION
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3406 ---
# Input:     YGYS UBBN FBE PWSHE OZQWB BFY CYP.
# Decrypted: LOOK WHAT TOM FOUND UNDER THE BED.
# Expected:  LOOK WHAT TOM FOUND UNDER THE BED.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3407 ---
# Input:     FZKSC
# Decrypted: SHAKE
# Expected:  SHAKE
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3408 ---
# Input:     GZO XYNJYZG OKA RLFUFRV PWP U GLMPLEZCX NUZQALTC.
# Decrypted: THE PATIENT WAS TREATED FOR A FRACTURED MANDIBLE.
# Expected:  THE PATIENT WAS TREATED FOR A FRACTURED MANDIBLE.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3409 ---
# Input:     GZSA RYB CE UGD.
# Decrypted: THIS TEA IS HOT.
# Expected:  THIS TEA IS HOT.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 3410 ---
# Input:     GZSA JCUNXR ZYCQY JM YL DYLECOA.
# Decrypted: THIS LITTLE HOUSE IS MY LODGING.
# Expected:  THIS LITTLE HOUSE IS MY LODGING.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3411 ---
# Input:     GGW TMPFM DBOSVE.
# Decrypted: TOM LOVES ROWING.
# Expected:  TOM LOVES ROWING.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 3412 ---
# Input:     V ZKBC NPG NRUKCQY SYMFGXA.
# Decrypted: I HATE TOM BECAUSE REASONS.
# Expected:  I HATE TOM BECAUSE REASONS.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3413 ---
# Input:     GGW XPUZYP GG QWB ZPL TRDZ.
# Decrypted: TOM PRAYED TO GOD FOR HELP.
# Expected:  TOM PRAYED TO GOD FOR HELP.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3414 ---
# Input:     GGW EYM TNMAVSVE UU NTR TKZ UBFH U JSVSCX JHFB LRM AFVV.
# Decrypted: TOM WAS STANDING AT THE BAR WHEN I WALKED INTO THE CLUB.
# Expected:  TOM WAS STANDING AT THE BAR WHEN I WALKED INTO THE CLUB.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 3415 ---
# Input:     V UOZRUJHXL ZYXC NPG INADA DIS GQ.
# Decrypted: I CERTAINLY HOPE TOM WAITS FOR ME.
# Expected:  I CERTAINLY HOPE TOM WAITS FOR ME.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3416 ---
# Input:     V EEAR JSIFRKD.
# Decrypted: I MUST PROTEST.
# Expected:  I MUST PROTEST.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 3417 ---
# Input:     QGXIRY
# Decrypted: DONATE
# Expected:  DONATE
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3418 ---
# Input:     GZO XMFJWQ GJKKIYE MMZA NWUH.
# Decrypted: THE POLICE TRACKED SAMI DOWN.
# Expected:  THE POLICE TRACKED SAMI DOWN.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3419 ---
# Input:     MABQ YHE LUZS RITY JMEHWC.
# Decrypted: ZIRI AND RIMA HAVE ISSUES.
# Expected:  ZIRI AND RIMA HAVE ISSUES.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3420 ---
# Input:     YWFMJM
# Decrypted: LEVELS
# Expected:  LEVELS
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3421 ---
# Input:     QG GPYN ZIGE XKBFYS MMLK.
# Decrypted: DO WHAT YOUR FATHER SAYS.
# Expected:  DO WHAT YOUR FATHER SAYS.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3422 ---
# Input:     GGW ARYBXURV RQKMFFR.
# Decrypted: TOM STEADIED HIMSELF.
# Expected:  TOM STEADIED HIMSELF.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3423 ---
# Input:     PADM
# Decrypted: CITE
# Expected:  CITE
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3424 ---
# Input:     UGZMDOMFK
# Decrypted: HOPEFULLY
# Expected:  HOPEFULLY
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3425 ---
# Input:     V ZKL LIUBUAY DW BI XCFU LRIR COWUQWXB.
# Decrypted: I HAD NOTHING TO DO WITH THAT INCIDENT.
# Expected:  I HAD NOTHING TO DO WITH THAT INCIDENT.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3426 ---
# Input:     GZO PMOTY INK FIAUON.
# Decrypted: THE HOUSE WAS VACANT.
# Expected:  THE HOUSE WAS VACANT.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3427 ---
# Input:     GGW ILX NUDL KKQB NIYK SWVB FOSN.
# Decrypted: TOM AND MARY SAID THEY FELT HURT.
# Expected:  TOM AND MARY SAID THEY FELT HURT.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3428 ---
# Input:     BJVMYHT
# Decrypted: ORLEANS
# Expected:  ORLEANS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3429 ---
# Input:     LSXVG NIIGTZD PC QBM MOGFM CPFLKOGNG CFTY.
# Decrypted: YANNI THOUGHT HE WAS ABOVE EVERYBODY ELSE.
# Expected:  YANNI THOUGHT HE WAS ABOVE EVERYBODY ELSE.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 3430 ---
# Input:     V CSAQ NIY SEGEVB VFHQNLR GMOS ZQRL.
# Decrypted: I KISS THE GROUND BENEATH YOUR FEET.
# Expected:  I KISS THE GROUND BENEATH YOUR FEET.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 3431 ---
# Input:     ZQ WIRB UYMPZOZ GM BGMMAXO.
# Decrypted: MY MATH TEACHER IS AMAZING.
# Expected:  MY MATH TEACHER IS AMAZING.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3432 ---
# Input:     V CXWU VFNFRJ DPYH UI NBJBWU GPHQL XBWK ZSCQAVC.
# Decrypted: I KNOW BETTER THAN TO BORROW MONEY FROM FRIENDS.
# Expected:  I KNOW BETTER THAN TO BORROW MONEY FROM FRIENDS.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 3433 ---
# Input:     BFO WD NIY RRDVWUM ZIG JWBM UCUB UF S PZGYOX AS ESVC.
# Decrypted: ONE OF THE FELLOWS YOU WERE WITH IS A FRIEND OF MINE.
# Expected:  ONE OF THE FELLOWS YOU WERE WITH IS A FRIEND OF MINE.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 3434 ---
# Input:     BFMM MH UBQ EGKL UY BLQ BFVG RQP GUYWC NPIN NTR JKDGHF QTRJO BFY IIDFWC IPY XUUGAXO.
# Decrypted: ONCE ON THE ROAD WE ARE ONLY TWO MILES FROM THE RAVINE WHERE THE ORSESS ARE WAITING.
# Expected:  ONCE ON THE ROAD WE ARE ONLY TWO MILES FROM THE RAVINE WHERE THE HORSES ARE WAITING.
# Match:     ❌
# Char Accuracy: 79/84 (94.0%)
#
# --- Case 3435 ---
# Input:     ODYKI
# Decrypted: BLOCK
# Expected:  BLOCK
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3436 ---
# Input:     JW KZC JSUOGAMIJFZ ZMZAVG.
# Decrypted: WE ARE PRACTICALLY FAMILY.
# Expected:  WE ARE PRACTICALLY FAMILY.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3437 ---
# Input:     FMZXMLUYDF GP BFY QLAWWMB QUZ CF JAVT EYOYDNLO JYXMS ZRWNMB DPVE NFN ZCMQYOG DYKYF TYZFADQTCUCQF.
# Decrypted: SUPPORTERS OF THE PROJECT SAY IT WILL GENERATE BADLY NEEDED JOBS AND RESPECT LOCIE SENNITIVITITIT.
# Expected:  SUPPORTERS OF THE PROJECT SAY IT WILL GENERATE BADLY NEEDED JOBS AND RESPECT LOCAL SENSITIVITIES.
# Match:     ❌
# Char Accuracy: 91/98 (92.9%)
#
# --- Case 3438 ---
# Input:     YWKAGHH
# Decrypted: LEASING
# Expected:  LEASING
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3439 ---
# Input:     QJOIKM NOEG TO JGAHYD GZKV DYBL.
# Decrypted: DREAMS MUST BE BIGEER THAN FEAR.
# Expected:  DREAMS MUST BE BIGGER THAN FEAR.
# Match:     ❌
# Char Accuracy: 31/32 (96.9%)
#
# --- Case 3440 ---
# Input:     GZO EYNFL UA LRM JULY DREKQLYE GGECI IDNFL FUW CBMLN.
# Decrypted: THE WATER IN THE LAKE REMAINED MURKY AFTER THE STORM.
# Expected:  THE WATER IN THE LAKE REMAINED MURKY AFTER THE STORM.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 3441 ---
# Input:     NKCWACBNQ
# Decrypted: ASSOCIATE
# Expected:  ASSOCIATE
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3442 ---
# Input:     GWOVQ
# Decrypted: TEENS
# Expected:  TEENS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3443 ---
# Input:     GMBBJY
# Decrypted: TURTLE
# Expected:  TURTLE
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3444 ---
# Input:     V DSSC MLCUAY.
# Decrypted: I LIKE SKIING.
# Expected:  I LIKE SKIING.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 3445 ---
# Input:     USBLCL
# Decrypted: HARDER
# Expected:  HARDER
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3446 ---
# Input:     GZKB UUT U CHWCBGIO NAZ KOMKYE LQNVI NML.
# Decrypted: THAT WAS A QUESTION TOM SEEMED READY FOR.
# Expected:  THAT WAS A QUESTION TOM SEEMED READY FOR.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 3447 ---
# Input:     EGLMPN FRBYSSVCX UBMG EKZRBB QMF ZSA AIVMUA.
# Decrypted: ROBERT EXPLAINED THAT MARTHA WAS HIS COUSIN.
# Expected:  ROBERT EXPLAINED THAT MARTHA WAS HIS COUSIN.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3448 ---
# Input:     GGW VCYEM EBEO ZMJF.
# Decrypted: TOM NEEDS SOME ROPE.
# Expected:  TOM NEEDS SOME ROPE.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 3449 ---
# Input:     UW CWKYUCYRK ZTYST NQAFSA UCUB TRJ.
# Decrypted: HE SOMETIMES PLAYS TENNIS WITH HER.
# Expected:  HE SOMETIMES PLAYS TENNIS WITH HER.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3450 ---
# Input:     YAOA YLF NTR OOINIOM AS LRM CPJF.
# Decrypted: LIES ARE THE WEAPONS OF THE EVIL.
# Expected:  LIES ARE THE WEAPONS OF THE EVIL.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3451 ---
# Input:     GZOG YLF NQNURQLA CYDOWB IR U OYMETI AABPIX.
# Decrypted: THEY ARE TEACHING BERBER AT A NEARBY SCHOOL.
# Expected:  THEY ARE TEACHING BERBER AT A NEARBY SCHOOL.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3452 ---
# Input:     GGW EYM BFDRSNG YMMYQC ORML C HIF UGWM.
# Decrypted: TOM WAS ALREADY ASLEEP WHEN I GOT HOME.
# Expected:  TOM WAS ALREADY ASLEEP WHEN I GOT HOME.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3453 ---
# Input:     PSVU
# Decrypted: CALM
# Expected:  CALM
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3454 ---
# Input:     ZGYVJCHBF JGX BFY PMONJ PWP VFMF CAMBSLF.
# Decrypted: MOONLIGHT WON THE OSCAR FOR BEST PICTURE.
# Expected:  MOONLIGHT WON THE OSCAR FOR BEST PICTURE.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 3455 ---
# Input:     GZOG QUJX FUWI NCFU ADRSD.
# Decrypted: THEY SAID THEY FELT GREAT.
# Expected:  THEY SAID THEY FELT GREAT.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3456 ---
# Input:     GZOG NIVLQQ LRMKMFFHRK NZGHLM.
# Decrypted: THEY POURED THEMSELVES DRINKS.
# Expected:  THEY POURED THEMSELVES DRINKS.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3457 ---
# Input:     V KWMJFFX NNUYV.
# Decrypted: I SMELLED BACON.
# Expected:  I SMELLED BACON.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 3458 ---
# Input:     HKNI
# Decrypted: USDA
# Expected:  USDA
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3459 ---
# Input:     FSWQ UUT U ERUBMRCWY YNF.
# Decrypted: SAMI WAS A SECRETIVE MAN.
# Expected:  SAMI WAS A SECRETIVE MAN.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3460 ---
# Input:     GGW QQ NSSUAY DW QYMF TVK YTB WBL.
# Decrypted: TOM IS TRYING TO SELL HIS OLD CAR.
# Expected:  TOM IS TRYING TO SELL HIS OLD CAR.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3461 ---
# Input:     NLDZYWUCAA
# Decrypted: ATTRACTION
# Expected:  ATTRACTION
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3462 ---
# Input:     UW MISAIN M TDSUNMF IR GZO LPCWYD NK DPC NSUUA JKKCX QUEG.
# Decrypted: HE CAUGHT A GLIMPSE OF THE DRIVER AS THE TRAIN RACED PAST.
# Expected:  HE CAUGHT A GLIMPSE OF THE DRIVER AS THE TRAIN RACED PAST.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 3463 ---
# Input:     BJNMP
# Decrypted: ORDER
# Expected:  ORDER
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3464 ---
# Input:     FAD WTYS BQEW.
# Decrypted: SIT OVER HERE.
# Expected:  SIT OVER HERE.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 3465 ---
# Input:     V DSSC QJHFRJ LMRNFL FUSX ASGNYD.
# Decrypted: I LIKE WINTER BETTER THAN SUMMER.
# Expected:  I LIKE WINTER BETTER THAN SUMMER.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3466 ---
# Input:     V EEAR JSYBNJO NML UBQ RPKU.
# Decrypted: I MUST PREPARE FOR THE EXAM.
# Expected:  I MUST PREPARE FOR THE EXAM.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 3467 ---
# Input:     VFDMPFJHSHS RIQ ZJPQ BDNMP MJMFRJC.
# Decrypted: INTERLINGUA HAS FIVE OLDER SISTERS.
# Expected:  INTERLINGUA HAS FIVE OLDER SISTERS.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3468 ---
# Input:     QJIMP
# Decrypted: DRYER
# Expected:  DRYER
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3469 ---
# Input:     NDQMPCB HQRVC BM COWDRSCM GNT UEFWBBGPFHQFK SV RBF LQTAYV.
# Decrypted: ALGERIA NEEDS TO INCREASE ITS ASSERTIVENESS IN THE REGION.
# Expected:  ALGERIA NEEDS TO INCREASE ITS ASSERTIVENESS IN THE REGION.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 3470 ---
# Input:     GZOG QBVN FUWSZ KIVNTF.
# Decrypted: THEY SHUT THEIR MOUTHS.
# Expected:  THEY SHUT THEIR MOUTHS.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3471 ---
# Input:     SJSMLXT
# Decrypted: FRIENDS
# Expected:  FRIENDS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3472 ---
# Input:     MABQ GM KOEG SC LYHHYDBMC IQ BF QMF TONMLF.
# Decrypted: ZIRI IS JUST AS DANGEROUS AS HE WAS BEFORE.
# Expected:  ZIRI IS JUST AS DANGEROUS AS HE WAS BEFORE.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3473 ---
# Input:     UW DWME POF N HSMAY PZ BNHOZ.
# Decrypted: HE TOOK OUT A PIECE OF PAPER.
# Expected:  HE TOOK OUT A PIECE OF PAPER.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3474 ---
# Input:     V DSSC NP MWNLO.
# Decrypted: I LIKE TO SKATE.
# Expected:  I LIKE TO SKATE.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 3475 ---
# Input:     GGW AYCE C INK QWPAFIGF.
# Decrypted: TOM SAID I WAS GORGEOUS.
# Expected:  TOM SAID I WAS GORGEOUS.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 3476 ---
# Input:     GZO ZMUE WXVELA RI UBQ IAVTYAF.
# Decrypted: THE ROAD CLIMBS TO THE VILLAGE.
# Expected:  THE ROAD CLIMBS TO THE VILLAGE.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 3477 ---
# Input:     FSWQ UUONQQ LY JSS B QMGUR.
# Decrypted: SAMI WANTED TO BUY A WATCH.
# Expected:  SAMI WANTED TO BUY A WATCH.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3478 ---
# Input:     NYKQL
# Decrypted: AGAIN
# Expected:  AGAIN
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3479 ---
# Input:     JW LWRB UYMPZ OIAB PNTRJ DPC FBHSHSQM.
# Decrypted: WE BOTH TEACH EACH OTHER THE LANGUAGE.
# Expected:  WE BOTH TEACH EACH OTHER THE LANGUAGE.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 3480 ---
# Input:     V KKE RBBN FBE RIB U WCEVLYZ.
# Decrypted: I SAW THAT TOM HAD A VISITOR.
# Expected:  I SAW THAT TOM HAD A VISITOR.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3481 ---
# Input:     CSSVRVBFX
# Decrypted: PAINTBALL
# Expected:  PAINTBALL
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3482 ---
# Input:     GZOZCVZ
# Decrypted: THEREBY
# Expected:  THEREBY
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3483 ---
# Input:     GGW PYM PZRRJOL RI UUWR EO PMGF.
# Decrypted: TOM HAS OFFERED TO TAKE ME HOME.
# Expected:  TOM HAS OFFERED TO TAKE ME HOME.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3484 ---
# Input:     RNOZW FBHSHSQM AIONUAMOA RI DBMAYO IQ FPHS NK SB GM TJAXWX.
# Decrypted: EVERY LANGUAGE CONTINUES TO CHANGE AS LONG AS IT IS SPOKEN.
# Expected:  EVERY LANGUAGE CONTINUES TO CHANGE AS LONG AS IT IS SPOKEN.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 3485 ---
# Input:     VUYVQ
# Decrypted: ICONS
# Expected:  ICONS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3486 ---
# Input:     QAKUMHE
# Decrypted: DIAMOND
# Expected:  DIAMOND
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3487 ---
# Input:     NEZTGZJYD
# Decrypted: AMPLIFIER
# Expected:  AMPLIFIER
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3488 ---
# Input:     GGW CQYE NA QJOIK IG JXNQSVE JSIRRKCQMHBF NNKOJYFM.
# Decrypted: TOM USED TO DREAM OF PLAYING PROFESSIONAL BASEBALL.
# Expected:  TOM USED TO DREAM OF PLAYING PROFESSIONAL BASEBALL.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3489 ---
# Input:     WMCB QNBS AHL YN KS TOUGUKAC.
# Decrypted: JUST STAY OUT OF MY SUITCASE.
# Expected:  JUST STAY OUT OF MY SUITCASE.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3490 ---
# Input:     NHZIPYM
# Decrypted: APPAREL
# Expected:  APPAREL
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3491 ---
# Input:     CDKGJCTN
# Decrypted: PLAYLIST
# Expected:  PLAYLIST
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3492 ---
# Input:     FSWQ FUT JDBTKJJS EIZR KYUCNICZT TKL.
# Decrypted: SAMI HAS PROBABLY DONE SOMETHING BAD.
# Expected:  SAMI HAS PROBABLY DONE SOMETHING BAD.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3493 ---
# Input:     ZQ WWRBFL FBDN UC NP YMG EI DCAFNMODOA.
# Decrypted: MY MOTHER TOLD ME TO EAT MY VEGETABLES.
# Expected:  MY MOTHER TOLD ME TO EAT MY VEGETABLES.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3494 ---
# Input:     UW CPYLFM TVK YNDCDY IVLR PCL.
# Decrypted: HE SHARES HIS OFFICE WITH HER.
# Expected:  HE SHARES HIS OFFICE WITH HER.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3495 ---
# Input:     ZQ NISAINQE AC IL BPHAE KDCBYON.
# Decrypted: MY DAUGHTER IS AN HONOR STUDENT.
# Expected:  MY DAUGHTER IS AN HONOR STUDENT.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3496 ---
# Input:     V OKA RLZCZT LY NGHE U INQ SV.
# Decrypted: I WAS TRYING TO FIND A WAY IN.
# Expected:  I WAS TRYING TO FIND A WAY IN.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3497 ---
# Input:     FUYZGHH
# Decrypted: SCORING
# Expected:  SCORING
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3498 ---
# Input:     MABQ FYBLP GZO AMOOX AS S WWRISWKPDO MABPCZT AX BFY WUXYWI.
# Decrypted: ZIRI HEARD THE SOUND OF A MOTORCYCLE ECHOING IN THE CALLEY.
# Expected:  ZIRI HEARD THE SOUND OF A MOTORCYCLE ECHOING IN THE VALLEY.
# Match:     ❌
# Char Accuracy: 58/59 (98.3%)
#
# --- Case 3499 ---
# Input:     RJSA GM UBQ ZGCB KUTMUIW NEYLG JXNFOB GH UBQ FGVIP MZMFRE.
# Decrypted: ERIS IS THE MOST MASSIVE DWARF PLANET IN THE SOLAR SYSTEM.
# Expected:  ERIS IS THE MOST MASSIVE DWARF PLANET IN THE SOLAR SYSTEM.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 3500 ---
# Input:     OJYEL CT IGE WXOJCTB FRSMPCL.
# Decrypted: BROWN IS OUR ENGLISH TEACHER.
# Expected:  BROWN IS OUR ENGLISH TEACHER.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3501 ---
# Input:     UW PZYGFX FUW ZQANVLQ UW RIB VPOSUL YV RBF MFEWOB.
# Decrypted: HE FRAMED THE PICTURE HE HAD BOUGHT ON THE STREET.
# Expected:  HE FRAMED THE PICTURE HE HAD BOUGHT ON THE STREET.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 3502 ---
# Input:     CSET QWSYMZWN QL ZFUD.
# Decrypted: PAUL SCREAMED IN FEAR.
# Expected:  PAUL SCREAMED IN FEAR.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3503 ---
# Input:     GGW USMU BMIW LMCH FRTNMCBCX.
# Decrypted: TOM MUST HAVE BEEN EXHAUSTED.
# Expected:  TOM MUST HAVE BEEN EXHAUSTED.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3504 ---
# Input:     GZO QTS WCZRK KZC AFNFVFQ TYLHYD.
# Decrypted: THE IVY VINES ARE GETTING LARGER.
# Expected:  THE IVY VINES ARE GETTING LARGER.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3505 ---
# Input:     GZO UYNDB UF GFMP.
# Decrypted: THE MATCH IS OVER.
# Expected:  THE MATCH IS OVER.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3506 ---
# Input:     ZSBG QHJZRYWN.
# Decrypted: MARY SNIFFLED.
# Expected:  MARY SNIFFLED.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 3507 ---
# Input:     GGW ECHU XAJF DW RBF ZUEKD NJIPL.
# Decrypted: TOM WENT DOWN TO THE FIRST FLOOR.
# Expected:  TOM WENT DOWN TO THE FIRST FLOOR.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3508 ---
# Input:     UW PWAOTYP BF DPC ABGQ.
# Decrypted: HE FOCUSED ON THE GAME.
# Expected:  HE FOCUSED ON THE GAME.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3509 ---
# Input:     GGW ILX NUDL SBM QCDE.
# Decrypted: TOM AND MARY ARE SICK.
# Expected:  TOM AND MARY ARE SICK.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3510 ---
# Input:     RNOZWIOY UA LRM AFBME YAUMQ NPG.
# Decrypted: EVERYONE IN THE CLASS LIKES TOM.
# Expected:  EVERYONE IN THE CLASS LIKES TOM.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3511 ---
# Input:     OGVB
# Decrypted: BOLT
# Expected:  BOLT
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3512 ---
# Input:     LGE UGAIN INFD BM AP QUGZ WM.
# Decrypted: YOU MIGHT WANT TO GO WITH ME.
# Expected:  YOU MIGHT WANT TO GO WITH ME.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3513 ---
# Input:     YGKV
# Decrypted: LOAN
# Expected:  LOAN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3514 ---
# Input:     NUMMQMJVUYADG
# Decrypted: ACCESSIBILITY
# Expected:  ACCESSIBILITY
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 3515 ---
# Input:     FSPMRS
# Decrypted: SAFETY
# Expected:  SAFETY
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3516 ---
# Input:     GGW QQ KVCFR S CPW JFLEBF.
# Decrypted: TOM IS QUITE A SHY PERSON.
# Expected:  TOM IS QUITE A SHY PERSON.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3517 ---
# Input:     FSWQ GM GFUELSVE QJNT BLRMP AJLXF.
# Decrypted: SAMI IS FLIRTING WITH OTHER GIRLS.
# Expected:  SAMI IS FLIRTING WITH OTHER GIRLS.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3518 ---
# Input:     ZQ WWRBFL ZRSBTW BBX MA SLWPNJIZ JZOV G QBM NBJX.
# Decrypted: MY MOTHER NEARLY HAD AN ABORTION WHEN I WAS BORN.
# Expected:  MY MOTHER NEARLY HAD AN ABORTION WHEN I WAS BORN.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3519 ---
# Input:     GZOIRLF
# Decrypted: THEATRE
# Expected:  THEATRE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3520 ---
# Input:     GGW AYCE BQ GZYCEBU NTNL WIPS XUE N LOIABFL.
# Decrypted: TOM SAID HE THOUGHT THAT MARY WAS A TEACHER.
# Expected:  TOM SAID HE THOUGHT THAT MARY WAS A TEACHER.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 3521 ---
# Input:     V ZKDC HP LQTJOBQ UCIGG JOBGLJHS.
# Decrypted: I HAVE NO REGRETS ABOUT RETIRING.
# Expected:  I HAVE NO REGRETS ABOUT RETIRING.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3522 ---
# Input:     UW CIWM IY OBGUA UYMF.
# Decrypted: HE SAYS HE COOKS WELL.
# Expected:  HE SAYS HE COOKS WELL.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3523 ---
# Input:     FZO BMFE GQ GZKB QBF QMF OBWLA.
# Decrypted: SHE TOLD ME THAT SHE WAS WRONG.
# Expected:  SHE TOLD ME THAT SHE WAS WRONG.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 3524 ---
# Input:     AG YVC CT MMLAXO RBBN.
# Decrypted: NO ONE IS SAYING THAT.
# Expected:  NO ONE IS SAYING THAT.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3525 ---
# Input:     CSBQQ
# Decrypted: PARIS
# Expected:  PARIS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3526 ---
# Input:     LGE MVJMUUAWN QR QFFX.
# Decrypted: YOU EXPLAINED IT WELL.
# Expected:  YOU EXPLAINED IT WELL.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3527 ---
# Input:     GGW LGX ICE OWCB RI DUXZ EKZW XPQZ.
# Decrypted: TOM DID HIS BEST TO CALM MARY DOWN.
# Expected:  TOM DID HIS BEST TO CALM MARY DOWN.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3528 ---
# Input:     GGW TGEFX KBM.
# Decrypted: TOM LIKED YOU.
# Expected:  TOM LIKED YOU.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 3529 ---
# Input:     FSWQ UUT PQEQ EVNLPZQFKSWLUM.
# Decrypted: SAMI WAS VERY UNPROFESSIONAL.
# Expected:  SAMI WAS VERY UNPROFESSIONAL.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3530 ---
# Input:     EAWI JIPEE YAUM Y JSCZPWCA GH UBMG KRIUC ELQFK.
# Decrypted: RIMA LOOKS LIKE A PRINCESS IN THAT SHAWI DRESS.
# Expected:  RIMA LOOKS LIKE A PRINCESS IN THAT SHAWI DRESS.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 3531 ---
# Input:     UAC EGZF CE N UEBC WAYOU OYUYH.
# Decrypted: HIS WIFE IS A CUTE CZECH WOMAN.
# Expected:  HIS WIFE IS A CUTE CZECH WOMAN.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 3532 ---
# Input:     FGWMMHF UXJSIA DCOXE GAWM.
# Decrypted: SOMEONE ALWAYS FINDS TIME.
# Expected:  SOMEONE ALWAYS FINDS TIME.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3533 ---
# Input:     ZAMPCF EUZFWV PYM XLUGLOV Y HPPQY OSBFIVN QIWB CQCOA M FAXOJY WYDO.
# Decrypted: MICHEL DANSEL HAS WRITTEN A NOVEL WITHOUT EVER USING A SINGLE VERB.
# Expected:  MICHEL DANSEL HAS WRITTEN A NOVEL WITHOUT EVER USING A SINGLE VERB.
# Match:     ✅
# Char Accuracy: 67/67 (100.0%)
#
# --- Case 3534 ---
# Input:     PGVTCWU SAHJ QMYL.
# Decrypted: COLLECT YOUR GEAR.
# Expected:  COLLECT YOUR GEAR.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3535 ---
# Input:     FSN.
# Decrypted: SAD.
# Expected:  SAD.
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3536 ---
# Input:     GZO AYFF IR CGCBYAF MFNEZA RI GIDRAQV AIMFQPLYZQ CT UZ VEZWPNBHF FGEZAY PZ DRNOVSY.
# Decrypted: THE SALE OF POSTAGE STAMPS TO FOREIGN COLLECTORS IS AN IMPORTANT SOURCE OF REVENIE.
# Expected:  THE SALE OF POSTAGE STAMPS TO FOREIGN COLLECTORS IS AN IMPORTANT SOURCE OF REVENUE.
# Match:     ❌
# Char Accuracy: 82/83 (98.8%)
#
# --- Case 3537 ---
# Input:     GJOMQ
# Decrypted: TREES
# Expected:  TREES
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3538 ---
# Input:     BMB BCUDBQE OKA MOU NTNL NIW.
# Decrypted: OUR TEACHER WAS OUT THAT DAY.
# Expected:  OUR TEACHER WAS OUT THAT DAY.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3539 ---
# Input:     YAXSCX
# Decrypted: LINKED
# Expected:  LINKED
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3540 ---
# Input:     PGXBPIMFQEK
# Decrypted: CONTROLLERS
# Expected:  CONTROLLERS
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3541 ---
# Input:     V SCASGF NTNL IWS BBPQ FGWM GHGIDZSDQMH BVAHL DPGM.
# Decrypted: I ASSUME THAT YOU HAVE SOME INFORMATION ABOUT THIS.
# Expected:  I ASSUME THAT YOU HAVE SOME INFORMATION ABOUT THIS.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3542 ---
# Input:     LMBQ UUT UF GZO JMNUIY BX DPC NPNQZ HYTC.
# Decrypted: YURI WAS AT THE BOTTOM OF THE TOTEM POLE.
# Expected:  YURI WAS AT THE BOTTOM OF THE TOTEM POLE.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 3543 ---
# Input:     V CXMU NPG IBMVL FUWY FB VY BFUU.
# Decrypted: I KNEW TOM WOULD HAVE TO DO THAT.
# Expected:  I KNEW TOM WOULD HAVE TO DO THAT.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3544 ---
# Input:     PZEKI
# Decrypted: CHUCK
# Expected:  CHUCK
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3545 ---
# Input:     V DOIPHU CF SJYU FCN.
# Decrypted: I LEARNT IT FROM HIM.
# Expected:  I LEARNT IT FROM HIM.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3546 ---
# Input:     GGW LMYT NTR VSAFYT UE FGYV YM IY RVFSAFYT YMGAXO.
# Decrypted: TOM DOES THE DISHES AS SOON AS HE FINISHES EATING.
# Expected:  TOM DOES THE DISHES AS SOON AS HE FINISHES EATING.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 3547 ---
# Input:     JW RITY OI OUGSKC VVN FB WKB RBJM YBDNG ZLFUP.
# Decrypted: WE HAVE NO CHOICE BUT TO EAT THIS MOLDY BREAD.
# Expected:  WE HAVE NO CHOICE BUT TO EAT THIS MOLDY BREAD.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 3548 ---
# Input:     JAXMQ
# Decrypted: WINES
# Expected:  WINES
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3549 ---
# Input:     JW XMCXFX MYD DPYN.
# Decrypted: WE NEEDED ALL THAT.
# Expected:  WE NEEDED ALL THAT.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 3550 ---
# Input:     JW GWPE GID SJOM.
# Decrypted: WE WORK FOR FREE.
# Expected:  WE WORK FOR FREE.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 3551 ---
# Input:     VUO
# Decrypted: ICE
# Expected:  ICE
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 3552 ---
# Input:     MABQ NOTBQQ JSUY UXUK NFN AFY GYXY GX BFY HLAHFN.
# Decrypted: ZIRI PUSHED RIMA AWAY AND SHE FELL ON THE GROUND.
# Expected:  ZIRI PUSHED RIMA AWAY AND SHE FELL ON THE GROUND.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3553 ---
# Input:     JW GQQB ZIG N ZKXNS DBDVKDUYM BHP N ZKXNS OYI LWKZ.
# Decrypted: WE WISH YOU A HAPPY CHRISTMAS AND A HAPPY NEW YEAR.
# Expected:  WE WISH YOU A HAPPY CHRISTMAS AND A HAPPY NEW YEAR.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3554 ---
# Input:     ZSIJC NPG INK RQBCOA EBEOBFCOA.
# Decrypted: MAYBE TOM WAS HIDING SOMETHING.
# Expected:  MAYBE TOM WAS HIDING SOMETHING.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 3555 ---
# Input:     ZQ CPMYT QUYD RITY UI NR EOVBYE.
# Decrypted: MY SHOES WILL HAVE TO BE MENDED.
# Expected:  MY SHOES WILL HAVE TO BE MENDED.
# Match:     ✅
# ...
#
# --- Case 3917 ---
# Input:     GZSA KOTCO ZSUMQ GF MXRWZ.
# Decrypted: THIS MUSIC MAKES ME SLEEP.
# Expected:  THIS MUSIC MAKES ME SLEEP.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3918 ---
# Input:     SGYBLIUYE USFM ZYFH BEGFQBYE.
# Decrypted: FOOTNOTES HAVE BEEN PROVIDED.
# Expected:  FOOTNOTES HAVE BEEN PROVIDED.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3919 ---
# Input:     PGWXYLBVXR
# Decrypted: COMPARABLE
# Expected:  COMPARABLE
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3920 ---
# Input:     GZSA GM NOOU DOAQ NIUZ FSWQ CRQYOGWN.
# Decrypted: THIS IS MUCH LESS THAN SAMI EXPECTED.
# Expected:  THIS IS MUCH LESS THAN SAMI EXPECTED.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3921 ---
# Input:     GGW LCZJHUGWVG BCE QTNL RM QUJX TR VSL.
# Decrypted: TOM DEFINITELY DID WHAT HE SAID HE DID.
# Expected:  TOM DEFINITELY DID WHAT HE SAID HE DID.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 3922 ---
# Input:     YSITY UOX ENES ZYCTYP PSWMJM BHP FGVL RBFG.
# Decrypted: LAYLA AND SAMI RAISED CAMELS AND SOLD THEM.
# Expected:  LAYLA AND SAMI RAISED CAMELS AND SOLD THEM.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3923 ---
# Input:     V XSVB CU PQEQ EVDISNGASDM RBBN U USFM LIU MQRF DPC CNJQEAKT NUMUOR VEZGHH GK FLKG YN CYUWAXO. G WPOXQ FYB QYF CF OWMISMF C PVV XWR BBPQ RFYCEB UCYR.
# Decrypted: I FIND IT VERY UNFORTUNATE THAT I HAVE NOT SEEN THE IMPERISL PALACE IMPING MY STAY AT BEIKING. MOCHIONG TONG THE ME.
# Expected:  I FIND IT VERY UNFORTUNATE THAT I HAVE NOT SEEN THE IMPERIAL PALACE DURING MY STAY AT BEIJING. I COULD NOT SEE IT BECAUSE I DID NOT HAVE ENOUGH TIME.
# Match:     ❌
# Char Accuracy: 91/149 (61.1%)
#
# --- Case 3924 ---
# Input:     GJYCR
# Decrypted: TROUT
# Expected:  TROUT
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3925 ---
# Input:     V EKSC CU U DHDO BM JMUK GWXVGM XCFU ZSU QOOXMLK.
# Decrypted: I MAKE IT A RULE TO PLAY TENNIS WITH HIM SUNDAYS.
# Expected:  I MAKE IT A RULE TO PLAY TENNIS WITH HIM SUNDAYS.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3926 ---
# Input:     GGW PYM CYQA EKSGHH NTEWKBQ.
# Decrypted: TOM HAS BEEN MAKING THREATS.
# Expected:  TOM HAS BEEN MAKING THREATS.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 3927 ---
# Input:     GZOAC JFIBYW KZC APHZN LY TCUSH IUSD BM MBS IUWX AMGFIZR KKGQ NIUZX QYC.
# Decrypted: THESE PEOPLE ARE GONNA TO LEARN WHAT TO SAY WHEN SOMEONE SAYS THANK YOU.
# Expected:  THESE PEOPLE ARE GONNA TO LEARN WHAT TO SAY WHEN SOMEONE SAYS THANK YOU.
# Match:     ✅
# Char Accuracy: 72/72 (100.0%)
#
# --- Case 3928 ---
# Input:     GZO QBYB CE CJOBRS TCYCDO.
# Decrypted: THE IDEA IS PRETTY SIMPLE.
# Expected:  THE IDEA IS PRETTY SIMPLE.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3929 ---
# Input:     CJYOPUNGUAY
# Decrypted: PROGRAMMING
# Expected:  PROGRAMMING
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3930 ---
# Input:     GZO BPYF VAEW QWJXFH MCHVMQ.
# Decrypted: THE TREE BORE GOLDEN APPLES.
# Expected:  THE TREE BORE GOLDEN APPLES.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 3931 ---
# Input:     V CXMU BFL IRDV.
# Decrypted: I KNEW HER WELL.
# Expected:  I KNEW HER WELL.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 3932 ---
# Input:     JW GMPY ULGGZPCJ.
# Decrypted: WE WERE TRUTHFUL.
# Expected:  WE WERE TRUTHFUL.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 3933 ---
# Input:     GGW ILX J BMIW UVMQO YMPZ YBFYS ZAE SLWSN UBDRW IMYLT.
# Decrypted: TOM AND I HAVE KNOWN EACH OTHER FOR ABOUT THREE YEARS.
# Expected:  TOM AND I HAVE KNOWN EACH OTHER FOR ABOUT THREE YEARS.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 3934 ---
# Input:     MABQ RIPE M YGXO QBPQQE AX BFY CUFUJYWK.
# Decrypted: ZIRI TOOK A LONG SHOWER IN THE BATHROOM.
# Expected:  ZIRI TOOK A LONG SHOWER IN THE BATHROOM.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 3935 ---
# Input:     GGW KYFMYP ZSXG RCNYE.
# Decrypted: TOM CALLED MANY TIMES.
# Expected:  TOM CALLED MANY TIMES.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3936 ---
# Input:     CWXLGHH
# Decrypted: PENDING
# Expected:  PENDING
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3937 ---
# Input:     UW KTUUZM PEAXSQ BJM OBXPMC VMUOX.
# Decrypted: HE ALWAYS DRINKS HIS COFFEE BLACK.
# Expected:  HE ALWAYS DRINKS HIS COFFEE BLACK.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3938 ---
# Input:     FSWQ FUT AAG LBWSVMY.
# Decrypted: SAMI HAS GOT TROUBLE.
# Expected:  SAMI HAS GOT TROUBLE.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3939 ---
# Input:     FLBILAF NTVFQA FUQJQAWN QL NIUF UGEAC.
# Decrypted: STRANGE THINGS HAPPENED IN THAT HOUSE.
# Expected:  STRANGE THINGS HAPPENED IN THAT HOUSE.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 3940 ---
# Input:     UGXLY
# Decrypted: HONDA
# Expected:  HONDA
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3941 ---
# Input:     V BEAR XJX YL BYJ.
# Decrypted: I JUST DID MY JOB.
# Expected:  I JUST DID MY JOB.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 3942 ---
# Input:     FAXOJY
# Decrypted: SINGLE
# Expected:  SINGLE
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3943 ---
# Input:     PJOIK
# Decrypted: CREAM
# Expected:  CREAM
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3944 ---
# Input:     UMXLPYEM
# Decrypted: HUNDREDS
# Expected:  HUNDREDS
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3945 ---
# Input:     NKUMB
# Decrypted: ASKED
# Expected:  ASKED
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3946 ---
# Input:     GZOG LYWYD FSG VSDB UF FURWMF BAMVF.
# Decrypted: THEY NEVER SAW NUJA AT SCHOOL AGAIN.
# Expected:  THEY NEVER SAW NUJA AT SCHOOL AGAIN.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 3947 ---
# Input:     GZO XMHE BMF XBWXYO IHRJ.
# Decrypted: THE POND HAS FROZEN OVER.
# Expected:  THE POND HAS FROZEN OVER.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3948 ---
# Input:     PGWXJCBHF
# Decrypted: COMPLIANT
# Expected:  COMPLIANT
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3949 ---
# Input:     MABQ AUNY AHL YN RBF BAHKO.
# Decrypted: ZIRI CAME OUT OF THE HOUSE.
# Expected:  ZIRI CAME OUT OF THE HOUSE.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3950 ---
# Input:     NHZZCWJUFR
# Decrypted: APPRECIATE
# Expected:  APPRECIATE
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 3951 ---
# Input:     EWCBMLF
# Decrypted: RESTORE
# Expected:  RESTORE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3952 ---
# Input:     ZW KVB GZ GAGZOZ YLF CZ GZO OYLEYZ.
# Decrypted: ME AND MY MOTHER ARE IN THE GARDEN.
# Expected:  ME AND MY MOTHER ARE IN THE GARDEN.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3953 ---
# Input:     YWD UC AFN FUAC ARLBCSUL.
# Decrypted: LET ME GET THIS STRAIGHT.
# Expected:  LET ME GET THIS STRAIGHT.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3954 ---
# Input:     FSWQ BCE MAZWDPGHH LQNDVG ZUE.
# Decrypted: SAMI DID SOMETHING REALLY BAD.
# Expected:  SAMI DID SOMETHING REALLY BAD.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3955 ---
# Input:     JW XMCX UI NHQ DWK MPGQGZSVE.
# Decrypted: WE NEED TO BUY TOM SOMETHING.
# Expected:  WE NEED TO BUY TOM SOMETHING.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3956 ---
# Input:     ZWMPYHJWE
# Decrypted: MECHANICS
# Expected:  MECHANICS
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3957 ---
# Input:     V CXWU NIUF GGW CQYE NA OW K KYMICQE SD I ELPWQEQ CBMLF.
# Decrypted: I KNOW THAT TOM USED TO BE A CASHIER AT A GROCERY STORE.
# Expected:  I KNOW THAT TOM USED TO BE A CASHIER AT A GROCERY STORE.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 3958 ---
# Input:     GJKQLYS
# Decrypted: TRAINER
# Expected:  TRAINER
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3959 ---
# Input:     GGW QQ NIY AADI XCLTIZ V CXWU CO UGFLBIJCB.
# Decrypted: TOM IS THE ONLY PERSON I KNOW IN AUSTRALIA.
# Expected:  TOM IS THE ONLY PERSON I KNOW IN AUSTRALIA.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 3960 ---
# Input:     GGW PYM BH MAYOZ GMTOQ.
# Decrypted: TOM HAS AN ANGER ISSUE.
# Expected:  TOM HAS AN ANGER ISSUE.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 3961 ---
# Input:     UW SA FCLCZT.
# Decrypted: HE IS HIKING.
# Expected:  HE IS HIKING.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 3962 ---
# Input:     JW GQQB MIZT DSNC NP NTBKO EFI CLUAY DPC EBVKYW VILAVUSR LY TGZF.
# Decrypted: WE WISH LONG LIFE TO THOSE WHO BRING THE KABYLE LANGUAGE TO LIFE.
# Expected:  WE WISH LONG LIFE TO THOSE WHO BRING THE KABYLE LANGUAGE TO LIFE.
# Match:     ✅
# Char Accuracy: 65/65 (100.0%)
#
# --- Case 3963 ---
# Input:     GGW ILX NUDL KKQB NIYK JSXBCX UI SRL CWKY TFQRH.
# Decrypted: TOM AND MARY SAID THEY WANTED TO GET SOME SLEEP.
# Expected:  TOM AND MARY SAID THEY WANTED TO GET SOME SLEEP.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 3964 ---
# Input:     ZQ MPGFELQA DSSC MBWOUSBCK.
# Decrypted: MY CHILDREN LIKE SACCHARUM.
# Expected:  MY CHILDREN LIKE SACCHARUM.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3965 ---
# Input:     GZO EMLEM THJD PGM QLUQW.
# Decrypted: THE WORDS HURT HIS PRIDE.
# Expected:  THE WORDS HURT HIS PRIDE.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 3966 ---
# Input:     PGZA JCF.
# Decrypted: COPS LIE.
# Expected:  COPS LIE.
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3967 ---
# Input:     GZOG YLF NTR XYTCS BLFVKDA MZ UBUF HBWBODNUBF.
# Decrypted: THEY ARE THE FOLEY ARTISTS OF THIS PRODUCTION.
# Expected:  THEY ARE THE FOLEY ARTISTS OF THIS PRODUCTION.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 3968 ---
# Input:     UW CMCGFX FB WXRMS ICYFWVN YN UBQ CSBBW FBMF AAQPR.
# Decrypted: HE SEEMED TO ENJOY HIMSELF AT THE PARTY LAST NIGHT.
# Expected:  HE SEEMED TO ENJOY HIMSELF AT THE PARTY LAST NIGHT.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 3969 ---
# Input:     ZSBQMH
# Decrypted: MARION
# Expected:  MARION
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3970 ---
# Input:     NVWQQMJIZ VFDW QIDCQGQ WMYHT UOPWZBGHH CFF JETCM.
# Decrypted: ADMISSION INTO SOCIETY MEANS ACCEPTING ITS RULES.
# Expected:  ADMISSION INTO SOCIETY MEANS ACCEPTING ITS RULES.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 3971 ---
# Input:     NFDQACQUFRV
# Decrypted: ANTICIPATED
# Expected:  ANTICIPATED
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3972 ---
# Input:     EWTMANFX
# Decrypted: REJECTED
# Expected:  REJECTED
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 3973 ---
# Input:     GZOZC USY YNFI XGWUODRK SV RBJM NBGU.
# Decrypted: THERE ARE MANY PICTURES IN THIS BOOK.
# Expected:  THERE ARE MANY PICTURES IN THIS BOOK.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 3974 ---
# Input:     UW OFNYSCQAUOL Y JBCZ VF RQQ FFA.
# Decrypted: HE EXPERIENCED A PAIN IN HIS LEG.
# Expected:  HE EXPERIENCED A PAIN IN HIS LEG.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 3975 ---
# Input:     GGW NMLHIF GG ZIW BJM OEWNQR WBLP OAVT MH UCYR.
# Decrypted: TOM FORGOT TO PAY HIS CREDIT CARD BILL ON TIME.
# Expected:  TOM FORGOT TO PAY HIS CREDIT CARD BILL ON TIME.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 3976 ---
# Input:     YSCB LCHBF UW CIU UO OZVVOVRCGCQQ XVGGHH INWWMB GH UBQ FCI.
# Decrypted: LAST NIGHT HE SAW AN UNIDENTIFIED FLYING OBJECT IN THE SKY.
# Expected:  LAST NIGHT HE SAW AN UNIDENTIFIED FLYING OBJECT IN THE SKY.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 3977 ---
# Input:     QWCS
# Decrypted: DESK
# Expected:  DESK
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3978 ---
# Input:     BFO EYS UI XBOOZ RBF HGZTOZ MZ FLDBJC QL NIY FNLYMZU DIDCMC EMOMX NR LY MLWPODNYO XCIQFQ GG YVJS ULMAKVIRY JHFB LRMGL OUFVNO TYHHOMTWC QLMUYMQ GP DGWF PQEKK.
# Decrypted: ONE WAY TO LOWER THE NUMBER OF ERRORS IN THE TATOEBA CORPUS WOULD BE TO ORCURAGEE PEOPLE TO ONIR TORANGRAND THE THE THE TING.
# Expected:  ONE WAY TO LOWER THE NUMBER OF ERRORS IN THE TATOEBA CORPUS WOULD BE TO ENCOURAGE PEOPLE TO ONLY TRANSLATE INTO THEIR NATIVE LANGUAGES INSTEAD OF VICE VERSA.
# Match:     ❌
# Char Accuracy: 95/157 (60.5%)
#
# --- Case 3979 ---
# Input:     TJOIR
# Decrypted: GREAT
# Expected:  GREAT
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3980 ---
# Input:     JW VQTY POD YAWQRYE FUSW SV RBF WABJNQLUUY ELKDMK IG NUZW KVB GPHQL.
# Decrypted: WE LIVE OUR LIMITED LIFE IN THE COORDINATE SYSTEM OF TIME AND MONEY.
# Expected:  WE LIVE OUR LIMITED LIFE IN THE COORDINATE SYSTEM OF TIME AND MONEY.
# Match:     ✅
# Char Accuracy: 68/68 (100.0%)
#
# --- Case 3981 ---
# Input:     CGVQRCDCMAK BMYFMS XBNO BM NBFW.
# Decrypted: POLITICIANS REALLY LOVE TO TALK.
# Expected:  POLITICIANS REALLY LOVE TO TALK.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 3982 ---
# Input:     YAWQRUUCAAK
# Decrypted: LIMITATIONS
# Expected:  LIMITATIONS
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3983 ---
# Input:     V ZKDC YWYDLLRQLA J QMALOL.
# Decrypted: I HAVE EVERYTHING I WANTED.
# Expected:  I HAVE EVERYTHING I WANTED.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3984 ---
# Input:     GZOG BCE YJNUDTW UT C FBDN BFYN NA QG.
# Decrypted: THEY DID EXACTLY AS I TOLD THEM TO DO.
# Expected:  THEY DID EXACTLY AS I TOLD THEM TO DO.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 3985 ---
# Input:     FLKBSM
# Decrypted: STATUS
# Expected:  STATUS
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3986 ---
# Input:     UW GMYLT U IBGV AUYBNQE.
# Decrypted: HE WEARS A WOOL SWEATER.
# Expected:  HE WEARS A WOOL SWEATER.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 3987 ---
# Input:     LSXVG UOX EXMBI UYSY NNUU QL UMAURJC LSLJHS GZO ASGNYD OJOII.
# Decrypted: YANNI AND SKURA WERE BACK IN ALGIERS DURING THE SUMMER BREAK.
# Expected:  YANNI AND SKURA WERE BACK IN ALGIERS DURING THE SUMMER BREAK.
# Match:     ✅
# Char Accuracy: 61/61 (100.0%)
#
# --- Case 3988 ---
# Input:     GZOG YLF JDRHKZGHH ZAE LRMGL ULUC.
# Decrypted: THEY ARE PREPARING FOR THEIR TRIP.
# Expected:  THEY ARE PREPARING FOR THEIR TRIP.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3989 ---
# Input:     QABBW
# Decrypted: DIRTY
# Expected:  DIRTY
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 3990 ---
# Input:     V OKA YVEOOGWN ILX JGBEWQVYNFX NL OYTTYT QTB DKVBYE NTRAB NJSJHS FSEKCL JH YL TKKISBLP.
# Decrypted: I WAS ABDUCTED AND IMPREGNATED BY WOLVES WHO LANDED THEIR FLYING SAUCER IN MY BACKY.
# Expected:  I WAS ABDUCTED AND IMPREGNATED BY WOLVES WHO LANDED THEIR FLYING SAUCER IN MY BACKYARD.
# Match:     ❌
# Char Accuracy: 83/87 (95.4%)
#
# --- Case 3991 ---
# Input:     GZO NGFN QMF XEVLS.
# Decrypted: THE FILM WAS FUNNY.
# Expected:  THE FILM WAS FUNNY.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 3992 ---
# Input:     V XYCLX VM M JSI WSN.
# Decrypted: I FOUND US A WAY OUT.
# Expected:  I FOUND US A WAY OUT.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 3993 ---
# Input:     V OSAFYE NTRE VCAE.
# Decrypted: I WISHED THEM LUCK.
# Expected:  I WISHED THEM LUCK.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 3994 ---
# Input:     V OKA JOSYP GG DPC MUIDR TI BFY BXHRJDQQYNYZG.
# Decrypted: I WAS LURED TO THE STORE BY THE ADVERTISEMENT.
# Expected:  I WAS LURED TO THE STORE BY THE ADVERTISEMENT.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 3995 ---
# Input:     WSI
# Decrypted: JAY
# Expected:  JAY
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 3996 ---
# Input:     V DSSC GJFW NFN JPYBX.
# Decrypted: I LIKE MILK AND BREAD.
# Expected:  I LIKE MILK AND BREAD.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3997 ---
# Input:     GGW EYCUYP VF DPC WBL.
# Decrypted: TOM WAITED IN THE CAR.
# Expected:  TOM WAITED IN THE CAR.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 3998 ---
# Input:     UW MIKY UI ONKR QL NIY OUWMS.
# Decrypted: HE CAME TO CASH IN THE CHECK.
# Expected:  HE CAME TO CASH IN THE CHECK.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 3999 ---
# Input:     GZOAC VVAE NJO ILHPSUAY.
# Decrypted: THESE BUGS ARE ANNOYING.
# Expected:  THESE BUGS ARE ANNOYING.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 4000 ---
# Input:     ZSBG RIMX FBE CPC QBM BYSXVGHH NA QG DPYN.
# Decrypted: MARY TOLD TOM SHE WAS PLANNING TO DO THAT.
# Expected:  MARY TOLD TOM SHE WAS PLANNING TO DO THAT.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# Full results saved to /content/drive/MyDrive/inference_vigenere_one_vanilla.xlsx
#
# === Final Summary ===
# Full-match accuracy: 3907/4000
# Character-level accuracy: 111986/112977 (99.12%)
