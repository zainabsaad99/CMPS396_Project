# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
import string

# Data Preparation
def load_data(file_path):
    df = pd.read_excel(file_path)

    # Filter rows where 'Output' length is <=500
    df = df[df['output'].str.len() <= 200]

    # Get the count of such rows
    count_filtered = len(df)

    # Randomly select 250,000 rows (if available)
    if count_filtered > 400000:
        df = df.sample(n=400000, random_state=42)
    print(len(df))
    inputs = df['input'].astype(str).tolist()
    outputs = df['output'].astype(str).tolist()


    return inputs, outputs

# Tokenization and Vocabulary
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        # Special tokens
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        # All printable characters
        all_chars = list(string.printable)

        # Create vocabulary
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})

        # Reverse mapping
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Dataset Class
class CipherDataset(data.Dataset):
    def __init__(self, inputs, outputs, vocab, max_length):
        self.inputs = inputs
        self.outputs = outputs
        self.vocab = vocab
        self.max_length = max_length

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_text = self.inputs[idx]
        output_text = self.outputs[idx]

        # Encode with SOS and EOS tokens
        input_encoded = [self.vocab.sos_token] + self.vocab.encode(input_text) + [self.vocab.eos_token]
        output_encoded = [self.vocab.sos_token] + self.vocab.encode(output_text) + [self.vocab.eos_token]

        # Pad sequences
        input_padded = input_encoded + [self.vocab.pad_token] * (self.max_length - len(input_encoded))
        output_padded = output_encoded + [self.vocab.pad_token] * (self.max_length - len(output_encoded))

        # Truncate if necessary
        input_padded = input_padded[:self.max_length]
        output_padded = output_padded[:self.max_length]

        return torch.tensor(input_padded), torch.tensor(output_padded)

# Transformer Model (same as your implementation)
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Q, K, V shapes: (batch_size, num_heads, seq_len, d_k)
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn_probs = torch.softmax(scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        # Source mask
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, src_len)

        # Target mask
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, tgt_len)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=tgt.device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask  # (batch_size, 1, tgt_len, tgt_len)

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (src, tgt) in enumerate(train_loader):
            src, tgt = src.to(device), tgt.to(device)

            optimizer.zero_grad()
            output = model(src, tgt[:, :-1])

            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch_idx % 10 == 0:
                print(f'Epoch: {epoch+1}, Batch: {batch_idx}, Loss: {loss.item():.4f}')

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        val_loss = evaluate_model(model, val_loader, criterion, device)
        print(f'Epoch: {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), '/content/drive/MyDrive/mono_vanilla_one.pth')

    return model

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            total_loss += loss.item()

    return total_loss / len(data_loader)

# Inference Function
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        # Encode the input text
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        # Initialize target with SOS token
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        # Decode the output
        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

# Main Execution
if __name__ == "__main__":
    # Load and prepare data
    inputs, outputs = load_data('/content/Full_training_vigenere_one.xlsx')

    # Create vocabulary
    vocab = Vocabulary()

    # Split data into train and validation
    train_inputs, val_inputs, train_outputs, val_outputs = train_test_split(
        inputs, outputs, test_size=0.2, random_state=42
    )

    # Create datasets
    max_length = 256  # Adjust based on your data
    train_dataset = CipherDataset(train_inputs, train_outputs, vocab, max_length)
    val_dataset = CipherDataset(val_inputs, val_outputs, vocab, max_length)

    # Create data loaders
    batch_size = 256
    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=8,
        num_layers=6,
        d_ff=256,
        max_seq_length=max_length,
        dropout=0.1125331367392462
    ).to(device)


    # Loss and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=vocab.pad_token)
    optimizer = optim.Adam(model.parameters(), lr=0.0003515867391592575, betas=(0.9, 0.98), eps=1e-9)

    # Train the model
    num_epochs = 30
    trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

    # Test the model
    test_text = "gfbs"  # Should decrypt to "fear"
    decrypted = decrypt_text(trained_model, test_text, vocab, max_length, device)
    print(f"Input: {test_text}, Decrypted: {decrypted}")
# Out:
# 35995
# Epoch: 1, Batch: 0, Loss: 4.8873
# Epoch: 1, Batch: 10, Loss: 3.0806
# Epoch: 1, Batch: 20, Loss: 3.0147
# Epoch: 1, Batch: 30, Loss: 2.9851
# Epoch: 1, Batch: 40, Loss: 2.9883
# Epoch: 1, Batch: 50, Loss: 2.9849
# Epoch: 1, Batch: 60, Loss: 2.8553
# Epoch: 1, Batch: 70, Loss: 2.9016
# Epoch: 1, Batch: 80, Loss: 2.5033
# Epoch: 1, Batch: 90, Loss: 2.3925
# Epoch: 1, Batch: 100, Loss: 2.3007
# Epoch: 1, Batch: 110, Loss: 2.3966
# Epoch: 1, Train Loss: 2.8349, Val Loss: 2.2487
# Epoch: 2, Batch: 0, Loss: 2.2426
# Epoch: 2, Batch: 10, Loss: 2.2305
# Epoch: 2, Batch: 20, Loss: 2.1201
# Epoch: 2, Batch: 30, Loss: 2.0909
# Epoch: 2, Batch: 40, Loss: 2.0289
# Epoch: 2, Batch: 50, Loss: 2.0319
# Epoch: 2, Batch: 60, Loss: 1.9316
# Epoch: 2, Batch: 70, Loss: 1.9267
# Epoch: 2, Batch: 80, Loss: 1.8737
# Epoch: 2, Batch: 90, Loss: 1.7864
# Epoch: 2, Batch: 100, Loss: 1.8126
# Epoch: 2, Batch: 110, Loss: 1.7376
# Epoch: 2, Train Loss: 1.9768, Val Loss: 1.7355
# Epoch: 3, Batch: 0, Loss: 1.7428
# Epoch: 3, Batch: 10, Loss: 1.7175
# Epoch: 3, Batch: 20, Loss: 1.6683
# Epoch: 3, Batch: 30, Loss: 1.6606
# Epoch: 3, Batch: 40, Loss: 1.6215
# Epoch: 3, Batch: 50, Loss: 1.6322
# Epoch: 3, Batch: 60, Loss: 1.6534
# Epoch: 3, Batch: 70, Loss: 1.5521
# Epoch: 3, Batch: 80, Loss: 1.5307
# Epoch: 3, Batch: 90, Loss: 1.5650
# Epoch: 3, Batch: 100, Loss: 1.5131
# Epoch: 3, Batch: 110, Loss: 1.5308
# Epoch: 3, Train Loss: 1.6098, Val Loss: 1.5328
# Epoch: 4, Batch: 0, Loss: 1.5065
# Epoch: 4, Batch: 10, Loss: 1.5191
# Epoch: 4, Batch: 20, Loss: 1.4715
# Epoch: 4, Batch: 30, Loss: 1.4515
# Epoch: 4, Batch: 40, Loss: 1.4590
# Epoch: 4, Batch: 50, Loss: 1.4370
# Epoch: 4, Batch: 60, Loss: 1.4052
# Epoch: 4, Batch: 70, Loss: 1.4056
# Epoch: 4, Batch: 80, Loss: 1.4048
# Epoch: 4, Batch: 90, Loss: 1.3798
# Epoch: 4, Batch: 100, Loss: 1.4242
# Epoch: 4, Batch: 110, Loss: 1.3958
# Epoch: 4, Train Loss: 1.4344, Val Loss: 1.4016
# Epoch: 5, Batch: 0, Loss: 1.3498
# Epoch: 5, Batch: 10, Loss: 1.3088
# Epoch: 5, Batch: 20, Loss: 1.2897
# Epoch: 5, Batch: 30, Loss: 1.3188
# Epoch: 5, Batch: 40, Loss: 1.3480
# Epoch: 5, Batch: 50, Loss: 1.3092
# Epoch: 5, Batch: 60, Loss: 1.2559
# Epoch: 5, Batch: 70, Loss: 1.2550
# Epoch: 5, Batch: 80, Loss: 1.2355
# Epoch: 5, Batch: 90, Loss: 1.2193
# Epoch: 5, Batch: 100, Loss: 1.1448
# Epoch: 5, Batch: 110, Loss: 1.1575
# Epoch: 5, Train Loss: 1.2723, Val Loss: 1.2000
# Epoch: 6, Batch: 0, Loss: 1.1354
# Epoch: 6, Batch: 10, Loss: 1.0712
# Epoch: 6, Batch: 20, Loss: 1.0102
# Epoch: 6, Batch: 30, Loss: 1.0325
# Epoch: 6, Batch: 40, Loss: 0.9769
# Epoch: 6, Batch: 50, Loss: 0.9996
# Epoch: 6, Batch: 60, Loss: 0.9443
# Epoch: 6, Batch: 70, Loss: 0.8618
# Epoch: 6, Batch: 80, Loss: 0.8759
# Epoch: 6, Batch: 90, Loss: 0.7641
# Epoch: 6, Batch: 100, Loss: 0.7383
# Epoch: 6, Batch: 110, Loss: 0.8051
# Epoch: 6, Train Loss: 0.9418, Val Loss: 0.7882
# Epoch: 7, Batch: 0, Loss: 0.6737
# Epoch: 7, Batch: 10, Loss: 0.5975
# Epoch: 7, Batch: 20, Loss: 0.5603
# Epoch: 7, Batch: 30, Loss: 0.4806
# Epoch: 7, Batch: 40, Loss: 0.4248
# Epoch: 7, Batch: 50, Loss: 0.4109
# Epoch: 7, Batch: 60, Loss: 0.3964
# Epoch: 7, Batch: 70, Loss: 0.3460
# Epoch: 7, Batch: 80, Loss: 0.2857
# Epoch: 7, Batch: 90, Loss: 0.2259
# Epoch: 7, Batch: 100, Loss: 0.2303
# Epoch: 7, Batch: 110, Loss: 0.1352
# Epoch: 7, Train Loss: 0.3930, Val Loss: 0.1959
# Epoch: 8, Batch: 0, Loss: 0.1541
# Epoch: 8, Batch: 10, Loss: 0.1769
# Epoch: 8, Batch: 20, Loss: 0.1200
# Epoch: 8, Batch: 30, Loss: 0.1574
# Epoch: 8, Batch: 40, Loss: 0.1365
# Epoch: 8, Batch: 50, Loss: 0.0995
# Epoch: 8, Batch: 60, Loss: 0.1214
# Epoch: 8, Batch: 70, Loss: 0.0982
# Epoch: 8, Batch: 80, Loss: 0.0789
# Epoch: 8, Batch: 90, Loss: 0.0846
# Epoch: 8, Batch: 100, Loss: 0.1193
# Epoch: 8, Batch: 110, Loss: 0.5382
# Epoch: 8, Train Loss: 0.1626, Val Loss: 0.3819
# Epoch: 9, Batch: 0, Loss: 0.3581
# Epoch: 9, Batch: 10, Loss: 0.1812
# Epoch: 9, Batch: 20, Loss: 0.1376
# Epoch: 9, Batch: 30, Loss: 0.0975
# Epoch: 9, Batch: 40, Loss: 0.0493
# Epoch: 9, Batch: 50, Loss: 0.0833
# Epoch: 9, Batch: 60, Loss: 0.0269
# Epoch: 9, Batch: 70, Loss: 0.0722
# Epoch: 9, Batch: 80, Loss: 0.0507
# Epoch: 9, Batch: 90, Loss: 0.0816
# Epoch: 9, Batch: 100, Loss: 0.0472
# Epoch: 9, Batch: 110, Loss: 0.0355
# Epoch: 9, Train Loss: 0.0889, Val Loss: 0.0564
# Epoch: 10, Batch: 0, Loss: 0.0475
# Epoch: 10, Batch: 10, Loss: 0.0557
# Epoch: 10, Batch: 20, Loss: 0.0451
# Epoch: 10, Batch: 30, Loss: 0.0650
# Epoch: 10, Batch: 40, Loss: 0.0802
# Epoch: 10, Batch: 50, Loss: 0.0668
# Epoch: 10, Batch: 60, Loss: 0.0588
# Epoch: 10, Batch: 70, Loss: 0.1015
# Epoch: 10, Batch: 80, Loss: 0.1111
# Epoch: 10, Batch: 90, Loss: 0.0698
# Epoch: 10, Batch: 100, Loss: 0.0513
# Epoch: 10, Batch: 110, Loss: 0.0268
# Epoch: 10, Train Loss: 0.0596, Val Loss: 0.0471
# Epoch: 11, Batch: 0, Loss: 0.0221
# Epoch: 11, Batch: 10, Loss: 0.0096
# Epoch: 11, Batch: 20, Loss: 0.0514
# Epoch: 11, Batch: 30, Loss: 0.0133
# Epoch: 11, Batch: 40, Loss: 0.0322
# Epoch: 11, Batch: 50, Loss: 0.0473
# Epoch: 11, Batch: 60, Loss: 0.0784
# Epoch: 11, Batch: 70, Loss: 0.1479
# Epoch: 11, Batch: 80, Loss: 0.0832
# Epoch: 11, Batch: 90, Loss: 0.0357
# Epoch: 11, Batch: 100, Loss: 0.0272
# Epoch: 11, Batch: 110, Loss: 0.0230
# Epoch: 11, Train Loss: 0.0550, Val Loss: 0.0439
# Epoch: 12, Batch: 0, Loss: 0.0562
# Epoch: 12, Batch: 10, Loss: 0.0250
# Epoch: 12, Batch: 20, Loss: 0.0299
# Epoch: 12, Batch: 30, Loss: 0.0141
# Epoch: 12, Batch: 40, Loss: 0.0138
# Epoch: 12, Batch: 50, Loss: 0.0259
# Epoch: 12, Batch: 60, Loss: 0.0480
# Epoch: 12, Batch: 70, Loss: 0.0302
# Epoch: 12, Batch: 80, Loss: 0.0690
# Epoch: 12, Batch: 90, Loss: 0.1060
# Epoch: 12, Batch: 100, Loss: 0.0595
# Epoch: 12, Batch: 110, Loss: 0.0400
# Epoch: 12, Train Loss: 0.0396, Val Loss: 0.0696
# Epoch: 13, Batch: 0, Loss: 0.0774
# Epoch: 13, Batch: 10, Loss: 0.0191
# Epoch: 13, Batch: 20, Loss: 0.0242
# Epoch: 13, Batch: 30, Loss: 0.0108
# Epoch: 13, Batch: 40, Loss: 0.0509
# Epoch: 13, Batch: 50, Loss: 0.0477
# Epoch: 13, Batch: 60, Loss: 0.0131
# Epoch: 13, Batch: 70, Loss: 0.0410
# Epoch: 13, Batch: 80, Loss: 0.0956
# Epoch: 13, Batch: 90, Loss: 0.1751
# Epoch: 13, Batch: 100, Loss: 0.0437
# Epoch: 13, Batch: 110, Loss: 0.0166
# Epoch: 13, Train Loss: 0.0530, Val Loss: 0.0433
# Epoch: 14, Batch: 0, Loss: 0.0200
# Epoch: 14, Batch: 10, Loss: 0.0080
# Epoch: 14, Batch: 20, Loss: 0.0401
# Epoch: 14, Batch: 30, Loss: 0.0146
# Epoch: 14, Batch: 40, Loss: 0.0130
# Epoch: 14, Batch: 50, Loss: 0.0154
# Epoch: 14, Batch: 60, Loss: 0.0257
# Epoch: 14, Batch: 70, Loss: 0.0489
# Epoch: 14, Batch: 80, Loss: 0.0276
# Epoch: 14, Batch: 90, Loss: 0.0569
# Epoch: 14, Batch: 100, Loss: 0.0154
# Epoch: 14, Batch: 110, Loss: 0.0112
# Epoch: 14, Train Loss: 0.0275, Val Loss: 0.0341
# Epoch: 15, Batch: 0, Loss: 0.0191
# Epoch: 15, Batch: 10, Loss: 0.0254
# Epoch: 15, Batch: 20, Loss: 0.0096
# Epoch: 15, Batch: 30, Loss: 0.0500
# Epoch: 15, Batch: 40, Loss: 0.0468
# Epoch: 15, Batch: 50, Loss: 0.0044
# Epoch: 15, Batch: 60, Loss: 0.0208
# Epoch: 15, Batch: 70, Loss: 0.0365
# Epoch: 15, Batch: 80, Loss: 0.0216
# Epoch: 15, Batch: 90, Loss: 0.0366
# Epoch: 15, Batch: 100, Loss: 0.0328
# Epoch: 15, Batch: 110, Loss: 0.0324
# Epoch: 15, Train Loss: 0.0233, Val Loss: 0.0493
# Epoch: 16, Batch: 0, Loss: 0.0422
# Epoch: 16, Batch: 10, Loss: 0.0185
# Epoch: 16, Batch: 20, Loss: 0.0333
# Epoch: 16, Batch: 30, Loss: 0.0086
# Epoch: 16, Batch: 40, Loss: 0.0265
# Epoch: 16, Batch: 50, Loss: 0.1760
# Epoch: 16, Batch: 60, Loss: 0.0559
# Epoch: 16, Batch: 70, Loss: 0.0111
# Epoch: 16, Batch: 80, Loss: 0.0265
# Epoch: 16, Batch: 90, Loss: 0.0328
# Epoch: 16, Batch: 100, Loss: 0.0251
# Epoch: 16, Batch: 110, Loss: 0.0129
# Epoch: 16, Train Loss: 0.0544, Val Loss: 0.0262
# Epoch: 17, Batch: 0, Loss: 0.0031
# Epoch: 17, Batch: 10, Loss: 0.0046
# Epoch: 17, Batch: 20, Loss: 0.0141
# Epoch: 17, Batch: 30, Loss: 0.0069
# Epoch: 17, Batch: 40, Loss: 0.0468
# Epoch: 17, Batch: 50, Loss: 0.0102
# Epoch: 17, Batch: 60, Loss: 0.0207
# Epoch: 17, Batch: 70, Loss: 0.0143
# Epoch: 17, Batch: 80, Loss: 0.0180
# Epoch: 17, Batch: 90, Loss: 0.0437
# Epoch: 17, Batch: 100, Loss: 0.0275
# Epoch: 17, Batch: 110, Loss: 0.0113
# Epoch: 17, Train Loss: 0.0143, Val Loss: 0.0299
# Epoch: 18, Batch: 0, Loss: 0.0276
# Epoch: 18, Batch: 10, Loss: 0.0248
# Epoch: 18, Batch: 20, Loss: 0.0086
# Epoch: 18, Batch: 30, Loss: 0.0176
# Epoch: 18, Batch: 40, Loss: 0.0095
# Epoch: 18, Batch: 50, Loss: 0.0312
# Epoch: 18, Batch: 60, Loss: 0.0267
# Epoch: 18, Batch: 70, Loss: 0.0393
# Epoch: 18, Batch: 80, Loss: 0.0257
# Epoch: 18, Batch: 90, Loss: 0.0140
# Epoch: 18, Batch: 100, Loss: 0.0169
# Epoch: 18, Batch: 110, Loss: 0.0294
# Epoch: 18, Train Loss: 0.0186, Val Loss: 0.0492
# Epoch: 19, Batch: 0, Loss: 0.0105
# Epoch: 19, Batch: 10, Loss: 0.0169
# Epoch: 19, Batch: 20, Loss: 0.0258
# Epoch: 19, Batch: 30, Loss: 0.0430
# Epoch: 19, Batch: 40, Loss: 0.0259
# Epoch: 19, Batch: 50, Loss: 0.0130
# Epoch: 19, Batch: 60, Loss: 0.0587
# Epoch: 19, Batch: 70, Loss: 0.0126
# Epoch: 19, Batch: 80, Loss: 0.0126
# Epoch: 19, Batch: 90, Loss: 0.0184
# Epoch: 19, Batch: 100, Loss: 0.0112
# Epoch: 19, Batch: 110, Loss: 0.0114
# Epoch: 19, Train Loss: 0.0240, Val Loss: 0.0311
# Epoch: 20, Batch: 0, Loss: 0.0077
# Epoch: 20, Batch: 10, Loss: 0.0108
# Epoch: 20, Batch: 20, Loss: 0.0187
# Epoch: 20, Batch: 30, Loss: 0.0324
# Epoch: 20, Batch: 40, Loss: 0.0045
# Epoch: 20, Batch: 50, Loss: 0.0280
# Epoch: 20, Batch: 60, Loss: 0.0098
# Epoch: 20, Batch: 70, Loss: 0.0088
# Epoch: 20, Batch: 80, Loss: 0.0184
# Epoch: 20, Batch: 90, Loss: 0.0207
# Epoch: 20, Batch: 100, Loss: 0.0245
# Epoch: 20, Batch: 110, Loss: 0.0266
# Epoch: 20, Train Loss: 0.0146, Val Loss: 0.0436
# Epoch: 21, Batch: 0, Loss: 0.0259
# Epoch: 21, Batch: 10, Loss: 0.0200
# Epoch: 21, Batch: 20, Loss: 0.0097
# Epoch: 21, Batch: 30, Loss: 0.0148
# Epoch: 21, Batch: 40, Loss: 0.0048
# Epoch: 21, Batch: 50, Loss: 0.0189
# Epoch: 21, Batch: 60, Loss: 0.0216
# Epoch: 21, Batch: 70, Loss: 0.0525
# Epoch: 21, Batch: 80, Loss: 0.0214
# Epoch: 21, Batch: 90, Loss: 0.0099
# Epoch: 21, Batch: 100, Loss: 0.0114
# Epoch: 21, Batch: 110, Loss: 0.0078
# Epoch: 21, Train Loss: 0.0304, Val Loss: 0.0183
# Epoch: 22, Batch: 0, Loss: 0.0249
# Epoch: 22, Batch: 10, Loss: 0.0014
# Epoch: 22, Batch: 20, Loss: 0.0035
# Epoch: 22, Batch: 30, Loss: 0.0033
# Epoch: 22, Batch: 40, Loss: 0.0076
# Epoch: 22, Batch: 50, Loss: 0.0075
# Epoch: 22, Batch: 60, Loss: 0.0009
# Epoch: 22, Batch: 70, Loss: 0.0015
# Epoch: 22, Batch: 80, Loss: 0.0023
# Epoch: 22, Batch: 90, Loss: 0.0056
# Epoch: 22, Batch: 100, Loss: 0.0161
# Epoch: 22, Batch: 110, Loss: 0.0067
# Epoch: 22, Train Loss: 0.0064, Val Loss: 0.0247
# Epoch: 23, Batch: 0, Loss: 0.0105
# Epoch: 23, Batch: 10, Loss: 0.0318
# Epoch: 23, Batch: 20, Loss: 0.0242
# Epoch: 23, Batch: 30, Loss: 0.0140
# Epoch: 23, Batch: 40, Loss: 0.0300
# Epoch: 23, Batch: 50, Loss: 0.0039
# Epoch: 23, Batch: 60, Loss: 0.0066
# Epoch: 23, Batch: 70, Loss: 0.0066
# Epoch: 23, Batch: 80, Loss: 0.0019
# Epoch: 23, Batch: 90, Loss: 0.0131
# Epoch: 23, Batch: 100, Loss: 0.0050
# Epoch: 23, Batch: 110, Loss: 0.0165
# Epoch: 23, Train Loss: 0.0151, Val Loss: 0.0239
# Epoch: 24, Batch: 0, Loss: 0.0118
# Epoch: 24, Batch: 10, Loss: 0.0347
# Epoch: 24, Batch: 20, Loss: 0.0194
# Epoch: 24, Batch: 30, Loss: 0.0070
# Epoch: 24, Batch: 40, Loss: 0.0168
# Epoch: 24, Batch: 50, Loss: 0.0115
# Epoch: 24, Batch: 60, Loss: 0.0106
# Epoch: 24, Batch: 70, Loss: 0.0056
# Epoch: 24, Batch: 80, Loss: 0.0108
# Epoch: 24, Batch: 90, Loss: 0.0052
# Epoch: 24, Batch: 100, Loss: 0.0157
# Epoch: 24, Batch: 110, Loss: 0.0277
# Epoch: 24, Train Loss: 0.0129, Val Loss: 0.0380
# Epoch: 25, Batch: 0, Loss: 0.0114
# Epoch: 25, Batch: 10, Loss: 0.0085
# Epoch: 25, Batch: 20, Loss: 0.0055
# Epoch: 25, Batch: 30, Loss: 0.0090
# Epoch: 25, Batch: 40, Loss: 0.0051
# Epoch: 25, Batch: 50, Loss: 0.0209
# Epoch: 25, Batch: 60, Loss: 0.0194
# Epoch: 25, Batch: 70, Loss: 0.0070
# Epoch: 25, Batch: 80, Loss: 0.0025
# Epoch: 25, Batch: 90, Loss: 0.0061
# Epoch: 25, Batch: 100, Loss: 0.0112
# Epoch: 25, Batch: 110, Loss: 0.0060
# Epoch: 25, Train Loss: 0.0126, Val Loss: 0.0237
# Epoch: 26, Batch: 0, Loss: 0.0054
# Epoch: 26, Batch: 10, Loss: 0.0064
# Epoch: 26, Batch: 20, Loss: 0.0066
# Epoch: 26, Batch: 30, Loss: 0.0220
# Epoch: 26, Batch: 40, Loss: 0.0199
# Epoch: 26, Batch: 50, Loss: 0.0053
# Epoch: 26, Batch: 60, Loss: 0.0066
# Epoch: 26, Batch: 70, Loss: 0.0020
# Epoch: 26, Batch: 80, Loss: 0.0042
# Epoch: 26, Batch: 90, Loss: 0.0064
# Epoch: 26, Batch: 100, Loss: 0.0158
# Epoch: 26, Batch: 110, Loss: 0.0743
# Epoch: 26, Train Loss: 0.0127, Val Loss: 0.0442
# Epoch: 27, Batch: 0, Loss: 0.0141
# Epoch: 27, Batch: 10, Loss: 0.0222
# Epoch: 27, Batch: 20, Loss: 0.0095
# Epoch: 27, Batch: 30, Loss: 0.0114
# Epoch: 27, Batch: 40, Loss: 0.0009
# Epoch: 27, Batch: 50, Loss: 0.0026
# Epoch: 27, Batch: 60, Loss: 0.0011
# Epoch: 27, Batch: 70, Loss: 0.0042
# Epoch: 27, Batch: 80, Loss: 0.0105
# Epoch: 27, Batch: 90, Loss: 0.0038
# Epoch: 27, Batch: 100, Loss: 0.0021
# Epoch: 27, Batch: 110, Loss: 0.0013
# Epoch: 27, Train Loss: 0.0111, Val Loss: 0.0198
# Epoch: 28, Batch: 0, Loss: 0.0042
# Epoch: 28, Batch: 10, Loss: 0.0025
# Epoch: 28, Batch: 20, Loss: 0.0279
# Epoch: 28, Batch: 30, Loss: 0.0297
# Epoch: 28, Batch: 40, Loss: 0.0035
# Epoch: 28, Batch: 50, Loss: 0.0067
# Epoch: 28, Batch: 60, Loss: 0.0096
# Epoch: 28, Batch: 70, Loss: 0.0097
# Epoch: 28, Batch: 80, Loss: 0.0100
# Epoch: 28, Batch: 90, Loss: 0.0050
# Epoch: 28, Batch: 100, Loss: 0.0150
# Epoch: 28, Batch: 110, Loss: 0.0045
# Epoch: 28, Train Loss: 0.0094, Val Loss: 0.0263
# Epoch: 29, Batch: 0, Loss: 0.0056
# Epoch: 29, Batch: 10, Loss: 0.0089
# Epoch: 29, Batch: 20, Loss: 0.0042
# Epoch: 29, Batch: 30, Loss: 0.0109
# Epoch: 29, Batch: 40, Loss: 0.0112
# Epoch: 29, Batch: 50, Loss: 0.0072
# Epoch: 29, Batch: 60, Loss: 0.0016
# Epoch: 29, Batch: 70, Loss: 0.0171
# Epoch: 29, Batch: 80, Loss: 0.0082
# Epoch: 29, Batch: 90, Loss: 0.0111
# Epoch: 29, Batch: 100, Loss: 0.0050
# Epoch: 29, Batch: 110, Loss: 0.0101
# Epoch: 29, Train Loss: 0.0096, Val Loss: 0.0244
# Epoch: 30, Batch: 0, Loss: 0.0036
# Epoch: 30, Batch: 10, Loss: 0.0397
# Epoch: 30, Batch: 20, Loss: 0.0147
# Epoch: 30, Batch: 30, Loss: 0.0144
# Epoch: 30, Batch: 40, Loss: 0.0122
# Epoch: 30, Batch: 50, Loss: 0.0024
# Epoch: 30, Batch: 60, Loss: 0.0027
# Epoch: 30, Batch: 70, Loss: 0.0005
# Epoch: 30, Batch: 80, Loss: 0.0025
# Epoch: 30, Batch: 90, Loss: 0.0060
# Epoch: 30, Batch: 100, Loss: 0.0034
# Epoch: 30, Batch: 110, Loss: 0.0028
# Epoch: 30, Train Loss: 0.0126, Val Loss: 0.0162
# Input: gfbs, Decrypted: MOM
