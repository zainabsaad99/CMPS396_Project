# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
import string

# Data Preparation
def load_data(file_path):
    df = pd.read_excel(file_path)

    # Filter rows where 'Output' length is <=500
    df = df[df['output'].str.len() <= 200]

    # Get the count of such rows
    count_filtered = len(df)

    # Randomly select 250,000 rows (if available)
    if count_filtered > 400000:
        df = df.sample(n=400000, random_state=42)
    print(len(df))
    inputs = df['input'].astype(str).tolist()
    outputs = df['output'].astype(str).tolist()


    return inputs, outputs

# Tokenization and Vocabulary
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        # Special tokens
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        # All printable characters
        all_chars = list(string.printable)

        # Create vocabulary
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})

        # Reverse mapping
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Dataset Class
class CipherDataset(data.Dataset):
    def __init__(self, inputs, outputs, vocab, max_length):
        self.inputs = inputs
        self.outputs = outputs
        self.vocab = vocab
        self.max_length = max_length

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_text = self.inputs[idx]
        output_text = self.outputs[idx]

        # Encode with SOS and EOS tokens
        input_encoded = [self.vocab.sos_token] + self.vocab.encode(input_text) + [self.vocab.eos_token]
        output_encoded = [self.vocab.sos_token] + self.vocab.encode(output_text) + [self.vocab.eos_token]

        # Pad sequences
        input_padded = input_encoded + [self.vocab.pad_token] * (self.max_length - len(input_encoded))
        output_padded = output_encoded + [self.vocab.pad_token] * (self.max_length - len(output_encoded))

        # Truncate if necessary
        input_padded = input_padded[:self.max_length]
        output_padded = output_padded[:self.max_length]

        return torch.tensor(input_padded), torch.tensor(output_padded)

# Transformer Model (same as your implementation)
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Q, K, V shapes: (batch_size, num_heads, seq_len, d_k)
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn_probs = torch.softmax(scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        # Source mask
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, src_len)

        # Target mask
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, tgt_len)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=tgt.device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask  # (batch_size, 1, tgt_len, tgt_len)

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (src, tgt) in enumerate(train_loader):
            src, tgt = src.to(device), tgt.to(device)

            optimizer.zero_grad()
            output = model(src, tgt[:, :-1])

            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch_idx % 10 == 0:
                print(f'Epoch: {epoch+1}, Batch: {batch_idx}, Loss: {loss.item():.4f}')

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        val_loss = evaluate_model(model, val_loader, criterion, device)
        print(f'Epoch: {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), '/content/drive/MyDrive/vigenere_vanilla_five.pth')

    return model

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            total_loss += loss.item()

    return total_loss / len(data_loader)

# Inference Function
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        # Encode the input text
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        # Initialize target with SOS token
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        # Decode the output
        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

# Main Execution
if __name__ == "__main__":
    # Load and prepare data
    inputs, outputs = load_data('/content/Full_training_vigenere_5.xlsx')

    # Create vocabulary
    vocab = Vocabulary()

    # Split data into train and validation
    train_inputs, val_inputs, train_outputs, val_outputs = train_test_split(
        inputs, outputs, test_size=0.2, random_state=42
    )

    # Create datasets
    max_length = 256  # Adjust based on your data
    train_dataset = CipherDataset(train_inputs, train_outputs, vocab, max_length)
    val_dataset = CipherDataset(val_inputs, val_outputs, vocab, max_length)

    # Create data loaders
    batch_size = 700
    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=256,
        num_heads=2,
        num_layers=6,
        d_ff=512,
        max_seq_length=max_length,
        dropout=0.10213470498440091
    ).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=vocab.pad_token)
    optimizer = optim.Adam(model.parameters(), lr=0.0004286912950025756, betas=(0.9, 0.98), eps=1e-9)

    # Train the model
    num_epochs = 30
    trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

    # Test the model
    test_text = "gfbs"  # Should decrypt to "fear"
    decrypted = decrypt_text(trained_model, test_text, vocab, max_length, device)
    print(f"Input: {test_text}, Decrypted: {decrypted}")
# Out:
# 179975
# Epoch: 1, Batch: 0, Loss: 4.7095
# Epoch: 1, Batch: 10, Loss: 3.0941
# Epoch: 1, Batch: 20, Loss: 2.6557
# Epoch: 1, Batch: 30, Loss: 2.4253
# Epoch: 1, Batch: 40, Loss: 2.3257
# Epoch: 1, Batch: 50, Loss: 2.2692
# Epoch: 1, Batch: 60, Loss: 2.2086
# Epoch: 1, Batch: 70, Loss: 2.1667
# Epoch: 1, Batch: 80, Loss: 2.1315
# Epoch: 1, Batch: 90, Loss: 2.0839
# Epoch: 1, Batch: 100, Loss: 2.0542
# Epoch: 1, Batch: 110, Loss: 1.9998
# Epoch: 1, Batch: 120, Loss: 1.9740
# Epoch: 1, Batch: 130, Loss: 1.9858
# Epoch: 1, Batch: 140, Loss: 1.9028
# Epoch: 1, Batch: 150, Loss: 1.8801
# Epoch: 1, Batch: 160, Loss: 1.8299
# Epoch: 1, Batch: 170, Loss: 1.8797
# Epoch: 1, Batch: 180, Loss: 1.7780
# Epoch: 1, Batch: 190, Loss: 1.7927
# Epoch: 1, Batch: 200, Loss: 1.7352
# Epoch: 1, Train Loss: 2.1481, Val Loss: 1.6625
# Epoch: 2, Batch: 0, Loss: 1.6599
# Epoch: 2, Batch: 10, Loss: 1.6762
# Epoch: 2, Batch: 20, Loss: 1.5952
# Epoch: 2, Batch: 30, Loss: 1.5626
# Epoch: 2, Batch: 40, Loss: 1.5302
# Epoch: 2, Batch: 50, Loss: 1.5228
# Epoch: 2, Batch: 60, Loss: 1.4784
# Epoch: 2, Batch: 70, Loss: 1.4559
# Epoch: 2, Batch: 80, Loss: 1.4609
# Epoch: 2, Batch: 90, Loss: 1.3813
# Epoch: 2, Batch: 100, Loss: 1.3983
# Epoch: 2, Batch: 110, Loss: 1.3397
# Epoch: 2, Batch: 120, Loss: 1.4653
# Epoch: 2, Batch: 130, Loss: 1.3572
# Epoch: 2, Batch: 140, Loss: 1.2962
# Epoch: 2, Batch: 150, Loss: 1.2793
# Epoch: 2, Batch: 160, Loss: 1.2334
# Epoch: 2, Batch: 170, Loss: 1.2854
# Epoch: 2, Batch: 180, Loss: 1.2349
# Epoch: 2, Batch: 190, Loss: 1.1819
# Epoch: 2, Batch: 200, Loss: 1.2440
# Epoch: 2, Train Loss: 1.4099, Val Loss: 1.1998
# Epoch: 3, Batch: 0, Loss: 1.1933
# Epoch: 3, Batch: 10, Loss: 1.2037
# Epoch: 3, Batch: 20, Loss: 1.1344
# Epoch: 3, Batch: 30, Loss: 1.0684
# Epoch: 3, Batch: 40, Loss: 1.0635
# Epoch: 3, Batch: 50, Loss: 1.0482
# Epoch: 3, Batch: 60, Loss: 1.0645
# Epoch: 3, Batch: 70, Loss: 1.0859
# Epoch: 3, Batch: 80, Loss: 1.0015
# Epoch: 3, Batch: 90, Loss: 0.9986
# Epoch: 3, Batch: 100, Loss: 0.9394
# Epoch: 3, Batch: 110, Loss: 0.9557
# Epoch: 3, Batch: 120, Loss: 0.9204
# Epoch: 3, Batch: 130, Loss: 0.9077
# Epoch: 3, Batch: 140, Loss: 0.8729
# Epoch: 3, Batch: 150, Loss: 0.8398
# Epoch: 3, Batch: 160, Loss: 0.8158
# Epoch: 3, Batch: 170, Loss: 0.7868
# Epoch: 3, Batch: 180, Loss: 0.7757
# Epoch: 3, Batch: 190, Loss: 0.7538
# Epoch: 3, Batch: 200, Loss: 0.7186
# Epoch: 3, Train Loss: 0.9559, Val Loss: 0.7160
# Epoch: 4, Batch: 0, Loss: 0.7180
# Epoch: 4, Batch: 10, Loss: 0.6781
# Epoch: 4, Batch: 20, Loss: 0.6796
# Epoch: 4, Batch: 30, Loss: 0.6626
# Epoch: 4, Batch: 40, Loss: 0.6148
# Epoch: 4, Batch: 50, Loss: 0.6012
# Epoch: 4, Batch: 60, Loss: 0.5774
# Epoch: 4, Batch: 70, Loss: 0.5802
# Epoch: 4, Batch: 80, Loss: 0.5690
# Epoch: 4, Batch: 90, Loss: 0.5657
# Epoch: 4, Batch: 100, Loss: 0.5241
# Epoch: 4, Batch: 110, Loss: 0.4959
# Epoch: 4, Batch: 120, Loss: 0.5097
# Epoch: 4, Batch: 130, Loss: 1.0199
# Epoch: 4, Batch: 140, Loss: 0.6737
# Epoch: 4, Batch: 150, Loss: 0.5488
# Epoch: 4, Batch: 160, Loss: 0.4822
# Epoch: 4, Batch: 170, Loss: 0.4679
# Epoch: 4, Batch: 180, Loss: 0.4526
# Epoch: 4, Batch: 190, Loss: 0.4223
# Epoch: 4, Batch: 200, Loss: 0.4046
# Epoch: 4, Train Loss: 0.5696, Val Loss: 0.4217
# Epoch: 5, Batch: 0, Loss: 0.4097
# Epoch: 5, Batch: 10, Loss: 0.3838
# Epoch: 5, Batch: 20, Loss: 0.3819
# Epoch: 5, Batch: 30, Loss: 0.3693
# Epoch: 5, Batch: 40, Loss: 0.3464
# Epoch: 5, Batch: 50, Loss: 0.3668
# Epoch: 5, Batch: 60, Loss: 0.3355
# Epoch: 5, Batch: 70, Loss: 0.3451
# Epoch: 5, Batch: 80, Loss: 0.3197
# Epoch: 5, Batch: 90, Loss: 0.3016
# Epoch: 5, Batch: 100, Loss: 0.3198
# Epoch: 5, Batch: 110, Loss: 0.3061
# Epoch: 5, Batch: 120, Loss: 0.3249
# Epoch: 5, Batch: 130, Loss: 0.3969
# Epoch: 5, Batch: 140, Loss: 0.3828
# Epoch: 5, Batch: 150, Loss: 0.3109
# Epoch: 5, Batch: 160, Loss: 0.3006
# Epoch: 5, Batch: 170, Loss: 0.2394
# Epoch: 5, Batch: 180, Loss: 0.2359
# Epoch: 5, Batch: 190, Loss: 0.2414
# Epoch: 5, Batch: 200, Loss: 0.2265
# Epoch: 5, Train Loss: 0.3330, Val Loss: 0.2492
# Epoch: 6, Batch: 0, Loss: 0.2144
# Epoch: 6, Batch: 10, Loss: 0.1962
# Epoch: 6, Batch: 20, Loss: 0.2223
# Epoch: 6, Batch: 30, Loss: 0.2285
# Epoch: 6, Batch: 40, Loss: 0.2074
# Epoch: 6, Batch: 50, Loss: 0.2067
# Epoch: 6, Batch: 60, Loss: 0.1948
# Epoch: 6, Batch: 70, Loss: 0.1816
# Epoch: 6, Batch: 80, Loss: 0.1996
# Epoch: 6, Batch: 90, Loss: 0.1973
# Epoch: 6, Batch: 100, Loss: 0.1825
# Epoch: 6, Batch: 110, Loss: 0.2072
# Epoch: 6, Batch: 120, Loss: 0.1913
# Epoch: 6, Batch: 130, Loss: 0.1969
# Epoch: 6, Batch: 140, Loss: 0.1971
# Epoch: 6, Batch: 150, Loss: 0.1705
# Epoch: 6, Batch: 160, Loss: 0.1669
# Epoch: 6, Batch: 170, Loss: 0.1575
# Epoch: 6, Batch: 180, Loss: 0.1629
# Epoch: 6, Batch: 190, Loss: 0.1522
# Epoch: 6, Batch: 200, Loss: 0.1574
# Epoch: 6, Train Loss: 0.1936, Val Loss: 0.1602
# Epoch: 7, Batch: 0, Loss: 0.1264
# Epoch: 7, Batch: 10, Loss: 0.1230
# Epoch: 7, Batch: 20, Loss: 0.1350
# Epoch: 7, Batch: 30, Loss: 0.1459
# Epoch: 7, Batch: 40, Loss: 0.1373
# Epoch: 7, Batch: 50, Loss: 0.1319
# Epoch: 7, Batch: 60, Loss: 0.1408
# Epoch: 7, Batch: 70, Loss: 0.1206
# Epoch: 7, Batch: 80, Loss: 0.1317
# Epoch: 7, Batch: 90, Loss: 0.1430
# Epoch: 7, Batch: 100, Loss: 0.1282
# Epoch: 7, Batch: 110, Loss: 0.6168
# Epoch: 7, Batch: 120, Loss: 0.2497
# Epoch: 7, Batch: 130, Loss: 0.1545
# Epoch: 7, Batch: 140, Loss: 0.1178
# Epoch: 7, Batch: 150, Loss: 0.1117
# Epoch: 7, Batch: 160, Loss: 0.1029
# Epoch: 7, Batch: 170, Loss: 0.1095
# Epoch: 7, Batch: 180, Loss: 0.1035
# Epoch: 7, Batch: 190, Loss: 0.0928
# Epoch: 7, Batch: 200, Loss: 0.1003
# Epoch: 7, Train Loss: 0.1474, Val Loss: 0.1017
# Epoch: 8, Batch: 0, Loss: 0.0728
# Epoch: 8, Batch: 10, Loss: 0.1020
# Epoch: 8, Batch: 20, Loss: 0.0830
# Epoch: 8, Batch: 30, Loss: 0.0838
# Epoch: 8, Batch: 40, Loss: 0.0858
# Epoch: 8, Batch: 50, Loss: 0.0932
# Epoch: 8, Batch: 60, Loss: 0.0920
# Epoch: 8, Batch: 70, Loss: 0.0780
# Epoch: 8, Batch: 80, Loss: 0.0955
# Epoch: 8, Batch: 90, Loss: 0.0736
# Epoch: 8, Batch: 100, Loss: 0.0834
# Epoch: 8, Batch: 110, Loss: 0.0669
# Epoch: 8, Batch: 120, Loss: 0.0733
# Epoch: 8, Batch: 130, Loss: 0.0727
# Epoch: 8, Batch: 140, Loss: 0.0880
# Epoch: 8, Batch: 150, Loss: 0.1043
# Epoch: 8, Batch: 160, Loss: 0.0966
# Epoch: 8, Batch: 170, Loss: 0.0763
# Epoch: 8, Batch: 180, Loss: 0.0696
# Epoch: 8, Batch: 190, Loss: 0.0904
# Epoch: 8, Batch: 200, Loss: 0.3705
# Epoch: 8, Train Loss: 0.0987, Val Loss: 0.2091
# Epoch: 9, Batch: 0, Loss: 0.1837
# Epoch: 9, Batch: 10, Loss: 0.1292
# Epoch: 9, Batch: 20, Loss: 0.0626
# Epoch: 9, Batch: 30, Loss: 0.0636
# Epoch: 9, Batch: 40, Loss: 0.0603
# Epoch: 9, Batch: 50, Loss: 0.0532
# Epoch: 9, Batch: 60, Loss: 0.0524
# Epoch: 9, Batch: 70, Loss: 0.0476
# Epoch: 9, Batch: 80, Loss: 0.0380
# Epoch: 9, Batch: 90, Loss: 0.0443
# Epoch: 9, Batch: 100, Loss: 0.0490
# Epoch: 9, Batch: 110, Loss: 0.0789
# Epoch: 9, Batch: 120, Loss: 0.0495
# Epoch: 9, Batch: 130, Loss: 0.0555
# Epoch: 9, Batch: 140, Loss: 0.0567
# Epoch: 9, Batch: 150, Loss: 0.0512
# Epoch: 9, Batch: 160, Loss: 0.0631
# Epoch: 9, Batch: 170, Loss: 0.0621
# Epoch: 9, Batch: 180, Loss: 0.0474
# Epoch: 9, Batch: 190, Loss: 0.0616
# Epoch: 9, Batch: 200, Loss: 0.0524
# Epoch: 9, Train Loss: 0.0620, Val Loss: 0.0727
# Epoch: 10, Batch: 0, Loss: 0.0427
# Epoch: 10, Batch: 10, Loss: 0.0427
# Epoch: 10, Batch: 20, Loss: 0.0567
# Epoch: 10, Batch: 30, Loss: 0.0383
# Epoch: 10, Batch: 40, Loss: 0.0474
# Epoch: 10, Batch: 50, Loss: 0.0567
# Epoch: 10, Batch: 60, Loss: 0.2015
# Epoch: 10, Batch: 70, Loss: 0.1172
# Epoch: 10, Batch: 80, Loss: 0.0753
# Epoch: 10, Batch: 90, Loss: 0.0461
# Epoch: 10, Batch: 100, Loss: 0.0509
# Epoch: 10, Batch: 110, Loss: 0.0399
# Epoch: 10, Batch: 120, Loss: 0.0345
# Epoch: 10, Batch: 130, Loss: 0.0337
# Epoch: 10, Batch: 140, Loss: 0.0313
# Epoch: 10, Batch: 150, Loss: 0.0347
# Epoch: 10, Batch: 160, Loss: 0.0438
# Epoch: 10, Batch: 170, Loss: 0.0328
# Epoch: 10, Batch: 180, Loss: 0.0320
# Epoch: 10, Batch: 190, Loss: 0.0439
# Epoch: 10, Batch: 200, Loss: 0.0423
# Epoch: 10, Train Loss: 0.0606, Val Loss: 0.0560
# Epoch: 11, Batch: 0, Loss: 0.0325
# Epoch: 11, Batch: 10, Loss: 0.0348
# Epoch: 11, Batch: 20, Loss: 0.0550
# Epoch: 11, Batch: 30, Loss: 0.0445
# Epoch: 11, Batch: 40, Loss: 0.0364
# Epoch: 11, Batch: 50, Loss: 0.0341
# Epoch: 11, Batch: 60, Loss: 0.0381
# Epoch: 11, Batch: 70, Loss: 0.0498
# Epoch: 11, Batch: 80, Loss: 0.0468
# Epoch: 11, Batch: 90, Loss: 0.0349
# Epoch: 11, Batch: 100, Loss: 0.0447
# Epoch: 11, Batch: 110, Loss: 0.0433
# Epoch: 11, Batch: 120, Loss: 0.0373
# Epoch: 11, Batch: 130, Loss: 0.0401
# Epoch: 11, Batch: 140, Loss: 0.0296
# Epoch: 11, Batch: 150, Loss: 0.0411
# Epoch: 11, Batch: 160, Loss: 0.0457
# Epoch: 11, Batch: 170, Loss: 0.0420
# Epoch: 11, Batch: 180, Loss: 0.0504
# Epoch: 11, Batch: 190, Loss: 0.0302
# Epoch: 11, Batch: 200, Loss: 0.0407
# Epoch: 11, Train Loss: 0.0399, Val Loss: 0.0489
# Epoch: 12, Batch: 0, Loss: 0.0364
# Epoch: 12, Batch: 10, Loss: 0.0211
# Epoch: 12, Batch: 20, Loss: 0.0235
# Epoch: 12, Batch: 30, Loss: 0.0322
# Epoch: 12, Batch: 40, Loss: 0.0272
# Epoch: 12, Batch: 50, Loss: 0.0395
# Epoch: 12, Batch: 60, Loss: 0.0375
# Epoch: 12, Batch: 70, Loss: 0.0348
# Epoch: 12, Batch: 80, Loss: 0.0262
# Epoch: 12, Batch: 90, Loss: 0.0321
# Epoch: 12, Batch: 100, Loss: 0.0343
# Epoch: 12, Batch: 110, Loss: 0.0335
# Epoch: 12, Batch: 120, Loss: 0.0452
# Epoch: 12, Batch: 130, Loss: 0.0278
# Epoch: 12, Batch: 140, Loss: 0.0283
# Epoch: 12, Batch: 150, Loss: 0.0321
# Epoch: 12, Batch: 160, Loss: 0.0403
# Epoch: 12, Batch: 170, Loss: 0.0282
# Epoch: 12, Batch: 180, Loss: 0.0359
# Epoch: 12, Batch: 190, Loss: 0.0374
# Epoch: 12, Batch: 200, Loss: 0.0265
# Epoch: 12, Train Loss: 0.0331, Val Loss: 0.0400
# Epoch: 13, Batch: 0, Loss: 0.0190
# Epoch: 13, Batch: 10, Loss: 0.0296
# Epoch: 13, Batch: 20, Loss: 0.0185
# Epoch: 13, Batch: 30, Loss: 0.0239
# Epoch: 13, Batch: 40, Loss: 0.0232
# Epoch: 13, Batch: 50, Loss: 0.0278
# Epoch: 13, Batch: 60, Loss: 0.0253
# Epoch: 13, Batch: 70, Loss: 0.0344
# Epoch: 13, Batch: 80, Loss: 0.0260
# Epoch: 13, Batch: 90, Loss: 0.0237
# Epoch: 13, Batch: 100, Loss: 0.0188
# Epoch: 13, Batch: 110, Loss: 0.0417
# Epoch: 13, Batch: 120, Loss: 0.0655
# Epoch: 13, Batch: 130, Loss: 0.0332
# Epoch: 13, Batch: 140, Loss: 0.0236
# Epoch: 13, Batch: 150, Loss: 0.0178
# Epoch: 13, Batch: 160, Loss: 0.0141
# Epoch: 13, Batch: 170, Loss: 0.0178
# Epoch: 13, Batch: 180, Loss: 0.0157
# Epoch: 13, Batch: 190, Loss: 0.0218
# Epoch: 13, Batch: 200, Loss: 0.0184
# Epoch: 13, Train Loss: 0.0277, Val Loss: 0.0338
# Epoch: 14, Batch: 0, Loss: 0.0132
# Epoch: 14, Batch: 10, Loss: 0.0142
# Epoch: 14, Batch: 20, Loss: 0.0116
# Epoch: 14, Batch: 30, Loss: 0.0187
# Epoch: 14, Batch: 40, Loss: 0.0182
# Epoch: 14, Batch: 50, Loss: 0.0127
# Epoch: 14, Batch: 60, Loss: 0.0151
# Epoch: 14, Batch: 70, Loss: 0.0183
# Epoch: 14, Batch: 80, Loss: 0.0195
# Epoch: 14, Batch: 90, Loss: 0.0194
# Epoch: 14, Batch: 100, Loss: 0.0209
# Epoch: 14, Batch: 110, Loss: 0.0192
# Epoch: 14, Batch: 120, Loss: 0.0209
# Epoch: 14, Batch: 130, Loss: 0.0198
# Epoch: 14, Batch: 140, Loss: 0.0241
# Epoch: 14, Batch: 150, Loss: 0.0205
# Epoch: 14, Batch: 160, Loss: 0.0316
# Epoch: 14, Batch: 170, Loss: 0.0331
# Epoch: 14, Batch: 180, Loss: 0.0221
# Epoch: 14, Batch: 190, Loss: 0.0257
# Epoch: 14, Batch: 200, Loss: 0.0189
# Epoch: 14, Train Loss: 0.0216, Val Loss: 0.0381
# Epoch: 15, Batch: 0, Loss: 0.0170
# Epoch: 15, Batch: 10, Loss: 0.0198
# Epoch: 15, Batch: 20, Loss: 0.0220
# Epoch: 15, Batch: 30, Loss: 0.0215
# Epoch: 15, Batch: 40, Loss: 0.0185
# Epoch: 15, Batch: 50, Loss: 0.0171
# Epoch: 15, Batch: 60, Loss: 0.5782
# Epoch: 15, Batch: 70, Loss: 0.0928
# Epoch: 15, Batch: 80, Loss: 0.0322
# Epoch: 15, Batch: 90, Loss: 0.0227
# Epoch: 15, Batch: 100, Loss: 0.0123
# Epoch: 15, Batch: 110, Loss: 0.0068
# Epoch: 15, Batch: 120, Loss: 0.0091
# Epoch: 15, Batch: 130, Loss: 0.0121
# Epoch: 15, Batch: 140, Loss: 0.0102
# Epoch: 15, Batch: 150, Loss: 0.0115
# Epoch: 15, Batch: 160, Loss: 0.0098
# Epoch: 15, Batch: 170, Loss: 0.0092
# Epoch: 15, Batch: 180, Loss: 0.0085
# Epoch: 15, Batch: 190, Loss: 0.0123
# Epoch: 15, Batch: 200, Loss: 0.0200
# Epoch: 15, Train Loss: 0.0257, Val Loss: 0.0244
# Epoch: 16, Batch: 0, Loss: 0.0075
# Epoch: 16, Batch: 10, Loss: 0.0121
# Epoch: 16, Batch: 20, Loss: 0.0090
# Epoch: 16, Batch: 30, Loss: 0.0068
# Epoch: 16, Batch: 40, Loss: 0.0117
# Epoch: 16, Batch: 50, Loss: 0.0112
# Epoch: 16, Batch: 60, Loss: 0.0156
# Epoch: 16, Batch: 70, Loss: 0.0140
# Epoch: 16, Batch: 80, Loss: 0.0212
# Epoch: 16, Batch: 90, Loss: 0.0171
# Epoch: 16, Batch: 100, Loss: 0.0233
# Epoch: 16, Batch: 110, Loss: 0.0173
# Epoch: 16, Batch: 120, Loss: 0.0193
# Epoch: 16, Batch: 130, Loss: 0.0165
# Epoch: 16, Batch: 140, Loss: 0.0176
# Epoch: 16, Batch: 150, Loss: 0.0241
# Epoch: 16, Batch: 160, Loss: 0.0195
# Epoch: 16, Batch: 170, Loss: 0.0225
# Epoch: 16, Batch: 180, Loss: 0.0174
# Epoch: 16, Batch: 190, Loss: 0.0155
# Epoch: 16, Batch: 200, Loss: 0.0146
# Epoch: 16, Train Loss: 0.0165, Val Loss: 0.0299
# Epoch: 17, Batch: 0, Loss: 0.0150
# Epoch: 17, Batch: 10, Loss: 0.0219
# Epoch: 17, Batch: 20, Loss: 0.0099
# Epoch: 17, Batch: 30, Loss: 0.0675
# Epoch: 17, Batch: 40, Loss: 0.0249
# Epoch: 17, Batch: 50, Loss: 0.0128
# Epoch: 17, Batch: 60, Loss: 0.0155
# Epoch: 17, Batch: 70, Loss: 0.0141
# Epoch: 17, Batch: 80, Loss: 0.0205
# Epoch: 17, Batch: 90, Loss: 0.0167
# Epoch: 17, Batch: 100, Loss: 0.0177
# Epoch: 17, Batch: 110, Loss: 0.0143
# Epoch: 17, Batch: 120, Loss: 0.0166
# Epoch: 17, Batch: 130, Loss: 0.0148
# Epoch: 17, Batch: 140, Loss: 0.0141
# Epoch: 17, Batch: 150, Loss: 0.0201
# Epoch: 17, Batch: 160, Loss: 0.0156
# Epoch: 17, Batch: 170, Loss: 0.0140
# Epoch: 17, Batch: 180, Loss: 0.0128
# Epoch: 17, Batch: 190, Loss: 0.0119
# Epoch: 17, Batch: 200, Loss: 0.0138
# Epoch: 17, Train Loss: 0.0165, Val Loss: 0.0274
# Epoch: 18, Batch: 0, Loss: 0.0226
# Epoch: 18, Batch: 10, Loss: 0.0132
# Epoch: 18, Batch: 20, Loss: 0.0110
# Epoch: 18, Batch: 30, Loss: 0.0096
# Epoch: 18, Batch: 40, Loss: 0.0510
# Epoch: 18, Batch: 50, Loss: 0.0945
# Epoch: 18, Batch: 60, Loss: 0.0303
# Epoch: 18, Batch: 70, Loss: 0.0173
# Epoch: 18, Batch: 80, Loss: 0.0125
# Epoch: 18, Batch: 90, Loss: 0.0092
# Epoch: 18, Batch: 100, Loss: 0.0124
# Epoch: 18, Batch: 110, Loss: 0.0055
# Epoch: 18, Batch: 120, Loss: 0.0051
# Epoch: 18, Batch: 130, Loss: 0.0067
# Epoch: 18, Batch: 140, Loss: 0.0108
# Epoch: 18, Batch: 150, Loss: 0.0064
# Epoch: 18, Batch: 160, Loss: 0.0071
# Epoch: 18, Batch: 170, Loss: 0.0062
# Epoch: 18, Batch: 180, Loss: 0.0079
# Epoch: 18, Batch: 190, Loss: 0.0080
# Epoch: 18, Batch: 200, Loss: 0.0098
# Epoch: 18, Train Loss: 0.0192, Val Loss: 0.0283
# Epoch: 19, Batch: 0, Loss: 0.0099
# Epoch: 19, Batch: 10, Loss: 0.0107
# Epoch: 19, Batch: 20, Loss: 0.0134
# Epoch: 19, Batch: 30, Loss: 0.0106
# Epoch: 19, Batch: 40, Loss: 0.0097
# Epoch: 19, Batch: 50, Loss: 0.0078
# Epoch: 19, Batch: 60, Loss: 0.0100
# Epoch: 19, Batch: 70, Loss: 0.0146
# Epoch: 19, Batch: 80, Loss: 0.0154
# Epoch: 19, Batch: 90, Loss: 0.0145
# Epoch: 19, Batch: 100, Loss: 0.0098
# Epoch: 19, Batch: 110, Loss: 0.0153
# Epoch: 19, Batch: 120, Loss: 0.0116
# Epoch: 19, Batch: 130, Loss: 0.0139
# Epoch: 19, Batch: 140, Loss: 0.0129
# Epoch: 19, Batch: 150, Loss: 0.0102
# Epoch: 19, Batch: 160, Loss: 0.0168
# Epoch: 19, Batch: 170, Loss: 0.0172
# Epoch: 19, Batch: 180, Loss: 0.0103
# Epoch: 19, Batch: 190, Loss: 0.0138
# Epoch: 19, Batch: 200, Loss: 0.0139
# Epoch: 19, Train Loss: 0.0131, Val Loss: 0.0247
# Epoch: 20, Batch: 0, Loss: 0.0128
# Epoch: 20, Batch: 10, Loss: 0.0165
# Epoch: 20, Batch: 20, Loss: 0.0102
# Epoch: 20, Batch: 30, Loss: 0.0159
# Epoch: 20, Batch: 40, Loss: 0.0078
# Epoch: 20, Batch: 50, Loss: 0.0066
# Epoch: 20, Batch: 60, Loss: 0.0090
# Epoch: 20, Batch: 70, Loss: 0.0128
# Epoch: 20, Batch: 80, Loss: 0.0094
# Epoch: 20, Batch: 90, Loss: 0.0186
# Epoch: 20, Batch: 100, Loss: 0.0101
# Epoch: 20, Batch: 110, Loss: 0.0097
# Epoch: 20, Batch: 120, Loss: 0.0097
# Epoch: 20, Batch: 130, Loss: 0.0096
# Epoch: 20, Batch: 140, Loss: 0.0078
# Epoch: 20, Batch: 150, Loss: 0.0103
# Epoch: 20, Batch: 160, Loss: 0.0138
# Epoch: 20, Batch: 170, Loss: 0.0190
# Epoch: 20, Batch: 180, Loss: 0.0123
# Epoch: 20, Batch: 190, Loss: 0.0112
# Epoch: 20, Batch: 200, Loss: 0.0126
# Epoch: 20, Train Loss: 0.0118, Val Loss: 0.0199
# Epoch: 21, Batch: 0, Loss: 0.0143
# Epoch: 21, Batch: 10, Loss: 0.0092
# Epoch: 21, Batch: 20, Loss: 0.0201
# Epoch: 21, Batch: 30, Loss: 0.0093
# Epoch: 21, Batch: 40, Loss: 0.0106
# Epoch: 21, Batch: 50, Loss: 0.0082
# Epoch: 21, Batch: 60, Loss: 0.0125
# Epoch: 21, Batch: 70, Loss: 0.0100
# Epoch: 21, Batch: 80, Loss: 0.0108
# Epoch: 21, Batch: 90, Loss: 0.0114
# Epoch: 21, Batch: 100, Loss: 0.0146
# Epoch: 21, Batch: 110, Loss: 0.0122
# Epoch: 21, Batch: 120, Loss: 0.0103
# Epoch: 21, Batch: 130, Loss: 0.0086
# Epoch: 21, Batch: 140, Loss: 0.0144
# Epoch: 21, Batch: 150, Loss: 0.0098
# Epoch: 21, Batch: 160, Loss: 0.0090
# Epoch: 21, Batch: 170, Loss: 0.0147
# Epoch: 21, Batch: 180, Loss: 0.0092
# Epoch: 21, Batch: 190, Loss: 0.0089
# Epoch: 21, Batch: 200, Loss: 0.0090
# Epoch: 21, Train Loss: 0.0108, Val Loss: 0.0232
# Epoch: 22, Batch: 0, Loss: 0.0079
# Epoch: 22, Batch: 10, Loss: 0.0098
# Epoch: 22, Batch: 20, Loss: 0.0088
# Epoch: 22, Batch: 30, Loss: 0.0124
# Epoch: 22, Batch: 40, Loss: 0.0114
# Epoch: 22, Batch: 50, Loss: 0.0069
# Epoch: 22, Batch: 60, Loss: 0.0081
# Epoch: 22, Batch: 70, Loss: 0.0101
# Epoch: 22, Batch: 80, Loss: 0.0072
# Epoch: 22, Batch: 90, Loss: 0.0095
# Epoch: 22, Batch: 100, Loss: 0.0084
# Epoch: 22, Batch: 110, Loss: 0.0129
# Epoch: 22, Batch: 120, Loss: 0.0131
# Epoch: 22, Batch: 130, Loss: 0.0169
# Epoch: 22, Batch: 140, Loss: 0.0177
# Epoch: 22, Batch: 150, Loss: 0.0095
# Epoch: 22, Batch: 160, Loss: 0.0089
# Epoch: 22, Batch: 170, Loss: 0.0099
# Epoch: 22, Batch: 180, Loss: 0.0088
# Epoch: 22, Batch: 190, Loss: 0.0070
# Epoch: 22, Batch: 200, Loss: 0.0076
# Epoch: 22, Train Loss: 0.0102, Val Loss: 0.0207
# Epoch: 23, Batch: 0, Loss: 0.0083
# Epoch: 23, Batch: 10, Loss: 0.0060
# Epoch: 23, Batch: 20, Loss: 0.0071
# Epoch: 23, Batch: 30, Loss: 0.0089
# Epoch: 23, Batch: 40, Loss: 0.0105
# Epoch: 23, Batch: 50, Loss: 0.0083
# Epoch: 23, Batch: 60, Loss: 0.0074
# Epoch: 23, Batch: 70, Loss: 0.0081
# Epoch: 23, Batch: 80, Loss: 0.0096
# Epoch: 23, Batch: 90, Loss: 0.0098
# Epoch: 23, Batch: 100, Loss: 0.0087
# Epoch: 23, Batch: 110, Loss: 0.0079
# Epoch: 23, Batch: 120, Loss: 0.0097
# Epoch: 23, Batch: 130, Loss: 0.0080
# Epoch: 23, Batch: 140, Loss: 0.0094
# Epoch: 23, Batch: 150, Loss: 0.0118
# Epoch: 23, Batch: 160, Loss: 0.0088
# Epoch: 23, Batch: 170, Loss: 0.0115
# Epoch: 23, Batch: 180, Loss: 0.0115
# Epoch: 23, Batch: 190, Loss: 0.0080
# Epoch: 23, Batch: 200, Loss: 0.0155
# Epoch: 23, Train Loss: 0.0094, Val Loss: 0.0223
# Epoch: 24, Batch: 0, Loss: 0.0080
# Epoch: 24, Batch: 10, Loss: 0.0076
# Epoch: 24, Batch: 20, Loss: 0.0061
# Epoch: 24, Batch: 30, Loss: 0.0075
# Epoch: 24, Batch: 40, Loss: 0.0047
# Epoch: 24, Batch: 50, Loss: 0.0072
# Epoch: 24, Batch: 60, Loss: 0.0056
# Epoch: 24, Batch: 70, Loss: 0.0072
# Epoch: 24, Batch: 80, Loss: 0.0061
# Epoch: 24, Batch: 90, Loss: 0.0125
# Epoch: 24, Batch: 100, Loss: 0.0077
# Epoch: 24, Batch: 110, Loss: 0.0118
# Epoch: 24, Batch: 120, Loss: 0.0075
# Epoch: 24, Batch: 130, Loss: 0.0114
# Epoch: 24, Batch: 140, Loss: 0.0173
# Epoch: 24, Batch: 150, Loss: 0.0099
# Epoch: 24, Batch: 160, Loss: 0.0125
# Epoch: 24, Batch: 170, Loss: 0.0080
# Epoch: 24, Batch: 180, Loss: 0.0076
# Epoch: 24, Batch: 190, Loss: 0.0120
# Epoch: 24, Batch: 200, Loss: 0.0108
# Epoch: 24, Train Loss: 0.0088, Val Loss: 0.0155
# Epoch: 25, Batch: 0, Loss: 0.0050
# Epoch: 25, Batch: 10, Loss: 0.0053
# Epoch: 25, Batch: 20, Loss: 0.0053
# Epoch: 25, Batch: 30, Loss: 0.0113
# Epoch: 25, Batch: 40, Loss: 0.0081
# Epoch: 25, Batch: 50, Loss: 0.0063
# Epoch: 25, Batch: 60, Loss: 0.0086
# Epoch: 25, Batch: 70, Loss: 0.0139
# Epoch: 25, Batch: 80, Loss: 0.0067
# Epoch: 25, Batch: 90, Loss: 0.0054
# Epoch: 25, Batch: 100, Loss: 0.0038
# Epoch: 25, Batch: 110, Loss: 0.0063
# Epoch: 25, Batch: 120, Loss: 0.0055
# Epoch: 25, Batch: 130, Loss: 0.0056
# Epoch: 25, Batch: 140, Loss: 0.0066
# Epoch: 25, Batch: 150, Loss: 0.0060
# Epoch: 25, Batch: 160, Loss: 0.0081
# Epoch: 25, Batch: 170, Loss: 0.0078
# Epoch: 25, Batch: 180, Loss: 0.0099
# Epoch: 25, Batch: 190, Loss: 0.0075
# Epoch: 25, Batch: 200, Loss: 0.0076
# Epoch: 25, Train Loss: 0.0080, Val Loss: 0.0168
# Epoch: 26, Batch: 0, Loss: 0.0082
# Epoch: 26, Batch: 10, Loss: 0.0062
# Epoch: 26, Batch: 20, Loss: 0.0052
# Epoch: 26, Batch: 30, Loss: 0.0068
# Epoch: 26, Batch: 40, Loss: 0.0047
# Epoch: 26, Batch: 50, Loss: 0.0058
# Epoch: 26, Batch: 60, Loss: 0.0051
# Epoch: 26, Batch: 70, Loss: 0.0105
# Epoch: 26, Batch: 80, Loss: 0.0053
# Epoch: 26, Batch: 90, Loss: 0.0080
# Epoch: 26, Batch: 100, Loss: 0.0084
# Epoch: 26, Batch: 110, Loss: 0.0064
# Epoch: 26, Batch: 120, Loss: 0.0054
# Epoch: 26, Batch: 130, Loss: 0.0052
# Epoch: 26, Batch: 140, Loss: 0.0102
# Epoch: 26, Batch: 150, Loss: 0.0129
# Epoch: 26, Batch: 160, Loss: 0.0073
# Epoch: 26, Batch: 170, Loss: 0.0067
# Epoch: 26, Batch: 180, Loss: 0.0127
# Epoch: 26, Batch: 190, Loss: 0.0106
# Epoch: 26, Batch: 200, Loss: 0.0076
# Epoch: 26, Train Loss: 0.0077, Val Loss: 0.0144
# Epoch: 27, Batch: 0, Loss: 0.0052
# Epoch: 27, Batch: 10, Loss: 0.0048
# Epoch: 27, Batch: 20, Loss: 0.0070
# Epoch: 27, Batch: 30, Loss: 0.0063
# Epoch: 27, Batch: 40, Loss: 0.0042
# Epoch: 27, Batch: 50, Loss: 0.0054
# Epoch: 27, Batch: 60, Loss: 0.0097
# Epoch: 27, Batch: 70, Loss: 0.0115
# Epoch: 27, Batch: 80, Loss: 0.0083
# Epoch: 27, Batch: 90, Loss: 0.0106
# Epoch: 27, Batch: 100, Loss: 0.0080
# Epoch: 27, Batch: 110, Loss: 0.0062
# Epoch: 27, Batch: 120, Loss: 0.0059
# Epoch: 27, Batch: 130, Loss: 0.0056
# Epoch: 27, Batch: 140, Loss: 0.0059
# Epoch: 27, Batch: 150, Loss: 0.0046
# Epoch: 27, Batch: 160, Loss: 0.0046
# Epoch: 27, Batch: 170, Loss: 0.0073
# Epoch: 27, Batch: 180, Loss: 0.0118
# Epoch: 27, Batch: 190, Loss: 0.0088
# Epoch: 27, Batch: 200, Loss: 0.0105
# Epoch: 27, Train Loss: 0.0074, Val Loss: 0.0165
# Epoch: 28, Batch: 0, Loss: 0.0057
# Epoch: 28, Batch: 10, Loss: 0.0056
# Epoch: 28, Batch: 20, Loss: 0.0092
# Epoch: 28, Batch: 30, Loss: 0.0086
# Epoch: 28, Batch: 40, Loss: 0.0072
# Epoch: 28, Batch: 50, Loss: 0.0072
# Epoch: 28, Batch: 60, Loss: 0.0072
# Epoch: 28, Batch: 70, Loss: 0.0053
# Epoch: 28, Batch: 80, Loss: 0.0074
# Epoch: 28, Batch: 90, Loss: 0.0059
# Epoch: 28, Batch: 100, Loss: 0.0060
# Epoch: 28, Batch: 110, Loss: 0.0105
# Epoch: 28, Batch: 120, Loss: 0.0050
# Epoch: 28, Batch: 130, Loss: 0.0087
# Epoch: 28, Batch: 140, Loss: 0.0044
# Epoch: 28, Batch: 150, Loss: 0.0093
# Epoch: 28, Batch: 160, Loss: 0.0067
# Epoch: 28, Batch: 170, Loss: 0.0069
# Epoch: 28, Batch: 180, Loss: 0.0090
# Epoch: 28, Batch: 190, Loss: 0.0082
# Epoch: 28, Batch: 200, Loss: 0.0074
# Epoch: 28, Train Loss: 0.0070, Val Loss: 0.0133
# Epoch: 29, Batch: 0, Loss: 0.0055
# Epoch: 29, Batch: 10, Loss: 0.0047
# Epoch: 29, Batch: 20, Loss: 0.0040
# Epoch: 29, Batch: 30, Loss: 0.0057
# Epoch: 29, Batch: 40, Loss: 0.0081
# Epoch: 29, Batch: 50, Loss: 0.0051
# Epoch: 29, Batch: 60, Loss: 0.0059
# Epoch: 29, Batch: 70, Loss: 0.0082
# Epoch: 29, Batch: 80, Loss: 0.0061
# Epoch: 29, Batch: 90, Loss: 0.0089
# Epoch: 29, Batch: 100, Loss: 0.0109
# Epoch: 29, Batch: 110, Loss: 0.0117
# Epoch: 29, Batch: 120, Loss: 0.0085
# Epoch: 29, Batch: 130, Loss: 0.0091
# Epoch: 29, Batch: 140, Loss: 0.0063
# Epoch: 29, Batch: 150, Loss: 0.0063
# Epoch: 29, Batch: 160, Loss: 0.0069
# Epoch: 29, Batch: 170, Loss: 0.0065
# Epoch: 29, Batch: 180, Loss: 0.0052
# Epoch: 29, Batch: 190, Loss: 0.0051
# Epoch: 29, Batch: 200, Loss: 0.0046
# Epoch: 29, Train Loss: 0.0066, Val Loss: 0.0128
# Epoch: 30, Batch: 0, Loss: 0.0039
# Epoch: 30, Batch: 10, Loss: 0.0052
# Epoch: 30, Batch: 20, Loss: 0.0065
# Epoch: 30, Batch: 30, Loss: 0.0033
# Epoch: 30, Batch: 40, Loss: 0.0278
# Epoch: 30, Batch: 50, Loss: 0.0145
# Epoch: 30, Batch: 60, Loss: 0.0089
# Epoch: 30, Batch: 70, Loss: 0.0077
# Epoch: 30, Batch: 80, Loss: 0.0041
# Epoch: 30, Batch: 90, Loss: 0.0057
# Epoch: 30, Batch: 100, Loss: 0.0029
# Epoch: 30, Batch: 110, Loss: 0.0051
# Epoch: 30, Batch: 120, Loss: 0.0050
# Epoch: 30, Batch: 130, Loss: 0.0034
# Epoch: 30, Batch: 140, Loss: 0.0031
# Epoch: 30, Batch: 150, Loss: 0.0052
# Epoch: 30, Batch: 160, Loss: 0.0034
# Epoch: 30, Batch: 170, Loss: 0.0061
# Epoch: 30, Batch: 180, Loss: 0.0048
# Epoch: 30, Batch: 190, Loss: 0.0037
# Epoch: 30, Batch: 200, Loss: 0.0041
# Epoch: 30, Train Loss: 0.0071, Val Loss: 0.0133
# Input: gfbs, Decrypted: SPUR
