# %%
import torch
import torch.nn as nn
import pandas as pd
from tqdm import tqdm
import string
import random

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Vocabulary Class
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        all_chars = list(string.printable)
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Model Architecture
class CaesarTransformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model=256, num_heads=4, num_layers=4, d_ff=256, max_seq_length=256, dropout=0.2):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.encoder_pos = nn.Embedding(max_seq_length, d_model)
        self.decoder_pos = nn.Embedding(max_seq_length, d_model)

        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model, num_heads, d_ff, dropout, batch_first=True)
            for _ in range(num_layers)
        ])

        self.decoder_layers = nn.ModuleList([
            nn.TransformerDecoderLayer(d_model, num_heads, d_ff, dropout, batch_first=True)
            for _ in range(num_layers)
        ])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)
        self.max_seq_length = max_seq_length

    def forward(self, src, tgt):
        src_mask = (src == 0)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt.size(1)).to(device)

        src_pos = torch.arange(0, src.size(1), device=device).unsqueeze(0)
        tgt_pos = torch.arange(0, tgt.size(1), device=device).unsqueeze(0)

        src_embedded = self.dropout(self.encoder_embedding(src) + self.encoder_pos(src_pos))
        tgt_embedded = self.dropout(self.decoder_embedding(tgt) + self.decoder_pos(tgt_pos))

        memory = src_embedded
        for layer in self.encoder_layers:
            memory = layer(memory, src_key_padding_mask=src_mask)

        output = tgt_embedded
        for layer in self.decoder_layers:
            output = layer(output, memory, tgt_mask=tgt_mask, memory_key_padding_mask=src_mask)

        return self.fc(output)

def load_model(model_path, vocab_size, device):
    model = CaesarTransformer(
        src_vocab_size=vocab_size,
        tgt_vocab_size=vocab_size,
        d_model=256,
        num_heads=4,
        num_layers=4,
        d_ff=256,
        max_seq_length=256,
        dropout=0.2
    ).to(device)

    model.load_state_dict(torch.load(model_path, map_location=device), strict=False)
    model.eval()
    return model

def decrypt_text(model, text, vocab, max_length=256):
    model.eval()
    with torch.no_grad():
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

def load_test_data(file_path, n_samples=4000):
    df = pd.read_csv(file_path)
    df = df.sample(min(n_samples, len(df)), random_state=42)
    inputs = df['Input'].tolist()
    outputs = df['Output'].tolist()
    return inputs, outputs

def print_comparison(input_text, expected, generated, index):
    # Calculate character matches
    char_matches = []
    min_len = min(len(generated), len(expected))
    for i in range(min_len):
        char_matches.append(generated[i] == expected[i])

    # Format generated text with indicators
    generated_display = []
    for i in range(min_len):
        if char_matches[i]:
            generated_display.append(generated[i])
        else:
            generated_display.append(f'[{generated[i]}]')

    # Handle extra/missing characters
    if len(generated) > len(expected):
        extra_chars = generated[min_len:]
        generated_display.append(f'(+{extra_chars})')
    elif len(expected) > len(generated):
        missing_chars = expected[min_len:]
        generated_display.append(f'(missing:{missing_chars})')

    print(f"\nSample {index+1}")
    print(f"Input: {input_text}")
    print(f"Expected: {expected}")
    print(f"Generated: {''.join(generated_display)}")
    print(f"Match: {'✓' if generated == expected else '✗'}")
    print(f"Char Accuracy: {sum(char_matches)}/{len(expected)} ({sum(char_matches)/len(expected):.1%})")

def evaluate_and_save(model, test_inputs, test_outputs, vocab, output_file='/content/drive/MyDrive/decryption_results_caesar_update.xlsx'):
    all_results = []
    full_match_count = 0
    char_match_count = 0
    total_chars = 0

    print(f"\nEvaluating {len(test_inputs)} samples...\n")

    for i, (input_text, expected) in enumerate(zip(test_inputs, test_outputs)):
        decrypted = decrypt_text(model, input_text, vocab)

        # Calculate matches
        is_full_match = decrypted == expected
        full_match_count += int(is_full_match)

        # Character-level comparison
        char_matches = []
        min_len = min(len(decrypted), len(expected))
        for j in range(min_len):
            match = decrypted[j] == expected[j]
            char_match_count += int(match)
            char_matches.append(match)
        total_chars += len(expected)

        # Store results
        result = {
            'Index': i+1,
            'Input': input_text,
            'Expected': expected,
            'Generated': decrypted,
            'Full Match': 'Yes' if is_full_match else 'No',
            'Correct Characters': sum(char_matches),
            'Total Characters': len(expected),
            'Character Accuracy': sum(char_matches)/len(expected),
            'Length Difference': len(decrypted) - len(expected)
        }
        all_results.append(result)

        # Print comparison
        print_comparison(input_text, expected, decrypted, i)

        # Print progress every 100 samples
        if (i+1) % 100 == 0 or (i+1) == len(test_inputs):
            print(f"\nProgress: {i+1}/{len(test_inputs)}")
            print(f"Current Accuracy: {full_match_count/(i+1):.1%} full matches")
            print(f"Character Accuracy: {char_match_count/total_chars:.1%}\n")

    # Save to Excel
    df_results = pd.DataFrame(all_results)
    df_results.to_excel(output_file, index=False)

    # Final summary
    final_accuracy = full_match_count / len(test_inputs)
    final_char_accuracy = char_match_count / total_chars if total_chars > 0 else 0

    print(f"\nFINAL RESULTS")
    print(f"Total Samples: {len(test_inputs)}")
    print(f"Full Match Accuracy: {final_accuracy:.2%}")
    print(f"Character Accuracy: {final_char_accuracy:.2%}")
    print(f"\nAll results saved to: {output_file}")

    return df_results

# Main execution
if __name__ == "__main__":
    # Initialize components
    vocab = Vocabulary()
    model = load_model('/content/drive/MyDrive/best_caesar_updated.pth', len(vocab), device)

    # Load test data - now properly unpacking just inputs and outputs
    test_data = load_test_data('/content/testing_newshift_1.csv', 4000)
    test_inputs, test_outputs = test_data[0], test_data[1]

    # Run evaluation
    results_df = evaluate_and_save(
        model,
        test_inputs,
        test_outputs,
        vocab,
        output_file='/content/drive/MyDrive/decryption_results_caesar_update.xlsx'
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected: Tom denied that Mary was the one who told him to do that.
# Generated: Tom denied that Mary was the one who told him to do that.
# Match: ✓
# Char Accuracy: 57/57 (100.0%)
#
# Sample 3294
# Input: Fhuup dhz isllkpun.
# Expected: Yanni was bleeding.
# Generated: Yanni was bleeding.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3295
# Input: Nbymy uly mcgcful von hin nby mugy.
# Expected: These are similar but not the same.
# Generated: These are similar but not the same.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3296
# Input: Y sedwhqjkbqju oek rejx.
# Expected: I congratulate you both.
# Generated: I congratulate you both.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3297
# Input: cpio
# Expected: hunt
# Generated: hunt
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3298
# Input: Ojh ojgy Hvmt cz rjpgy vgrvtn gjqz czm.
# Expected: Tom told Mary he would always love her.
# Generated: Tom told Mary he would always love her.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3299
# Input: Sp yppopo xzypj.
# Expected: He needed money.
# Generated: He needed money.
# Match: ✓
# Char Accuracy: 16/16 (100.0%)
#
# Sample 3300
# Input: clfylackclrq
# Expected: enhancements
# Generated: enhancements
# Match: ✓
# Char Accuracy: 12/12 (100.0%)
#
# Progress: 3300/4000
# Current Accuracy: 94.7% full matches
# Character Accuracy: 99.1%
#
#
# Sample 3301
# Input: wxcrln
# Expected: notice
# Generated: notice
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3302
# Input: Brx eholhyhg lw zdv xqlpsruwdqw.
# Expected: You believed it was unimportant.
# Generated: You believed it was unimportant.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3303
# Input: Zh ohdyh iru Dxvwudold rq Prqgdb.
# Expected: We leave for Australia on Monday.
# Generated: We leave for Australia on Monday.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3304
# Input: Uzj htww yze wlde qzcpgpc.
# Expected: Joy will not last forever.
# Generated: Joy will not last forever.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3305
# Input: Ypylsihy cm ualyyx.
# Expected: Everyone is agreed.
# Generated: Everyone is agreed.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3306
# Input: sfcfddb
# Expected: rebecca
# Generated: rebecca
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3307
# Input: Zus oy payz ghuaz gy urj gy O gs.
# Expected: Tom is just about as old as I am.
# Generated: Tom is just about as old as I am.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3308
# Input: E jaaz pk bejz okiakja sdk ywj pwga ywna kb iu ydehznaj.
# Expected: I need to find someone who can take care of my children.
# Generated: I need to find someone who can take care of my children.
# Match: ✓
# Char Accuracy: 56/56 (100.0%)
#
# Sample 3309
# Input: Pki lnapajzaz pk xa opqlez.
# Expected: Tom pretended to be stupid.
# Generated: Tom pretended to be stupid.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3310
# Input: Vod Wkbi gkdmr grkd cro gkxdc.
# Expected: Let Mary watch what she wants.
# Generated: Let Mary watch what she wants.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3311
# Input: Ixu mqi iyffydw xuh cqhwqhyjq.
# Expected: She was sipping her margarita.
# Generated: She was sipping her margarita.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3312
# Input: Pvs xbmmt bsf qjol.
# Expected: Our walls are pink.
# Generated: Our walls are pink.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3313
# Input: Wfof txp sbov tloofba.
# Expected: Ziri was very worried.
# Generated: Ziri was very worried.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3314
# Input: kvsbsjsf
# Expected: whenever
# Generated: whenever
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3315
# Input: Cqho mqi jqaud qrqsa mxud ixu dejysut jxqj jxu fxejevyj ev jxu ikifusjut rkhwbqh beeaut byau Jec.
# Expected: Mary was taken aback when she noticed that the photofit of the suspected burglar looked like Tom.
# Generated: Mary was taken aback when she noticed that the photofit of the suspected burglar looked like Tom.
# Match: ✓
# Char Accuracy: 97/97 (100.0%)
#
# Sample 3316
# Input: gjdwsfk
# Expected: orleans
# Generated: orleans
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3317
# Input: N lty nsyt fs fwlzrjsy bnym Ytr.
# Expected: I got into an argument with Tom.
# Generated: I got into an argument with Tom.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3318
# Input: E swjp pk oaa sdwp pkiknnks xnejco.
# Expected: I want to see what tomorrow brings.
# Generated: I want to see what tomorrow brings.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3319
# Input: Xluqcha xluaihm uhx xinncha ch nby ysym cm u zuvfy.
# Expected: Drawing dragons and dotting in the eyes is a fable.
# Generated: Drawing dragons and dotting in the eyes is a fable.
# Match: ✓
# Char Accuracy: 51/51 (100.0%)
#
# Sample 3320
# Input: F bxq ofzb xijlpq bsbov axv.
# Expected: I eat rice almost every day.
# Generated: I eat rice almost every day.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3321
# Input: Qozz gcascbs.
# Expected: Call someone.
# Generated: Call someone.
# Match: ✓
# Char Accuracy: 13/13 (100.0%)
#
# Sample 3322
# Input: Fay gegmxxk fmwqe m imxw qhqdk yadzuzs nqradq ndqmwrmef.
# Expected: Tom usually takes a walk every morning before breakfast.
# Generated: Tom usually takes a walk every morning before breakfast.
# Match: ✓
# Char Accuracy: 56/56 (100.0%)
#
# Sample 3323
# Input: Bpm xqhhi apwctl jm pmzm ivg uqvcbm.
# Expected: The pizza should be here any minute.
# Generated: The pizza should be here any minute.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3324
# Input: F ifhb ql bumilob ilzxi xqqoxzqflkp.
# Expected: I like to explore local attractions.
# Generated: I like to explore local attractions.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3325
# Input: ifbmuiz
# Expected: healthy
# Generated: healthy
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3326
# Input: Matm ftr ghm lheox max ikhuexf.
# Expected: That may not solve the problem.
# Generated: That may not solve the problem.
# Match: ✓
# Char Accuracy: 31/31 (100.0%)
#
# Sample 3327
# Input: ntnva
# Expected: again
# Generated: again
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3328
# Input: ytqvg
# Expected: wrote
# Generated: wrote
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3329
# Input: Sbkb atmxw Kbft lfhdbgz bg max vtk.
# Expected: Ziri hated Rima smoking in the car.
# Generated: Ziri hated Rima smoking in the car.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3330
# Input: Qfc uyq ucypgle y lcejgecc.
# Expected: She was wearing a negligee.
# Generated: She was wearing a negligee.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3331
# Input: Gigjksoiy cxozk lux gigjksoi puaxtgry.
# Expected: Academics write for academic journals.
# Generated: Academics write for academic journals.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3332
# Input: Y mqi jhoydw je vydt q mqo yd.
# Expected: I was trying to find a way in.
# Generated: I was trying to find a way in.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3333
# Input: E swjp pk iaap Iwnu.
# Expected: I want to meet Mary.
# Generated: I want to meet Mary.
# Match: ✓
# Char Accuracy: 20/20 (100.0%)
#
# Sample 3334
# Input: Gbz unf ybfg nyy frafr bs ernyvgl.
# Expected: Tom has lost all sense of reality.
# Generated: Tom has lost all sense of reality.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3335
# Input: Ow gxlwf oaf.
# Expected: We often win.
# Generated: We often win.
# Match: ✓
# Char Accuracy: 13/13 (100.0%)
#
# Sample 3336
# Input: Idb wph dlcts iwpi rpg udg iwgtt ntpgh.
# Expected: Tom has owned that car for three years.
# Generated: Tom has owned that car for three years.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3337
# Input: Zus iuarj ju kbkxeznotm nk ngj zu ju.
# Expected: Tom could do everything he had to do.
# Generated: Tom could do everything he had to do.
# Match: ✓
# Char Accuracy: 37/37 (100.0%)
#
# Sample 3338
# Input: Jyv wfleu yvi wzijk xivp yrzi.
# Expected: She found her first grey hair.
# Generated: She found her first grey hair.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3339
# Input: Bzqknr zmc ghr gdqc cnf zqd z sdzl.
# Expected: Carlos and his herd dog are a team.
# Generated: Carlos and his herd dog are a team.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3340
# Input: Vdpl frqihvvhg wr ghwhfwlyhv wkdw kh dqg Odbod kdg frqvsluhg wr nloo klv zlih.
# Expected: Sami confessed to detectives that he and Layla had conspired to kill his wife.
# Generated: Sami confessed to detectives that he and Layla had conspired to kill his wife.
# Match: ✓
# Char Accuracy: 78/78 (100.0%)
#
# Sample 3341
# Input: Bpib eia i ycmabqwv Bwu ammuml zmilg nwz.
# Expected: That was a question Tom seemed ready for.
# Generated: That was a question Tom seemed ready for.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3342
# Input: yilzh
# Expected: block
# Generated: block
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3343
# Input: If mpplt mjlf b dmfwfs cpz.
# Expected: He looks like a clever boy.
# Generated: He looks like a clever boy.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3344
# Input: Xfrn nx gd mnrxjqk.
# Expected: Sami is by himself.
# Generated: Sami is by himself.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3345
# Input: Snl hr sgd dwodchshnm kdzcdq.
# Expected: Tom is the expedition leader.
# Generated: Tom is the expedition leader.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3346
# Input: Kag mdq egdq fa egooqqp uz fuyq.
# Expected: You are sure to succeed in time.
# Generated: You are sure to succeed in time.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3347
# Input: Hca gowr W zccysr vibufm.
# Expected: Tom said I looked hungry.
# Generated: Tom said I looked hungry.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3348
# Input: rdbepgpqat
# Expected: comparable
# Generated: comparable
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3349
# Input: N Zrkvpna jbzna gnhtug ure Fcnavfu.
# Expected: A Mexican woman taught her Spanish.
# Generated: A Mexican woman taught her Spanish.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3350
# Input: Ujg jcu c nqv qh htkgpfu jgtg.
# Expected: She has a lot of friends here.
# Generated: She has a lot of friends here.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3351
# Input: Qebv pqorzh Jfkx.
# Expected: They struck Mina.
# Generated: They struck Mina.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3352
# Input: Ymjwj fwj ymnslx ns rd qnkj N fr sty uwtzi tk.
# Expected: There are things in my life I am not proud of.
# Generated: There are things in my life I am not proud of.
# Match: ✓
# Char Accuracy: 46/46 (100.0%)
#
# Sample 3353
# Input: Pm smxb Asczi qvnwzuml ijwcb pqa epmzmijwcba.
# Expected: He kept Skura informed about his whereabouts.
# Generated: He kept Skura informed about his whereabouts.
# Match: ✓
# Char Accuracy: 45/45 (100.0%)
#
# Sample 3354
# Input: unbzshnmzk
# Expected: vocational
# Generated: vocational
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3355
# Input: Vjcv pgy ikboq vjcv aqw ycpv ku qxgt cv vjg uvqtg pqy.
# Expected: That new gizmo that you want is over at the store now.
# Generated: That new gizmo that you want is over at the store now.
# Match: ✓
# Char Accuracy: 54/54 (100.0%)
#
# Sample 3356
# Input: Rc cjbcnb anjuuh hdvvh.
# Expected: It tastes really yummy.
# Generated: It tastes really yummy.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3357
# Input: N qnpj dtzw gnpj.
# Expected: I like your bike.
# Generated: I like your bike.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3358
# Input: Znk vnuzu hkrutmy zu nkx.
# Expected: The photo belongs to her.
# Generated: The photo belongs to her.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3359
# Input: gub
# Expected: dry
# Generated: [m][a][h]
# Match: ✗
# Char Accuracy: 0/3 (0.0%)
#
# Sample 3360
# Input: Da wniaz deioahb sepd w cqj wjz sajp pk bwya pda ajaiu ywil.
# Expected: He armed himself with a gun and went to face the enemy camp.
# Generated: He armed himself with a gun and went to face the enemy camp.
# Match: ✓
# Char Accuracy: 60/60 (100.0%)
#
# Sample 3361
# Input: zevxpgvodji
# Expected: ejaculation
# Generated: [i][n][e][g][y][p][e][x][m][s][r]
# Match: ✗
# Char Accuracy: 0/11 (0.0%)
#
# Sample 3362
# Input: Dfcpzsag ofs o qcaacb cqqiffsbqs wb zwts.
# Expected: Problems are a common occurrence in life.
# Generated: Problems are a common occurrence in life.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3363
# Input: Px axeixw maxf tl pxee.
# Expected: We helped them as well.
# Generated: We helped them as well.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3364
# Input: Wms ayl ngai sn rfc icw dpmk pcacnrgml.
# Expected: You can pick up the key from reception.
# Generated: You can pick up the key from reception.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3365
# Input: Rgd hr zbbdrrhakd sn ohsx.
# Expected: She is accessible to pity.
# Generated: She is accessible to pity.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3366
# Input: L dvnhg klp.
# Expected: I asked him.
# Generated: I asked him.
# Match: ✓
# Char Accuracy: 12/12 (100.0%)
#
# Sample 3367
# Input: Ytr xfni Rfwd nx lqfi ymfy xmj htzqi it ymfy ktw dtz.
# Expected: Tom said Mary is glad that she could do that for you.
# Generated: Tom said Mary is glad that she could do that for you.
# Match: ✓
# Char Accuracy: 53/53 (100.0%)
#
# Sample 3368
# Input: Xfrn fsi Qfdqf xmfwji gfsp fhhtzsyx ytljymjw.
# Expected: Sami and Layla shared bank accounts together.
# Generated: Sami and Layla shared bank accounts together.
# Match: ✓
# Char Accuracy: 45/45 (100.0%)
#
# Sample 3369
# Input: Xzxabjfzp tofqb clo xzxabjfz glrokxip.
# Expected: Academics write for academic journals.
# Generated: Academics write for academic journals.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3370
# Input: Z yrmv r kyvjzj kf nizkv.
# Expected: I have a thesis to write.
# Generated: I have a thesis to write.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3371
# Input: vgtpi
# Expected: great
# Generated: great
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3372
# Input: nxqxo
# Expected: qatar
# Generated: [b][l][e][l][c]
# Match: ✗
# Char Accuracy: 0/5 (0.0%)
#
# Sample 3373
# Input: etgy
# Expected: crew
# Generated: crew
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3374
# Input: coxkzfpzl
# Expected: francisco
# Generated: francisco
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3375
# Input: Avt mvbuk aol lewlyplujl mybzayhapun.
# Expected: Tom found the experience frustrating.
# Generated: Tom found the experience frustrating.
# Match: ✓
# Char Accuracy: 37/37 (100.0%)
#
# Sample 3376
# Input: X lxaa dcan axkt udg bn rwxas xc iwt ujijgt.
# Expected: I will only live for my child in the future.
# Generated: I will only live for my child in the future.
# Match: ✓
# Char Accuracy: 44/44 (100.0%)
#
# Sample 3377
# Input: Prze x zofjb zxkklq yb abpmfpba bklrde.
# Expected: Such a crime cannot be despised enough.
# Generated: Such a crime cannot be despised enough.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3378
# Input: hnmkxtva
# Expected: outreach
# Generated: outreach
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3379
# Input: Bpgiwp palpnh sgthhts ktgn bdsthian.
# Expected: Martha always dressed very modestly.
# Generated: Martha always dressed very modestly.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3380
# Input: Zc qspc rm zc gl rgkc.
# Expected: Be sure to be in time.
# Generated: Be sure to be in time.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3381
# Input: xpe
# Expected: ash
# Generated: [m][e][t]
# Match: ✗
# Char Accuracy: 0/3 (0.0%)
#
# Sample 3382
# Input: Wrp zrqghuhg zkdw Pdub zdv derxw wr gr.
# Expected: Tom wondered what Mary was about to do.
# Generated: Tom wondered what Mary was about to do.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3383
# Input: yjgpgxgt
# Expected: whenever
# Generated: whenever
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3384
# Input: Tq ime dqrgeqp yqpuomx fdqmfyqzf.
# Expected: He was refused medical treatment.
# Generated: He was refused medical treatment.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3385
# Input: oqqsdh
# Expected: accept
# Generated: accept
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3386
# Input: Tif tqfblt qspqfs Cfscfs.
# Expected: She speaks proper Berber.
# Generated: She speaks proper Berber.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3387
# Input: Iwnu pneaz jkp pk hap dan iejz swjzan.
# Expected: Mary tried not to let her mind wander.
# Generated: Mary tried not to let her mind wander.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3388
# Input: apcsxcv
# Expected: landing
# Generated: landing
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3389
# Input: pqbdqeeuaz
# Expected: depression
# Generated: depression
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3390
# Input: Ulpd zdqwv Clul wr frph zlwk khu wr wkh frqfhuw.
# Expected: Rima wants Ziri to come with her to the concert.
# Generated: Rima wants Ziri to come with her to the concert.
# Match: ✓
# Char Accuracy: 48/48 (100.0%)
#
# Sample 3391
# Input: Fhuup ohalz ihk wlvwsl.
# Expected: Yanni hates bad people.
# Generated: Yanni hates bad people.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3392
# Input: Mu qhu rejx je rbqcu.
# Expected: We are both to blame.
# Generated: We are both to blame.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3393
# Input: mbokdsyx
# Expected: creation
# Generated: creation
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3394
# Input: Cqrb luxcq rb bxum kh cqn hjam.
# Expected: This cloth is sold by the yard.
# Generated: This cloth is sold by the yard.
# Match: ✓
# Char Accuracy: 31/31 (100.0%)
#
# Sample 3395
# Input: Zus ingykj sk.
# Expected: Tom chased me.
# Generated: Tom chased me.
# Match: ✓
# Char Accuracy: 14/14 (100.0%)
#
# Sample 3396
# Input: bqnoornum
# Expected: sheffield
# Generated: sheffield
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3397
# Input: opalcexpye
# Expected: department
# Generated: department
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3398
# Input: Nbys mnulnyx u zilvcxxyh uhx wfuhxymnchy lyfuncihmbcj.
# Expected: They started a forbidden and clandestine relationship.
# Generated: They started a forbidden and clandestine relationship.
# Match: ✓
# Char Accuracy: 54/54 (100.0%)
#
# Sample 3399
# Input: Hpbx wps pc prrdbeaxrt.
# Expected: Sami had an accomplice.
# Generated: Sami had an accomplice.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3400
# Input: Pnu kj xkpd pdaoa ykwpo wjz ykilwna pdai.
# Expected: Try on both these coats and compare them.
# Generated: Try on both these coats and compare them.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Progress: 3400/4000
# Current Accuracy: 94.7% full matches
# Character Accuracy: 99.1%
#
#
# Sample 3401
# Input: skf
# Expected: asn
# Generated: [c][u][p]
# Match: ✗
# Char Accuracy: 0/3 (0.0%)
#
# Sample 3402
# Input: rwgqzcgs
# Expected: disclose
# Generated: disclose
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3403
# Input: bgdl
# Expected: chem
# Generated: chem
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3404
# Input: kirixmgw
# Expected: genetics
# Generated: genetics
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3405
# Input: U saf euow m xaf itqz U ime m wup.
# Expected: I got sick a lot when I was a kid.
# Generated: I got sick a lot when I was a kid.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3406
# Input: matb
# Expected: thai
# Generated: thai
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3407
# Input: Zpslm ugjj zc uyrafgle Pgky.
# Expected: Bruno will be watching Rima.
# Generated: Bruno will be watching Rima.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3408
# Input: Hsnplyz pz hu vsk jpaf.
# Expected: Algiers is an old city.
# Generated: Algiers is an old city.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3409
# Input: Ukqn ywianw eo jkp wo atyahhajp wo iu ywianw.
# Expected: Your camera is not as excellent as my camera.
# Generated: Your camera is not as excellent as my camera.
# Match: ✓
# Char Accuracy: 45/45 (100.0%)
#
# Sample 3410
# Input: Kbkxeutk corr hk ygzoylokj.
# Expected: Everyone will be satisfied.
# Generated: Everyone will be satisfied.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3411
# Input: nwmrwp
# Expected: ending
# Generated: ending
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3412
# Input: Lge ygl vakimsdaxawv.
# Expected: Tom got disqualified.
# Generated: Tom got disqualified.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3413
# Input: frdolwlrq
# Expected: coalition
# Generated: coalition
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3414
# Input: ikpdano
# Expected: mothers
# Generated: mothers
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3415
# Input: Dlxt tydapnepo esp leetn.
# Expected: Sami inspected the attic.
# Generated: Sami inspected the attic.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3416
# Input: aczgp
# Expected: prove
# Generated: prove
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3417
# Input: Hezmh xvmih xs lyk Eqerhe.
# Expected: David tried to hug Amanda.
# Generated: David tried to hug Amanda.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3418
# Input: Ro dkvuon klyed wecsm.
# Expected: He talked about music.
# Generated: He talked about music.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3419
# Input: lvbxgmblml
# Expected: scientists
# Generated: scientists
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3420
# Input: Pxjf fp gbxilrp lc Ixvix.
# Expected: Sami is jealous of Layla.
# Generated: Sami is jealous of Layla.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3421
# Input: Vjah rb lxwlnawnm jkxdc qna bjonch.
# Expected: Mary is concerned about her safety.
# Generated: Mary is concerned about her safety.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3422
# Input: Ytr hfwjkzqqd ktqiji mnx hqtymjx fsi uzy ymjr nsyt mnx xznyhfxj.
# Expected: Tom carefully folded his clothes and put them into his suitcase.
# Generated: Tom carefully folded his clothes and put them into his suitcase.
# Match: ✓
# Char Accuracy: 64/64 (100.0%)
#
# Sample 3423
# Input: iusvrogtz
# Expected: compliant
# Generated: compliant
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3424
# Input: Hpbx xh uaxgixcv lxiw diwtg vxgah.
# Expected: Sami is flirting with other girls.
# Generated: Sami is flirting with other girls.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3425
# Input: Mrkq jrhv wr wkh pdunhw.
# Expected: John goes to the market.
# Generated: John goes to the market.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3426
# Input: Kyv Grcvjkzezrej riv svjzvxvu ze uvdfxirgyzt srekljkrej kf sv tfekifccvu reu vmveklrccp vogvccvu fw kyvzi tflekip.
# Expected: The Palestinians are besieged in demographic bantustans to be controlled and eventually expelled of their country.
# Generated: The Palestinians are besieged in demographic bantustans to be controlled and eventually expelled of their country.
# Match: ✓
# Char Accuracy: 114/114 (100.0%)
#
# Sample 3427
# Input: Ezx td lwhljd mzespctyr xp.
# Expected: Tom is always bothering me.
# Generated: Tom is always bothering me.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3428
# Input: Goaw goh hvsfs.
# Expected: Sami sat there.
# Generated: Sami sat there.
# Match: ✓
# Char Accuracy: 15/15 (100.0%)
#
# Sample 3429
# Input: Vjah bjrm bqn qjm bxvncqrwp rvyxacjwc cx mx.
# Expected: Mary said she had something important to do.
# Generated: Mary said she had something important to do.
# Match: ✓
# Char Accuracy: 44/44 (100.0%)
#
# Sample 3430
# Input: Lixlcai xlijjyx ihy iz nby MX wulxm.
# Expected: Rodrigo dropped one of the SD cards.
# Generated: Rodrigo dropped one of the SD cards.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3431
# Input: Fumn hcabn by muq uh ohcxyhnczcyx zfscha ivdywn ch nby mes.
# Expected: Last night he saw an unidentified flying object in the sky.
# Generated: Last night he saw an unidentified flying object in the sky.
# Match: ✓
# Char Accuracy: 59/59 (100.0%)
#
# Sample 3432
# Input: Iwnu dwo jaran rkpaz ej dan heba.
# Expected: Mary has never voted in her life.
# Generated: Mary has never voted in her life.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3433
# Input: Qn mxnb wxc bnnv yunjbnm frcq qrb lxwmrcrxw.
# Expected: He does not seem pleased with his condition.
# Generated: He does not seem pleased with his condition.
# Match: ✓
# Char Accuracy: 44/44 (100.0%)
#
# Sample 3434
# Input: uu
# Expected: nn
# Generated: [i][i]
# Match: ✗
# Char Accuracy: 0/2 (0.0%)
#
# Sample 3435
# Input: Yjqq zx ymj xytwd ns Gjwgjw.
# Expected: Tell us the story in Berber.
# Generated: Tell us the story in Berber.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3436
# Input: Jec iqyt Y beeaut xkdwho.
# Expected: Tom said I looked hungry.
# Generated: Tom said I looked hungry.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3437
# Input: Amzixc kvmvomjjkzmn kzmajmhzy vomjxdjpn ojmopmzn oj Vgbzmdvin ypmdib ocz gdwzmvodji rvm.
# Expected: French paratroopers performed atrocious tortures to Algerians during the liberation war.
# Generated: French paratroopers performed atrocious tortures to Algerians during the liberation war.
# Match: ✓
# Char Accuracy: 88/88 (100.0%)
#
# Sample 3438
# Input: Avt huk Thyf ibtwlk puav lhjo vaoly huk kyvwwlk aolpy ivvrz vu aol msvvy.
# Expected: Tom and Mary bumped into each other and dropped their books on the floor.
# Generated: Tom and Mary bumped into each other and dropped their books on the floor.
# Match: ✓
# Char Accuracy: 73/73 (100.0%)
#
# Sample 3439
# Input: mpod
# Expected: beds
# Generated: beds
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3440
# Input: R qjm mroorlduch mxrwp cqjc.
# Expected: I had difficulty doing that.
# Generated: I had difficulty doing that.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3441
# Input: bu
# Expected: ha
# Generated: [p][i]
# Match: ✗
# Char Accuracy: 0/2 (0.0%)
#
# Sample 3442
# Input: Nig nifx Ncg uvion Nihs.
# Expected: Tom told Tim about Tony.
# Generated: Tom told Tim about Tony.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3443
# Input: cmyed
# Expected: scout
# Generated: scout
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3444
# Input: Hs vzr zm zvetk lnuhd.
# Expected: It was an awful movie.
# Generated: It was an awful movie.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3445
# Input: Ftqk tqxbqp ftqyeqxhqe fa oarrqq.
# Expected: They helped themselves to coffee.
# Generated: They helped themselves to coffee.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3446
# Input: Hp htds jzf l slaaj Nsctdexld lyo l slaaj Yph Jplc.
# Expected: We wish you a happy Christmas and a happy New Year.
# Generated: We wish you a happy Christmas and a happy New Year.
# Match: ✓
# Char Accuracy: 51/51 (100.0%)
#
# Sample 3447
# Input: eurzvh
# Expected: browse
# Generated: browse
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3448
# Input: Avt dhualk av il h ahaavv hyapza.
# Expected: Tom wanted to be a tattoo artist.
# Generated: Tom wanted to be a tattoo artist.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3449
# Input: agtgjgyl
# Expected: civilian
# Generated: civilian
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3450
# Input: Qy hyyx ziix olayhnfs.
# Expected: We need food urgently.
# Generated: We need food urgently.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3451
# Input: Uc ucpc mddclbcb.
# Expected: We were offended.
# Generated: We were offended.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3452
# Input: Mu qbb cyiiut jxuc.
# Expected: We all missed them.
# Generated: We all missed them.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3453
# Input: Zus rubky xucotm.
# Expected: Tom loves rowing.
# Generated: Tom loves rowing.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3454
# Input: Zw kljmyydwv lg klsfv mh.
# Expected: He struggled to stand up.
# Generated: He struggled to stand up.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3455
# Input: Kmzzu bgf tue omd uzfa pudqof egzxustf fa fdk mzp ruzp mxx ftq otube mzp eodmfotqe az tue iuzpetuqxp.
# Expected: Yanni put his car into direct sunlight to try and find all the chips and scratches on his windshield.
# Generated: Yanni put his car into direct sunlight to try and find all the chips and scratches on his windshield.
# Match: ✓
# Char Accuracy: 101/101 (100.0%)
#
# Sample 3456
# Input: Eb xmlildfwba ql ebo clo efp jfpqxhb.
# Expected: He apologized to her for his mistake.
# Generated: He apologized to her for his mistake.
# Match: ✓
# Char Accuracy: 37/37 (100.0%)
#
# Sample 3457
# Input: K iqv ewv.
# Expected: I got cut.
# Generated: I got cut.
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3458
# Input: hfyjltwnjx
# Expected: categories
# Generated: categories
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3459
# Input: vkgx
# Expected: lawn
# Generated: lawn
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3460
# Input: A zghw A zsnw lzw uzsfuw lg vg lzsl.
# Expected: I hope I have the chance to do that.
# Generated: I hope I have the chance to do that.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3461
# Input: Gd snnj ghr rhrsdq zknmf.
# Expected: He took his sister along.
# Generated: He took his sister along.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3462
# Input: Nzjufd yvcgj lj ermzxrkv tyrexv.
# Expected: Wisdom helps us navigate change.
# Generated: Wisdom helps us navigate change.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3463
# Input: bmjsjajw
# Expected: whenever
# Generated: whenever
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3464
# Input: vdzonmr
# Expected: weapons
# Generated: weapons
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3465
# Input: R qnjam j knjdcrodu yxnv hnbcnamjh.
# Expected: I heard a beautiful poem yesterday.
# Generated: I heard a beautiful poem yesterday.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3466
# Input: qjgcxcv
# Expected: burning
# Generated: burning
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3467
# Input: Rmk lctcp ctcl ilcu fgq dyrfcp.
# Expected: Tom never even knew his father.
# Generated: Tom never even knew his father.
# Match: ✓
# Char Accuracy: 31/31 (100.0%)
#
# Sample 3468
# Input: A ogjcwv sl s tsfc.
# Expected: I worked at a bank.
# Generated: I worked at a bank.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3469
# Input: Tq mewqp yq itmf U zqqpqp.
# Expected: He asked me what I needed.
# Generated: He asked me what I needed.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3470
# Input: Hpbx wps id sd iwpi dcaxct.
# Expected: Sami had to do that online.
# Generated: Sami had to do that online.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3471
# Input: Epkivme lew kssh vipexmsrw amxl xli REXS eppmergi.
# Expected: Algeria has good relations with the NATO alliance.
# Generated: Algeria has good relations with the NATO alliance.
# Match: ✓
# Char Accuracy: 50/50 (100.0%)
#
# Sample 3472
# Input: P dhua ohsm vm h zhstvu.
# Expected: I want half of a salmon.
# Generated: I want half of a salmon.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3473
# Input: mynnfyx
# Expected: settled
# Generated: settled
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3474
# Input: Vqo jcu cp cpigt kuuwg.
# Expected: Tom has an anger issue.
# Generated: Tom has an anger issue.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3475
# Input: xkqfzfmxqba
# Expected: anticipated
# Generated: anticipated
# Match: ✓
# Char Accuracy: 11/11 (100.0%)
#
# Sample 3476
# Input: Kfd nzcc sv grpzex wfi vmvipkyzex.
# Expected: Tom will be paying for everything.
# Generated: Tom will be paying for everything.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3477
# Input: R qnuynm Cxv mx rc.
# Expected: I helped Tom do it.
# Generated: I helped Tom do it.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3478
# Input: snoxdspsmkdsyx
# Expected: identification
# Generated: identification
# Match: ✓
# Char Accuracy: 14/14 (100.0%)
#
# Sample 3479
# Input: Jxov pelria yb xyib ql qxhb zxob lc ebopbic.
# Expected: Mary should be able to take care of herself.
# Generated: Mary should be able to take care of herself.
# Match: ✓
# Char Accuracy: 44/44 (100.0%)
#
# Sample 3480
# Input: Gulnbu ufqusm xlymmyx pyls gixymnfs.
# Expected: Martha always dressed very modestly.
# Generated: Martha always dressed very modestly.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3481
# Input: royxk
# Expected: urban
# Generated: [l][i][s][r][e]
# Match: ✗
# Char Accuracy: 0/5 (0.0%)
#
# Sample 3482
# Input: Weqm aew sfzmsywpc xss hvyro xs hvmzi lsqi.
# Expected: Sami was obviously too drunk to drive home.
# Generated: Sami was obviously too drunk to drive home.
# Match: ✓
# Char Accuracy: 43/43 (100.0%)
#
# Sample 3483
# Input: Ghmabgz vtg atiixg fhkx uxtnmbyne matg wxtma.
# Expected: Nothing can happen more beautiful than death.
# Generated: Nothing can happen more beautiful than death.
# Match: ✓
# Char Accuracy: 45/45 (100.0%)
#
# Sample 3484
# Input: X iwxcz Idb pcs Bpgn pgt xcigxvjts.
# Expected: I think Tom and Mary are intrigued.
# Generated: I think Tom and Mary are intrigued.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3485
# Input: Rz czgkzy oczh vn rzgg.
# Expected: We helped them as well.
# Generated: We helped them as well.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3486
# Input: Xli aexiv mr xli peoi viqemrih qyvoc ejxiv xli wxsvq.
# Expected: The water in the lake remained murky after the storm.
# Generated: The water in the lake remained murky after the storm.
# Match: ✓
# Char Accuracy: 53/53 (100.0%)
#
# Sample 3487
# Input: jmbu
# Expected: adsl
# Generated: [b][e][t][m]
# Match: ✗
# Char Accuracy: 0/4 (0.0%)
#
# Sample 3488
# Input: Spesjhp fkfdufe gspn uif qmbof.
# Expected: Rodrigo ejected from the plane.
# Generated: Rodrigo ejected from the plane.
# Match: ✓
# Char Accuracy: 31/31 (100.0%)
#
# Sample 3489
# Input: Snl knudr qnvhmf.
# Expected: Tom loves rowing.
# Generated: Tom loves rowing.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3490
# Input: ilsmhza
# Expected: belfast
# Generated: belfast
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3491
# Input: Q nwcvl ca i eig wcb.
# Expected: I found us a way out.
# Generated: I found us a way out.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3492
# Input: Hpbx wps p gthigpxcxcv dgstg pvpxchi Apnap.
# Expected: Sami had a restraining order against Layla.
# Generated: Sami had a restraining order against Layla.
# Match: ✓
# Char Accuracy: 43/43 (100.0%)
#
# Sample 3493
# Input: Uxghi adkt xh p zxcs du kprrxcpixdc lwxrw hpkth p bpc ugdb rpirwxcv iwt rdbeapxci iwt htrdcs ixbt.
# Expected: First love is a kind of vaccination which saves a man from catching the complaint the second time.
# Generated: First love is a kind of vaccination which saves a man from catching the complaint the second time.
# Match: ✓
# Char Accuracy: 98/98 (100.0%)
#
# Sample 3494
# Input: Qziz nrekj bzebp jvo.
# Expected: Ziri wants kinky sex.
# Generated: Ziri wants kinky sex.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3495
# Input: Ygso lkrr ut noy qtkky gtj hkmmkj Rgerg tuz zu xkvuxz nos zu znk vuroik.
# Expected: Sami fell on his knees and begged Layla not to report him to the police.
# Generated: Sami fell on his knees and begged Layla not to report him to the police.
# Match: ✓
# Char Accuracy: 72/72 (100.0%)
#
# Sample 3496
# Input: Ojh nvdy ocvo cz ocjpbco Hvmt rvn kmjwvwgt ijo cvqdib vit api yjdib ocvo.
# Expected: Tom said that he thought Mary was probably not having any fun doing that.
# Generated: Tom said that he thought Mary was probably not having any fun doing that.
# Match: ✓
# Char Accuracy: 73/73 (100.0%)
#
# Sample 3497
# Input: Xf xfsf usvuigvm.
# Expected: We were truthful.
# Generated: We were truthful.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3498
# Input: Sgd adsqzxzk kdes z rbzq sgzs vntkc mdudq gdzk.
# Expected: The betrayal left a scar that would never heal.
# Generated: The betrayal left a scar that would never heal.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3499
# Input: oqnctbsr
# Expected: products
# Generated: products
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3500
# Input: B gxoxk ngwxklmhhw mabl.
# Expected: I never understood this.
# Generated: I never understood this.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Progress: 3500/4000
# Current Accuracy: 94.7% full matches
# Character Accuracy: 99.1%
#
#
# Sample 3501
# Input: Zqzmtwjyt fijrn ocz hjji dn hvyz ja xczznz.
# Expected: Everybody knows the moon is made of cheese.
# Generated: Everybody knows the moon is made of cheese.
# Match: ✓
# Char Accuracy: 43/43 (100.0%)
#
# Sample 3502
# Input: C muq Nig wigcha niqulx gy.
# Expected: I saw Tom coming toward me.
# Generated: I saw Tom coming toward me.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3503
# Input: Aol ovbzl dolyl Tvghya dhz ivyu pz pu Zhsgibyn.
# Expected: The house where Mozart was born is in Salzburg.
# Generated: The house where Mozart was born is in Salzburg.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3504
# Input: Ftmf ftq iqn ue rgxx ar bufrmxxe ue oayyaz wzaixqpsq.
# Expected: That the web is full of pitfalls is common knowledge.
# Generated: That the web is full of pitfalls is common knowledge.
# Match: ✓
# Char Accuracy: 53/53 (100.0%)
#
# Sample 3505
# Input: Pqdqfa mpgy vjcv Vqo ycu iqkpi vq dg jgtg.
# Expected: Nobody knew that Tom was going to be here.
# Generated: Nobody knew that Tom was going to be here.
# Match: ✓
# Char Accuracy: 42/42 (100.0%)
#
# Sample 3506
# Input: Mj pnhpji rj ts uzwutxj.
# Expected: He kicked me on purpose.
# Generated: He kicked me on purpose.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3507
# Input: Wkh lyb ylqhv duh jhwwlqj odujhu.
# Expected: The ivy vines are getting larger.
# Generated: The ivy vines are getting larger.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3508
# Input: Ypth svvrz sprl h wypujlzz pu aoha Zohdp kylzz.
# Expected: Rima looks like a princess in that Shawi dress.
# Generated: Rima looks like a princess in that Shawi dress.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3509
# Input: Yg hcnn cpf yg igv wr.
# Expected: We fall and we get up.
# Generated: We fall and we get up.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3510
# Input: Mhf tldxw Ftkr mh ptox mh abf ykhf max utevhgr.
# Expected: Tom asked Mary to wave to him from the balcony.
# Generated: Tom asked Mary to wave to him from the balcony.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3511
# Input: Xli amgoih amxgl tywlih liv mrxs xli hiit aexiv.
# Expected: The wicked witch pushed her into the deep water.
# Generated: The wicked witch pushed her into the deep water.
# Match: ✓
# Char Accuracy: 48/48 (100.0%)
#
# Sample 3512
# Input: Qy omyx ni vy aiix un nbcm.
# Expected: We used to be good at this.
# Generated: We used to be good at this.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3513
# Input: Dyw wecd rkfo loox ohrkecdon.
# Expected: Tom must have been exhausted.
# Generated: Tom must have been exhausted.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3514
# Input: Nwfw kobhg Fwao hc rc wh.
# Expected: Ziri wants Rima to do it.
# Generated: Ziri wants Rima to do it.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3515
# Input: Nvtisppnt bsf opu gps sfou boe uif hjohfscsfbe ipvtf jt opu up mfu bu uif npnfou.
# Expected: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Generated: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Match: ✓
# Char Accuracy: 81/81 (100.0%)
#
# Sample 3516
# Input: Nig cm chni wihmnluchn uhx fiacw jlialuggcha.
# Expected: Tom is into constraint and logic programming.
# Generated: Tom is into constraint and logic programming.
# Match: ✓
# Char Accuracy: 45/45 (100.0%)
#
# Sample 3517
# Input: Gzo hz ozvxc tjp cjr oj odz v odz.
# Expected: Let me teach you how to tie a tie.
# Generated: Let me teach you how to tie a tie.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3518
# Input: Xqazup ime efmdfuzs fa rqqx puembbauzfqp.
# Expected: Leonid was starting to feel disappointed.
# Generated: Leonid was starting to feel disappointed.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3519
# Input: Goaw kcizr rc hvs goas tcf as.
# Expected: Sami would do the same for me.
# Generated: Sami would do the same for me.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3520
# Input: G suznkx cnu ghgtjuty nkx inorjxkt juky tuz jkykxbk zu mkz znks hgiq.
# Expected: A mother who abandons her children does not deserve to get them back.
# Generated: A mother who abandons her children does not deserve to get them back.
# Match: ✓
# Char Accuracy: 69/69 (100.0%)
#
# Sample 3521
# Input: Kfd rjbvu dv r tflgcv fw hlvjkzfej.
# Expected: Tom asked me a couple of questions.
# Generated: Tom asked me a couple of questions.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3522
# Input: Libd xka Ofjx bxze pxq fk afccbobkq olljp.
# Expected: Oleg and Rima each sat in different rooms.
# Generated: Oleg and Rima each sat in different rooms.
# Match: ✓
# Char Accuracy: 42/42 (100.0%)
#
# Sample 3523
# Input: Ocvo izr bduhj ocvo tjp rvio dn jqzm vo ocz nojmz ijr.
# Expected: That new gizmo that you want is over at the store now.
# Generated: That new gizmo that you want is over at the store now.
# Match: ✓
# Char Accuracy: 54/54 (100.0%)
#
# Sample 3524
# Input: Xlic orsa xlex M orsa.
# Expected: They know that I know.
# Generated: They know that I know.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3525
# Input: U omz eqq itk Fay pqoupqp zaf fa sa.
# Expected: I can see why Tom decided not to go.
# Generated: I can see why Tom decided not to go.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3526
# Input: Guvf jbeq vf fcryyrq jvgu n ulcura.
# Expected: This word is spelled with a hyphen.
# Generated: This word is spelled with a hyphen.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3527
# Input: Dggc ozsl Lge xgmfv mfvwj lzw twv.
# Expected: Look what Tom found under the bed.
# Generated: Look what Tom found under the bed.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3528
# Input: lcl
# Expected: pgp
# Generated: [e][v][e]
# Match: ✗
# Char Accuracy: 0/3 (0.0%)
#
# Sample 3529
# Input: Sd sc nsppsmevd dy bowksx kgkbo grsvo nbokwsxq.
# Expected: It is difficult to remain aware while dreaming.
# Generated: It is difficult to remain aware while dreaming.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3530
# Input: Jec xqi ruud beeaydw veh oek wkoi.
# Expected: Tom has been looking for you guys.
# Generated: Tom has been looking for you guys.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3531
# Input: Jxuo mudj je q Aqrobu ckiys sedsuhj.
# Expected: They went to a Kabyle music concert.
# Generated: They went to a Kabyle music concert.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3532
# Input: Yv gviwfidvu kyv kiztb nzky vrjv.
# Expected: He performed the trick with ease.
# Generated: He performed the trick with ease.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3533
# Input: S drsxu drkd Dyw gsvv lo ceczsmsyec.
# Expected: I think that Tom will be suspicious.
# Generated: I think that Tom will be suspicious.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3534
# Input: Jmpclxm bpmtc bmul rfc fgjj.
# Expected: Lorenzo drove down the hill.
# Generated: Lorenzo drove down the hill.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3535
# Input: Yhqh zmc Qhlz lzcd mnhrd.
# Expected: Ziri and Rima made noise.
# Generated: Ziri and Rima made noise.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3536
# Input: jc
# Expected: tm
# Generated: [p][i]
# Match: ✗
# Char Accuracy: 0/2 (0.0%)
#
# Sample 3537
# Input: Zus luxmuz zu vge noy ixkjoz igxj horr ut zosk.
# Expected: Tom forgot to pay his credit card bill on time.
# Generated: Tom forgot to pay his credit card bill on time.
# Match: ✓
# Char Accuracy: 47/47 (100.0%)
#
# Sample 3538
# Input: Dro yvn wkx kcuon wo k pkfyb.
# Expected: The old man asked me a favor.
# Generated: The old man asked me a favor.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3539
# Input: zmvcq
# Expected: boxes
# Generated: boxes
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3540
# Input: Tktubv bl fr fhmaxk mhgznx.
# Expected: Arabic is my mother tongue.
# Generated: Arabic is my mother tongue.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3541
# Input: Dsqds kzsjhwfwv zwj fsadk.
# Expected: Layla sharpened her nails.
# Generated: Layla sharpened her nails.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3542
# Input: Da olajp bkqnpaaj uawno kb deo heba pnuejc pk hawnj Xanxan.
# Expected: He spent fourteen years of his life trying to learn Berber.
# Generated: He spent fourteen years of his life trying to learn Berber.
# Match: ✓
# Char Accuracy: 59/59 (100.0%)
#
# Sample 3543
# Input: Lzw dskl zghw xdwv xjge zak eafv.
# Expected: The last hope fled from his mind.
# Generated: The last hope fled from his mind.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3544
# Input: nzgzxodib
# Expected: selecting
# Generated: selecting
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3545
# Input: D rvn xjhkzggzy oj xjiaznn.
# Expected: I was compelled to confess.
# Generated: I was compelled to confess.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3546
# Input: W bsjsf oqhiozzm gok vwa.
# Expected: I never actually saw him.
# Generated: I never actually saw him.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3547
# Input: Pda zaikj opwnpaz bhuejc xwygswnzo.
# Expected: The demon started flying backwards.
# Generated: The demon started flying backwards.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3548
# Input: Bwu ivl Q izm zmilg bw tmidm.
# Expected: Tom and I are ready to leave.
# Generated: Tom and I are ready to leave.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3549
# Input: Hvsfs ofs aobm uccr fsogcbg bch hc rc wh.
# Expected: There are many good reasons not to do it.
# Generated: There are many good reasons not to do it.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3550
# Input: Qernzf nyjnlf pbzr bhg qvssreragyl.
# Expected: Dreams always come out differently.
# Generated: Dreams always come out differently.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3551
# Input: avntnen
# Expected: niagara
# Generated: niagara
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3552
# Input: Jxuo jebt cu jxuo muhu ibuufo.
# Expected: They told me they were sleepy.
# Generated: They told me they were sleepy.
# Match: ✓
# Char Accuracy: 30/30 (100.0%)
#
# Sample 3553
# Input: mwznv
# Expected: block
# Generated: block
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3554
# Input: Guls bum fimn byl picwy.
# Expected: Mary has lost her voice.
# Generated: Mary has lost her voice.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3555
# Input: Vene ows pda eilnejp kb w hwnca wjeiwh huejc ej pda ojks.
# Expected: Ziri saw the imprint of a large animal lying in the snow.
# Generated: Ziri saw the imprint of a large animal lying in the snow.
# Match: ✓
# Char Accuracy: 57/57 (100.0%)
#
# Sample 3556
# Input: hmzmhi
# Expected: divide
# Generated: divide
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3557
# Input: ebwnc
# Expected: vsnet
# Generated: [r][o][j][a][p]
# Match: ✗
# Char Accuracy: 0/5 (0.0%)
#
# Sample 3558
# Input: W ybck hvoh Hca igsr hc ps o qogvwsf oh o ufcqsfm ghcfs.
# Expected: I know that Tom used to be a cashier at a grocery store.
# Generated: I know that Tom used to be a cashier at a grocery store.
# Match: ✓
# Char Accuracy: 56/56 (100.0%)
#
# Sample 3559
# Input: By musm by wiiem qyff.
# Expected: He says he cooks well.
# Generated: He says he cooks well.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3560
# Input: Vlr jrpq afpxpplzfxqb vlropbic colj qebj.
# Expected: You must disassociate yourself from them.
# Generated: You must disassociate yourself from them.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3561
# Input: Weqm hmh xlmw xs vipmizi lmw wxviww.
# Expected: Sami did this to relieve his stress.
# Generated: Sami did this to relieve his stress.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3562
# Input: Ytr lty ajwd bjfp.
# Expected: Tom got very weak.
# Generated: Tom got very weak.
# Match: ✓
# Char Accuracy: 18/18 (100.0%)
#
# Sample 3563
# Input: M xlmro xlex Xsq lew jeppir ewpiit.
# Expected: I think that Tom has fallen asleep.
# Generated: I think that Tom has fallen asleep.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3564
# Input: guleynm
# Expected: markets
# Generated: markets
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3565
# Input: A cfgo lzsl Lge ak mfdmucq.
# Expected: I know that Tom is unlucky.
# Generated: I know that Tom is unlucky.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3566
# Input: Vjah dbnm qna yqxwn jb j vraaxa.
# Expected: Mary used her phone as a mirror.
# Generated: Mary used her phone as a mirror.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3567
# Input: djsdvmbs
# Expected: circular
# Generated: circular
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3568
# Input: hfrorjb
# Expected: ecology
# Generated: [g][e][q][n][q][i][a]
# Match: ✗
# Char Accuracy: 0/7 (0.0%)
#
# Sample 3569
# Input: Jzqvo bpib jcksmb wn eibmz wdmz pmzm.
# Expected: Bring that bucket of water over here.
# Generated: Bring that bucket of water over here.
# Match: ✓
# Char Accuracy: 37/37 (100.0%)
#
# Sample 3570
# Input: Cqn mnvxw bcjacnm ouhrwp kjltfjamb.
# Expected: The demon started flying backwards.
# Generated: The demon started flying backwards.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3571
# Input: npupsdzdmft
# Expected: motorcycles
# Generated: motorcycles
# Match: ✓
# Char Accuracy: 11/11 (100.0%)
#
# Sample 3572
# Input: Hyhubrqh wklqnv lq wkhlu rzq zdb.
# Expected: Everyone thinks in their own way.
# Generated: Everyone thinks in their own way.
# Match: ✓
# Char Accuracy: 33/33 (100.0%)
#
# Sample 3573
# Input: offefe
# Expected: needed
# Generated: needed
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3574
# Input: Wvemfvg jwegnwv zak ysk eskc.
# Expected: Edmundo removed his gas mask.
# Generated: Edmundo removed his gas mask.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3575
# Input: Hpbx ldgzts pi iwt djisddg edda.
# Expected: Sami worked at the outdoor pool.
# Generated: Sami worked at the outdoor pool.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3576
# Input: Vgar yixkgskj ot lkgx.
# Expected: Paul screamed in fear.
# Generated: Paul screamed in fear.
# Match: ✓
# ...
#
# Sample 3907
# Input: Fc pcdsqcq rm dglgqf sn rfcpc dmp wms.
# Expected: He refuses to finish up there for you.
# Generated: He refuses to finish up there for you.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3908
# Input: pfczap
# Expected: europe
# Generated: europe
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3909
# Input: Xyjkfs xfb ymj rtsxyjw bmt pnqqji Wnrf.
# Expected: Stefan saw the monster who killed Rima.
# Generated: Stefan saw the monster who killed Rima.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3910
# Input: piitcixdc
# Expected: attention
# Generated: attention
# Match: ✓
# Char Accuracy: 9/9 (100.0%)
#
# Sample 3911
# Input: Bapr n lrne.
# Expected: Once a year.
# Generated: Once a year.
# Match: ✓
# Char Accuracy: 12/12 (100.0%)
#
# Sample 3912
# Input: Lzwkw sjw kaeadsj tml fgl lzw ksew.
# Expected: These are similar but not the same.
# Generated: These are similar but not the same.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3913
# Input: Ygso oy tuz muotm zu yge oz.
# Expected: Sami is not going to say it.
# Generated: Sami is not going to say it.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3914
# Input: Uhma hy nl tkx zktgwytmaxkl.
# Expected: Both of us are grandfathers.
# Generated: Both of us are grandfathers.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3915
# Input: bziqvmz
# Expected: trainer
# Generated: trainer
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3916
# Input: Upn btlfe nf opu up ljtt ijn jo qvcmjd.
# Expected: Tom asked me not to kiss him in public.
# Generated: Tom asked me not to kiss him in public.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3917
# Input: Ynk qkvz muotm.
# Expected: She kept going.
# Generated: She kept going.
# Match: ✓
# Char Accuracy: 15/15 (100.0%)
#
# Sample 3918
# Input: Xmj xfni xmj bfx ytt xmd yt it ymfy.
# Expected: She said she was too shy to do that.
# Generated: She said she was too shy to do that.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3919
# Input: F xdobb fk mofkzfmib.
# Expected: I agree in principle.
# Generated: I agree in principle.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3920
# Input: yhewxk
# Expected: folder
# Generated: folder
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3921
# Input: terngre
# Expected: greater
# Generated: greater
# Match: ✓
# Char Accuracy: 7/7 (100.0%)
#
# Sample 3922
# Input: Nig bum vyyh fiiecha zil sio aosm.
# Expected: Tom has been looking for you guys.
# Generated: Tom has been looking for you guys.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3923
# Input: Yv trlxyk drep irkj nzky kyv kirg.
# Expected: He caught many rats with the trap.
# Generated: He caught many rats with the trap.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3924
# Input: N bfsy dtz yt futqtlnej yt Ytr.
# Expected: I want you to apologize to Tom.
# Generated: I want you to apologize to Tom.
# Match: ✓
# Char Accuracy: 31/31 (100.0%)
#
# Sample 3925
# Input: apa
# Expected: tit
# Generated: tit
# Match: ✓
# Char Accuracy: 3/3 (100.0%)
#
# Sample 3926
# Input: sjst
# Expected: arab
# Generated: arab
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3927
# Input: Mcruzdzi bvgk kyrk r jvtivk wifd Reer.
# Expected: Vladimir kept that a secret from Anna.
# Generated: Vladimir kept that a secret from Anna.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3928
# Input: Diqznodbvojmn ajdgzy v kgjo oj cdevxf vi vdmkgviz.
# Expected: Investigators foiled a plot to hijack an airplane.
# Generated: Investigators foiled a plot to hijack an airplane.
# Match: ✓
# Char Accuracy: 50/50 (100.0%)
#
# Sample 3929
# Input: Ludu omz xqmhq zai.
# Expected: Ziri can leave now.
# Generated: Ziri can leave now.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3930
# Input: Fnlakhhfl tkx ghm yhk kxgm tgw max zbgzxkukxtw ahnlx bl ghm mh exm tm max fhfxgm.
# Expected: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Generated: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Match: ✓
# Char Accuracy: 81/81 (100.0%)
#
# Sample 3931
# Input: Qykg zcaykc y kgjjgmlygpc.
# Expected: Sami became a millionaire.
# Generated: Sami became a millionaire.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3932
# Input: Nvhd rviozy Gvtgv oj novt ndibgz ajm cdh.
# Expected: Sami wanted Layla to stay single for him.
# Generated: Sami wanted Layla to stay single for him.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3933
# Input: Oa ceeqwpv iqv jcemgf.
# Expected: My account got hacked.
# Generated: My account got hacked.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3934
# Input: Iwnu swjpo dan ikjau xwyg.
# Expected: Mary wants her money back.
# Generated: Mary wants her money back.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3935
# Input: pcvb
# Expected: hunt
# Generated: hunt
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3936
# Input: Buj cu jubb oek mxqj Y iuu.
# Expected: Let me tell you what I see.
# Generated: Let me tell you what I see.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3937
# Input: Jwcxw Bijwmxa Ujenh oxdwmnm cqn Lqdalq xo Bjcjw.
# Expected: Anton Szandor Lavey founded the Church of Satan.
# Generated: Anton Szandor Lavey founded the Church of Satan.
# Match: ✓
# Char Accuracy: 48/48 (100.0%)
#
# Sample 3938
# Input: Ezx lyo Xlcj ezwo pgpcjmzoj espj hpcp mzcpo.
# Expected: Tom and Mary told everybody they were bored.
# Generated: Tom and Mary told everybody they were bored.
# Match: ✓
# Char Accuracy: 44/44 (100.0%)
#
# Sample 3939
# Input: Hvsm ksbh hc o Yopmzs aigwq qcbqsfh.
# Expected: They went to a Kabyle music concert.
# Generated: They went to a Kabyle music concert.
# Match: ✓
# Char Accuracy: 36/36 (100.0%)
#
# Sample 3940
# Input: ocvg
# Expected: mate
# Generated: mate
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3941
# Input: bibbww
# Expected: tattoo
# Generated: tattoo
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3942
# Input: Tzw rtymjw bfx ajwd mfuud ktw ymj anxny tk mjw lwfsixts fsi httpji f xzgxyfsynfq rjfq ktw ymj thhfxnts.
# Expected: Our mother was very happy for the visit of her grandson and cooked a substantial meal for the occasion.
# Generated: Our mother was very happy for the visit of her grandson and cooked a substantial meal for the occasion.
# Match: ✓
# Char Accuracy: 103/103 (100.0%)
#
# Sample 3943
# Input: Nby qcweyx qcnwb jombyx byl chni nby xyyj qunyl.
# Expected: The wicked witch pushed her into the deep water.
# Generated: The wicked witch pushed her into the deep water.
# Match: ✓
# Char Accuracy: 48/48 (100.0%)
#
# Sample 3944
# Input: Tjp ncjpgy cvqz vi vnndnovio.
# Expected: You should have an assistant.
# Generated: You should have an assistant.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3945
# Input: Grkd iye cksn gkc fobi pexxi.
# Expected: What you said was very funny.
# Generated: What you said was very funny.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3946
# Input: Vjg rjqvq dgnqpiu vq jgt.
# Expected: The photo belongs to her.
# Generated: The photo belongs to her.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3947
# Input: ykocpufyhn
# Expected: equivalent
# Generated: equivalent
# Match: ✓
# Char Accuracy: 10/10 (100.0%)
#
# Sample 3948
# Input: fzqkhb
# Expected: garlic
# Generated: garlic
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3949
# Input: xsmuxkwo
# Expected: nickname
# Generated: nickname
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 3950
# Input: A lzafc Lge sfv Esjq sjw jwdawnwv.
# Expected: I think Tom and Mary are relieved.
# Generated: I think Tom and Mary are relieved.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3951
# Input: Ug lzmiu emvb cx qv auwsm.
# Expected: My dream went up in smoke.
# Generated: My dream went up in smoke.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3952
# Input: Cxv uxxtnm jc Vjah jwm bx mrm Sxqw.
# Expected: Tom looked at Mary and so did John.
# Generated: Tom looked at Mary and so did John.
# Match: ✓
# Char Accuracy: 35/35 (100.0%)
#
# Sample 3953
# Input: Bpcn etdeat igpkta id qt lxiw upbxan udg Rwgxhibph.
# Expected: Many people travel to be with family for Christmas.
# Generated: Many people travel to be with family for Christmas.
# Match: ✓
# Char Accuracy: 51/51 (100.0%)
#
# Sample 3954
# Input: Suxuiiu oy vaxyaotm gt kdvgtyoutoyz vuroie ot Ckyzkxt Ygngxg.
# Expected: Morocco is pursuing an expansionist policy in Western Sahara.
# Generated: Morocco is pursuing an expansionist policy in Western Sahara.
# Match: ✓
# Char Accuracy: 61/61 (100.0%)
#
# Sample 3955
# Input: Xmj bfx mtsjxy.
# Expected: She was honest.
# Generated: She was honest.
# Match: ✓
# Char Accuracy: 15/15 (100.0%)
#
# Sample 3956
# Input: Irar fjb bjcrbornm.
# Expected: Ziri was satisfied.
# Generated: Ziri was satisfied.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3957
# Input: clhmw
# Expected: enjoy
# Generated: enjoy
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3958
# Input: Vkh qhhgv wr eh wrog wr gr wkdw eb khuvhoi.
# Expected: She needs to be told to do that by herself.
# Generated: She needs to be told to do that by herself.
# Match: ✓
# Char Accuracy: 43/43 (100.0%)
#
# Sample 3959
# Input: Bcnojw bjf cqn vxwbcna fqx truunm Arvj.
# Expected: Stefan saw the monster who killed Rima.
# Generated: Stefan saw the monster who killed Rima.
# Match: ✓
# Char Accuracy: 39/39 (100.0%)
#
# Sample 3960
# Input: wymxw
# Expected: suits
# Generated: suits
# Match: ✓
# Char Accuracy: 5/5 (100.0%)
#
# Sample 3961
# Input: Gur jngre vf pnyz.
# Expected: The water is calm.
# Generated: The water is calm.
# Match: ✓
# Char Accuracy: 18/18 (100.0%)
#
# Sample 3962
# Input: Ufzq xhwjfrji ns kjfw.
# Expected: Paul screamed in fear.
# Generated: Paul screamed in fear.
# Match: ✓
# Char Accuracy: 22/22 (100.0%)
#
# Sample 3963
# Input: Uc bm fytc qmkcrfgle ufgaf gq kmpc gl wmsp npgac pylec.
# Expected: We do have something which is more in your price range.
# Generated: We do have something which is more in your price range.
# Match: ✓
# Char Accuracy: 55/55 (100.0%)
#
# Sample 3964
# Input: mnenuxyvnwc
# Expected: development
# Generated: development
# Match: ✓
# Char Accuracy: 11/11 (100.0%)
#
# Sample 3965
# Input: F txp ylok ql pbq rm x dixofkd buxjmib lc przzbpp clo lqebop ql cliilt.
# Expected: I was born to set up a glaring example of success for others to follow.
# Generated: I was born to set up a glaring example of success for others to follow.
# Match: ✓
# Char Accuracy: 71/71 (100.0%)
#
# Sample 3966
# Input: Wkbi gkc rsqrvi yppoxnon li grkd Dyw rkn dy cki.
# Expected: Mary was highly offended by what Tom had to say.
# Generated: Mary was highly offended by what Tom had to say.
# Match: ✓
# Char Accuracy: 48/48 (100.0%)
#
# Sample 3967
# Input: Dro yxvi bowybco Pknsv crygon gkc pyb dro pkmd ro gkc mkeqrd.
# Expected: The only remorse Fadil showed was for the fact he was caught.
# Generated: The only remorse Fadil showed was for the fact he was caught.
# Match: ✓
# Char Accuracy: 61/61 (100.0%)
#
# Sample 3968
# Input: Zxj ittwrfyx fy jsywdbfdx yt rnsnrnej inwy gjnsl gwtzlmy nsxnij.
# Expected: Use doormats at entryways to minimize dirt being brought inside.
# Generated: Use doormats at entryways to minimize dirt being brought inside.
# Match: ✓
# Char Accuracy: 64/64 (100.0%)
#
# Sample 3969
# Input: Oek cywxj mqdj je we myjx cu.
# Expected: You might want to go with me.
# Generated: You might want to go with me.
# Match: ✓
# Char Accuracy: 29/29 (100.0%)
#
# Sample 3970
# Input: Gwc nwcvl um ieism.
# Expected: You found me awake.
# Generated: You found me awake.
# Match: ✓
# Char Accuracy: 19/19 (100.0%)
#
# Sample 3971
# Input: Fbuqiu seddusj q sedjhebbuh.
# Expected: Please connect a controller.
# Generated: Please connect a controller.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3972
# Input: Yxo ydrob fsmdsw bowksxc ryczsdkvsjon.
# Expected: One other victim remains hospitalized.
# Generated: One other victim remains hospitalized.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3973
# Input: Qlj fp pqfii qefoqbbk vbxop lia.
# Expected: Tom is still thirteen years old.
# Generated: Tom is still thirteen years old.
# Match: ✓
# Char Accuracy: 32/32 (100.0%)
#
# Sample 3974
# Input: Dvdfizqv kyfjv jvekvetvj.
# Expected: Memorize those sentences.
# Generated: Memorize those sentences.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3975
# Input: Vene swjpo Neiw pk zk ep.
# Expected: Ziri wants Rima to do it.
# Generated: Ziri wants Rima to do it.
# Match: ✓
# Char Accuracy: 25/25 (100.0%)
#
# Sample 3976
# Input: T slo eczfmwp dwppatyr.
# Expected: I had trouble sleeping.
# Generated: I had trouble sleeping.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3977
# Input: mtws
# Expected: horn
# Generated: horn
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3978
# Input: T tygpye dezctpd mj hctetyr ozhy hslepgpc T estyv zq.
# Expected: I invent stories by writing down whatever I think of.
# Generated: I invent stories by writing down whatever I think of.
# Match: ✓
# Char Accuracy: 53/53 (100.0%)
#
# Sample 3979
# Input: Snl zmc Lzqx szkjdc pthdskx.
# Expected: Tom and Mary talked quietly.
# Generated: Tom and Mary talked quietly.
# Match: ✓
# Char Accuracy: 28/28 (100.0%)
#
# Sample 3980
# Input: Eb fp cobb tfqe efp jlkbv.
# Expected: He is free with his money.
# Generated: He is free with his money.
# Match: ✓
# Char Accuracy: 26/26 (100.0%)
#
# Sample 3981
# Input: Znel vf n znfba.
# Expected: Mary is a mason.
# Generated: Mary is a mason.
# Match: ✓
# Char Accuracy: 16/16 (100.0%)
#
# Sample 3982
# Input: unsx
# Expected: pins
# Generated: pins
# Match: ✓
# Char Accuracy: 4/4 (100.0%)
#
# Sample 3983
# Input: Bqn ngyujrwnm cqn adunb rw mncjru.
# Expected: She explained the rules in detail.
# Generated: She explained the rules in detail.
# Match: ✓
# Char Accuracy: 34/34 (100.0%)
#
# Sample 3984
# Input: V zhfg cebgrfg.
# Expected: I must protest.
# Generated: I must protest.
# Match: ✓
# Char Accuracy: 15/15 (100.0%)
#
# Sample 3985
# Input: Rhqsu oekhiublui.
# Expected: Brace yourselves.
# Generated: Brace yourselves.
# Match: ✓
# Char Accuracy: 17/17 (100.0%)
#
# Sample 3986
# Input: Ezx hld mczfrse fa ty esp wla zq wfifcj.
# Expected: Tom was brought up in the lap of luxury.
# Generated: Tom was brought up in the lap of luxury.
# Match: ✓
# Char Accuracy: 40/40 (100.0%)
#
# Sample 3987
# Input: Fay rqxf uxx.
# Expected: Tom felt ill.
# Generated: Tom felt ill.
# Match: ✓
# Char Accuracy: 13/13 (100.0%)
#
# Sample 3988
# Input: Mvev gevrq gb jnyx nf pnfhnyyl nf cbffvoyr.
# Expected: Ziri tried to walk as casually as possible.
# Generated: Ziri tried to walk as casually as possible.
# Match: ✓
# Char Accuracy: 43/43 (100.0%)
#
# Sample 3989
# Input: Tuhuje kryk cuarj nkrv nkx.
# Expected: Nobody else would help her.
# Generated: Nobody else would help her.
# Match: ✓
# Char Accuracy: 27/27 (100.0%)
#
# Sample 3990
# Input: Ojh viy Hvmt nvdy oczt rzmz mzvggt wmjfz.
# Expected: Tom and Mary said they were really broke.
# Generated: Tom and Mary said they were really broke.
# Match: ✓
# Char Accuracy: 41/41 (100.0%)
#
# Sample 3991
# Input: Snl rzxr Lzqx hr shqdc.
# Expected: Tom says Mary is tired.
# Generated: Tom says Mary is tired.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3992
# Input: Vjgtg ctg eqwpvnguu ekxknkcp ecuwcnvkgu.
# Expected: There are countless civilian casualties.
# Generated: There are countless civilian casualties.
# Match: ✓
# Char Accuracy: 40/40 (100.0%)
#
# Sample 3993
# Input: pdrmnm
# Expected: guided
# Generated: guided
# Match: ✓
# Char Accuracy: 6/6 (100.0%)
#
# Sample 3994
# Input: Znke gxk ynuxz gtj znot.
# Expected: They are short and thin.
# Generated: They are short and thin.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3995
# Input: Kh fdph wr ylvlw khu.
# Expected: He came to visit her.
# Generated: He came to visit her.
# Match: ✓
# Char Accuracy: 21/21 (100.0%)
#
# Sample 3996
# Input: Jec iqyt Y mqi wehwueki.
# Expected: Tom said I was gorgeous.
# Generated: Tom said I was gorgeous.
# Match: ✓
# Char Accuracy: 24/24 (100.0%)
#
# Sample 3997
# Input: Mx xewxiw vieppc cyqqc.
# Expected: It tastes really yummy.
# Generated: It tastes really yummy.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Sample 3998
# Input: Xfrn fsi Qfdqf hfrj kwtr gwtpjs mtrjx.
# Expected: Sami and Layla came from broken homes.
# Generated: Sami and Layla came from broken homes.
# Match: ✓
# Char Accuracy: 38/38 (100.0%)
#
# Sample 3999
# Input: dqttioma
# Expected: villages
# Generated: villages
# Match: ✓
# Char Accuracy: 8/8 (100.0%)
#
# Sample 4000
# Input: Dyw vsuoc nyxq zejjvoc.
# Expected: Tom likes dong puzzles.
# Generated: Tom likes dong puzzles.
# Match: ✓
# Char Accuracy: 23/23 (100.0%)
#
# Progress: 4000/4000
# Current Accuracy: 95.0% full matches
# Character Accuracy: 99.2%
#
#
# FINAL RESULTS
# Total Samples: 4000
# Full Match Accuracy: 94.95%
# Character Accuracy: 99.17%
#
# All results saved to: /content/drive/MyDrive/decryption_results_caesar_update.xlsx
