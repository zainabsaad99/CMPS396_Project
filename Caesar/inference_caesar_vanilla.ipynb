# %%
import torch
import torch.nn as nn
import math
import pandas as pd
import string
import numpy as np
from tqdm import tqdm

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# --- Vocabulary Class ---
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        all_chars = list(string.printable)
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        if isinstance(text, float):  # Handle NaN values
            text = str(text)
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# --- Transformer Model ---
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))
        attn_probs = torch.softmax(scores, dim=-1)
        return torch.matmul(attn_probs, V)

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        return self.W_o(self.combine_heads(attn_output))

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super().__init__()
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm2(x + self.dropout(ff_output))

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm3(x + self.dropout(ff_output))

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask
        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        return self.fc(dec_output)

# --- Inference Functions ---
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        return vocab.decode(target[0].cpu().numpy())

def process_and_print_results(model, test_file, vocab, max_length, device, num_samples=4000):
    try:
        df = pd.read_excel(test_file) if test_file.endswith('.xlsx') else pd.read_csv(test_file)
    except Exception as e:
        print(f"Error loading test file: {e}")
        return None

    if len(df) > num_samples:
        df = df.sample(n=num_samples, random_state=42)

    results = []
    total_correct = 0
    total_chars_correct = 0
    total_chars = 0

    print("\n=== Starting Inference ===")
    print(f"Processing {len(df)} test cases...\n")

    for idx, row in df.iterrows():
        try:
            input_text = str(row['Input'])
            expected = str(row['Output'])

            # Decrypt the text
            decrypted = decrypt_text(model, input_text, vocab, max_length, device)
            decrypted_clean = decrypted.replace('<SOS>', '').replace('<EOS>', '').strip()

            # Calculate metrics
            full_match = decrypted_clean == expected
            total_correct += int(full_match)

            min_len = min(len(decrypted_clean), len(expected))
            char_matches = sum(1 for a, b in zip(decrypted_clean[:min_len], expected[:min_len]) if a == b)
            total_chars_correct += char_matches
            total_chars += max(len(decrypted_clean), len(expected))

            # Print detailed results for each case
            print(f"\n--- Case {idx+1} ---")
            print(f"Input:     {input_text}")
            print(f"Decrypted: {decrypted_clean}")
            print(f"Expected:  {expected}")
            print(f"Match:     {'✅' if full_match else '❌'}")
            print(f"Char Accuracy: {char_matches}/{max(len(decrypted_clean), len(expected))} ({(char_matches/max(len(decrypted_clean), len(expected)))*100:.1f}%)")

            results.append({
                'Case #': idx+1,
                'Input': input_text,
                'Decrypted': decrypted_clean,
                'Expected': expected,
                'Full Match': 'Yes' if full_match else 'No',
                'Char Matches': f"{char_matches}/{max(len(decrypted_clean), len(expected))}",
                'Char Accuracy': f"{(char_matches/max(len(decrypted_clean), len(expected)))*100:.2f}%"
            })

        except Exception as e:
            print(f"\nError processing case {idx+1}: {e}")
            continue

    # Create results DataFrame
    results_df = pd.DataFrame(results)

    # Add summary
    full_acc = (total_correct/len(results))*100 if results else 0
    char_acc = (total_chars_correct/total_chars)*100 if total_chars > 0 else 0

    summary = pd.DataFrame([{
        'Case #': 'SUMMARY',
        'Input': f"Total Cases: {len(results)}",
        'Decrypted': f"Full Accuracy: {full_acc:.2f}%",
        'Expected': f"Char Accuracy: {char_acc:.2f}%",
        'Full Match': f"{total_correct}/{len(results)}",
        'Char Matches': f"{total_chars_correct}/{total_chars}",
        'Char Accuracy': f"{char_acc:.2f}%"
    }])

    return pd.concat([results_df, summary], ignore_index=True)

# --- Main Execution ---
if __name__ == "__main__":
    # Configuration - UPDATE THESE PATHS
    MODEL_PATH = '/content/drive/MyDrive/caesar_vanilla.pth'
    TEST_FILE = '/content/testing_newshift_1.csv'
    OUTPUT_FILE = '/content/drive/MyDrive/inference_results_caesar_vanilla.xlsx'
    MAX_LENGTH = 256

    # Initialize vocabulary and model
    vocab = Vocabulary()
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=4,
        num_layers=6,
        d_ff=512,
        max_seq_length=MAX_LENGTH,
        dropout=0.11034371565549608
    ).to(device)

    # Load trained model
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
        model.eval()
        print("Model loaded successfully")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    # Process test cases and print all results
    results = process_and_print_results(model, TEST_FILE, vocab, MAX_LENGTH, device)

    # Save to Excel
    if results is not None:
        try:
            results.to_excel(OUTPUT_FILE, index=False)
            print(f"\nFull results saved to {OUTPUT_FILE}")

            # Print final summary
            print("\n=== Final Summary ===")
            print(f"Full-match accuracy: {results.iloc[-1]['Full Match']}")
            print(f"Character-level accuracy: {results.iloc[-1]['Char Matches']} ({results.iloc[-1]['Char Accuracy']})")
        except Exception as e:
            print(f"\nError saving results: {e}")
    else:
        print("\nNo results were generated")
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected:  I think Tom is too young.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 18608 ---
# Input:     rmnn
# Decrypted: idee
# Expected:  jeff
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 55118 ---
# Input:     Zwsnwf usf osal.
# Decrypted: Lievir ger awmb.
# Expected:  Heaven can wait.
# Match:     ❌
# Char Accuracy: 4/16 (25.0%)
#
# --- Case 9559 ---
# Input:     Cqn cnuncqxw rb j Oanwlq CE yaxpajv xapjwrinm nenah hnja cx lxuunlc odwmb rw xamna cx orwjwln vnmrlju anbnjalq.
# Decrypted: The telethon is a French TV program organized every year to collect funds in order to finance medical resselv.
# Expected:  The telethon is a French TV program organized every year to collect funds in order to finance medical research.
# Match:     ❌
# Char Accuracy: 105/111 (94.6%)
#
# --- Case 51202 ---
# Input:     Yg uyco hcuv.
# Decrypted: It weiy niat.
# Expected:  We swam fast.
# Match:     ❌
# Char Accuracy: 4/13 (30.8%)
#
# --- Case 83470 ---
# Input:     Migyvixs wugy.
# Decrypted: Somebody cume.
# Expected:  Somebody came.
# Match:     ❌
# Char Accuracy: 13/14 (92.9%)
#
# --- Case 52118 ---
# Input:     Lge vwfawv lzsl Esjq osk lzw gfw ozg lgdv zae lg vg lzsl.
# Decrypted: Tom denied that Mary was the one who told him to do that.
# Expected:  Tom denied that Mary was the one who told him to do that.
# Match:     ✅
# Char Accuracy: 57/57 (100.0%)
#
# --- Case 7032 ---
# Input:     Fhuup dhz isllkpun.
# Decrypted: Yanni was bleeding.
# Expected:  Yanni was bleeding.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 26895 ---
# Input:     Nbymy uly mcgcful von hin nby mugy.
# Decrypted: These are similar but not the same.
# Expected:  These are similar but not the same.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 26941 ---
# Input:     Y sedwhqjkbqju oek rejx.
# Decrypted: I congratulate you both.
# Expected:  I congratulate you both.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 64421 ---
# Input:     cpio
# Decrypted: hunt
# Expected:  hunt
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 76996 ---
# Input:     Ojh ojgy Hvmt cz rjpgy vgrvtn gjqz czm.
# Decrypted: Tom told Mary he would always love her.
# Expected:  Tom told Mary he would always love her.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 19136 ---
# Input:     Sp yppopo xzypj.
# Decrypted: He needed money.
# Expected:  He needed money.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 18249 ---
# Input:     clfylackclrq
# Decrypted: enhancements
# Expected:  enhancements
# Match:     ✅
# Char Accuracy: 12/12 (100.0%)
#
# --- Case 27184 ---
# Input:     wxcrln
# Decrypted: notice
# Expected:  notice
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 14903 ---
# Input:     Brx eholhyhg lw zdv xqlpsruwdqw.
# Decrypted: You believed it was unimportant.
# Expected:  You believed it was unimportant.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 71378 ---
# Input:     Zh ohdyh iru Dxvwudold rq Prqgdb.
# Decrypted: We leave for Australia on Monday.
# Expected:  We leave for Australia on Monday.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 79836 ---
# Input:     Uzj htww yze wlde qzcpgpc.
# Decrypted: Joy will not last forever.
# Expected:  Joy will not last forever.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 25470 ---
# Input:     Ypylsihy cm ualyyx.
# Decrypted: Everyone is agreed.
# Expected:  Everyone is agreed.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 66476 ---
# Input:     sfcfddb
# Decrypted: rebecca
# Expected:  rebecca
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 47006 ---
# Input:     Zus oy payz ghuaz gy urj gy O gs.
# Decrypted: Tom is just about as old as I am.
# Expected:  Tom is just about as old as I am.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 54247 ---
# Input:     E jaaz pk bejz okiakja sdk ywj pwga ywna kb iu ydehznaj.
# Decrypted: I need to find someone who can take care of my children.
# Expected:  I need to find someone who can take care of my children.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 60847 ---
# Input:     Pki lnapajzaz pk xa opqlez.
# Decrypted: Tom pretended to be stupid.
# Expected:  Tom pretended to be stupid.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 69210 ---
# Input:     Vod Wkbi gkdmr grkd cro gkxdc.
# Decrypted: Let Mary watch what she wants.
# Expected:  Let Mary watch what she wants.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 89716 ---
# Input:     Ixu mqi iyffydw xuh cqhwqhyjq.
# Decrypted: She was sipping her margarita.
# Expected:  She was sipping her margarita.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 68376 ---
# Input:     Pvs xbmmt bsf qjol.
# Decrypted: Our walls are pink.
# Expected:  Our walls are pink.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 45498 ---
# Input:     Wfof txp sbov tloofba.
# Decrypted: Ziri was very worried.
# Expected:  Ziri was very worried.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 46089 ---
# Input:     kvsbsjsf
# Decrypted: whenever
# Expected:  whenever
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 59916 ---
# Input:     Cqho mqi jqaud qrqsa mxud ixu dejysut jxqj jxu fxejevyj ev jxu ikifusjut rkhwbqh beeaut byau Jec.
# Decrypted: Mary was taken aback when she noticed that the photofit of the suspected burglar lokede like Tom.
# Expected:  Mary was taken aback when she noticed that the photofit of the suspected burglar looked like Tom.
# Match:     ❌
# Char Accuracy: 93/97 (95.9%)
#
# --- Case 85693 ---
# Input:     gjdwsfk
# Decrypted: orleans
# Expected:  orleans
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 71580 ---
# Input:     N lty nsyt fs fwlzrjsy bnym Ytr.
# Decrypted: I got into an argument with Tom.
# Expected:  I got into an argument with Tom.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 44197 ---
# Input:     E swjp pk oaa sdwp pkiknnks xnejco.
# Decrypted: I want to see what tomorrow brings.
# Expected:  I want to see what tomorrow brings.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 78245 ---
# Input:     Xluqcha xluaihm uhx xinncha ch nby ysym cm u zuvfy.
# Decrypted: Drawing dragons and dotting in the eyes is a fable.
# Expected:  Drawing dragons and dotting in the eyes is a fable.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 73098 ---
# Input:     F bxq ofzb xijlpq bsbov axv.
# Decrypted: I eat rice almost every day.
# Expected:  I eat rice almost every day.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 15939 ---
# Input:     Qozz gcascbs.
# Decrypted: Call someone.
# Expected:  Call someone.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 21287 ---
# Input:     Fay gegmxxk fmwqe m imxw qhqdk yadzuzs nqradq ndqmwrmef.
# Decrypted: Tom usually takes a walk every morning before breakfast.
# Expected:  Tom usually takes a walk every morning before breakfast.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 18108 ---
# Input:     Bpm xqhhi apwctl jm pmzm ivg uqvcbm.
# Decrypted: The pizza should be here any minute.
# Expected:  The pizza should be here any minute.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 43698 ---
# Input:     F ifhb ql bumilob ilzxi xqqoxzqflkp.
# Decrypted: I like to explore local attractions.
# Expected:  I like to explore local attractions.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 52326 ---
# Input:     ifbmuiz
# Decrypted: healthy
# Expected:  healthy
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 36169 ---
# Input:     Matm ftr ghm lheox max ikhuexf.
# Decrypted: That may not solve the problem.
# Expected:  That may not solve the problem.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 86938 ---
# Input:     ntnva
# Decrypted: again
# Expected:  again
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 8777 ---
# Input:     ytqvg
# Decrypted: wrote
# Expected:  wrote
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 93869 ---
# Input:     Sbkb atmxw Kbft lfhdbgz bg max vtk.
# Decrypted: Ziri hated Rima smoking in the car.
# Expected:  Ziri hated Rima smoking in the car.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 30849 ---
# Input:     Qfc uyq ucypgle y lcejgecc.
# Decrypted: She was wearing a negligee.
# Expected:  She was wearing a negligee.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 3031 ---
# Input:     Gigjksoiy cxozk lux gigjksoi puaxtgry.
# Decrypted: Academics write for academic journals.
# Expected:  Academics write for academic journals.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 87391 ---
# Input:     Y mqi jhoydw je vydt q mqo yd.
# Decrypted: I was trying to find a way in.
# Expected:  I was trying to find a way in.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 33472 ---
# Input:     E swjp pk iaap Iwnu.
# Decrypted: I want to meet Mary.
# Expected:  I want to meet Mary.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 35013 ---
# Input:     Gbz unf ybfg nyy frafr bs ernyvgl.
# Decrypted: Tom has lost all sense of reality.
# Expected:  Tom has lost all sense of reality.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 35193 ---
# Input:     Ow gxlwf oaf.
# Decrypted: We often win.
# Expected:  We often win.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 26065 ---
# Input:     Idb wph dlcts iwpi rpg udg iwgtt ntpgh.
# Decrypted: Tom has owned that car for three years.
# Expected:  Tom has owned that car for three years.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 93531 ---
# Input:     Zus iuarj ju kbkxeznotm nk ngj zu ju.
# Decrypted: Tom could do everything he had to do.
# Expected:  Tom could do everything he had to do.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 10217 ---
# Input:     Jyv wfleu yvi wzijk xivp yrzi.
# Decrypted: She found her first grey hair.
# Expected:  She found her first grey hair.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 43600 ---
# Input:     Bzqknr zmc ghr gdqc cnf zqd z sdzl.
# Decrypted: Carlos and his herd dog are a team.
# Expected:  Carlos and his herd dog are a team.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 68778 ---
# Input:     Vdpl frqihvvhg wr ghwhfwlyhv wkdw kh dqg Odbod kdg frqvsluhg wr nloo klv zlih.
# Decrypted: Sami confessed to detectives that he and Layla had conspired to kill his wife.
# Expected:  Sami confessed to detectives that he and Layla had conspired to kill his wife.
# Match:     ✅
# Char Accuracy: 78/78 (100.0%)
#
# --- Case 86133 ---
# Input:     Bpib eia i ycmabqwv Bwu ammuml zmilg nwz.
# Decrypted: That was a question Tom seemed ready for.
# Expected:  That was a question Tom seemed ready for.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 85873 ---
# Input:     yilzh
# Decrypted: block
# Expected:  block
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 95751 ---
# Input:     If mpplt mjlf b dmfwfs cpz.
# Decrypted: He looks like a clever boy.
# Expected:  He looks like a clever boy.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 68930 ---
# Input:     Xfrn nx gd mnrxjqk.
# Decrypted: Sami is by himself.
# Expected:  Sami is by himself.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 34725 ---
# Input:     Snl hr sgd dwodchshnm kdzcdq.
# Decrypted: Tom is the expedition leader.
# Expected:  Tom is the expedition leader.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 14337 ---
# Input:     Kag mdq egdq fa egooqqp uz fuyq.
# Decrypted: You are sure to succeed in time.
# Expected:  You are sure to succeed in time.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 5039 ---
# Input:     Hca gowr W zccysr vibufm.
# Decrypted: Tom said I looked hungry.
# Expected:  Tom said I looked hungry.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 97965 ---
# Input:     rdbepgpqat
# Decrypted: comparable
# Expected:  comparable
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 42538 ---
# Input:     N Zrkvpna jbzna gnhtug ure Fcnavfu.
# Decrypted: A Mexican woman taught her Spanish.
# Expected:  A Mexican woman taught her Spanish.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 14002 ---
# Input:     Ujg jcu c nqv qh htkgpfu jgtg.
# Decrypted: She has a lot of friends here.
# Expected:  She has a lot of friends here.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 72773 ---
# Input:     Qebv pqorzh Jfkx.
# Decrypted: They struck Mina.
# Expected:  They struck Mina.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 36505 ---
# Input:     Ymjwj fwj ymnslx ns rd qnkj N fr sty uwtzi tk.
# Decrypted: There are things in my life I am not proud of.
# Expected:  There are things in my life I am not proud of.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 70408 ---
# Input:     Pm smxb Asczi qvnwzuml ijwcb pqa epmzmijwcba.
# Decrypted: He kept Skura informed about his whereabouts.
# Expected:  He kept Skura informed about his whereabouts.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 64000 ---
# Input:     unbzshnmzk
# Decrypted: vocational
# Expected:  vocational
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 51877 ---
# Input:     Vjcv pgy ikboq vjcv aqw ycpv ku qxgt cv vjg uvqtg pqy.
# Decrypted: That new gizmo that you want is over at the store now.
# Expected:  That new gizmo that you want is over at the store now.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 27059 ---
# Input:     Rc cjbcnb anjuuh hdvvh.
# Decrypted: It tastes really yummy.
# Expected:  It tastes really yummy.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 2955 ---
# Input:     N qnpj dtzw gnpj.
# Decrypted: I like your bike.
# Expected:  I like your bike.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 7706 ---
# Input:     Znk vnuzu hkrutmy zu nkx.
# Decrypted: The photo belongs to her.
# Expected:  The photo belongs to her.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 778 ---
# Input:     gub
# Decrypted: fta
# Expected:  dry
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 65347 ---
# Input:     Da wniaz deioahb sepd w cqj wjz sajp pk bwya pda ajaiu ywil.
# Decrypted: He armed himself with a gun and went to face the enemy camp.
# Expected:  He armed himself with a gun and went to face the enemy camp.
# Match:     ✅
# Char Accuracy: 60/60 (100.0%)
#
# --- Case 81696 ---
# Input:     zevxpgvodji
# Decrypted: ejaculation
# Expected:  ejaculation
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 90314 ---
# Input:     Dfcpzsag ofs o qcaacb cqqiffsbqs wb zwts.
# Decrypted: Problems are a common occurrence in life.
# Expected:  Problems are a common occurrence in life.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 74119 ---
# Input:     Px axeixw maxf tl pxee.
# Decrypted: We helped them as well.
# Expected:  We helped them as well.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 5999 ---
# Input:     Wms ayl ngai sn rfc icw dpmk pcacnrgml.
# Decrypted: You can pick up the key from reception.
# Expected:  You can pick up the key from reception.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 42475 ---
# Input:     Rgd hr zbbdrrhakd sn ohsx.
# Decrypted: She is accessible to pity.
# Expected:  She is accessible to pity.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 14503 ---
# Input:     L dvnhg klp.
# Decrypted: I asked him.
# Expected:  I asked him.
# Match:     ✅
# Char Accuracy: 12/12 (100.0%)
#
# --- Case 65005 ---
# Input:     Ytr xfni Rfwd nx lqfi ymfy xmj htzqi it ymfy ktw dtz.
# Decrypted: Tom said Mary is glad that she could do that for you.
# Expected:  Tom said Mary is glad that she could do that for you.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 24805 ---
# Input:     Xfrn fsi Qfdqf xmfwji gfsp fhhtzsyx ytljymjw.
# Decrypted: Sami and Layla shared bank accounts together.
# Expected:  Sami and Layla shared bank accounts together.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 3048 ---
# Input:     Xzxabjfzp tofqb clo xzxabjfz glrokxip.
# Decrypted: Academics write for academic journals.
# Expected:  Academics write for academic journals.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 69792 ---
# Input:     Z yrmv r kyvjzj kf nizkv.
# Decrypted: I have a thesis to write.
# Expected:  I have a thesis to write.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 99465 ---
# Input:     vgtpi
# Decrypted: great
# Expected:  great
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 4273 ---
# Input:     nxqxo
# Decrypted: blelc
# Expected:  qatar
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 55227 ---
# Input:     etgy
# Decrypted: shum
# Expected:  crew
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 35148 ---
# Input:     coxkzfpzl
# Decrypted: franciscy
# Expected:  francisco
# Match:     ❌
# Char Accuracy: 8/9 (88.9%)
#
# --- Case 3657 ---
# Input:     Avt mvbuk aol lewlyplujl mybzayhapun.
# Decrypted: Tom found the experience frustrating.
# Expected:  Tom found the experience frustrating.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 40715 ---
# Input:     X lxaa dcan axkt udg bn rwxas xc iwt ujijgt.
# Decrypted: I will only live for my child in the future.
# Expected:  I will only live for my child in the future.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 43298 ---
# Input:     Prze x zofjb zxkklq yb abpmfpba bklrde.
# Decrypted: Such a crime cannot be despised enough.
# Expected:  Such a crime cannot be despised enough.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 66069 ---
# Input:     hnmkxtva
# Decrypted: outreach
# Expected:  outreach
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 31940 ---
# Input:     Bpgiwp palpnh sgthhts ktgn bdsthian.
# Decrypted: Martha always dressed very modestly.
# Expected:  Martha always dressed very modestly.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 22224 ---
# Input:     Zc qspc rm zc gl rgkc.
# Decrypted: Be sure to be in time.
# Expected:  Be sure to be in time.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 13423 ---
# Input:     xpe
# Decrypted: met
# Expected:  ash
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 38078 ---
# Input:     Wrp zrqghuhg zkdw Pdub zdv derxw wr gr.
# Decrypted: Tom wondered what Mary was about to do.
# Expected:  Tom wondered what Mary was about to do.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 46077 ---
# Input:     yjgpgxgt
# Decrypted: whenever
# Expected:  whenever
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 52562 ---
# Input:     Tq ime dqrgeqp yqpuomx fdqmfyqzf.
# Decrypted: He was refused medical treatment.
# Expected:  He was refused medical treatment.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 18714 ---
# Input:     oqqsdh
# Decrypted: prrtei
# Expected:  accept
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# --- Case 82151 ---
# Input:     Tif tqfblt qspqfs Cfscfs.
# Decrypted: She speaks proper Berber.
# Expected:  She speaks proper Berber.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 11097 ---
# Input:     Iwnu pneaz jkp pk hap dan iejz swjzan.
# Decrypted: Mary tried not to let her mind wander.
# Expected:  Mary tried not to let her mind wander.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 96940 ---
# Input:     apcsxcv
# Decrypted: landing
# Expected:  landing
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 27262 ---
# Input:     pqbdqeeuaz
# Decrypted: depression
# Expected:  depression
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 35153 ---
# Input:     Ulpd zdqwv Clul wr frph zlwk khu wr wkh frqfhuw.
# Decrypted: Rima wants Ziri to come with her to the concert.
# Expected:  Rima wants Ziri to come with her to the concert.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 82057 ---
# Input:     Fhuup ohalz ihk wlvwsl.
# Decrypted: Yanni hates bad people.
# Expected:  Yanni hates bad people.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 44316 ---
# Input:     Mu qhu rejx je rbqcu.
# Decrypted: We are both to blame.
# Expected:  We are both to blame.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 51410 ---
# Input:     mbokdsyx
# Decrypted: creation
# Expected:  creation
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 62259 ---
# Input:     Cqrb luxcq rb bxum kh cqn hjam.
# Decrypted: This cloth is sold by the yard.
# Expected:  This cloth is sold by the yard.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 28031 ---
# Input:     Zus ingykj sk.
# Decrypted: Tom chased me.
# Expected:  Tom chased me.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 19084 ---
# Input:     bqnoornum
# Decrypted: sheffield
# Expected:  sheffield
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 59111 ---
# Input:     opalcexpye
# Decrypted: department
# Expected:  department
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 62670 ---
# Input:     Nbys mnulnyx u zilvcxxyh uhx wfuhxymnchy lyfuncihmbcj.
# Decrypted: They started a forbidden and clandestine relationship.
# Expected:  They started a forbidden and clandestine relationship.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 44365 ---
# Input:     Hpbx wps pc prrdbeaxrt.
# Decrypted: Sami had an accomplice.
# Expected:  Sami had an accomplice.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 16847 ---
# Input:     Pnu kj xkpd pdaoa ykwpo wjz ykilwna pdai.
# Decrypted: Try on both these coats and compare them.
# Expected:  Try on both these coats and compare them.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 53993 ---
# Input:     skf
# Decrypted: cup
# Expected:  asn
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 79139 ---
# Input:     rwgqzcgs
# Decrypted: disclose
# Expected:  disclose
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 48550 ---
# Input:     bgdl
# Decrypted: difT
# Expected:  chem
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 27079 ---
# Input:     kirixmgw
# Decrypted: genetics
# Expected:  genetics
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 37487 ---
# Input:     U saf euow m xaf itqz U ime m wup.
# Decrypted: I got sick a lot when I was a kid.
# Expected:  I got sick a lot when I was a kid.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 57719 ---
# Input:     matb
# Decrypted: thai
# Expected:  thai
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 44599 ---
# Input:     Zpslm ugjj zc uyrafgle Pgky.
# Decrypted: Bruno will be watching Rima.
# Expected:  Bruno will be watching Rima.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 93832 ---
# Input:     Hsnplyz pz hu vsk jpaf.
# Decrypted: Algiers is an old city.
# Expected:  Algiers is an old city.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 79822 ---
# Input:     Ukqn ywianw eo jkp wo atyahhajp wo iu ywianw.
# Decrypted: Your camera is not as excellent as my camera.
# Expected:  Your camera is not as excellent as my camera.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 26781 ---
# Input:     Kbkxeutk corr hk ygzoylokj.
# Decrypted: Everyone will be satisfied.
# Expected:  Everyone will be satisfied.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 16084 ---
# Input:     nwmrwp
# Decrypted: ending
# Expected:  ending
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 65693 ---
# Input:     Lge ygl vakimsdaxawv.
# Decrypted: Tom got disqualified.
# Expected:  Tom got disqualified.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 68628 ---
# Input:     frdolwlrq
# Decrypted: coalition
# Expected:  coalition
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 37572 ---
# Input:     ikpdano
# Decrypted: mothers
# Expected:  mothers
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 56661 ---
# Input:     Dlxt tydapnepo esp leetn.
# Decrypted: Sami inspected the attic.
# Expected:  Sami inspected the attic.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 57961 ---
# Input:     aczgp
# Decrypted: prove
# Expected:  prove
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 28079 ---
# Input:     Hezmh xvmih xs lyk Eqerhe.
# Decrypted: David tried to hug Amanda.
# Expected:  David tried to hug Amanda.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 3435 ---
# Input:     Ro dkvuon klyed wecsm.
# Decrypted: He talked about music.
# Expected:  He talked about music.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 77069 ---
# Input:     lvbxgmblml
# Decrypted: scientists
# Expected:  scientists
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 1123 ---
# Input:     Pxjf fp gbxilrp lc Ixvix.
# Decrypted: Sami is jealous of Layla.
# Expected:  Sami is jealous of Layla.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 53309 ---
# Input:     Vjah rb lxwlnawnm jkxdc qna bjonch.
# Decrypted: Mary is concerned about her safety.
# Expected:  Mary is concerned about her safety.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3905 ---
# Input:     Ytr hfwjkzqqd ktqiji mnx hqtymjx fsi uzy ymjr nsyt mnx xznyhfxj.
# Decrypted: Tom carefully folded his clothes and put them into his suitcase.
# Expected:  Tom carefully folded his clothes and put them into his suitcase.
# Match:     ✅
# Char Accuracy: 64/64 (100.0%)
#
# --- Case 98681 ---
# Input:     iusvrogtz
# Decrypted: compliant
# Expected:  compliant
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 87915 ---
# Input:     Hpbx xh uaxgixcv lxiw diwtg vxgah.
# Decrypted: Sami is flirting with other girls.
# Expected:  Sami is flirting with other girls.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 23603 ---
# Input:     Mrkq jrhv wr wkh pdunhw.
# Decrypted: John goes to the market.
# Expected:  John goes to the market.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 47167 ---
# Input:     Kyv Grcvjkzezrej riv svjzvxvu ze uvdfxirgyzt srekljkrej kf sv tfekifccvu reu vmveklrccp vogvccvu fw kyvzi tflekip.
# Decrypted: The Palestinians are besieged in demographic bantustans to be controlled and eventually expelled of their country.
# Expected:  The Palestinians are besieged in demographic bantustans to be controlled and eventually expelled of their country.
# Match:     ✅
# Char Accuracy: 114/114 (100.0%)
#
# --- Case 30161 ---
# Input:     Ezx td lwhljd mzespctyr xp.
# Decrypted: Tom is always bothering me.
# Expected:  Tom is always bothering me.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 94314 ---
# Input:     Goaw goh hvsfs.
# Decrypted: Sami sat there.
# Expected:  Sami sat there.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 36859 ---
# Input:     Vjah bjrm bqn qjm bxvncqrwp rvyxacjwc cx mx.
# Decrypted: Mary said she had something important to do.
# Expected:  Mary said she had something important to do.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 81795 ---
# Input:     Lixlcai xlijjyx ihy iz nby MX wulxm.
# Decrypted: Rodrigo dropped one of the SD cards.
# Expected:  Rodrigo dropped one of the SD cards.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 99395 ---
# Input:     Fumn hcabn by muq uh ohcxyhnczcyx zfscha ivdywn ch nby mes.
# Decrypted: Last night he saw an unidentified flying object in the sky.
# Expected:  Last night he saw an unidentified flying object in the sky.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 81947 ---
# Input:     Iwnu dwo jaran rkpaz ej dan heba.
# Decrypted: Mary has never voted in her life.
# Expected:  Mary has never voted in her life.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 50034 ---
# Input:     Qn mxnb wxc bnnv yunjbnm frcq qrb lxwmrcrxw.
# Decrypted: He does not seem pleased with his condition.
# Expected:  He does not seem pleased with his condition.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 48882 ---
# Input:     uu
# Decrypted: dd
# Expected:  nn
# Match:     ❌
# Char Accuracy: 0/2 (0.0%)
#
# --- Case 25330 ---
# Input:     Yjqq zx ymj xytwd ns Gjwgjw.
# Decrypted: Tell us the story in Berber.
# Expected:  Tell us the story in Berber.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 5041 ---
# Input:     Jec iqyt Y beeaut xkdwho.
# Decrypted: Tom said I looked hungry.
# Expected:  Tom said I looked hungry.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 95671 ---
# Input:     Amzixc kvmvomjjkzmn kzmajmhzy vomjxdjpn ojmopmzn oj Vgbzmdvin ypmdib ocz gdwzmvodji rvm.
# Decrypted: French paratroopers performed atrocious tortures to Algerians during the liberation war.
# Expected:  French paratroopers performed atrocious tortures to Algerians during the liberation war.
# Match:     ✅
# Char Accuracy: 88/88 (100.0%)
#
# --- Case 94907 ---
# Input:     Avt huk Thyf ibtwlk puav lhjo vaoly huk kyvwwlk aolpy ivvrz vu aol msvvy.
# Decrypted: Tom and Mary bumped into each other and dropped their books on the floor.
# Expected:  Tom and Mary bumped into each other and dropped their books on the floor.
# Match:     ✅
# Char Accuracy: 73/73 (100.0%)
#
# --- Case 96736 ---
# Input:     mpod
# Decrypted: beds
# Expected:  beds
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 77984 ---
# Input:     R qjm mroorlduch mxrwp cqjc.
# Decrypted: I had difficulty doing that.
# Expected:  I had difficulty doing that.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 28145 ---
# Input:     bu
# Decrypted: at
# Expected:  ha
# Match:     ❌
# Char Accuracy: 0/2 (0.0%)
#
# --- Case 56020 ---
# Input:     Nig nifx Ncg uvion Nihs.
# Decrypted: Tom told Tim about Tony.
# Expected:  Tom told Tim about Tony.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 84260 ---
# Input:     cmyed
# Decrypted: scout
# Expected:  scout
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 61700 ---
# Input:     Hs vzr zm zvetk lnuhd.
# Decrypted: It was an awful movie.
# Expected:  It was an awful movie.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 81287 ---
# Input:     Ftqk tqxbqp ftqyeqxhqe fa oarrqq.
# Decrypted: They helped themselves to coffee.
# Expected:  They helped themselves to coffee.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 88811 ---
# Input:     Hp htds jzf l slaaj Nsctdexld lyo l slaaj Yph Jplc.
# Decrypted: We wish you a happy Christmas and a happy New Year.
# Expected:  We wish you a happy Christmas and a happy New Year.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 92878 ---
# Input:     eurzvh
# Decrypted: browse
# Expected:  browse
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 96707 ---
# Input:     Avt dhualk av il h ahaavv hyapza.
# Decrypted: Tom wanted to be a tattoo artist.
# Expected:  Tom wanted to be a tattoo artist.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 74974 ---
# Input:     agtgjgyl
# Decrypted: civilian
# Expected:  civilian
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 25120 ---
# Input:     Qy hyyx ziix olayhnfs.
# Decrypted: We need food urgently.
# Expected:  We need food urgently.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 9024 ---
# Input:     Uc ucpc mddclbcb.
# Decrypted: We were offended.
# Expected:  We were offended.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 39241 ---
# Input:     Mu qbb cyiiut jxuc.
# Decrypted: We all missed them.
# Expected:  We all missed them.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 85256 ---
# Input:     Zus rubky xucotm.
# Decrypted: Tom loves rowing.
# Expected:  Tom loves rowing.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 79168 ---
# Input:     Zw kljmyydwv lg klsfv mh.
# Decrypted: He struggled to stand up.
# Expected:  He struggled to stand up.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 14487 ---
# Input:     Kmzzu bgf tue omd uzfa pudqof egzxustf fa fdk mzp ruzp mxx ftq otube mzp eodmfotqe az tue iuzpetuqxp.
# Decrypted: Yanni put his car into direct sunlight to try and find all the chips and scratches on his windshield.
# Expected:  Yanni put his car into direct sunlight to try and find all the chips and scratches on his windshield.
# Match:     ✅
# Char Accuracy: 101/101 (100.0%)
#
# --- Case 41323 ---
# Input:     Eb xmlildfwba ql ebo clo efp jfpqxhb.
# Decrypted: He apologized to her for his mistake.
# Expected:  He apologized to her for his mistake.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 90602 ---
# Input:     K iqv ewv.
# Decrypted: I got cut.
# Expected:  I got cut.
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 4080 ---
# Input:     hfyjltwnjx
# Decrypted: categories
# Expected:  categories
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 95160 ---
# Input:     vkgx
# Decrypted: pear
# Expected:  lawn
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 84793 ---
# Input:     A zghw A zsnw lzw uzsfuw lg vg lzsl.
# Decrypted: I hope I have the chance to do that.
# Expected:  I hope I have the chance to do that.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 73900 ---
# Input:     Gd snnj ghr rhrsdq zknmf.
# Decrypted: He took his sister along.
# Expected:  He took his sister along.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 90692 ---
# Input:     Nzjufd yvcgj lj ermzxrkv tyrexv.
# Decrypted: Wisdom helps us navigate change.
# Expected:  Wisdom helps us navigate change.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 46080 ---
# Input:     bmjsjajw
# Decrypted: whenever
# Expected:  whenever
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 61650 ---
# Input:     vdzonmr
# Decrypted: weapons
# Expected:  weapons
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 73959 ---
# Input:     R qnjam j knjdcrodu yxnv hnbcnamjh.
# Decrypted: I heard a beautiful poem yesterday.
# Expected:  I heard a beautiful poem yesterday.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 5390 ---
# Input:     qjgcxcv
# Decrypted: burning
# Expected:  burning
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 42224 ---
# Input:     Rmk lctcp ctcl ilcu fgq dyrfcp.
# Decrypted: Tom never even knew his father.
# Expected:  Tom never even knew his father.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 7068 ---
# Input:     A ogjcwv sl s tsfc.
# Decrypted: I worked at a bank.
# Expected:  I worked at a bank.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 71162 ---
# Input:     Tq mewqp yq itmf U zqqpqp.
# Decrypted: He asked me what I needed.
# Expected:  He asked me what I needed.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 50715 ---
# Input:     Hpbx wps id sd iwpi dcaxct.
# Decrypted: Sami had to do that online.
# Expected:  Sami had to do that online.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 58204 ---
# Input:     Epkivme lew kssh vipexmsrw amxl xli REXS eppmergi.
# Decrypted: Algeria has good relations with the NATO alliance.
# Expected:  Algeria has good relations with the NATO alliance.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 50507 ---
# Input:     P dhua ohsm vm h zhstvu.
# Decrypted: I want half of a salmon.
# Expected:  I want half of a salmon.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 20195 ---
# Input:     mynnfyx
# Decrypted: settled
# Expected:  settled
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 98977 ---
# Input:     Vqo jcu cp cpigt kuuwg.
# Decrypted: Tom has an anger issue.
# Expected:  Tom has an anger issue.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 99273 ---
# Input:     xkqfzfmxqba
# Decrypted: anticipated
# Expected:  anticipated
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 4892 ---
# Input:     Kfd nzcc sv grpzex wfi vmvipkyzex.
# Decrypted: Tom will be paying for everything.
# Expected:  Tom will be paying for everything.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 934 ---
# Input:     R qnuynm Cxv mx rc.
# Decrypted: I helped Tom do it.
# Expected:  I helped Tom do it.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 70335 ---
# Input:     snoxdspsmkdsyx
# Decrypted: identification
# Expected:  identification
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 69398 ---
# Input:     Jxov pelria yb xyib ql qxhb zxob lc ebopbic.
# Decrypted: Mary should be able to take care of herself.
# Expected:  Mary should be able to take care of herself.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 31945 ---
# Input:     Gulnbu ufqusm xlymmyx pyls gixymnfs.
# Decrypted: Martha always dressed very modestly.
# Expected:  Martha always dressed very modestly.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 64123 ---
# Input:     royxk
# Decrypted: lisre
# Expected:  urban
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 62529 ---
# Input:     Weqm aew sfzmsywpc xss hvyro xs hvmzi lsqi.
# Decrypted: Sami was obviously too drunk to drive home.
# Expected:  Sami was obviously too drunk to drive home.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 66594 ---
# Input:     Ghmabgz vtg atiixg fhkx uxtnmbyne matg wxtma.
# Decrypted: Nothing can happen more beautiful than death.
# Expected:  Nothing can happen more beautiful than death.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 19265 ---
# Input:     X iwxcz Idb pcs Bpgn pgt xcigxvjts.
# Decrypted: I think Tom and Mary are intrigued.
# Expected:  I think Tom and Mary are intrigued.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 74121 ---
# Input:     Rz czgkzy oczh vn rzgg.
# Decrypted: We helped them as well.
# Expected:  We helped them as well.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 85979 ---
# Input:     Xli aexiv mr xli peoi viqemrih qyvoc ejxiv xli wxsvq.
# Decrypted: The water in the lake remained murky after the storm.
# Expected:  The water in the lake remained murky after the storm.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 84734 ---
# Input:     jmbu
# Decrypted: loda
# Expected:  adsl
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 75301 ---
# Input:     Spesjhp fkfdufe gspn uif qmbof.
# Decrypted: Rodrigo ejected from the plane.
# Expected:  Rodrigo ejected from the plane.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 85275 ---
# Input:     Snl knudr qnvhmf.
# Decrypted: Tom loves rowing.
# Expected:  Tom loves rowing.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 21157 ---
# Input:     ilsmhza
# Decrypted: belfast
# Expected:  belfast
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 99783 ---
# Input:     Q nwcvl ca i eig wcb.
# Decrypted: I found us a way out.
# Expected:  I found us a way out.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 8290 ---
# Input:     Hpbx wps p gthigpxcxcv dgstg pvpxchi Apnap.
# Decrypted: Sami had a restraining order against Layla.
# Expected:  Sami had a restraining order against Layla.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 30865 ---
# Input:     Uxghi adkt xh p zxcs du kprrxcpixdc lwxrw hpkth p bpc ugdb rpirwxcv iwt rdbeapxci iwt htrdcs ixbt.
# Decrypted: First love is a kind of vaccination which saves a man from catching the complaint the second time.
# Expected:  First love is a kind of vaccination which saves a man from catching the complaint the second time.
# Match:     ✅
# Char Accuracy: 98/98 (100.0%)
#
# --- Case 97792 ---
# Input:     Qziz nrekj bzebp jvo.
# Decrypted: Ziri wants kinky mex.
# Expected:  Ziri wants kinky sex.
# Match:     ❌
# Char Accuracy: 20/21 (95.2%)
#
# --- Case 58931 ---
# Input:     Ygso lkrr ut noy qtkky gtj hkmmkj Rgerg tuz zu xkvuxz nos zu znk vuroik.
# Decrypted: Sami fell on his knees and begged Layla not to report him to the police.
# Expected:  Sami fell on his knees and begged Layla not to report him to the police.
# Match:     ✅
# Char Accuracy: 72/72 (100.0%)
#
# --- Case 78696 ---
# Input:     Ojh nvdy ocvo cz ocjpbco Hvmt rvn kmjwvwgt ijo cvqdib vit api yjdib ocvo.
# Decrypted: Tom said that he thought Mary was probably not having any fun doing that.
# Expected:  Tom said that he thought Mary was probably not having any fun doing that.
# Match:     ✅
# Char Accuracy: 73/73 (100.0%)
#
# --- Case 98276 ---
# Input:     Xf xfsf usvuigvm.
# Decrypted: We were truthful.
# Expected:  We were truthful.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 5800 ---
# Input:     Sgd adsqzxzk kdes z rbzq sgzs vntkc mdudq gdzk.
# Decrypted: The betrayal left a scar that would never heal.
# Expected:  The betrayal left a scar that would never heal.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 76875 ---
# Input:     oqnctbsr
# Decrypted: products
# Expected:  products
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 73619 ---
# Input:     B gxoxk ngwxklmhhw mabl.
# Decrypted: I never understood this.
# Expected:  I never understood this.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 21946 ---
# Input:     Zqzmtwjyt fijrn ocz hjji dn hvyz ja xczznz.
# Decrypted: Everybody knows the moon is made of cheese.
# Expected:  Everybody knows the moon is made of cheese.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 30920 ---
# Input:     C muq Nig wigcha niqulx gy.
# Decrypted: I saw Tom coming toward me.
# Expected:  I saw Tom coming toward me.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 18882 ---
# Input:     Aol ovbzl dolyl Tvghya dhz ivyu pz pu Zhsgibyn.
# Decrypted: The house where Mozart was born is in Salzburg.
# Expected:  The house where Mozart was born is in Salzburg.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 73112 ---
# Input:     Ftmf ftq iqn ue rgxx ar bufrmxxe ue oayyaz wzaixqpsq.
# Decrypted: That the web is full of pitfalls is common knowledge.
# Expected:  That the web is full of pitfalls is common knowledge.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 57102 ---
# Input:     Pqdqfa mpgy vjcv Vqo ycu iqkpi vq dg jgtg.
# Decrypted: Nobody knew that Tom was going to be here.
# Expected:  Nobody knew that Tom was going to be here.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 13155 ---
# Input:     Mj pnhpji rj ts uzwutxj.
# Decrypted: He kicked me on purpose.
# Expected:  He kicked me on purpose.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 87578 ---
# Input:     Wkh lyb ylqhv duh jhwwlqj odujhu.
# Decrypted: The ivy vines are getting larger.
# Expected:  The ivy vines are getting larger.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 88232 ---
# Input:     Ypth svvrz sprl h wypujlzz pu aoha Zohdp kylzz.
# Decrypted: Rima looks like a princess in that Shawi dress.
# Expected:  Rima looks like a princess in that Shawi dress.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 97727 ---
# Input:     Yg hcnn cpf yg igv wr.
# Decrypted: We fall and we get up.
# Expected:  We fall and we get up.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 63894 ---
# Input:     Mhf tldxw Ftkr mh ptox mh abf ykhf max utevhgr.
# Decrypted: Tom asked Mary to wave to him from the balcony.
# Expected:  Tom asked Mary to wave to him from the balcony.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 71404 ---
# Input:     Xli amgoih amxgl tywlih liv mrxs xli hiit aexiv.
# Decrypted: The wicked witch pushed her into the deep water.
# Expected:  The wicked witch pushed her into the deep water.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 78220 ---
# Input:     Qy omyx ni vy aiix un nbcm.
# Decrypted: We used to be good at this.
# Expected:  We used to be good at this.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 87560 ---
# Input:     Dyw wecd rkfo loox ohrkecdon.
# Decrypted: Tom must have been exhausted.
# Expected:  Tom must have been exhausted.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 23964 ---
# Input:     Nwfw kobhg Fwao hc rc wh.
# Decrypted: Ziri wants Rima to do it.
# Expected:  Ziri wants Rima to do it.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 71926 ---
# Input:     Nvtisppnt bsf opu gps sfou boe uif hjohfscsfbe ipvtf jt opu up mfu bu uif npnfou.
# Decrypted: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Expected:  Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Match:     ✅
# Char Accuracy: 81/81 (100.0%)
#
# --- Case 78995 ---
# Input:     Nig cm chni wihmnluchn uhx fiacw jlialuggcha.
# Decrypted: Tom is into constraint and logic programming.
# Expected:  Tom is into constraint and logic programming.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 19646 ---
# Input:     Gzo hz ozvxc tjp cjr oj odz v odz.
# Decrypted: Let me teach you how to tie a tie.
# Expected:  Let me teach you how to tie a tie.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 67587 ---
# Input:     Xqazup ime efmdfuzs fa rqqx puembbauzfqp.
# Decrypted: Leonid was starting to feel disappointed.
# Expected:  Leonid was starting to feel disappointed.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 92414 ---
# Input:     Goaw kcizr rc hvs goas tcf as.
# Decrypted: Sami would do the same for me.
# Expected:  Sami would do the same for me.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 9106 ---
# Input:     G suznkx cnu ghgtjuty nkx inorjxkt juky tuz jkykxbk zu mkz znks hgiq.
# Decrypted: A mother who abandons her children does not deserve to get them back.
# Expected:  A mother who abandons her children does not deserve to get them back.
# Match:     ✅
# Char Accuracy: 69/69 (100.0%)
#
# --- Case 11467 ---
# Input:     Kfd rjbvu dv r tflgcv fw hlvjkzfej.
# Decrypted: Tom asked me a couple of questions.
# Expected:  Tom asked me a couple of questions.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 83198 ---
# Input:     Libd xka Ofjx bxze pxq fk afccbobkq olljp.
# Decrypted: Oleg and Rima each sat in different rooms.
# Expected:  Oleg and Rima each sat in different rooms.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 51896 ---
# Input:     Ocvo izr bduhj ocvo tjp rvio dn jqzm vo ocz nojmz ijr.
# Decrypted: That new gizmo that you want is over at the store now.
# Expected:  That new gizmo that you want is over at the store now.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 20154 ---
# Input:     Xlic orsa xlex M orsa.
# Decrypted: They know that I know.
# Expected:  They know that I know.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 38712 ---
# Input:     U omz eqq itk Fay pqoupqp zaf fa sa.
# Decrypted: I can see why Tom decided not to go.
# Expected:  I can see why Tom decided not to go.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 84038 ---
# Input:     Guvf jbeq vf fcryyrq jvgu n ulcura.
# Decrypted: This word is spelled with a hyphen.
# Expected:  This word is spelled with a hyphen.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 85143 ---
# Input:     Dggc ozsl Lge xgmfv mfvwj lzw twv.
# Decrypted: Look what Tom found under the bed.
# Expected:  Look what Tom found under the bed.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 94397 ---
# Input:     lcl
# Decrypted: ara
# Expected:  pgp
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 11835 ---
# Input:     Sd sc nsppsmevd dy bowksx kgkbo grsvo nbokwsxq.
# Decrypted: It is difficult to remain aware while dreaming.
# Expected:  It is difficult to remain aware while dreaming.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 53516 ---
# Input:     Jec xqi ruud beeaydw veh oek wkoi.
# Decrypted: Tom has been looking for you guys.
# Expected:  Tom has been looking for you guys.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 72691 ---
# Input:     Jxuo mudj je q Aqrobu ckiys sedsuhj.
# Decrypted: They went to a Kabyle music concert.
# Expected:  They went to a Kabyle music concert.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 54017 ---
# Input:     Yv gviwfidvu kyv kiztb nzky vrjv.
# Decrypted: He performed the trick with ease.
# Expected:  He performed the trick with ease.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 84710 ---
# Input:     S drsxu drkd Dyw gsvv lo ceczsmsyec.
# Decrypted: I think that Tom will be suspicious.
# Expected:  I think that Tom will be suspicious.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 28324 ---
# Input:     Jmpclxm bpmtc bmul rfc fgjj.
# Decrypted: Lorenzo drove down the hill.
# Expected:  Lorenzo drove down the hill.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 38125 ---
# Input:     Yhqh zmc Qhlz lzcd mnhrd.
# Decrypted: Ziri and Rima made noise.
# Expected:  Ziri and Rima made noise.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 94766 ---
# Input:     jc
# Decrypted: at
# Expected:  tm
# Match:     ❌
# Char Accuracy: 0/2 (0.0%)
#
# --- Case 99356 ---
# Input:     Zus luxmuz zu vge noy ixkjoz igxj horr ut zosk.
# Decrypted: Tom forgot to pay his credit card bill on time.
# Expected:  Tom forgot to pay his credit card bill on time.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 75435 ---
# Input:     Dro yvn wkx kcuon wo k pkfyb.
# Decrypted: The old man asked me a favor.
# Expected:  The old man asked me a favor.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 44099 ---
# Input:     zmvcq
# Decrypted: renui
# Expected:  boxes
# Match:     ❌
# Char Accuracy: 0/5 (0.0%)
#
# --- Case 36194 ---
# Input:     Tktubv bl fr fhmaxk mhgznx.
# Decrypted: Arabic is my mother tongue.
# Expected:  Arabic is my mother tongue.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 54668 ---
# Input:     Dsqds kzsjhwfwv zwj fsadk.
# Decrypted: Layla sharpened her nails.
# Expected:  Layla sharpened her nails.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 56597 ---
# Input:     Da olajp bkqnpaaj uawno kb deo heba pnuejc pk hawnj Xanxan.
# Decrypted: He spent fourteen years of his life trying to learn Berber.
# Expected:  He spent fourteen years of his life trying to learn Berber.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 47543 ---
# Input:     Lzw dskl zghw xdwv xjge zak eafv.
# Decrypted: The last hope fled from his mind.
# Expected:  The last hope fled from his mind.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 9621 ---
# Input:     nzgzxodib
# Decrypted: selecting
# Expected:  selecting
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 2321 ---
# Input:     D rvn xjhkzggzy oj xjiaznn.
# Decrypted: I was compelled to confess.
# Expected:  I was compelled to confess.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 34864 ---
# Input:     W bsjsf oqhiozzm gok vwa.
# Decrypted: I never actually saw him.
# Expected:  I never actually saw him.
# Match:     ✅
# ...
# Decrypted: trainer
# Expected:  trainer
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 68251 ---
# Input:     Upn btlfe nf opu up ljtt ijn jo qvcmjd.
# Decrypted: Tom asked me not to kiss him in public.
# Expected:  Tom asked me not to kiss him in public.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 20056 ---
# Input:     Ynk qkvz muotm.
# Decrypted: She kept going.
# Expected:  She kept going.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 76530 ---
# Input:     Xmj xfni xmj bfx ytt xmd yt it ymfy.
# Decrypted: She said she was too shy to do that.
# Expected:  She said she was too shy to do that.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 27773 ---
# Input:     F xdobb fk mofkzfmib.
# Decrypted: I agree in principle.
# Expected:  I agree in principle.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 13944 ---
# Input:     yhewxk
# Decrypted: folder
# Expected:  folder
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 64313 ---
# Input:     terngre
# Decrypted: greater
# Expected:  greater
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 53520 ---
# Input:     Nig bum vyyh fiiecha zil sio aosm.
# Decrypted: Tom has been looking for you guys.
# Expected:  Tom has been looking for you guys.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 69592 ---
# Input:     Yv trlxyk drep irkj nzky kyv kirg.
# Decrypted: He caught many rats with the trap.
# Expected:  He caught many rats with the trap.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 42855 ---
# Input:     N bfsy dtz yt futqtlnej yt Ytr.
# Decrypted: I want you to apologize to Tom.
# Expected:  I want you to apologize to Tom.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 89382 ---
# Input:     apa
# Decrypted: pep
# Expected:  tit
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 66643 ---
# Input:     sjst
# Decrypted: jaza
# Expected:  arab
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 46617 ---
# Input:     Mcruzdzi bvgk kyrk r jvtivk wifd Reer.
# Decrypted: Vladimir kept that a secret from Anna.
# Expected:  Vladimir kept that a secret from Anna.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 46371 ---
# Input:     Diqznodbvojmn ajdgzy v kgjo oj cdevxf vi vdmkgviz.
# Decrypted: Investigators foiled a plot to hijack an airplane.
# Expected:  Investigators foiled a plot to hijack an airplane.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 65237 ---
# Input:     Ludu omz xqmhq zai.
# Decrypted: Ziri can leave now.
# Expected:  Ziri can leave now.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 71944 ---
# Input:     Fnlakhhfl tkx ghm yhk kxgm tgw max zbgzxkukxtw ahnlx bl ghm mh exm tm max fhfxgm.
# Decrypted: Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Expected:  Mushrooms are not for rent and the gingerbread house is not to let at the moment.
# Match:     ✅
# Char Accuracy: 81/81 (100.0%)
#
# --- Case 10824 ---
# Input:     Qykg zcaykc y kgjjgmlygpc.
# Decrypted: Sami became a millionaire.
# Expected:  Sami became a millionaire.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 5121 ---
# Input:     Nvhd rviozy Gvtgv oj novt ndibgz ajm cdh.
# Decrypted: Sami wanted Layla to stay single for him.
# Expected:  Sami wanted Layla to stay single for him.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 75402 ---
# Input:     Oa ceeqwpv iqv jcemgf.
# Decrypted: My acciont ait bucked.
# Expected:  My account got hacked.
# Match:     ❌
# Char Accuracy: 16/22 (72.7%)
#
# --- Case 37222 ---
# Input:     Iwnu swjpo dan ikjau xwyg.
# Decrypted: Mary wants her money back.
# Expected:  Mary wants her money back.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 64408 ---
# Input:     pcvb
# Decrypted: hunt
# Expected:  hunt
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 18466 ---
# Input:     Buj cu jubb oek mxqj Y iuu.
# Decrypted: Let me tell you what I see.
# Expected:  Let me tell you what I see.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 7384 ---
# Input:     Jwcxw Bijwmxa Ujenh oxdwmnm cqn Lqdalq xo Bjcjw.
# Decrypted: Anton Szandor Lavey founded the Church of Satan.
# Expected:  Anton Szandor Lavey founded the Church of Satan.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 52011 ---
# Input:     Ezx lyo Xlcj ezwo pgpcjmzoj espj hpcp mzcpo.
# Decrypted: Tom and Mary told everybody they were bored.
# Expected:  Tom and Mary told everybody they were bored.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 72689 ---
# Input:     Hvsm ksbh hc o Yopmzs aigwq qcbqsfh.
# Decrypted: They went to a Kabyle music concert.
# Expected:  They went to a Kabyle music concert.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 39952 ---
# Input:     ocvg
# Decrypted: mate
# Expected:  mate
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 12733 ---
# Input:     bibbww
# Decrypted: tattoo
# Expected:  tattoo
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 78830 ---
# Input:     Tzw rtymjw bfx ajwd mfuud ktw ymj anxny tk mjw lwfsixts fsi httpji f xzgxyfsynfq rjfq ktw ymj thhfxnts.
# Decrypted: Our mother was very happy for the visit of her grandson and cooked a substantial meal for the occasion.
# Expected:  Our mother was very happy for the visit of her grandson and cooked a substantial meal for the occasion.
# Match:     ✅
# Char Accuracy: 103/103 (100.0%)
#
# --- Case 71420 ---
# Input:     Nby qcweyx qcnwb jombyx byl chni nby xyyj qunyl.
# Decrypted: The wicked witch pushed her into the deep water.
# Expected:  The wicked witch pushed her into the deep water.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 59796 ---
# Input:     Tjp ncjpgy cvqz vi vnndnovio.
# Decrypted: You should have an assistant.
# Expected:  You should have an assistant.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 23035 ---
# Input:     Grkd iye cksn gkc fobi pexxi.
# Decrypted: What you said was very funny.
# Expected:  What you said was very funny.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 7702 ---
# Input:     Vjg rjqvq dgnqpiu vq jgt.
# Decrypted: The photo belongs to her.
# Expected:  The photo belongs to her.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 78495 ---
# Input:     ykocpufyhn
# Decrypted: equivalent
# Expected:  equivalent
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 16350 ---
# Input:     fzqkhb
# Decrypted: garlic
# Expected:  garlic
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 31010 ---
# Input:     xsmuxkwo
# Decrypted: nickname
# Expected:  nickname
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 79068 ---
# Input:     A lzafc Lge sfv Esjq sjw jwdawnwv.
# Decrypted: I think Tom and Mary are relieved.
# Expected:  I think Tom and Mary are relieved.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 76783 ---
# Input:     Ug lzmiu emvb cx qv auwsm.
# Decrypted: My dream went up in smoke.
# Expected:  My dream went up in smoke.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 32134 ---
# Input:     Cxv uxxtnm jc Vjah jwm bx mrm Sxqw.
# Decrypted: Tom looked at Mary and so did John.
# Expected:  Tom looked at Mary and so did John.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 34515 ---
# Input:     Bpcn etdeat igpkta id qt lxiw upbxan udg Rwgxhibph.
# Decrypted: Many people travel to be with family for Christmas.
# Expected:  Many people travel to be with family for Christmas.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 77931 ---
# Input:     Suxuiiu oy vaxyaotm gt kdvgtyoutoyz vuroie ot Ckyzkxt Ygngxg.
# Decrypted: Morocco is pursuing an expansionist policy in Western Sahara.
# Expected:  Morocco is pursuing an expansionist policy in Western Sahara.
# Match:     ✅
# Char Accuracy: 61/61 (100.0%)
#
# --- Case 21505 ---
# Input:     Xmj bfx mtsjxy.
# Decrypted: She was honest.
# Expected:  She was honest.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 52059 ---
# Input:     Irar fjb bjcrbornm.
# Decrypted: Ziri was satisfied.
# Expected:  Ziri was satisfied.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 31149 ---
# Input:     clhmw
# Decrypted: enjoy
# Expected:  enjoy
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 62428 ---
# Input:     Vkh qhhgv wr eh wrog wr gr wkdw eb khuvhoi.
# Decrypted: She needs to be told to do that by herself.
# Expected:  She needs to be told to do that by herself.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 89359 ---
# Input:     Bcnojw bjf cqn vxwbcna fqx truunm Arvj.
# Decrypted: Stefan saw the monster who killed Rima.
# Expected:  Stefan saw the monster who killed Rima.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 33704 ---
# Input:     wymxw
# Decrypted: suits
# Expected:  suits
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 48063 ---
# Input:     Gur jngre vf pnyz.
# Decrypted: The water is calm.
# Expected:  The water is calm.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 87530 ---
# Input:     Ufzq xhwjfrji ns kjfw.
# Decrypted: Paul screamed in fear.
# Expected:  Paul screamed in fear.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 44724 ---
# Input:     Uc bm fytc qmkcrfgle ufgaf gq kmpc gl wmsp npgac pylec.
# Decrypted: We do have something which is more in your price range.
# Expected:  We do have something which is more in your price range.
# Match:     ✅
# Char Accuracy: 55/55 (100.0%)
#
# --- Case 72284 ---
# Input:     mnenuxyvnwc
# Decrypted: development
# Expected:  development
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 42273 ---
# Input:     F txp ylok ql pbq rm x dixofkd buxjmib lc przzbpp clo lqebop ql cliilt.
# Decrypted: I was born to set up a glaring example of success for others to follow.
# Expected:  I was born to set up a glaring example of success for others to follow.
# Match:     ✅
# Char Accuracy: 71/71 (100.0%)
#
# --- Case 37235 ---
# Input:     Wkbi gkc rsqrvi yppoxnon li grkd Dyw rkn dy cki.
# Decrypted: Mary was highly offended by what Tom had to say.
# Expected:  Mary was highly offended by what Tom had to say.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 76335 ---
# Input:     Dro yxvi bowybco Pknsv crygon gkc pyb dro pkmd ro gkc mkeqrd.
# Decrypted: The only remorse Fadil showed was for the fact he was caught.
# Expected:  The only remorse Fadil showed was for the fact he was caught.
# Match:     ✅
# Char Accuracy: 61/61 (100.0%)
#
# --- Case 17330 ---
# Input:     Zxj ittwrfyx fy jsywdbfdx yt rnsnrnej inwy gjnsl gwtzlmy nsxnij.
# Decrypted: Use doormats at entryways to minimize dirt being brought inside.
# Expected:  Use doormats at entryways to minimize dirt being brought inside.
# Match:     ✅
# Char Accuracy: 64/64 (100.0%)
#
# --- Case 87791 ---
# Input:     Oek cywxj mqdj je we myjx cu.
# Decrypted: You might want to go with me.
# Expected:  You might want to go with me.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 6433 ---
# Input:     Gwc nwcvl um ieism.
# Decrypted: You found me awake.
# Expected:  You found me awake.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 25416 ---
# Input:     Fbuqiu seddusj q sedjhebbuh.
# Decrypted: Please connect a controller.
# Expected:  Please connect a controller.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 59610 ---
# Input:     Yxo ydrob fsmdsw bowksxc ryczsdkvsjon.
# Decrypted: One other victim remains hospitalized.
# Expected:  One other victim remains hospitalized.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 56048 ---
# Input:     Qlj fp pqfii qefoqbbk vbxop lia.
# Decrypted: Tom is still thirteen years old.
# Expected:  Tom is still thirteen years old.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 92467 ---
# Input:     Dvdfizqv kyfjv jvekvetvj.
# Decrypted: Memorize those sentences.
# Expected:  Memorize those sentences.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 23972 ---
# Input:     Vene swjpo Neiw pk zk ep.
# Decrypted: Ziri wants Rima to do it.
# Expected:  Ziri wants Rima to do it.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 38411 ---
# Input:     T slo eczfmwp dwppatyr.
# Decrypted: I had trouble sleeping.
# Expected:  I had trouble sleeping.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 42980 ---
# Input:     mtws
# Decrypted: horn
# Expected:  horn
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 40236 ---
# Input:     T tygpye dezctpd mj hctetyr ozhy hslepgpc T estyv zq.
# Decrypted: I invent stories by writing down whatever I think of.
# Expected:  I invent stories by writing down whatever I think of.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 95950 ---
# Input:     Snl zmc Lzqx szkjdc pthdskx.
# Decrypted: Tom and Mary talked quietly.
# Expected:  Tom and Mary talked quietly.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 84848 ---
# Input:     Eb fp cobb tfqe efp jlkbv.
# Decrypted: He is free with his money.
# Expected:  He is free with his money.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 76713 ---
# Input:     Znel vf n znfba.
# Decrypted: Mary is a mason.
# Expected:  Mary is a mason.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 17255 ---
# Input:     unsx
# Decrypted: voty
# Expected:  pins
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 79909 ---
# Input:     Bqn ngyujrwnm cqn adunb rw mncjru.
# Decrypted: She explained the rules in detail.
# Expected:  She explained the rules in detail.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 85388 ---
# Input:     V zhfg cebgrfg.
# Decrypted: I must protest.
# Expected:  I must protest.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 32891 ---
# Input:     Rhqsu oekhiublui.
# Decrypted: Brace yourselves.
# Expected:  Brace yourselves.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 40661 ---
# Input:     Ezx hld mczfrse fa ty esp wla zq wfifcj.
# Decrypted: Tom was brought up in the lap of luxury.
# Expected:  Tom was brought up in the lap of luxury.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 42687 ---
# Input:     Fay rqxf uxx.
# Decrypted: Tom felt ill.
# Expected:  Tom felt ill.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 12163 ---
# Input:     Mvev gevrq gb jnyx nf pnfhnyyl nf cbffvoyr.
# Decrypted: Ziri tried to walk as casually as possible.
# Expected:  Ziri tried to walk as casually as possible.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 95556 ---
# Input:     Tuhuje kryk cuarj nkrv nkx.
# Decrypted: Nobody else would help her.
# Expected:  Nobody else would help her.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 39446 ---
# Input:     Ojh viy Hvmt nvdy oczt rzmz mzvggt wmjfz.
# Decrypted: Tom and Mary said they were really broke.
# Expected:  Tom and Mary said they were really broke.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 76175 ---
# Input:     Snl rzxr Lzqx hr shqdc.
# Decrypted: Tom says Mary is tired.
# Expected:  Tom says Mary is tired.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 16702 ---
# Input:     Vjgtg ctg eqwpvnguu ekxknkcp ecuwcnvkgu.
# Decrypted: There are countless civilian casualties.
# Expected:  There are countless civilian casualties.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 89434 ---
# Input:     pdrmnm
# Decrypted: gested
# Expected:  guided
# Match:     ❌
# Char Accuracy: 3/6 (50.0%)
#
# --- Case 881 ---
# Input:     Znke gxk ynuxz gtj znot.
# Decrypted: They are short and thin.
# Expected:  They are short and thin.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 68728 ---
# Input:     Kh fdph wr ylvlw khu.
# Decrypted: He came to visit her.
# Expected:  He came to visit her.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 86866 ---
# Input:     Jec iqyt Y mqi wehwueki.
# Decrypted: Tom said I was gorgeous.
# Expected:  Tom said I was gorgeous.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 27054 ---
# Input:     Mx xewxiw vieppc cyqqc.
# Decrypted: It tastes really yummy.
# Expected:  It tastes really yummy.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 91205 ---
# Input:     Xfrn fsi Qfdqf hfrj kwtr gwtpjs mtrjx.
# Decrypted: Sami and Layla came from broken homes.
# Expected:  Sami and Layla came from broken homes.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 46508 ---
# Input:     dqttioma
# Decrypted: naddscak
# Expected:  villages
# Match:     ❌
# Char Accuracy: 0/8 (0.0%)
#
# --- Case 41760 ---
# Input:     Dyw vsuoc nyxq zejjvoc.
# Decrypted: Tom likes dong puzzles.
# Expected:  Tom likes dong puzzles.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# Full results saved to /content/drive/MyDrive/inference_results_caesar_vanilla.xlsx
#
# === Final Summary ===
# Full-match accuracy: 3646/4000
# Character-level accuracy: 112092/113849 (98.46%)
