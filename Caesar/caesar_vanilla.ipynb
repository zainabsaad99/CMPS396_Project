# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
import string

# Data Preparation
def load_data(file_path):
    df = pd.read_csv(file_path)

    # Filter rows where 'Output' length is <=200
    df = df[df['Output'].str.len() <= 200]

    # Get the count of such rows
    count_filtered = len(df)

    # Randomly select 400,000 rows (if available)
    if count_filtered > 400000:
        df = df.sample(n=400000, random_state=42)
    print(len(df))
    inputs = df['Input'].astype(str).tolist()
    outputs = df['Output'].astype(str).tolist()


    return inputs, outputs

# Tokenization and Vocabulary
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        # Special tokens
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        # All printable characters
        all_chars = list(string.printable)

        # Create vocabulary
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})

        # Reverse mapping
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Dataset Class
class CipherDataset(data.Dataset):
    def __init__(self, inputs, outputs, vocab, max_length):
        self.inputs = inputs
        self.outputs = outputs
        self.vocab = vocab
        self.max_length = max_length

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_text = self.inputs[idx]
        output_text = self.outputs[idx]

        # Encode with SOS and EOS tokens
        input_encoded = [self.vocab.sos_token] + self.vocab.encode(input_text) + [self.vocab.eos_token]
        output_encoded = [self.vocab.sos_token] + self.vocab.encode(output_text) + [self.vocab.eos_token]

        # Pad sequences
        input_padded = input_encoded + [self.vocab.pad_token] * (self.max_length - len(input_encoded))
        output_padded = output_encoded + [self.vocab.pad_token] * (self.max_length - len(output_encoded))

        # Truncate if necessary
        input_padded = input_padded[:self.max_length]
        output_padded = output_padded[:self.max_length]

        return torch.tensor(input_padded), torch.tensor(output_padded)

# Transformer Model (same as your implementation)
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Q, K, V shapes: (batch_size, num_heads, seq_len, d_k)
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn_probs = torch.softmax(scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        # Source mask
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, src_len)

        # Target mask
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, tgt_len)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=tgt.device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask  # (batch_size, 1, tgt_len, tgt_len)

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (src, tgt) in enumerate(train_loader):
            src, tgt = src.to(device), tgt.to(device)

            optimizer.zero_grad()
            output = model(src, tgt[:, :-1])

            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch_idx % 10 == 0:
                print(f'Epoch: {epoch+1}, Batch: {batch_idx}, Loss: {loss.item():.4f}')

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        val_loss = evaluate_model(model, val_loader, criterion, device)
        print(f'Epoch: {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), '/content/drive/MyDrive/caesar_vanilla.pth')

    return model

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            total_loss += loss.item()

    return total_loss / len(data_loader)

# Inference Function
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        # Encode the input text
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        # Initialize target with SOS token
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        # Decode the output
        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

# Main Execution
if __name__ == "__main__":
    # Load and prepare data
    inputs, outputs = load_data('/content/training_newshift_1.csv')

    # Create vocabulary
    vocab = Vocabulary()

    # Split data into train and validation
    train_inputs, val_inputs, train_outputs, val_outputs = train_test_split(
        inputs, outputs, test_size=0.2, random_state=42
    )

    # Create datasets
    max_length = 200
    train_dataset = CipherDataset(train_inputs, train_outputs, vocab, max_length)
    val_dataset = CipherDataset(val_inputs, val_outputs, vocab, max_length)

    # Create data loaders
    batch_size = 512
    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=4,
        num_layers=6,
        d_ff=512,
        max_seq_length=max_length,
        dropout=0.11034371565549608
    ).to(device)



    # Loss and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=vocab.pad_token)
    optimizer = optim.Adam(model.parameters(), lr=0.000105, betas=(0.9, 0.98), eps=1e-9)

    # Train the model
    num_epochs = 10
    trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

    # Test the model
    test_text = "gfbs"  # Should decrypt to "fear"
    decrypted = decrypt_text(trained_model, test_text, vocab, max_length, device)
    print(f"Input: {test_text}, Decrypted: {decrypted}")
# Out:
# 400000
# Epoch: 1, Batch: 0, Loss: 4.8567
# Epoch: 1, Batch: 10, Loss: 3.0411
# Epoch: 1, Batch: 20, Loss: 2.6414
# Epoch: 1, Batch: 30, Loss: 2.4737
# Epoch: 1, Batch: 40, Loss: 2.3535
# Epoch: 1, Batch: 50, Loss: 2.2999
# Epoch: 1, Batch: 60, Loss: 2.2595
# Epoch: 1, Batch: 70, Loss: 2.1872
# Epoch: 1, Batch: 80, Loss: 2.1833
# Epoch: 1, Batch: 90, Loss: 2.1373
# Epoch: 1, Batch: 100, Loss: 2.1108
# Epoch: 1, Batch: 110, Loss: 2.0706
# Epoch: 1, Batch: 120, Loss: 2.0528
# Epoch: 1, Batch: 130, Loss: 2.0403
# Epoch: 1, Batch: 140, Loss: 2.0431
# Epoch: 1, Batch: 150, Loss: 1.9724
# Epoch: 1, Batch: 160, Loss: 1.9293
# Epoch: 1, Batch: 170, Loss: 1.9453
# Epoch: 1, Batch: 180, Loss: 1.9281
# Epoch: 1, Batch: 190, Loss: 1.9001
# Epoch: 1, Batch: 200, Loss: 1.8627
# Epoch: 1, Batch: 210, Loss: 1.8605
# Epoch: 1, Batch: 220, Loss: 1.8359
# Epoch: 1, Batch: 230, Loss: 1.7998
# Epoch: 1, Batch: 240, Loss: 1.7936
# Epoch: 1, Batch: 250, Loss: 1.7615
# Epoch: 1, Batch: 260, Loss: 1.7401
# Epoch: 1, Batch: 270, Loss: 1.7277
# Epoch: 1, Batch: 280, Loss: 1.7238
# Epoch: 1, Batch: 290, Loss: 1.6872
# Epoch: 1, Batch: 300, Loss: 1.7064
# Epoch: 1, Batch: 310, Loss: 1.6841
# Epoch: 1, Batch: 320, Loss: 1.6495
# Epoch: 1, Batch: 330, Loss: 1.6646
# Epoch: 1, Batch: 340, Loss: 1.6599
# Epoch: 1, Batch: 350, Loss: 1.6543
# Epoch: 1, Batch: 360, Loss: 1.6524
# Epoch: 1, Batch: 370, Loss: 1.5957
# Epoch: 1, Batch: 380, Loss: 1.6046
# Epoch: 1, Batch: 390, Loss: 1.5842
# Epoch: 1, Batch: 400, Loss: 1.5758
# Epoch: 1, Batch: 410, Loss: 1.5622
# Epoch: 1, Batch: 420, Loss: 1.5310
# Epoch: 1, Batch: 430, Loss: 1.5030
# Epoch: 1, Batch: 440, Loss: 1.5326
# Epoch: 1, Batch: 450, Loss: 1.5429
# Epoch: 1, Batch: 460, Loss: 1.5260
# Epoch: 1, Batch: 470, Loss: 1.4971
# Epoch: 1, Batch: 480, Loss: 1.5188
# Epoch: 1, Batch: 490, Loss: 1.5230
# Epoch: 1, Batch: 500, Loss: 1.4669
# Epoch: 1, Batch: 510, Loss: 1.4812
# Epoch: 1, Batch: 520, Loss: 1.4827
# Epoch: 1, Batch: 530, Loss: 1.4502
# Epoch: 1, Batch: 540, Loss: 1.4571
# Epoch: 1, Batch: 550, Loss: 1.4069
# Epoch: 1, Batch: 560, Loss: 1.4335
# Epoch: 1, Batch: 570, Loss: 1.4270
# Epoch: 1, Batch: 580, Loss: 1.3964
# Epoch: 1, Batch: 590, Loss: 1.4191
# Epoch: 1, Batch: 600, Loss: 1.3752
# Epoch: 1, Batch: 610, Loss: 1.3500
# Epoch: 1, Batch: 620, Loss: 1.3961
# Epoch: 1, Train Loss: 1.7866, Val Loss: 1.2923
# Epoch: 2, Batch: 0, Loss: 1.2761
# Epoch: 2, Batch: 10, Loss: 1.2871
# Epoch: 2, Batch: 20, Loss: 1.2608
# Epoch: 2, Batch: 30, Loss: 1.2216
# Epoch: 2, Batch: 40, Loss: 1.2549
# Epoch: 2, Batch: 50, Loss: 1.2292
# Epoch: 2, Batch: 60, Loss: 1.2232
# Epoch: 2, Batch: 70, Loss: 1.2210
# Epoch: 2, Batch: 80, Loss: 1.2177
# Epoch: 2, Batch: 90, Loss: 1.2127
# Epoch: 2, Batch: 100, Loss: 1.1407
# Epoch: 2, Batch: 110, Loss: 1.1900
# Epoch: 2, Batch: 120, Loss: 1.1539
# Epoch: 2, Batch: 130, Loss: 1.1322
# Epoch: 2, Batch: 140, Loss: 1.1814
# Epoch: 2, Batch: 150, Loss: 1.1348
# Epoch: 2, Batch: 160, Loss: 1.1189
# Epoch: 2, Batch: 170, Loss: 1.1338
# Epoch: 2, Batch: 180, Loss: 1.1186
# Epoch: 2, Batch: 190, Loss: 1.0914
# Epoch: 2, Batch: 200, Loss: 1.0793
# Epoch: 2, Batch: 210, Loss: 1.0870
# Epoch: 2, Batch: 220, Loss: 1.1211
# Epoch: 2, Batch: 230, Loss: 1.1371
# Epoch: 2, Batch: 240, Loss: 1.0788
# Epoch: 2, Batch: 250, Loss: 1.0602
# Epoch: 2, Batch: 260, Loss: 1.1074
# Epoch: 2, Batch: 270, Loss: 1.1117
# Epoch: 2, Batch: 280, Loss: 1.0656
# Epoch: 2, Batch: 290, Loss: 1.0319
# Epoch: 2, Batch: 300, Loss: 1.0013
# Epoch: 2, Batch: 310, Loss: 1.0417
# Epoch: 2, Batch: 320, Loss: 1.0170
# Epoch: 2, Batch: 330, Loss: 1.0059
# Epoch: 2, Batch: 340, Loss: 1.0190
# Epoch: 2, Batch: 350, Loss: 1.0022
# Epoch: 2, Batch: 360, Loss: 1.0373
# Epoch: 2, Batch: 370, Loss: 0.9761
# Epoch: 2, Batch: 380, Loss: 0.9631
# Epoch: 2, Batch: 390, Loss: 0.9708
# Epoch: 2, Batch: 400, Loss: 0.9413
# Epoch: 2, Batch: 410, Loss: 0.9687
# Epoch: 2, Batch: 420, Loss: 0.9579
# Epoch: 2, Batch: 430, Loss: 0.9403
# Epoch: 2, Batch: 440, Loss: 0.9245
# Epoch: 2, Batch: 450, Loss: 0.8891
# Epoch: 2, Batch: 460, Loss: 0.9039
# Epoch: 2, Batch: 470, Loss: 0.8965
# Epoch: 2, Batch: 480, Loss: 0.8925
# Epoch: 2, Batch: 490, Loss: 0.8647
# Epoch: 2, Batch: 500, Loss: 0.8376
# Epoch: 2, Batch: 510, Loss: 0.8072
# Epoch: 2, Batch: 520, Loss: 0.7795
# Epoch: 2, Batch: 530, Loss: 0.7829
# Epoch: 2, Batch: 540, Loss: 0.7814
# Epoch: 2, Batch: 550, Loss: 0.7280
# Epoch: 2, Batch: 560, Loss: 0.7068
# Epoch: 2, Batch: 570, Loss: 0.6833
# Epoch: 2, Batch: 580, Loss: 0.6792
# Epoch: 2, Batch: 590, Loss: 0.5842
# Epoch: 2, Batch: 600, Loss: 0.6285
# Epoch: 2, Batch: 610, Loss: 0.5435
# Epoch: 2, Batch: 620, Loss: 0.5564
# Epoch: 2, Train Loss: 1.0008, Val Loss: 0.5239
# Epoch: 3, Batch: 0, Loss: 0.5298
# Epoch: 3, Batch: 10, Loss: 0.4942
# Epoch: 3, Batch: 20, Loss: 0.4762
# Epoch: 3, Batch: 30, Loss: 0.4353
# Epoch: 3, Batch: 40, Loss: 0.4079
# Epoch: 3, Batch: 50, Loss: 0.4001
# Epoch: 3, Batch: 60, Loss: 0.3520
# Epoch: 3, Batch: 70, Loss: 0.3498
# Epoch: 3, Batch: 80, Loss: 0.3073
# Epoch: 3, Batch: 90, Loss: 0.3154
# Epoch: 3, Batch: 100, Loss: 0.3005
# Epoch: 3, Batch: 110, Loss: 0.2860
# Epoch: 3, Batch: 120, Loss: 0.2658
# Epoch: 3, Batch: 130, Loss: 0.2644
# Epoch: 3, Batch: 140, Loss: 0.2417
# Epoch: 3, Batch: 150, Loss: 0.2266
# Epoch: 3, Batch: 160, Loss: 0.2261
# Epoch: 3, Batch: 170, Loss: 0.2212
# Epoch: 3, Batch: 180, Loss: 0.2013
# Epoch: 3, Batch: 190, Loss: 0.1998
# Epoch: 3, Batch: 200, Loss: 0.1936
# Epoch: 3, Batch: 210, Loss: 0.1762
# Epoch: 3, Batch: 220, Loss: 0.1806
# Epoch: 3, Batch: 230, Loss: 0.1552
# Epoch: 3, Batch: 240, Loss: 0.1595
# Epoch: 3, Batch: 250, Loss: 0.1752
# Epoch: 3, Batch: 260, Loss: 0.1532
# Epoch: 3, Batch: 270, Loss: 0.1417
# Epoch: 3, Batch: 280, Loss: 0.1711
# Epoch: 3, Batch: 290, Loss: 0.1412
# Epoch: 3, Batch: 300, Loss: 0.1353
# Epoch: 3, Batch: 310, Loss: 0.1230
# Epoch: 3, Batch: 320, Loss: 0.1325
# Epoch: 3, Batch: 330, Loss: 0.1145
# Epoch: 3, Batch: 340, Loss: 0.1324
# Epoch: 3, Batch: 350, Loss: 0.1070
# Epoch: 3, Batch: 360, Loss: 0.1135
# Epoch: 3, Batch: 370, Loss: 0.1138
# Epoch: 3, Batch: 380, Loss: 0.1148
# Epoch: 3, Batch: 390, Loss: 0.1091
# Epoch: 3, Batch: 400, Loss: 0.1065
# Epoch: 3, Batch: 410, Loss: 0.1224
# Epoch: 3, Batch: 420, Loss: 0.1190
# Epoch: 3, Batch: 430, Loss: 0.1527
# Epoch: 3, Batch: 440, Loss: 0.1065
# Epoch: 3, Batch: 450, Loss: 0.1036
# Epoch: 3, Batch: 460, Loss: 0.1134
# Epoch: 3, Batch: 470, Loss: 0.1012
# Epoch: 3, Batch: 480, Loss: 0.0883
# Epoch: 3, Batch: 490, Loss: 0.0853
# Epoch: 3, Batch: 500, Loss: 0.1035
# Epoch: 3, Batch: 510, Loss: 0.0776
# Epoch: 3, Batch: 520, Loss: 0.0936
# Epoch: 3, Batch: 530, Loss: 0.0789
# Epoch: 3, Batch: 540, Loss: 0.0764
# Epoch: 3, Batch: 550, Loss: 0.0835
# Epoch: 3, Batch: 560, Loss: 0.0829
# Epoch: 3, Batch: 570, Loss: 0.0852
# Epoch: 3, Batch: 580, Loss: 0.0621
# Epoch: 3, Batch: 590, Loss: 0.0619
# Epoch: 3, Batch: 600, Loss: 0.0666
# Epoch: 3, Batch: 610, Loss: 0.0647
# Epoch: 3, Batch: 620, Loss: 0.0783
# Epoch: 3, Train Loss: 0.1817, Val Loss: 0.0691
# Epoch: 4, Batch: 0, Loss: 0.0652
# Epoch: 4, Batch: 10, Loss: 0.0650
# Epoch: 4, Batch: 20, Loss: 0.0680
# Epoch: 4, Batch: 30, Loss: 0.0651
# Epoch: 4, Batch: 40, Loss: 0.0601
# Epoch: 4, Batch: 50, Loss: 0.0477
# Epoch: 4, Batch: 60, Loss: 0.0563
# Epoch: 4, Batch: 70, Loss: 0.0562
# Epoch: 4, Batch: 80, Loss: 0.0552
# Epoch: 4, Batch: 90, Loss: 0.0748
# Epoch: 4, Batch: 100, Loss: 0.0469
# Epoch: 4, Batch: 110, Loss: 0.0514
# Epoch: 4, Batch: 120, Loss: 0.0508
# Epoch: 4, Batch: 130, Loss: 0.0411
# Epoch: 4, Batch: 140, Loss: 0.0436
# Epoch: 4, Batch: 150, Loss: 0.0412
# Epoch: 4, Batch: 160, Loss: 0.0481
# Epoch: 4, Batch: 170, Loss: 0.0595
# Epoch: 4, Batch: 180, Loss: 0.0441
# Epoch: 4, Batch: 190, Loss: 0.0501
# Epoch: 4, Batch: 200, Loss: 0.0507
# Epoch: 4, Batch: 210, Loss: 0.0489
# Epoch: 4, Batch: 220, Loss: 0.0354
# Epoch: 4, Batch: 230, Loss: 0.0311
# Epoch: 4, Batch: 240, Loss: 0.0351
# Epoch: 4, Batch: 250, Loss: 0.0299
# Epoch: 4, Batch: 260, Loss: 0.0421
# Epoch: 4, Batch: 270, Loss: 0.0301
# Epoch: 4, Batch: 280, Loss: 0.0315
# Epoch: 4, Batch: 290, Loss: 0.0357
# Epoch: 4, Batch: 300, Loss: 0.0304
# Epoch: 4, Batch: 310, Loss: 0.0323
# Epoch: 4, Batch: 320, Loss: 0.0301
# Epoch: 4, Batch: 330, Loss: 0.0443
# Epoch: 4, Batch: 340, Loss: 0.0349
# Epoch: 4, Batch: 350, Loss: 0.0382
# Epoch: 4, Batch: 360, Loss: 0.0374
# Epoch: 4, Batch: 370, Loss: 0.0266
# Epoch: 4, Batch: 380, Loss: 0.0257
# Epoch: 4, Batch: 390, Loss: 0.0282
# Epoch: 4, Batch: 400, Loss: 0.0247
# Epoch: 4, Batch: 410, Loss: 0.0240
# Epoch: 4, Batch: 420, Loss: 0.0228
# Epoch: 4, Batch: 430, Loss: 0.0671
# Epoch: 4, Batch: 440, Loss: 0.1116
# Epoch: 4, Batch: 450, Loss: 0.0634
# Epoch: 4, Batch: 460, Loss: 0.0422
# Epoch: 4, Batch: 470, Loss: 0.0421
# Epoch: 4, Batch: 480, Loss: 0.0230
# Epoch: 4, Batch: 490, Loss: 0.0245
# Epoch: 4, Batch: 500, Loss: 0.0214
# Epoch: 4, Batch: 510, Loss: 0.0199
# Epoch: 4, Batch: 520, Loss: 0.0216
# Epoch: 4, Batch: 530, Loss: 0.0258
# Epoch: 4, Batch: 540, Loss: 0.0204
# Epoch: 4, Batch: 550, Loss: 0.0179
# Epoch: 4, Batch: 560, Loss: 0.0212
# Epoch: 4, Batch: 570, Loss: 0.0205
# Epoch: 4, Batch: 580, Loss: 0.0175
# Epoch: 4, Batch: 590, Loss: 0.0151
# Epoch: 4, Batch: 600, Loss: 0.0217
# Epoch: 4, Batch: 610, Loss: 0.0154
# Epoch: 4, Batch: 620, Loss: 0.0161
# Epoch: 4, Train Loss: 0.0427, Val Loss: 0.0222
# Epoch: 5, Batch: 0, Loss: 0.0208
# Epoch: 5, Batch: 10, Loss: 0.0217
# Epoch: 5, Batch: 20, Loss: 0.0175
# Epoch: 5, Batch: 30, Loss: 0.0172
# Epoch: 5, Batch: 40, Loss: 0.0222
# Epoch: 5, Batch: 50, Loss: 0.0211
# Epoch: 5, Batch: 60, Loss: 0.0243
# Epoch: 5, Batch: 70, Loss: 0.0179
# Epoch: 5, Batch: 80, Loss: 0.0152
# Epoch: 5, Batch: 90, Loss: 0.0214
# Epoch: 5, Batch: 100, Loss: 0.0211
# Epoch: 5, Batch: 110, Loss: 0.0229
# Epoch: 5, Batch: 120, Loss: 0.0241
# Epoch: 5, Batch: 130, Loss: 0.0284
# Epoch: 5, Batch: 140, Loss: 0.0163
# Epoch: 5, Batch: 150, Loss: 0.0188
# Epoch: 5, Batch: 160, Loss: 0.0274
# Epoch: 5, Batch: 170, Loss: 0.0186
# Epoch: 5, Batch: 180, Loss: 0.0280
# Epoch: 5, Batch: 190, Loss: 0.0284
# Epoch: 5, Batch: 200, Loss: 0.0154
# Epoch: 5, Batch: 210, Loss: 0.0188
# Epoch: 5, Batch: 220, Loss: 0.0201
# Epoch: 5, Batch: 230, Loss: 0.0141
# Epoch: 5, Batch: 240, Loss: 0.0208
# Epoch: 5, Batch: 250, Loss: 0.0288
# Epoch: 5, Batch: 260, Loss: 0.0159
# Epoch: 5, Batch: 270, Loss: 0.0198
# Epoch: 5, Batch: 280, Loss: 0.0191
# Epoch: 5, Batch: 290, Loss: 0.0156
# Epoch: 5, Batch: 300, Loss: 0.0241
# Epoch: 5, Batch: 310, Loss: 0.0215
# Epoch: 5, Batch: 320, Loss: 0.0177
# Epoch: 5, Batch: 330, Loss: 0.0352
# Epoch: 5, Batch: 340, Loss: 0.0146
# Epoch: 5, Batch: 350, Loss: 0.0158
# Epoch: 5, Batch: 360, Loss: 0.0171
# Epoch: 5, Batch: 370, Loss: 0.0167
# Epoch: 5, Batch: 380, Loss: 0.0191
# Epoch: 5, Batch: 390, Loss: 0.0224
# Epoch: 5, Batch: 400, Loss: 0.0177
# Epoch: 5, Batch: 410, Loss: 0.0152
# Epoch: 5, Batch: 420, Loss: 0.0191
# Epoch: 5, Batch: 430, Loss: 0.0122
# Epoch: 5, Batch: 440, Loss: 0.0143
# Epoch: 5, Batch: 450, Loss: 0.0174
# Epoch: 5, Batch: 460, Loss: 0.0136
# Epoch: 5, Batch: 470, Loss: 0.0147
# Epoch: 5, Batch: 480, Loss: 0.0199
# Epoch: 5, Batch: 490, Loss: 0.0138
# Epoch: 5, Batch: 500, Loss: 0.0151
# Epoch: 5, Batch: 510, Loss: 0.0186
# Epoch: 5, Batch: 520, Loss: 0.0156
# Epoch: 5, Batch: 530, Loss: 0.0179
# Epoch: 5, Batch: 540, Loss: 0.0161
# Epoch: 5, Batch: 550, Loss: 0.0160
# Epoch: 5, Batch: 560, Loss: 0.0147
# Epoch: 5, Batch: 570, Loss: 0.0170
# Epoch: 5, Batch: 580, Loss: 0.0156
# Epoch: 5, Batch: 590, Loss: 0.0183
# Epoch: 5, Batch: 600, Loss: 0.0141
# Epoch: 5, Batch: 610, Loss: 0.0146
# Epoch: 5, Batch: 620, Loss: 0.0131
# Epoch: 5, Train Loss: 0.0187, Val Loss: 0.0139
# Epoch: 6, Batch: 0, Loss: 0.0143
# Epoch: 6, Batch: 10, Loss: 0.0120
# Epoch: 6, Batch: 20, Loss: 0.0105
# Epoch: 6, Batch: 30, Loss: 0.0102
# Epoch: 6, Batch: 40, Loss: 0.0153
# Epoch: 6, Batch: 50, Loss: 0.0196
# Epoch: 6, Batch: 60, Loss: 0.0164
# Epoch: 6, Batch: 70, Loss: 0.0117
# Epoch: 6, Batch: 80, Loss: 0.0105
# Epoch: 6, Batch: 90, Loss: 0.0104
# Epoch: 6, Batch: 100, Loss: 0.0084
# Epoch: 6, Batch: 110, Loss: 0.0096
# Epoch: 6, Batch: 120, Loss: 0.0106
# Epoch: 6, Batch: 130, Loss: 0.0086
# Epoch: 6, Batch: 140, Loss: 0.0141
# Epoch: 6, Batch: 150, Loss: 0.0139
# Epoch: 6, Batch: 160, Loss: 0.0104
# Epoch: 6, Batch: 170, Loss: 0.0119
# Epoch: 6, Batch: 180, Loss: 0.0111
# Epoch: 6, Batch: 190, Loss: 0.0097
# Epoch: 6, Batch: 200, Loss: 0.0107
# Epoch: 6, Batch: 210, Loss: 0.0195
# Epoch: 6, Batch: 220, Loss: 0.0103
# Epoch: 6, Batch: 230, Loss: 0.0151
# Epoch: 6, Batch: 240, Loss: 0.0142
# Epoch: 6, Batch: 250, Loss: 0.0100
# Epoch: 6, Batch: 260, Loss: 0.0121
# Epoch: 6, Batch: 270, Loss: 0.0196
# Epoch: 6, Batch: 280, Loss: 0.0113
# Epoch: 6, Batch: 290, Loss: 0.0112
# Epoch: 6, Batch: 300, Loss: 0.0104
# Epoch: 6, Batch: 310, Loss: 0.0093
# Epoch: 6, Batch: 320, Loss: 0.0118
# Epoch: 6, Batch: 330, Loss: 0.0187
# Epoch: 6, Batch: 340, Loss: 0.0110
# Epoch: 6, Batch: 350, Loss: 0.0111
# Epoch: 6, Batch: 360, Loss: 0.0154
# Epoch: 6, Batch: 370, Loss: 0.0131
# Epoch: 6, Batch: 380, Loss: 0.0114
# Epoch: 6, Batch: 390, Loss: 0.0114
# Epoch: 6, Batch: 400, Loss: 0.0176
# Epoch: 6, Batch: 410, Loss: 0.0124
# Epoch: 6, Batch: 420, Loss: 0.0143
# Epoch: 6, Batch: 430, Loss: 0.0083
# Epoch: 6, Batch: 440, Loss: 0.0130
# Epoch: 6, Batch: 450, Loss: 0.0119
# Epoch: 6, Batch: 460, Loss: 0.0109
# Epoch: 6, Batch: 470, Loss: 0.0095
# Epoch: 6, Batch: 480, Loss: 0.0147
# Epoch: 6, Batch: 490, Loss: 0.0133
# Epoch: 6, Batch: 500, Loss: 0.0111
# Epoch: 6, Batch: 510, Loss: 0.0101
# Epoch: 6, Batch: 520, Loss: 0.0121
# Epoch: 6, Batch: 530, Loss: 0.0102
# Epoch: 6, Batch: 540, Loss: 0.0079
# Epoch: 6, Batch: 550, Loss: 0.0101
# Epoch: 6, Batch: 560, Loss: 0.0120
# Epoch: 6, Batch: 570, Loss: 0.0096
# Epoch: 6, Batch: 580, Loss: 0.0096
# Epoch: 6, Batch: 590, Loss: 0.0136
# Epoch: 6, Batch: 600, Loss: 0.0116
# Epoch: 6, Batch: 610, Loss: 0.0174
# Epoch: 6, Batch: 620, Loss: 0.0186
# Epoch: 6, Train Loss: 0.0123, Val Loss: 0.0132
# Epoch: 7, Batch: 0, Loss: 0.0107
# Epoch: 7, Batch: 10, Loss: 0.0083
# Epoch: 7, Batch: 20, Loss: 0.0107
# Epoch: 7, Batch: 30, Loss: 0.0087
# Epoch: 7, Batch: 40, Loss: 0.0123
# Epoch: 7, Batch: 50, Loss: 0.0086
# Epoch: 7, Batch: 60, Loss: 0.0084
# Epoch: 7, Batch: 70, Loss: 0.0094
# Epoch: 7, Batch: 80, Loss: 0.0064
# Epoch: 7, Batch: 90, Loss: 0.0077
# Epoch: 7, Batch: 100, Loss: 0.0074
# Epoch: 7, Batch: 110, Loss: 0.0112
# Epoch: 7, Batch: 120, Loss: 0.0121
# Epoch: 7, Batch: 130, Loss: 0.0086
# Epoch: 7, Batch: 140, Loss: 0.0099
# Epoch: 7, Batch: 150, Loss: 0.0117
# Epoch: 7, Batch: 160, Loss: 0.0094
# Epoch: 7, Batch: 170, Loss: 0.0109
# Epoch: 7, Batch: 180, Loss: 0.0067
# Epoch: 7, Batch: 190, Loss: 0.0067
# Epoch: 7, Batch: 200, Loss: 0.0081
# Epoch: 7, Batch: 210, Loss: 0.0056
# Epoch: 7, Batch: 220, Loss: 0.0056
# Epoch: 7, Batch: 230, Loss: 0.0098
# Epoch: 7, Batch: 240, Loss: 0.0090
# Epoch: 7, Batch: 250, Loss: 0.0072
# Epoch: 7, Batch: 260, Loss: 0.0049
# Epoch: 7, Batch: 270, Loss: 0.0093
# Epoch: 7, Batch: 280, Loss: 0.0111
# Epoch: 7, Batch: 290, Loss: 0.0084
# Epoch: 7, Batch: 300, Loss: 0.0096
# Epoch: 7, Batch: 310, Loss: 0.0099
# Epoch: 7, Batch: 320, Loss: 0.0084
# Epoch: 7, Batch: 330, Loss: 0.0082
# Epoch: 7, Batch: 340, Loss: 0.0091
# Epoch: 7, Batch: 350, Loss: 0.0092
# Epoch: 7, Batch: 360, Loss: 0.0091
# Epoch: 7, Batch: 370, Loss: 0.0086
# Epoch: 7, Batch: 380, Loss: 0.0101
# Epoch: 7, Batch: 390, Loss: 0.0080
# Epoch: 7, Batch: 400, Loss: 0.0089
# Epoch: 7, Batch: 410, Loss: 0.0081
# Epoch: 7, Batch: 420, Loss: 0.0075
# Epoch: 7, Batch: 430, Loss: 0.0101
# Epoch: 7, Batch: 440, Loss: 0.0084
# Epoch: 7, Batch: 450, Loss: 0.0091
# Epoch: 7, Batch: 460, Loss: 0.0114
# Epoch: 7, Batch: 470, Loss: 0.0066
# Epoch: 7, Batch: 480, Loss: 0.0115
# Epoch: 7, Batch: 490, Loss: 0.0078
# Epoch: 7, Batch: 500, Loss: 0.0059
# Epoch: 7, Batch: 510, Loss: 0.0098
# Epoch: 7, Batch: 520, Loss: 0.0078
# Epoch: 7, Batch: 530, Loss: 0.0071
# Epoch: 7, Batch: 540, Loss: 0.0084
# Epoch: 7, Batch: 550, Loss: 0.0086
# Epoch: 7, Batch: 560, Loss: 0.0066
# Epoch: 7, Batch: 570, Loss: 0.0084
# Epoch: 7, Batch: 580, Loss: 0.0079
# Epoch: 7, Batch: 590, Loss: 0.0106
# Epoch: 7, Batch: 600, Loss: 0.0102
# Epoch: 7, Batch: 610, Loss: 0.0080
# Epoch: 7, Batch: 620, Loss: 0.0066
# Epoch: 7, Train Loss: 0.0089, Val Loss: 0.0086
# Epoch: 8, Batch: 0, Loss: 0.0051
# Epoch: 8, Batch: 10, Loss: 0.0070
# Epoch: 8, Batch: 20, Loss: 0.0115
# Epoch: 8, Batch: 30, Loss: 0.0079
# Epoch: 8, Batch: 40, Loss: 0.0072
# Epoch: 8, Batch: 50, Loss: 0.0080
# Epoch: 8, Batch: 60, Loss: 0.0079
# Epoch: 8, Batch: 70, Loss: 0.0062
# Epoch: 8, Batch: 80, Loss: 0.0088
# Epoch: 8, Batch: 90, Loss: 0.0115
# Epoch: 8, Batch: 100, Loss: 0.0075
# Epoch: 8, Batch: 110, Loss: 0.0103
# Epoch: 8, Batch: 120, Loss: 0.0093
# Epoch: 8, Batch: 130, Loss: 0.0055
# Epoch: 8, Batch: 140, Loss: 0.0045
# Epoch: 8, Batch: 150, Loss: 0.0062
# Epoch: 8, Batch: 160, Loss: 0.0059
# Epoch: 8, Batch: 170, Loss: 0.0056
# Epoch: 8, Batch: 180, Loss: 0.0044
# Epoch: 8, Batch: 190, Loss: 0.0079
# Epoch: 8, Batch: 200, Loss: 0.0071
# Epoch: 8, Batch: 210, Loss: 0.0095
# Epoch: 8, Batch: 220, Loss: 0.0088
# Epoch: 8, Batch: 230, Loss: 0.0056
# Epoch: 8, Batch: 240, Loss: 0.0092
# Epoch: 8, Batch: 250, Loss: 0.0054
# Epoch: 8, Batch: 260, Loss: 0.0063
# Epoch: 8, Batch: 270, Loss: 0.0088
# Epoch: 8, Batch: 280, Loss: 0.0084
# Epoch: 8, Batch: 290, Loss: 0.0072
# Epoch: 8, Batch: 300, Loss: 0.0080
# Epoch: 8, Batch: 310, Loss: 0.0081
# Epoch: 8, Batch: 320, Loss: 0.0074
# Epoch: 8, Batch: 330, Loss: 0.0088
# Epoch: 8, Batch: 340, Loss: 0.0075
# Epoch: 8, Batch: 350, Loss: 0.0081
# Epoch: 8, Batch: 360, Loss: 0.0069
# Epoch: 8, Batch: 370, Loss: 0.0063
# Epoch: 8, Batch: 380, Loss: 0.0057
# Epoch: 8, Batch: 390, Loss: 0.0058
# Epoch: 8, Batch: 400, Loss: 0.0082
# Epoch: 8, Batch: 410, Loss: 0.0085
# Epoch: 8, Batch: 420, Loss: 0.0065
# Epoch: 8, Batch: 430, Loss: 0.0077
# Epoch: 8, Batch: 440, Loss: 0.0094
# Epoch: 8, Batch: 450, Loss: 0.0057
# Epoch: 8, Batch: 460, Loss: 0.0042
# Epoch: 8, Batch: 470, Loss: 0.0071
# Epoch: 8, Batch: 480, Loss: 0.0059
# Epoch: 8, Batch: 490, Loss: 0.0050
# Epoch: 8, Batch: 500, Loss: 0.0057
# Epoch: 8, Batch: 510, Loss: 0.0071
# Epoch: 8, Batch: 520, Loss: 0.0067
# Epoch: 8, Batch: 530, Loss: 0.0069
# Epoch: 8, Batch: 540, Loss: 0.0068
# Epoch: 8, Batch: 550, Loss: 0.0057
# Epoch: 8, Batch: 560, Loss: 0.0057
# Epoch: 8, Batch: 570, Loss: 0.0076
# Epoch: 8, Batch: 580, Loss: 0.0059
# Epoch: 8, Batch: 590, Loss: 0.0062
# Epoch: 8, Batch: 600, Loss: 0.0048
# Epoch: 8, Batch: 610, Loss: 0.0071
# Epoch: 8, Batch: 620, Loss: 0.0063
# Epoch: 8, Train Loss: 0.0072, Val Loss: 0.0077
# Epoch: 9, Batch: 0, Loss: 0.0091
# Epoch: 9, Batch: 10, Loss: 0.0069
# Epoch: 9, Batch: 20, Loss: 0.0035
# Epoch: 9, Batch: 30, Loss: 0.0067
# Epoch: 9, Batch: 40, Loss: 0.0060
# Epoch: 9, Batch: 50, Loss: 0.0061
# Epoch: 9, Batch: 60, Loss: 0.0057
# Epoch: 9, Batch: 70, Loss: 0.0061
# Epoch: 9, Batch: 80, Loss: 0.0078
# Epoch: 9, Batch: 90, Loss: 0.0056
# Epoch: 9, Batch: 100, Loss: 0.0062
# Epoch: 9, Batch: 110, Loss: 0.0061
# Epoch: 9, Batch: 120, Loss: 0.0070
# Epoch: 9, Batch: 130, Loss: 0.0057
# Epoch: 9, Batch: 140, Loss: 0.0052
# Epoch: 9, Batch: 150, Loss: 0.0050
# Epoch: 9, Batch: 160, Loss: 0.0053
# Epoch: 9, Batch: 170, Loss: 0.0057
# Epoch: 9, Batch: 180, Loss: 0.0097
# Epoch: 9, Batch: 190, Loss: 0.0058
# Epoch: 9, Batch: 200, Loss: 0.0063
# Epoch: 9, Batch: 210, Loss: 0.0066
# Epoch: 9, Batch: 220, Loss: 0.0053
# Epoch: 9, Batch: 230, Loss: 0.0052
# Epoch: 9, Batch: 240, Loss: 0.0046
# Epoch: 9, Batch: 250, Loss: 0.0039
# Epoch: 9, Batch: 260, Loss: 0.0058
# Epoch: 9, Batch: 270, Loss: 0.0063
# Epoch: 9, Batch: 280, Loss: 0.0057
# Epoch: 9, Batch: 290, Loss: 0.0066
# Epoch: 9, Batch: 300, Loss: 0.0048
# Epoch: 9, Batch: 310, Loss: 0.0060
# Epoch: 9, Batch: 320, Loss: 0.0051
# Epoch: 9, Batch: 330, Loss: 0.0056
# Epoch: 9, Batch: 340, Loss: 0.0052
# Epoch: 9, Batch: 350, Loss: 0.0049
# Epoch: 9, Batch: 360, Loss: 0.0066
# Epoch: 9, Batch: 370, Loss: 0.0053
# Epoch: 9, Batch: 380, Loss: 0.0061
# Epoch: 9, Batch: 390, Loss: 0.0045
# Epoch: 9, Batch: 400, Loss: 0.0048
# Epoch: 9, Batch: 410, Loss: 0.0060
# Epoch: 9, Batch: 420, Loss: 0.0058
# Epoch: 9, Batch: 430, Loss: 0.0040
# Epoch: 9, Batch: 440, Loss: 0.0130
# Epoch: 9, Batch: 450, Loss: 0.0095
# Epoch: 9, Batch: 460, Loss: 0.0062
# Epoch: 9, Batch: 470, Loss: 0.0087
# Epoch: 9, Batch: 480, Loss: 0.0053
# Epoch: 9, Batch: 490, Loss: 0.0043
# Epoch: 9, Batch: 500, Loss: 0.0049
# Epoch: 9, Batch: 510, Loss: 0.0063
# Epoch: 9, Batch: 520, Loss: 0.0030
# Epoch: 9, Batch: 530, Loss: 0.0055
# Epoch: 9, Batch: 540, Loss: 0.0039
# Epoch: 9, Batch: 550, Loss: 0.0047
# Epoch: 9, Batch: 560, Loss: 0.0043
# Epoch: 9, Batch: 570, Loss: 0.0040
# Epoch: 9, Batch: 580, Loss: 0.0054
# Epoch: 9, Batch: 590, Loss: 0.0050
# Epoch: 9, Batch: 600, Loss: 0.0058
# Epoch: 9, Batch: 610, Loss: 0.0062
# Epoch: 9, Batch: 620, Loss: 0.0054
# Epoch: 9, Train Loss: 0.0057, Val Loss: 0.0072
# Epoch: 10, Batch: 0, Loss: 0.0050
# Epoch: 10, Batch: 10, Loss: 0.0038
# Epoch: 10, Batch: 20, Loss: 0.0048
# Epoch: 10, Batch: 30, Loss: 0.0048
# Epoch: 10, Batch: 40, Loss: 0.0058
# Epoch: 10, Batch: 50, Loss: 0.0046
# Epoch: 10, Batch: 60, Loss: 0.0036
# Epoch: 10, Batch: 70, Loss: 0.0058
# Epoch: 10, Batch: 80, Loss: 0.0037
# Epoch: 10, Batch: 90, Loss: 0.0040
# Epoch: 10, Batch: 100, Loss: 0.0058
# Epoch: 10, Batch: 110, Loss: 0.0058
# Epoch: 10, Batch: 120, Loss: 0.0040
# Epoch: 10, Batch: 130, Loss: 0.0048
# Epoch: 10, Batch: 140, Loss: 0.0040
# Epoch: 10, Batch: 150, Loss: 0.0042
# Epoch: 10, Batch: 160, Loss: 0.0038
# Epoch: 10, Batch: 170, Loss: 0.0061
# Epoch: 10, Batch: 180, Loss: 0.0050
# Epoch: 10, Batch: 190, Loss: 0.0041
# Epoch: 10, Batch: 200, Loss: 0.0043
# Epoch: 10, Batch: 210, Loss: 0.0041
# Epoch: 10, Batch: 220, Loss: 0.0047
# Epoch: 10, Batch: 230, Loss: 0.0041
# Epoch: 10, Batch: 240, Loss: 0.0049
# Epoch: 10, Batch: 250, Loss: 0.0040
# Epoch: 10, Batch: 260, Loss: 0.0039
# Epoch: 10, Batch: 270, Loss: 0.0058
# Epoch: 10, Batch: 280, Loss: 0.0043
# Epoch: 10, Batch: 290, Loss: 0.0049
# Epoch: 10, Batch: 300, Loss: 0.0051
# Epoch: 10, Batch: 310, Loss: 0.0172
# Epoch: 10, Batch: 320, Loss: 0.0053
# Epoch: 10, Batch: 330, Loss: 0.0047
# Epoch: 10, Batch: 340, Loss: 0.0050
# Epoch: 10, Batch: 350, Loss: 0.0033
# Epoch: 10, Batch: 360, Loss: 0.0043
# Epoch: 10, Batch: 370, Loss: 0.0052
# Epoch: 10, Batch: 380, Loss: 0.0045
# Epoch: 10, Batch: 390, Loss: 0.0041
# Epoch: 10, Batch: 400, Loss: 0.0035
# Epoch: 10, Batch: 410, Loss: 0.0051
# Epoch: 10, Batch: 420, Loss: 0.0040
# Epoch: 10, Batch: 430, Loss: 0.0047
# Epoch: 10, Batch: 440, Loss: 0.0055
# Epoch: 10, Batch: 450, Loss: 0.0039
# Epoch: 10, Batch: 460, Loss: 0.0037
# Epoch: 10, Batch: 470, Loss: 0.0058
# Epoch: 10, Batch: 480, Loss: 0.0058
# Epoch: 10, Batch: 490, Loss: 0.0031
# Epoch: 10, Batch: 500, Loss: 0.0048
# Epoch: 10, Batch: 510, Loss: 0.0042
# Epoch: 10, Batch: 520, Loss: 0.0056
# Epoch: 10, Batch: 530, Loss: 0.0049
# Epoch: 10, Batch: 540, Loss: 0.0042
# Epoch: 10, Batch: 550, Loss: 0.0036
# Epoch: 10, Batch: 560, Loss: 0.0043
# Epoch: 10, Batch: 570, Loss: 0.0062
# Epoch: 10, Batch: 580, Loss: 0.0059
# Epoch: 10, Batch: 590, Loss: 0.0057
# Epoch: 10, Batch: 600, Loss: 0.0045
# Epoch: 10, Batch: 610, Loss: 0.0038
# Epoch: 10, Batch: 620, Loss: 0.0046
# Epoch: 10, Train Loss: 0.0048, Val Loss: 0.0055
# Input: gfbs, Decrypted: fear
