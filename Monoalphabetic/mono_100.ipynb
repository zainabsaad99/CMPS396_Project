# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
import string

# Data Preparation
def load_data(file_path):
    df = pd.read_excel(file_path)

    # Filter rows where 'Output' length is <=500
    df = df[df['output'].str.len() <= 200]

    # Get the count of such rows
    count_filtered = len(df)

    # Randomly select 250,000 rows (if available)
    if count_filtered > 400000:
        df = df.sample(n=400000, random_state=42)
    print(len(df))
    inputs = df['input'].astype(str).tolist()
    outputs = df['output'].astype(str).tolist()


    return inputs, outputs

# Tokenization and Vocabulary
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        # Special tokens
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        # All printable characters
        all_chars = list(string.printable)

        # Create vocabulary
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})

        # Reverse mapping
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Dataset Class
class CipherDataset(data.Dataset):
    def __init__(self, inputs, outputs, vocab, max_length):
        self.inputs = inputs
        self.outputs = outputs
        self.vocab = vocab
        self.max_length = max_length

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_text = self.inputs[idx]
        output_text = self.outputs[idx]

        # Encode with SOS and EOS tokens
        input_encoded = [self.vocab.sos_token] + self.vocab.encode(input_text) + [self.vocab.eos_token]
        output_encoded = [self.vocab.sos_token] + self.vocab.encode(output_text) + [self.vocab.eos_token]

        # Pad sequences
        input_padded = input_encoded + [self.vocab.pad_token] * (self.max_length - len(input_encoded))
        output_padded = output_encoded + [self.vocab.pad_token] * (self.max_length - len(output_encoded))

        # Truncate if necessary
        input_padded = input_padded[:self.max_length]
        output_padded = output_padded[:self.max_length]

        return torch.tensor(input_padded), torch.tensor(output_padded)

# Transformer Model (same as your implementation)
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Q, K, V shapes: (batch_size, num_heads, seq_len, d_k)
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn_probs = torch.softmax(scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        # Source mask
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, src_len)

        # Target mask
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, tgt_len)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=tgt.device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask  # (batch_size, 1, tgt_len, tgt_len)

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (src, tgt) in enumerate(train_loader):
            src, tgt = src.to(device), tgt.to(device)

            optimizer.zero_grad()
            output = model(src, tgt[:, :-1])

            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch_idx % 10 == 0:
                print(f'Epoch: {epoch+1}, Batch: {batch_idx}, Loss: {loss.item():.4f}')

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        val_loss = evaluate_model(model, val_loader, criterion, device)
        print(f'Epoch: {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), '/content/drive/MyDrive/mono_vanilla_100.pth')

    return model

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            total_loss += loss.item()

    return total_loss / len(data_loader)

# Inference Function
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        # Encode the input text
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        # Initialize target with SOS token
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        # Decode the output
        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

# Main Execution
if __name__ == "__main__":
    # Load and prepare data
    inputs, outputs = load_data('/content/Full_training_mono_100.xlsx')

    # Create vocabulary
    vocab = Vocabulary()

    # Split data into train and validation
    train_inputs, val_inputs, train_outputs, val_outputs = train_test_split(
        inputs, outputs, test_size=0.2, random_state=42
    )

    # Create datasets
    max_length = 256  # Adjust based on your data
    train_dataset = CipherDataset(train_inputs, train_outputs, vocab, max_length)
    val_dataset = CipherDataset(val_inputs, val_outputs, vocab, max_length)

    # Create data loaders
    batch_size = 256
    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=8,
        num_layers=8,
        d_ff=256,
        max_seq_length=max_length,
        dropout=0.13711053703933423
    ).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=vocab.pad_token)
    optimizer = optim.Adam(model.parameters(), lr=0.00017560217719363183, betas=(0.9, 0.98), eps=1e-9)

    # Train the model
    num_epochs = 30
    trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

    # Test the model
    test_text = "gfbs"  # Should decrypt to "fear"
    decrypted = decrypt_text(trained_model, test_text, vocab, max_length, device)
    print(f"Input: {test_text}, Decrypted: {decrypted}")
# Out:
# 400000
# Epoch: 1, Batch: 0, Loss: 4.8438
# Epoch: 1, Batch: 10, Loss: 3.0798
# Epoch: 1, Batch: 20, Loss: 3.0103
# Epoch: 1, Batch: 30, Loss: 2.9575
# Epoch: 1, Batch: 40, Loss: 2.6061
# Epoch: 1, Batch: 50, Loss: 2.3679
# Epoch: 1, Batch: 60, Loss: 2.3086
# Epoch: 1, Batch: 70, Loss: 2.2693
# Epoch: 1, Batch: 80, Loss: 2.2388
# Epoch: 1, Batch: 90, Loss: 2.2111
# Epoch: 1, Batch: 100, Loss: 2.1577
# Epoch: 1, Batch: 110, Loss: 2.0735
# Epoch: 1, Batch: 120, Loss: 2.1258
# Epoch: 1, Batch: 130, Loss: 2.0370
# Epoch: 1, Batch: 140, Loss: 2.0299
# Epoch: 1, Batch: 150, Loss: 2.0617
# Epoch: 1, Batch: 160, Loss: 1.9854
# Epoch: 1, Batch: 170, Loss: 1.9155
# Epoch: 1, Batch: 180, Loss: 1.9339
# Epoch: 1, Batch: 190, Loss: 1.9576
# Epoch: 1, Batch: 200, Loss: 1.8641
# Epoch: 1, Batch: 210, Loss: 1.8587
# Epoch: 1, Batch: 220, Loss: 1.8727
# Epoch: 1, Batch: 230, Loss: 1.8075
# Epoch: 1, Batch: 240, Loss: 1.8027
# Epoch: 1, Batch: 250, Loss: 1.8103
# Epoch: 1, Batch: 260, Loss: 1.7480
# Epoch: 1, Batch: 270, Loss: 1.7339
# Epoch: 1, Batch: 280, Loss: 1.7060
# Epoch: 1, Batch: 290, Loss: 1.6567
# Epoch: 1, Batch: 300, Loss: 1.6789
# Epoch: 1, Batch: 310, Loss: 1.6776
# Epoch: 1, Batch: 320, Loss: 1.6504
# Epoch: 1, Batch: 330, Loss: 1.6276
# Epoch: 1, Batch: 340, Loss: 1.5971
# Epoch: 1, Batch: 350, Loss: 1.6338
# Epoch: 1, Batch: 360, Loss: 1.5797
# Epoch: 1, Batch: 370, Loss: 1.5944
# Epoch: 1, Batch: 380, Loss: 1.5337
# Epoch: 1, Batch: 390, Loss: 1.5412
# Epoch: 1, Batch: 400, Loss: 1.5163
# Epoch: 1, Batch: 410, Loss: 1.5208
# Epoch: 1, Batch: 420, Loss: 1.5329
# Epoch: 1, Batch: 430, Loss: 1.4649
# Epoch: 1, Batch: 440, Loss: 1.4869
# Epoch: 1, Batch: 450, Loss: 1.5104
# Epoch: 1, Batch: 460, Loss: 1.4548
# Epoch: 1, Batch: 470, Loss: 1.4375
# Epoch: 1, Batch: 480, Loss: 1.4155
# Epoch: 1, Batch: 490, Loss: 1.4595
# Epoch: 1, Batch: 500, Loss: 1.4804
# Epoch: 1, Batch: 510, Loss: 1.3942
# Epoch: 1, Batch: 520, Loss: 1.3878
# Epoch: 1, Batch: 530, Loss: 1.3991
# Epoch: 1, Batch: 540, Loss: 1.4104
# Epoch: 1, Batch: 550, Loss: 1.3598
# Epoch: 1, Batch: 560, Loss: 1.3664
# Epoch: 1, Batch: 570, Loss: 1.4417
# Epoch: 1, Batch: 580, Loss: 1.3132
# Epoch: 1, Batch: 590, Loss: 1.3466
# Epoch: 1, Batch: 600, Loss: 1.3396
# Epoch: 1, Batch: 610, Loss: 1.3024
# Epoch: 1, Batch: 620, Loss: 1.2791
# Epoch: 1, Batch: 630, Loss: 1.3102
# Epoch: 1, Batch: 640, Loss: 1.3046
# Epoch: 1, Batch: 650, Loss: 1.2859
# Epoch: 1, Batch: 660, Loss: 1.3159
# Epoch: 1, Batch: 670, Loss: 1.2695
# Epoch: 1, Batch: 680, Loss: 1.3127
# Epoch: 1, Batch: 690, Loss: 1.2781
# Epoch: 1, Batch: 700, Loss: 1.2156
# Epoch: 1, Batch: 710, Loss: 1.1837
# Epoch: 1, Batch: 720, Loss: 1.2758
# Epoch: 1, Batch: 730, Loss: 1.2742
# Epoch: 1, Batch: 740, Loss: 1.1931
# Epoch: 1, Batch: 750, Loss: 1.2022
# Epoch: 1, Batch: 760, Loss: 1.1996
# Epoch: 1, Batch: 770, Loss: 1.2375
# Epoch: 1, Batch: 780, Loss: 1.1813
# Epoch: 1, Batch: 790, Loss: 1.1942
# Epoch: 1, Batch: 800, Loss: 1.1364
# Epoch: 1, Batch: 810, Loss: 1.1196
# Epoch: 1, Batch: 820, Loss: 1.1586
# Epoch: 1, Batch: 830, Loss: 1.1298
# Epoch: 1, Batch: 840, Loss: 1.1713
# Epoch: 1, Batch: 850, Loss: 1.1005
# Epoch: 1, Batch: 860, Loss: 1.0960
# Epoch: 1, Batch: 870, Loss: 1.1253
# Epoch: 1, Batch: 880, Loss: 1.0912
# Epoch: 1, Batch: 890, Loss: 1.1462
# Epoch: 1, Batch: 900, Loss: 1.1362
# Epoch: 1, Batch: 910, Loss: 1.1243
# Epoch: 1, Batch: 920, Loss: 1.0673
# Epoch: 1, Batch: 930, Loss: 1.0903
# Epoch: 1, Batch: 940, Loss: 1.0739
# Epoch: 1, Batch: 950, Loss: 1.0911
# Epoch: 1, Batch: 960, Loss: 1.1030
# Epoch: 1, Batch: 970, Loss: 1.0671
# Epoch: 1, Batch: 980, Loss: 1.0762
# Epoch: 1, Batch: 990, Loss: 1.0548
# Epoch: 1, Batch: 1000, Loss: 1.0374
# Epoch: 1, Batch: 1010, Loss: 1.0220
# Epoch: 1, Batch: 1020, Loss: 1.0576
# Epoch: 1, Batch: 1030, Loss: 0.9887
# Epoch: 1, Batch: 1040, Loss: 1.0406
# Epoch: 1, Batch: 1050, Loss: 0.9908
# Epoch: 1, Batch: 1060, Loss: 1.0522
# Epoch: 1, Batch: 1070, Loss: 0.9681
# Epoch: 1, Batch: 1080, Loss: 0.9915
# Epoch: 1, Batch: 1090, Loss: 0.9772
# Epoch: 1, Batch: 1100, Loss: 0.9756
# Epoch: 1, Batch: 1110, Loss: 0.9933
# Epoch: 1, Batch: 1120, Loss: 0.9542
# Epoch: 1, Batch: 1130, Loss: 0.9407
# Epoch: 1, Batch: 1140, Loss: 0.9822
# Epoch: 1, Batch: 1150, Loss: 0.9481
# Epoch: 1, Batch: 1160, Loss: 0.9941
# Epoch: 1, Batch: 1170, Loss: 0.9765
# Epoch: 1, Batch: 1180, Loss: 0.9397
# Epoch: 1, Batch: 1190, Loss: 0.9136
# Epoch: 1, Batch: 1200, Loss: 0.9245
# Epoch: 1, Batch: 1210, Loss: 0.9161
# Epoch: 1, Batch: 1220, Loss: 0.9314
# Epoch: 1, Batch: 1230, Loss: 0.8989
# Epoch: 1, Batch: 1240, Loss: 0.9231
# Epoch: 1, Train Loss: 1.4389, Val Loss: 0.7903
# Epoch: 2, Batch: 0, Loss: 0.7493
# Epoch: 2, Batch: 10, Loss: 0.7310
# Epoch: 2, Batch: 20, Loss: 0.7647
# Epoch: 2, Batch: 30, Loss: 0.7202
# Epoch: 2, Batch: 40, Loss: 0.6867
# Epoch: 2, Batch: 50, Loss: 0.7010
# Epoch: 2, Batch: 60, Loss: 0.6433
# Epoch: 2, Batch: 70, Loss: 0.6744
# Epoch: 2, Batch: 80, Loss: 0.7046
# Epoch: 2, Batch: 90, Loss: 0.6521
# Epoch: 2, Batch: 100, Loss: 0.6942
# Epoch: 2, Batch: 110, Loss: 0.6702
# Epoch: 2, Batch: 120, Loss: 0.6872
# Epoch: 2, Batch: 130, Loss: 0.6112
# Epoch: 2, Batch: 140, Loss: 0.6157
# Epoch: 2, Batch: 150, Loss: 0.5775
# Epoch: 2, Batch: 160, Loss: 0.5800
# Epoch: 2, Batch: 170, Loss: 0.5645
# Epoch: 2, Batch: 180, Loss: 0.5476
# Epoch: 2, Batch: 190, Loss: 0.5480
# Epoch: 2, Batch: 200, Loss: 0.5833
# Epoch: 2, Batch: 210, Loss: 0.5205
# Epoch: 2, Batch: 220, Loss: 0.5266
# Epoch: 2, Batch: 230, Loss: 0.5054
# Epoch: 2, Batch: 240, Loss: 0.4796
# Epoch: 2, Batch: 250, Loss: 0.4696
# Epoch: 2, Batch: 260, Loss: 0.5058
# Epoch: 2, Batch: 270, Loss: 0.4548
# Epoch: 2, Batch: 280, Loss: 0.4648
# Epoch: 2, Batch: 290, Loss: 0.4254
# Epoch: 2, Batch: 300, Loss: 0.4389
# Epoch: 2, Batch: 310, Loss: 0.4199
# Epoch: 2, Batch: 320, Loss: 0.3969
# Epoch: 2, Batch: 330, Loss: 0.3973
# Epoch: 2, Batch: 340, Loss: 0.3716
# Epoch: 2, Batch: 350, Loss: 0.3614
# Epoch: 2, Batch: 360, Loss: 0.3789
# Epoch: 2, Batch: 370, Loss: 0.3711
# Epoch: 2, Batch: 380, Loss: 0.3244
# Epoch: 2, Batch: 390, Loss: 0.3472
# Epoch: 2, Batch: 400, Loss: 0.3248
# Epoch: 2, Batch: 410, Loss: 0.3284
# Epoch: 2, Batch: 420, Loss: 0.3191
# Epoch: 2, Batch: 430, Loss: 0.3336
# Epoch: 2, Batch: 440, Loss: 0.3115
# Epoch: 2, Batch: 450, Loss: 0.2797
# Epoch: 2, Batch: 460, Loss: 0.3182
# Epoch: 2, Batch: 470, Loss: 0.2741
# Epoch: 2, Batch: 480, Loss: 0.2799
# Epoch: 2, Batch: 490, Loss: 0.2705
# Epoch: 2, Batch: 500, Loss: 0.2648
# Epoch: 2, Batch: 510, Loss: 0.2734
# Epoch: 2, Batch: 520, Loss: 0.2601
# Epoch: 2, Batch: 530, Loss: 0.2461
# Epoch: 2, Batch: 540, Loss: 0.2412
# Epoch: 2, Batch: 550, Loss: 0.2209
# Epoch: 2, Batch: 560, Loss: 0.2119
# Epoch: 2, Batch: 570, Loss: 0.2293
# Epoch: 2, Batch: 580, Loss: 0.2143
# Epoch: 2, Batch: 590, Loss: 0.2194
# Epoch: 2, Batch: 600, Loss: 0.2193
# Epoch: 2, Batch: 610, Loss: 0.2129
# Epoch: 2, Batch: 620, Loss: 0.2041
# Epoch: 2, Batch: 630, Loss: 0.1928
# Epoch: 2, Batch: 640, Loss: 0.1942
# Epoch: 2, Batch: 650, Loss: 0.2083
# Epoch: 2, Batch: 660, Loss: 0.1829
# Epoch: 2, Batch: 670, Loss: 0.1865
# Epoch: 2, Batch: 680, Loss: 0.1805
# Epoch: 2, Batch: 690, Loss: 0.2165
# Epoch: 2, Batch: 700, Loss: 0.1828
# Epoch: 2, Batch: 710, Loss: 0.1811
# Epoch: 2, Batch: 720, Loss: 0.1874
# Epoch: 2, Batch: 730, Loss: 0.2084
# Epoch: 2, Batch: 740, Loss: 0.1739
# Epoch: 2, Batch: 750, Loss: 0.1660
# Epoch: 2, Batch: 760, Loss: 0.1661
# Epoch: 2, Batch: 770, Loss: 0.1776
# Epoch: 2, Batch: 780, Loss: 0.1803
# Epoch: 2, Batch: 790, Loss: 0.1786
# Epoch: 2, Batch: 800, Loss: 0.1566
# Epoch: 2, Batch: 810, Loss: 0.1631
# Epoch: 2, Batch: 820, Loss: 0.1660
# Epoch: 2, Batch: 830, Loss: 0.1597
# Epoch: 2, Batch: 840, Loss: 0.1605
# Epoch: 2, Batch: 850, Loss: 0.1577
# Epoch: 2, Batch: 860, Loss: 0.1608
# Epoch: 2, Batch: 870, Loss: 0.1594
# Epoch: 2, Batch: 880, Loss: 0.1453
# Epoch: 2, Batch: 890, Loss: 0.1563
# Epoch: 2, Batch: 900, Loss: 0.1519
# Epoch: 2, Batch: 910, Loss: 0.1616
# Epoch: 2, Batch: 920, Loss: 0.1349
# Epoch: 2, Batch: 930, Loss: 0.1552
# Epoch: 2, Batch: 940, Loss: 0.1409
# Epoch: 2, Batch: 950, Loss: 0.1344
# Epoch: 2, Batch: 960, Loss: 0.1284
# Epoch: 2, Batch: 970, Loss: 0.1404
# Epoch: 2, Batch: 980, Loss: 0.1522
# Epoch: 2, Batch: 990, Loss: 0.1396
# Epoch: 2, Batch: 1000, Loss: 0.1354
# Epoch: 2, Batch: 1010, Loss: 0.1387
# Epoch: 2, Batch: 1020, Loss: 0.1584
# Epoch: 2, Batch: 1030, Loss: 0.1314
# Epoch: 2, Batch: 1040, Loss: 0.1341
# Epoch: 2, Batch: 1050, Loss: 0.1166
# Epoch: 2, Batch: 1060, Loss: 0.1326
# Epoch: 2, Batch: 1070, Loss: 0.1363
# Epoch: 2, Batch: 1080, Loss: 0.1212
# Epoch: 2, Batch: 1090, Loss: 0.1354
# Epoch: 2, Batch: 1100, Loss: 0.1268
# Epoch: 2, Batch: 1110, Loss: 0.1253
# Epoch: 2, Batch: 1120, Loss: 0.1292
# Epoch: 2, Batch: 1130, Loss: 0.1411
# Epoch: 2, Batch: 1140, Loss: 0.1234
# Epoch: 2, Batch: 1150, Loss: 0.1240
# Epoch: 2, Batch: 1160, Loss: 0.1159
# Epoch: 2, Batch: 1170, Loss: 0.1226
# Epoch: 2, Batch: 1180, Loss: 0.1128
# Epoch: 2, Batch: 1190, Loss: 0.1323
# Epoch: 2, Batch: 1200, Loss: 0.1357
# Epoch: 2, Batch: 1210, Loss: 0.1238
# Epoch: 2, Batch: 1220, Loss: 0.1103
# Epoch: 2, Batch: 1230, Loss: 0.1303
# Epoch: 2, Batch: 1240, Loss: 0.1105
# Epoch: 2, Train Loss: 0.2957, Val Loss: 0.1204
# Epoch: 3, Batch: 0, Loss: 0.1181
# Epoch: 3, Batch: 10, Loss: 0.1143
# Epoch: 3, Batch: 20, Loss: 0.1135
# Epoch: 3, Batch: 30, Loss: 0.0892
# Epoch: 3, Batch: 40, Loss: 0.0993
# Epoch: 3, Batch: 50, Loss: 0.1172
# Epoch: 3, Batch: 60, Loss: 0.1213
# Epoch: 3, Batch: 70, Loss: 0.1109
# Epoch: 3, Batch: 80, Loss: 0.0991
# Epoch: 3, Batch: 90, Loss: 0.1178
# Epoch: 3, Batch: 100, Loss: 0.1160
# Epoch: 3, Batch: 110, Loss: 0.1035
# Epoch: 3, Batch: 120, Loss: 0.1090
# Epoch: 3, Batch: 130, Loss: 0.1057
# Epoch: 3, Batch: 140, Loss: 0.1124
# Epoch: 3, Batch: 150, Loss: 0.1072
# Epoch: 3, Batch: 160, Loss: 0.0985
# Epoch: 3, Batch: 170, Loss: 0.0894
# Epoch: 3, Batch: 180, Loss: 0.1047
# Epoch: 3, Batch: 190, Loss: 0.0942
# Epoch: 3, Batch: 200, Loss: 0.0838
# Epoch: 3, Batch: 210, Loss: 0.0883
# Epoch: 3, Batch: 220, Loss: 0.0942
# Epoch: 3, Batch: 230, Loss: 0.0957
# Epoch: 3, Batch: 240, Loss: 0.1046
# Epoch: 3, Batch: 250, Loss: 0.0842
# Epoch: 3, Batch: 260, Loss: 0.0993
# Epoch: 3, Batch: 270, Loss: 0.0966
# Epoch: 3, Batch: 280, Loss: 0.0997
# Epoch: 3, Batch: 290, Loss: 0.0990
# Epoch: 3, Batch: 300, Loss: 0.1002
# Epoch: 3, Batch: 310, Loss: 0.1132
# Epoch: 3, Batch: 320, Loss: 0.0893
# Epoch: 3, Batch: 330, Loss: 0.0860
# Epoch: 3, Batch: 340, Loss: 0.0967
# Epoch: 3, Batch: 350, Loss: 0.0872
# Epoch: 3, Batch: 360, Loss: 0.0846
# Epoch: 3, Batch: 370, Loss: 0.0808
# Epoch: 3, Batch: 380, Loss: 0.0981
# Epoch: 3, Batch: 390, Loss: 0.0896
# Epoch: 3, Batch: 400, Loss: 0.1025
# Epoch: 3, Batch: 410, Loss: 0.0830
# Epoch: 3, Batch: 420, Loss: 0.0885
# Epoch: 3, Batch: 430, Loss: 0.1003
# Epoch: 3, Batch: 440, Loss: 0.0879
# Epoch: 3, Batch: 450, Loss: 0.0690
# Epoch: 3, Batch: 460, Loss: 0.0927
# Epoch: 3, Batch: 470, Loss: 0.0997
# Epoch: 3, Batch: 480, Loss: 0.0801
# Epoch: 3, Batch: 490, Loss: 0.0811
# Epoch: 3, Batch: 500, Loss: 0.0774
# Epoch: 3, Batch: 510, Loss: 0.0873
# Epoch: 3, Batch: 520, Loss: 0.0829
# Epoch: 3, Batch: 530, Loss: 0.0813
# Epoch: 3, Batch: 540, Loss: 0.0993
# Epoch: 3, Batch: 550, Loss: 0.0698
# Epoch: 3, Batch: 560, Loss: 0.0919
# Epoch: 3, Batch: 570, Loss: 0.1063
# Epoch: 3, Batch: 580, Loss: 0.0878
# Epoch: 3, Batch: 590, Loss: 0.0937
# Epoch: 3, Batch: 600, Loss: 0.0857
# Epoch: 3, Batch: 610, Loss: 0.0875
# Epoch: 3, Batch: 620, Loss: 0.0888
# Epoch: 3, Batch: 630, Loss: 0.0879
# Epoch: 3, Batch: 640, Loss: 0.0842
# Epoch: 3, Batch: 650, Loss: 0.0781
# Epoch: 3, Batch: 660, Loss: 0.0676
# Epoch: 3, Batch: 670, Loss: 0.0874
# Epoch: 3, Batch: 680, Loss: 0.0742
# Epoch: 3, Batch: 690, Loss: 0.0803
# Epoch: 3, Batch: 700, Loss: 0.0862
# Epoch: 3, Batch: 710, Loss: 0.0687
# Epoch: 3, Batch: 720, Loss: 0.0792
# Epoch: 3, Batch: 730, Loss: 0.0744
# Epoch: 3, Batch: 740, Loss: 0.0730
# Epoch: 3, Batch: 750, Loss: 0.0776
# Epoch: 3, Batch: 760, Loss: 0.0722
# Epoch: 3, Batch: 770, Loss: 0.0835
# Epoch: 3, Batch: 780, Loss: 0.0891
# Epoch: 3, Batch: 790, Loss: 0.0743
# Epoch: 3, Batch: 800, Loss: 0.0871
# Epoch: 3, Batch: 810, Loss: 0.0826
# Epoch: 3, Batch: 820, Loss: 0.0751
# Epoch: 3, Batch: 830, Loss: 0.0789
# Epoch: 3, Batch: 840, Loss: 0.0802
# Epoch: 3, Batch: 850, Loss: 0.0860
# Epoch: 3, Batch: 860, Loss: 0.0753
# Epoch: 3, Batch: 870, Loss: 0.0683
# Epoch: 3, Batch: 880, Loss: 0.0662
# Epoch: 3, Batch: 890, Loss: 0.0793
# Epoch: 3, Batch: 900, Loss: 0.0782
# Epoch: 3, Batch: 910, Loss: 0.0776
# Epoch: 3, Batch: 920, Loss: 0.0816
# Epoch: 3, Batch: 930, Loss: 0.0844
# Epoch: 3, Batch: 940, Loss: 0.0613
# Epoch: 3, Batch: 950, Loss: 0.0696
# Epoch: 3, Batch: 960, Loss: 0.0818
# Epoch: 3, Batch: 970, Loss: 0.0760
# Epoch: 3, Batch: 980, Loss: 0.0707
# Epoch: 3, Batch: 990, Loss: 0.0608
# Epoch: 3, Batch: 1000, Loss: 0.0735
# Epoch: 3, Batch: 1010, Loss: 0.0705
# Epoch: 3, Batch: 1020, Loss: 0.0637
# Epoch: 3, Batch: 1030, Loss: 0.0717
# Epoch: 3, Batch: 1040, Loss: 0.0621
# Epoch: 3, Batch: 1050, Loss: 0.0682
# Epoch: 3, Batch: 1060, Loss: 0.0764
# Epoch: 3, Batch: 1070, Loss: 0.0803
# Epoch: 3, Batch: 1080, Loss: 0.0794
# Epoch: 3, Batch: 1090, Loss: 0.0612
# Epoch: 3, Batch: 1100, Loss: 0.0798
# Epoch: 3, Batch: 1110, Loss: 0.0694
# Epoch: 3, Batch: 1120, Loss: 0.0765
# Epoch: 3, Batch: 1130, Loss: 0.0684
# Epoch: 3, Batch: 1140, Loss: 0.0845
# Epoch: 3, Batch: 1150, Loss: 0.0664
# Epoch: 3, Batch: 1160, Loss: 0.0781
# Epoch: 3, Batch: 1170, Loss: 0.0793
# Epoch: 3, Batch: 1180, Loss: 0.0746
# Epoch: 3, Batch: 1190, Loss: 0.0683
# Epoch: 3, Batch: 1200, Loss: 0.0702
# Epoch: 3, Batch: 1210, Loss: 0.0638
# Epoch: 3, Batch: 1220, Loss: 0.0706
# Epoch: 3, Batch: 1230, Loss: 0.0698
# Epoch: 3, Batch: 1240, Loss: 0.0795
# Epoch: 3, Train Loss: 0.0859, Val Loss: 0.0690
# Epoch: 4, Batch: 0, Loss: 0.0725
# Epoch: 4, Batch: 10, Loss: 0.0693
# Epoch: 4, Batch: 20, Loss: 0.0588
# Epoch: 4, Batch: 30, Loss: 0.0654
# Epoch: 4, Batch: 40, Loss: 0.0611
# Epoch: 4, Batch: 50, Loss: 0.0645
# Epoch: 4, Batch: 60, Loss: 0.0661
# Epoch: 4, Batch: 70, Loss: 0.0547
# Epoch: 4, Batch: 80, Loss: 0.0671
# Epoch: 4, Batch: 90, Loss: 0.0703
# Epoch: 4, Batch: 100, Loss: 0.0598
# Epoch: 4, Batch: 110, Loss: 0.0647
# Epoch: 4, Batch: 120, Loss: 0.0619
# Epoch: 4, Batch: 130, Loss: 0.0592
# Epoch: 4, Batch: 140, Loss: 0.0572
# Epoch: 4, Batch: 150, Loss: 0.0558
# Epoch: 4, Batch: 160, Loss: 0.0613
# Epoch: 4, Batch: 170, Loss: 0.0692
# Epoch: 4, Batch: 180, Loss: 0.0588
# Epoch: 4, Batch: 190, Loss: 0.0690
# Epoch: 4, Batch: 200, Loss: 0.0657
# Epoch: 4, Batch: 210, Loss: 0.0656
# Epoch: 4, Batch: 220, Loss: 0.0660
# Epoch: 4, Batch: 230, Loss: 0.0519
# Epoch: 4, Batch: 240, Loss: 0.0615
# Epoch: 4, Batch: 250, Loss: 0.0663
# Epoch: 4, Batch: 260, Loss: 0.0533
# Epoch: 4, Batch: 270, Loss: 0.0495
# Epoch: 4, Batch: 280, Loss: 0.0547
# Epoch: 4, Batch: 290, Loss: 0.0640
# Epoch: 4, Batch: 300, Loss: 0.0575
# Epoch: 4, Batch: 310, Loss: 0.0490
# Epoch: 4, Batch: 320, Loss: 0.0590
# Epoch: 4, Batch: 330, Loss: 0.0646
# Epoch: 4, Batch: 340, Loss: 0.0582
# Epoch: 4, Batch: 350, Loss: 0.0650
# Epoch: 4, Batch: 360, Loss: 0.0633
# Epoch: 4, Batch: 370, Loss: 0.0554
# Epoch: 4, Batch: 380, Loss: 0.0662
# Epoch: 4, Batch: 390, Loss: 0.0491
# Epoch: 4, Batch: 400, Loss: 0.0522
# Epoch: 4, Batch: 410, Loss: 0.0566
# Epoch: 4, Batch: 420, Loss: 0.0560
# Epoch: 4, Batch: 430, Loss: 0.0413
# Epoch: 4, Batch: 440, Loss: 0.0552
# Epoch: 4, Batch: 450, Loss: 0.0440
# Epoch: 4, Batch: 460, Loss: 0.0601
# Epoch: 4, Batch: 470, Loss: 0.0592
# Epoch: 4, Batch: 480, Loss: 0.0503
# Epoch: 4, Batch: 490, Loss: 0.0608
# Epoch: 4, Batch: 500, Loss: 0.0553
# Epoch: 4, Batch: 510, Loss: 0.0603
# Epoch: 4, Batch: 520, Loss: 0.0489
# Epoch: 4, Batch: 530, Loss: 0.0600
# Epoch: 4, Batch: 540, Loss: 0.0476
# Epoch: 4, Batch: 550, Loss: 0.0568
# Epoch: 4, Batch: 560, Loss: 0.0634
# Epoch: 4, Batch: 570, Loss: 0.0582
# Epoch: 4, Batch: 580, Loss: 0.0552
# Epoch: 4, Batch: 590, Loss: 0.0647
# Epoch: 4, Batch: 600, Loss: 0.0558
# Epoch: 4, Batch: 610, Loss: 0.0492
# Epoch: 4, Batch: 620, Loss: 0.0545
# Epoch: 4, Batch: 630, Loss: 0.0644
# Epoch: 4, Batch: 640, Loss: 0.0532
# Epoch: 4, Batch: 650, Loss: 0.0515
# Epoch: 4, Batch: 660, Loss: 0.0505
# Epoch: 4, Batch: 670, Loss: 0.0608
# Epoch: 4, Batch: 680, Loss: 0.0581
# Epoch: 4, Batch: 690, Loss: 0.0589
# Epoch: 4, Batch: 700, Loss: 0.0554
# Epoch: 4, Batch: 710, Loss: 0.0505
# Epoch: 4, Batch: 720, Loss: 0.0541
# Epoch: 4, Batch: 730, Loss: 0.0657
# Epoch: 4, Batch: 740, Loss: 0.0482
# Epoch: 4, Batch: 750, Loss: 0.0553
# Epoch: 4, Batch: 760, Loss: 0.0565
# Epoch: 4, Batch: 770, Loss: 0.0567
# Epoch: 4, Batch: 780, Loss: 0.0537
# Epoch: 4, Batch: 790, Loss: 0.0571
# Epoch: 4, Batch: 800, Loss: 0.0494
# Epoch: 4, Batch: 810, Loss: 0.0449
# Epoch: 4, Batch: 820, Loss: 0.0524
# Epoch: 4, Batch: 830, Loss: 0.0486
# Epoch: 4, Batch: 840, Loss: 0.0538
# Epoch: 4, Batch: 850, Loss: 0.0488
# Epoch: 4, Batch: 860, Loss: 0.0493
# Epoch: 4, Batch: 870, Loss: 0.0529
# Epoch: 4, Batch: 880, Loss: 0.0600
# Epoch: 4, Batch: 890, Loss: 0.0459
# Epoch: 4, Batch: 900, Loss: 0.0517
# Epoch: 4, Batch: 910, Loss: 0.0441
# Epoch: 4, Batch: 920, Loss: 0.0512
# Epoch: 4, Batch: 930, Loss: 0.0481
# Epoch: 4, Batch: 940, Loss: 0.0535
# Epoch: 4, Batch: 950, Loss: 0.0492
# Epoch: 4, Batch: 960, Loss: 0.0473
# Epoch: 4, Batch: 970, Loss: 0.0467
# Epoch: 4, Batch: 980, Loss: 0.0513
# Epoch: 4, Batch: 990, Loss: 0.0518
# Epoch: 4, Batch: 1000, Loss: 0.0489
# Epoch: 4, Batch: 1010, Loss: 0.0492
# Epoch: 4, Batch: 1020, Loss: 0.0451
# Epoch: 4, Batch: 1030, Loss: 0.0558
# Epoch: 4, Batch: 1040, Loss: 0.0501
# Epoch: 4, Batch: 1050, Loss: 0.0438
# Epoch: 4, Batch: 1060, Loss: 0.0378
# Epoch: 4, Batch: 1070, Loss: 0.0385
# Epoch: 4, Batch: 1080, Loss: 0.0498
# Epoch: 4, Batch: 1090, Loss: 0.0512
# Epoch: 4, Batch: 1100, Loss: 0.0441
# Epoch: 4, Batch: 1110, Loss: 0.0440
# Epoch: 4, Batch: 1120, Loss: 0.0500
# Epoch: 4, Batch: 1130, Loss: 0.0492
# Epoch: 4, Batch: 1140, Loss: 0.0481
# Epoch: 4, Batch: 1150, Loss: 0.0528
# Epoch: 4, Batch: 1160, Loss: 0.0546
# Epoch: 4, Batch: 1170, Loss: 0.0537
# Epoch: 4, Batch: 1180, Loss: 0.0450
# Epoch: 4, Batch: 1190, Loss: 0.0373
# Epoch: 4, Batch: 1200, Loss: 0.0468
# Epoch: 4, Batch: 1210, Loss: 0.0475
# Epoch: 4, Batch: 1220, Loss: 0.0467
# Epoch: 4, Batch: 1230, Loss: 0.0429
# Epoch: 4, Batch: 1240, Loss: 0.0371
# Epoch: 4, Train Loss: 0.0553, Val Loss: 0.0479
# Epoch: 5, Batch: 0, Loss: 0.0380
# Epoch: 5, Batch: 10, Loss: 0.0412
# Epoch: 5, Batch: 20, Loss: 0.0434
# Epoch: 5, Batch: 30, Loss: 0.0467
# Epoch: 5, Batch: 40, Loss: 0.0466
# Epoch: 5, Batch: 50, Loss: 0.0432
# Epoch: 5, Batch: 60, Loss: 0.0577
# Epoch: 5, Batch: 70, Loss: 0.0484
# Epoch: 5, Batch: 80, Loss: 0.0384
# Epoch: 5, Batch: 90, Loss: 0.0472
# Epoch: 5, Batch: 100, Loss: 0.0421
# Epoch: 5, Batch: 110, Loss: 0.0400
# Epoch: 5, Batch: 120, Loss: 0.0414
# Epoch: 5, Batch: 130, Loss: 0.0522
# Epoch: 5, Batch: 140, Loss: 0.0366
# Epoch: 5, Batch: 150, Loss: 0.0422
# Epoch: 5, Batch: 160, Loss: 0.0556
# Epoch: 5, Batch: 170, Loss: 0.0444
# Epoch: 5, Batch: 180, Loss: 0.0522
# Epoch: 5, Batch: 190, Loss: 0.0349
# Epoch: 5, Batch: 200, Loss: 0.0535
# Epoch: 5, Batch: 210, Loss: 0.0477
# Epoch: 5, Batch: 220, Loss: 0.0419
# Epoch: 5, Batch: 230, Loss: 0.0407
# Epoch: 5, Batch: 240, Loss: 0.0434
# Epoch: 5, Batch: 250, Loss: 0.0402
# Epoch: 5, Batch: 260, Loss: 0.0440
# Epoch: 5, Batch: 270, Loss: 0.0453
# Epoch: 5, Batch: 280, Loss: 0.0382
# Epoch: 5, Batch: 290, Loss: 0.0410
# Epoch: 5, Batch: 300, Loss: 0.0486
# Epoch: 5, Batch: 310, Loss: 0.0451
# Epoch: 5, Batch: 320, Loss: 0.0442
# Epoch: 5, Batch: 330, Loss: 0.0470
# Epoch: 5, Batch: 340, Loss: 0.0421
# Epoch: 5, Batch: 350, Loss: 0.0394
# Epoch: 5, Batch: 360, Loss: 0.0512
# Epoch: 5, Batch: 370, Loss: 0.0528
# Epoch: 5, Batch: 380, Loss: 0.0310
# Epoch: 5, Batch: 390, Loss: 0.0564
# Epoch: 5, Batch: 400, Loss: 0.0502
# Epoch: 5, Batch: 410, Loss: 0.0426
# Epoch: 5, Batch: 420, Loss: 0.0436
# Epoch: 5, Batch: 430, Loss: 0.0388
# Epoch: 5, Batch: 440, Loss: 0.0537
# Epoch: 5, Batch: 450, Loss: 0.0404
# Epoch: 5, Batch: 460, Loss: 0.0470
# Epoch: 5, Batch: 470, Loss: 0.0490
# Epoch: 5, Batch: 480, Loss: 0.0411
# Epoch: 5, Batch: 490, Loss: 0.0448
# Epoch: 5, Batch: 500, Loss: 0.0412
# Epoch: 5, Batch: 510, Loss: 0.0466
# Epoch: 5, Batch: 520, Loss: 0.0449
# Epoch: 5, Batch: 530, Loss: 0.0389
# Epoch: 5, Batch: 540, Loss: 0.0400
# Epoch: 5, Batch: 550, Loss: 0.0391
# Epoch: 5, Batch: 560, Loss: 0.0398
# Epoch: 5, Batch: 570, Loss: 0.0363
# Epoch: 5, Batch: 580, Loss: 0.0366
# Epoch: 5, Batch: 590, Loss: 0.0410
# Epoch: 5, Batch: 600, Loss: 0.0423
# Epoch: 5, Batch: 610, Loss: 0.0447
# Epoch: 5, Batch: 620, Loss: 0.0422
# Epoch: 5, Batch: 630, Loss: 0.0420
# Epoch: 5, Batch: 640, Loss: 0.0444
# Epoch: 5, Batch: 650, Loss: 0.0424
# Epoch: 5, Batch: 660, Loss: 0.0429
# Epoch: 5, Batch: 670, Loss: 0.0244
# Epoch: 5, Batch: 680, Loss: 0.0376
# Epoch: 5, Batch: 690, Loss: 0.0445
# Epoch: 5, Batch: 700, Loss: 0.0474
# Epoch: 5, Batch: 710, Loss: 0.0453
# Epoch: 5, Batch: 720, Loss: 0.0383
# Epoch: 5, Batch: 730, Loss: 0.0423
# Epoch: 5, Batch: 740, Loss: 0.0365
# Epoch: 5, Batch: 750, Loss: 0.0423
# Epoch: 5, Batch: 760, Loss: 0.0457
# Epoch: 5, Batch: 770, Loss: 0.0405
# Epoch: 5, Batch: 780, Loss: 0.0361
# Epoch: 5, Batch: 790, Loss: 0.0319
# Epoch: 5, Batch: 800, Loss: 0.0412
# Epoch: 5, Batch: 810, Loss: 0.0410
# Epoch: 5, Batch: 820, Loss: 0.0386
# Epoch: 5, Batch: 830, Loss: 0.0450
# Epoch: 5, Batch: 840, Loss: 0.0477
# Epoch: 5, Batch: 850, Loss: 0.0456
# Epoch: 5, Batch: 860, Loss: 0.0353
# Epoch: 5, Batch: 870, Loss: 0.0419
# Epoch: 5, Batch: 880, Loss: 0.0370
# Epoch: 5, Batch: 890, Loss: 0.0429
# Epoch: 5, Batch: 900, Loss: 0.0346
# Epoch: 5, Batch: 910, Loss: 0.0437
# Epoch: 5, Batch: 920, Loss: 0.0495
# Epoch: 5, Batch: 930, Loss: 0.0468
# Epoch: 5, Batch: 940, Loss: 0.0365
# Epoch: 5, Batch: 950, Loss: 0.0335
# Epoch: 5, Batch: 960, Loss: 0.0388
# Epoch: 5, Batch: 970, Loss: 0.0414
# Epoch: 5, Batch: 980, Loss: 0.0440
# Epoch: 5, Batch: 990, Loss: 0.0463
# Epoch: 5, Batch: 1000, Loss: 0.0498
# Epoch: 5, Batch: 1010, Loss: 0.0445
# Epoch: 5, Batch: 1020, Loss: 0.0399
# Epoch: 5, Batch: 1030, Loss: 0.0406
# Epoch: 5, Batch: 1040, Loss: 0.0455
# Epoch: 5, Batch: 1050, Loss: 0.0366
# Epoch: 5, Batch: 1060, Loss: 0.0317
# Epoch: 5, Batch: 1070, Loss: 0.0329
# Epoch: 5, Batch: 1080, Loss: 0.0410
# Epoch: 5, Batch: 1090, Loss: 0.0411
# Epoch: 5, Batch: 1100, Loss: 0.0403
# Epoch: 5, Batch: 1110, Loss: 0.0370
# Epoch: 5, Batch: 1120, Loss: 0.0436
# Epoch: 5, Batch: 1130, Loss: 0.0389
# Epoch: 5, Batch: 1140, Loss: 0.0392
# Epoch: 5, Batch: 1150, Loss: 0.0392
# Epoch: 5, Batch: 1160, Loss: 0.0371
# Epoch: 5, Batch: 1170, Loss: 0.0412
# Epoch: 5, Batch: 1180, Loss: 0.0330
# Epoch: 5, Batch: 1190, Loss: 0.0426
# Epoch: 5, Batch: 1200, Loss: 0.0434
# Epoch: 5, Batch: 1210, Loss: 0.0394
# Epoch: 5, Batch: 1220, Loss: 0.0299
# Epoch: 5, Batch: 1230, Loss: 0.0390
# Epoch: 5, Batch: 1240, Loss: 0.0402
# Epoch: 5, Train Loss: 0.0416, Val Loss: 0.0398
# Epoch: 6, Batch: 0, Loss: 0.0311
# Epoch: 6, Batch: 10, Loss: 0.0378
# Epoch: 6, Batch: 20, Loss: 0.0353
# Epoch: 6, Batch: 30, Loss: 0.0316
# Epoch: 6, Batch: 40, Loss: 0.0370
# Epoch: 6, Batch: 50, Loss: 0.0305
# Epoch: 6, Batch: 60, Loss: 0.0385
# Epoch: 6, Batch: 70, Loss: 0.0361
# Epoch: 6, Batch: 80, Loss: 0.0317
# Epoch: 6, Batch: 90, Loss: 0.0349
# Epoch: 6, Batch: 100, Loss: 0.0387
# Epoch: 6, Batch: 110, Loss: 0.0292
# Epoch: 6, Batch: 120, Loss: 0.0348
# Epoch: 6, Batch: 130, Loss: 0.0337
# Epoch: 6, Batch: 140, Loss: 0.0350
# Epoch: 6, Batch: 150, Loss: 0.0393
# Epoch: 6, Batch: 160, Loss: 0.0413
# Epoch: 6, Batch: 170, Loss: 0.0416
# Epoch: 6, Batch: 180, Loss: 0.0295
# Epoch: 6, Batch: 190, Loss: 0.0341
# Epoch: 6, Batch: 200, Loss: 0.0316
# Epoch: 6, Batch: 210, Loss: 0.0374
# Epoch: 6, Batch: 220, Loss: 0.0312
# Epoch: 6, Batch: 230, Loss: 0.0342
# Epoch: 6, Batch: 240, Loss: 0.0309
# Epoch: 6, Batch: 250, Loss: 0.0391
# Epoch: 6, Batch: 260, Loss: 0.0362
# Epoch: 6, Batch: 270, Loss: 0.0338
# Epoch: 6, Batch: 280, Loss: 0.0318
# Epoch: 6, Batch: 290, Loss: 0.0419
# Epoch: 6, Batch: 300, Loss: 0.0312
# Epoch: 6, Batch: 310, Loss: 0.0365
# Epoch: 6, Batch: 320, Loss: 0.0270
# Epoch: 6, Batch: 330, Loss: 0.0355
# Epoch: 6, Batch: 340, Loss: 0.0344
# Epoch: 6, Batch: 350, Loss: 0.0284
# Epoch: 6, Batch: 360, Loss: 0.0371
# Epoch: 6, Batch: 370, Loss: 0.0330
# Epoch: 6, Batch: 380, Loss: 0.0286
# Epoch: 6, Batch: 390, Loss: 0.0385
# Epoch: 6, Batch: 400, Loss: 0.0361
# Epoch: 6, Batch: 410, Loss: 0.0338
# Epoch: 6, Batch: 420, Loss: 0.0323
# Epoch: 6, Batch: 430, Loss: 0.0347
# Epoch: 6, Batch: 440, Loss: 0.0345
# Epoch: 6, Batch: 450, Loss: 0.0283
# Epoch: 6, Batch: 460, Loss: 0.0443
# Epoch: 6, Batch: 470, Loss: 0.0313
# Epoch: 6, Batch: 480, Loss: 0.0460
# Epoch: 6, Batch: 490, Loss: 0.0344
# Epoch: 6, Batch: 500, Loss: 0.0279
# Epoch: 6, Batch: 510, Loss: 0.0267
# Epoch: 6, Batch: 520, Loss: 0.0301
# Epoch: 6, Batch: 530, Loss: 0.0338
# Epoch: 6, Batch: 540, Loss: 0.0331
# Epoch: 6, Batch: 550, Loss: 0.0349
# Epoch: 6, Batch: 560, Loss: 0.0343
# Epoch: 6, Batch: 570, Loss: 0.0389
# Epoch: 6, Batch: 580, Loss: 0.0369
# Epoch: 6, Batch: 590, Loss: 0.0389
# Epoch: 6, Batch: 600, Loss: 0.0387
# Epoch: 6, Batch: 610, Loss: 0.0375
# Epoch: 6, Batch: 620, Loss: 0.0294
# Epoch: 6, Batch: 630, Loss: 0.0321
# Epoch: 6, Batch: 640, Loss: 0.0302
# Epoch: 6, Batch: 650, Loss: 0.0356
# Epoch: 6, Batch: 660, Loss: 0.0324
# Epoch: 6, Batch: 670, Loss: 0.0440
# Epoch: 6, Batch: 680, Loss: 0.0299
# Epoch: 6, Batch: 690, Loss: 0.0365
# Epoch: 6, Batch: 700, Loss: 0.0349
# Epoch: 6, Batch: 710, Loss: 0.0387
# Epoch: 6, Batch: 720, Loss: 0.0329
# Epoch: 6, Batch: 730, Loss: 0.0386
# Epoch: 6, Batch: 740, Loss: 0.0323
# Epoch: 6, Batch: 750, Loss: 0.0349
# Epoch: 6, Batch: 760, Loss: 0.0329
# Epoch: 6, Batch: 770, Loss: 0.0272
# Epoch: 6, Batch: 780, Loss: 0.0347
# Epoch: 6, Batch: 790, Loss: 0.0277
# Epoch: 6, Batch: 800, Loss: 0.0326
# Epoch: 6, Batch: 810, Loss: 0.0341
# Epoch: 6, Batch: 820, Loss: 0.0322
# Epoch: 6, Batch: 830, Loss: 0.0295
# Epoch: 6, Batch: 840, Loss: 0.0368
# Epoch: 6, Batch: 850, Loss: 0.0329
# Epoch: 6, Batch: 860, Loss: 0.0406
# Epoch: 6, Batch: 870, Loss: 0.0386
# Epoch: 6, Batch: 880, Loss: 0.0335
# Epoch: 6, Batch: 890, Loss: 0.0277
# Epoch: 6, Batch: 900, Loss: 0.0354
# Epoch: 6, Batch: 910, Loss: 0.0412
# Epoch: 6, Batch: 920, Loss: 0.0357
# Epoch: 6, Batch: 930, Loss: 0.0274
# Epoch: 6, Batch: 940, Loss: 0.0319
# Epoch: 6, Batch: 950, Loss: 0.0349
# Epoch: 6, Batch: 960, Loss: 0.0334
# Epoch: 6, Batch: 970, Loss: 0.0340
# Epoch: 6, Batch: 980, Loss: 0.0306
# Epoch: 6, Batch: 990, Loss: 0.0299
# Epoch: 6, Batch: 1000, Loss: 0.0307
# Epoch: 6, Batch: 1010, Loss: 0.0272
# Epoch: 6, Batch: 1020, Loss: 0.0313
# Epoch: 6, Batch: 1030, Loss: 0.0377
# Epoch: 6, Batch: 1040, Loss: 0.0308
# Epoch: 6, Batch: 1050, Loss: 0.0364
# Epoch: 6, Batch: 1060, Loss: 0.0283
# Epoch: 6, Batch: 1070, Loss: 0.0352
# Epoch: 6, Batch: 1080, Loss: 0.0346
# Epoch: 6, Batch: 1090, Loss: 0.0296
# Epoch: 6, Batch: 1100, Loss: 0.0363
# Epoch: 6, Batch: 1110, Loss: 0.0355
# Epoch: 6, Batch: 1120, Loss: 0.0379
# Epoch: 6, Batch: 1130, Loss: 0.0334
# Epoch: 6, Batch: 1140, Loss: 0.0312
# Epoch: 6, Batch: 1150, Loss: 0.0374
# Epoch: 6, Batch: 1160, Loss: 0.0351
# Epoch: 6, Batch: 1170, Loss: 0.0402
# Epoch: 6, Batch: 1180, Loss: 0.0344
# Epoch: 6, Batch: 1190, Loss: 0.0423
# Epoch: 6, Batch: 1200, Loss: 0.0423
# Epoch: 6, Batch: 1210, Loss: 0.0408
# Epoch: 6, Batch: 1220, Loss: 0.0341
# Epoch: 6, Batch: 1230, Loss: 0.0362
# Epoch: 6, Batch: 1240, Loss: 0.0281
# Epoch: 6, Train Loss: 0.0339, Val Loss: 0.0354
# Epoch: 7, Batch: 0, Loss: 0.0336
# Epoch: 7, Batch: 10, Loss: 0.0328
# Epoch: 7, Batch: 20, Loss: 0.0269
# Epoch: 7, Batch: 30, Loss: 0.0211
# Epoch: 7, Batch: 40, Loss: 0.0259
# Epoch: 7, Batch: 50, Loss: 0.0279
# Epoch: 7, Batch: 60, Loss: 0.0323
# Epoch: 7, Batch: 70, Loss: 0.0234
# Epoch: 7, Batch: 80, Loss: 0.0336
# Epoch: 7, Batch: 90, Loss: 0.0251
# Epoch: 7, Batch: 100, Loss: 0.0265
# Epoch: 7, Batch: 110, Loss: 0.0265
# Epoch: 7, Batch: 120, Loss: 0.0275
# Epoch: 7, Batch: 130, Loss: 0.0390
# Epoch: 7, Batch: 140, Loss: 0.0319
# Epoch: 7, Batch: 150, Loss: 0.0324
# Epoch: 7, Batch: 160, Loss: 0.0227
# Epoch: 7, Batch: 170, Loss: 0.0226
# Epoch: 7, Batch: 180, Loss: 0.0384
# Epoch: 7, Batch: 190, Loss: 0.0309
# Epoch: 7, Batch: 200, Loss: 0.0299
# Epoch: 7, Batch: 210, Loss: 0.0251
# Epoch: 7, Batch: 220, Loss: 0.0384
# Epoch: 7, Batch: 230, Loss: 0.0338
# Epoch: 7, Batch: 240, Loss: 0.0346
# Epoch: 7, Batch: 250, Loss: 0.0287
# Epoch: 7, Batch: 260, Loss: 0.0210
# Epoch: 7, Batch: 270, Loss: 0.0302
# Epoch: 7, Batch: 280, Loss: 0.0228
# Epoch: 7, Batch: 290, Loss: 0.0221
# Epoch: 7, Batch: 300, Loss: 0.0283
# Epoch: 7, Batch: 310, Loss: 0.0246
# Epoch: 7, Batch: 320, Loss: 0.0330
# Epoch: 7, Batch: 330, Loss: 0.0405
# Epoch: 7, Batch: 340, Loss: 0.0291
# Epoch: 7, Batch: 350, Loss: 0.0245
# Epoch: 7, Batch: 360, Loss: 0.0243
# Epoch: 7, Batch: 370, Loss: 0.0258
# Epoch: 7, Batch: 380, Loss: 0.0282
# Epoch: 7, Batch: 390, Loss: 0.0307
# Epoch: 7, Batch: 400, Loss: 0.0267
# Epoch: 7, Batch: 410, Loss: 0.0350
# Epoch: 7, Batch: 420, Loss: 0.0358
# Epoch: 7, Batch: 430, Loss: 0.0317
# Epoch: 7, Batch: 440, Loss: 0.0208
# Epoch: 7, Batch: 450, Loss: 0.0229
# Epoch: 7, Batch: 460, Loss: 0.0266
# Epoch: 7, Batch: 470, Loss: 0.0287
# Epoch: 7, Batch: 480, Loss: 0.0329
# Epoch: 7, Batch: 490, Loss: 0.0261
# Epoch: 7, Batch: 500, Loss: 0.0288
# Epoch: 7, Batch: 510, Loss: 0.0397
# Epoch: 7, Batch: 520, Loss: 0.0250
# Epoch: 7, Batch: 530, Loss: 0.0248
# Epoch: 7, Batch: 540, Loss: 0.0297
# Epoch: 7, Batch: 550, Loss: 0.0345
# Epoch: 7, Batch: 560, Loss: 0.0330
# Epoch: 7, Batch: 570, Loss: 0.0259
# Epoch: 7, Batch: 580, Loss: 0.0312
# Epoch: 7, Batch: 590, Loss: 0.0307
# Epoch: 7, Batch: 600, Loss: 0.0325
# Epoch: 7, Batch: 610, Loss: 0.0284
# Epoch: 7, Batch: 620, Loss: 0.0261
# Epoch: 7, Batch: 630, Loss: 0.0320
# Epoch: 7, Batch: 640, Loss: 0.0322
# Epoch: 7, Batch: 650, Loss: 0.0250
# Epoch: 7, Batch: 660, Loss: 0.0384
# Epoch: 7, Batch: 670, Loss: 0.0296
# Epoch: 7, Batch: 680, Loss: 0.0310
# Epoch: 7, Batch: 690, Loss: 0.0317
# Epoch: 7, Batch: 700, Loss: 0.0303
# Epoch: 7, Batch: 710, Loss: 0.0347
# Epoch: 7, Batch: 720, Loss: 0.0303
# Epoch: 7, Batch: 730, Loss: 0.0240
# Epoch: 7, Batch: 740, Loss: 0.0337
# Epoch: 7, Batch: 750, Loss: 0.0272
# Epoch: 7, Batch: 760, Loss: 0.0264
# Epoch: 7, Batch: 770, Loss: 0.0376
# Epoch: 7, Batch: 780, Loss: 0.0352
# Epoch: 7, Batch: 790, Loss: 0.0281
# Epoch: 7, Batch: 800, Loss: 0.0288
# Epoch: 7, Batch: 810, Loss: 0.0287
# Epoch: 7, Batch: 820, Loss: 0.0231
# Epoch: 7, Batch: 830, Loss: 0.0287
# Epoch: 7, Batch: 840, Loss: 0.0269
# Epoch: 7, Batch: 850, Loss: 0.0332
# Epoch: 7, Batch: 860, Loss: 0.0308
# Epoch: 7, Batch: 870, Loss: 0.0253
# Epoch: 7, Batch: 880, Loss: 0.0290
# Epoch: 7, Batch: 890, Loss: 0.0248
# Epoch: 7, Batch: 900, Loss: 0.0290
# Epoch: 7, Batch: 910, Loss: 0.0338
# Epoch: 7, Batch: 920, Loss: 0.0321
# Epoch: 7, Batch: 930, Loss: 0.0236
# Epoch: 7, Batch: 940, Loss: 0.0240
# Epoch: 7, Batch: 950, Loss: 0.0304
# Epoch: 7, Batch: 960, Loss: 0.0311
# Epoch: 7, Batch: 970, Loss: 0.0248
# Epoch: 7, Batch: 980, Loss: 0.0294
# Epoch: 7, Batch: 990, Loss: 0.0233
# Epoch: 7, Batch: 1000, Loss: 0.0276
# Epoch: 7, Batch: 1010, Loss: 0.0270
# Epoch: 7, Batch: 1020, Loss: 0.0309
# Epoch: 7, Batch: 1030, Loss: 0.0274
# Epoch: 7, Batch: 1040, Loss: 0.0271
# Epoch: 7, Batch: 1050, Loss: 0.0289
# Epoch: 7, Batch: 1060, Loss: 0.0294
# Epoch: 7, Batch: 1070, Loss: 0.0311
# Epoch: 7, Batch: 1080, Loss: 0.0337
# Epoch: 7, Batch: 1090, Loss: 0.0272
# Epoch: 7, Batch: 1100, Loss: 0.0264
# Epoch: 7, Batch: 1110, Loss: 0.0290
# Epoch: 7, Batch: 1120, Loss: 0.0292
# Epoch: 7, Batch: 1130, Loss: 0.0306
# Epoch: 7, Batch: 1140, Loss: 0.0204
# Epoch: 7, Batch: 1150, Loss: 0.0291
# Epoch: 7, Batch: 1160, Loss: 0.0272
# Epoch: 7, Batch: 1170, Loss: 0.0302
# Epoch: 7, Batch: 1180, Loss: 0.0290
# Epoch: 7, Batch: 1190, Loss: 0.0233
# Epoch: 7, Batch: 1200, Loss: 0.0302
# Epoch: 7, Batch: 1210, Loss: 0.0260
# Epoch: 7, Batch: 1220, Loss: 0.0365
# Epoch: 7, Batch: 1230, Loss: 0.0269
# Epoch: 7, Batch: 1240, Loss: 0.0309
# Epoch: 7, Train Loss: 0.0289, Val Loss: 0.0318
# Epoch: 8, Batch: 0, Loss: 0.0261
# Epoch: 8, Batch: 10, Loss: 0.0222
# Epoch: 8, Batch: 20, Loss: 0.0234
# Epoch: 8, Batch: 30, Loss: 0.0210
# Epoch: 8, Batch: 40, Loss: 0.0227
# Epoch: 8, Batch: 50, Loss: 0.0273
# Epoch: 8, Batch: 60, Loss: 0.0274
# Epoch: 8, Batch: 70, Loss: 0.0261
# Epoch: 8, Batch: 80, Loss: 0.0223
# Epoch: 8, Batch: 90, Loss: 0.0216
# Epoch: 8, Batch: 100, Loss: 0.0263
# Epoch: 8, Batch: 110, Loss: 0.0168
# Epoch: 8, Batch: 120, Loss: 0.0335
# Epoch: 8, Batch: 130, Loss: 0.0260
# Epoch: 8, Batch: 140, Loss: 0.0278
# Epoch: 8, Batch: 150, Loss: 0.0224
# Epoch: 8, Batch: 160, Loss: 0.0256
# Epoch: 8, Batch: 170, Loss: 0.0281
# Epoch: 8, Batch: 180, Loss: 0.0330
# Epoch: 8, Batch: 190, Loss: 0.0397
# Epoch: 8, Batch: 200, Loss: 0.0213
# Epoch: 8, Batch: 210, Loss: 0.0211
# Epoch: 8, Batch: 220, Loss: 0.0236
# Epoch: 8, Batch: 230, Loss: 0.0245
# Epoch: 8, Batch: 240, Loss: 0.0242
# Epoch: 8, Batch: 250, Loss: 0.0267
# Epoch: 8, Batch: 260, Loss: 0.0220
# Epoch: 8, Batch: 270, Loss: 0.0181
# Epoch: 8, Batch: 280, Loss: 0.0233
# Epoch: 8, Batch: 290, Loss: 0.0289
# Epoch: 8, Batch: 300, Loss: 0.0302
# Epoch: 8, Batch: 310, Loss: 0.0329
# Epoch: 8, Batch: 320, Loss: 0.0262
# Epoch: 8, Batch: 330, Loss: 0.0213
# Epoch: 8, Batch: 340, Loss: 0.0218
# Epoch: 8, Batch: 350, Loss: 0.0167
# Epoch: 8, Batch: 360, Loss: 0.0265
# Epoch: 8, Batch: 370, Loss: 0.0249
# Epoch: 8, Batch: 380, Loss: 0.0304
# Epoch: 8, Batch: 390, Loss: 0.0286
# Epoch: 8, Batch: 400, Loss: 0.0238
# Epoch: 8, Batch: 410, Loss: 0.0240
# Epoch: 8, Batch: 420, Loss: 0.0243
# Epoch: 8, Batch: 430, Loss: 0.0305
# Epoch: 8, Batch: 440, Loss: 0.0266
# Epoch: 8, Batch: 450, Loss: 0.0297
# Epoch: 8, Batch: 460, Loss: 0.0227
# Epoch: 8, Batch: 470, Loss: 0.0212
# Epoch: 8, Batch: 480, Loss: 0.0314
# Epoch: 8, Batch: 490, Loss: 0.0229
# Epoch: 8, Batch: 500, Loss: 0.0281
# Epoch: 8, Batch: 510, Loss: 0.0201
# Epoch: 8, Batch: 520, Loss: 0.0243
# Epoch: 8, Batch: 530, Loss: 0.0227
# Epoch: 8, Batch: 540, Loss: 0.0260
# Epoch: 8, Batch: 550, Loss: 0.0258
# Epoch: 8, Batch: 560, Loss: 0.0294
# Epoch: 8, Batch: 570, Loss: 0.0277
# Epoch: 8, Batch: 580, Loss: 0.0210
# Epoch: 8, Batch: 590, Loss: 0.0248
# Epoch: 8, Batch: 600, Loss: 0.0279
# Epoch: 8, Batch: 610, Loss: 0.0250
# Epoch: 8, Batch: 620, Loss: 0.0235
# Epoch: 8, Batch: 630, Loss: 0.0329
# Epoch: 8, Batch: 640, Loss: 0.0242
# Epoch: 8, Batch: 650, Loss: 0.0308
# Epoch: 8, Batch: 660, Loss: 0.0238
# Epoch: 8, Batch: 670, Loss: 0.0273
# Epoch: 8, Batch: 680, Loss: 0.0269
# Epoch: 8, Batch: 690, Loss: 0.0249
# Epoch: 8, Batch: 700, Loss: 0.0284
# Epoch: 8, Batch: 710, Loss: 0.0149
# Epoch: 8, Batch: 720, Loss: 0.0248
# Epoch: 8, Batch: 730, Loss: 0.0194
# Epoch: 8, Batch: 740, Loss: 0.0255
# Epoch: 8, Batch: 750, Loss: 0.0226
# Epoch: 8, Batch: 760, Loss: 0.0257
# Epoch: 8, Batch: 770, Loss: 0.0208
# Epoch: 8, Batch: 780, Loss: 0.0279
# Epoch: 8, Batch: 790, Loss: 0.0250
# Epoch: 8, Batch: 800, Loss: 0.0227
# Epoch: 8, Batch: 810, Loss: 0.0324
# Epoch: 8, Batch: 820, Loss: 0.0255
# Epoch: 8, Batch: 830, Loss: 0.0213
# Epoch: 8, Batch: 840, Loss: 0.0233
# Epoch: 8, Batch: 850, Loss: 0.0342
# Epoch: 8, Batch: 860, Loss: 0.0391
# Epoch: 8, Batch: 870, Loss: 0.0287
# Epoch: 8, Batch: 880, Loss: 0.0267
# Epoch: 8, Batch: 890, Loss: 0.0248
# Epoch: 8, Batch: 900, Loss: 0.0261
# Epoch: 8, Batch: 910, Loss: 0.0241
# Epoch: 8, Batch: 920, Loss: 0.0146
# Epoch: 8, Batch: 930, Loss: 0.0204
# Epoch: 8, Batch: 940, Loss: 0.0278
# Epoch: 8, Batch: 950, Loss: 0.0235
# Epoch: 8, Batch: 960, Loss: 0.0339
# Epoch: 8, Batch: 970, Loss: 0.0256
# Epoch: 8, Batch: 980, Loss: 0.0268
# Epoch: 8, Batch: 990, Loss: 0.0272
# Epoch: 8, Batch: 1000, Loss: 0.0279
# Epoch: 8, Batch: 1010, Loss: 0.0257
# Epoch: 8, Batch: 1020, Loss: 0.0227
# Epoch: 8, Batch: 1030, Loss: 0.0287
# Epoch: 8, Batch: 1040, Loss: 0.0199
# Epoch: 8, Batch: 1050, Loss: 0.0252
# Epoch: 8, Batch: 1060, Loss: 0.0193
# Epoch: 8, Batch: 1070, Loss: 0.0254
# Epoch: 8, Batch: 1080, Loss: 0.0229
# Epoch: 8, Batch: 1090, Loss: 0.0235
# Epoch: 8, Batch: 1100, Loss: 0.0268
# Epoch: 8, Batch: 1110, Loss: 0.0315
# Epoch: 8, Batch: 1120, Loss: 0.0376
# Epoch: 8, Batch: 1130, Loss: 0.0261
# Epoch: 8, Batch: 1140, Loss: 0.0375
# Epoch: 8, Batch: 1150, Loss: 0.0323
# Epoch: 8, Batch: 1160, Loss: 0.0221
# Epoch: 8, Batch: 1170, Loss: 0.0202
# Epoch: 8, Batch: 1180, Loss: 0.0197
# Epoch: 8, Batch: 1190, Loss: 0.0262
# Epoch: 8, Batch: 1200, Loss: 0.0165
# Epoch: 8, Batch: 1210, Loss: 0.0228
# Epoch: 8, Batch: 1220, Loss: 0.0201
# Epoch: 8, Batch: 1230, Loss: 0.0188
# Epoch: 8, Batch: 1240, Loss: 0.0264
# Epoch: 8, Train Loss: 0.0257, Val Loss: 0.0302
# Epoch: 9, Batch: 0, Loss: 0.0189
# Epoch: 9, Batch: 10, Loss: 0.0201
# Epoch: 9, Batch: 20, Loss: 0.0148
# Epoch: 9, Batch: 30, Loss: 0.0230
# Epoch: 9, Batch: 40, Loss: 0.0216
# Epoch: 9, Batch: 50, Loss: 0.0239
# Epoch: 9, Batch: 60, Loss: 0.0264
# Epoch: 9, Batch: 70, Loss: 0.0207
# Epoch: 9, Batch: 80, Loss: 0.0236
# Epoch: 9, Batch: 90, Loss: 0.0253
# Epoch: 9, Batch: 100, Loss: 0.0288
# Epoch: 9, Batch: 110, Loss: 0.0248
# Epoch: 9, Batch: 120, Loss: 0.0234
# Epoch: 9, Batch: 130, Loss: 0.0216
# Epoch: 9, Batch: 140, Loss: 0.0253
# Epoch: 9, Batch: 150, Loss: 0.0220
# Epoch: 9, Batch: 160, Loss: 0.0289
# Epoch: 9, Batch: 170, Loss: 0.0180
# Epoch: 9, Batch: 180, Loss: 0.0273
# Epoch: 9, Batch: 190, Loss: 0.0198
# Epoch: 9, Batch: 200, Loss: 0.0219
# Epoch: 9, Batch: 210, Loss: 0.0230
# Epoch: 9, Batch: 220, Loss: 0.0207
# Epoch: 9, Batch: 230, Loss: 0.0307
# Epoch: 9, Batch: 240, Loss: 0.0205
# Epoch: 9, Batch: 250, Loss: 0.0254
# Epoch: 9, Batch: 260, Loss: 0.0297
# Epoch: 9, Batch: 270, Loss: 0.0170
# Epoch: 9, Batch: 280, Loss: 0.0168
# Epoch: 9, Batch: 290, Loss: 0.0239
# Epoch: 9, Batch: 300, Loss: 0.0209
# Epoch: 9, Batch: 310, Loss: 0.0223
# Epoch: 9, Batch: 320, Loss: 0.0275
# Epoch: 9, Batch: 330, Loss: 0.0210
# Epoch: 9, Batch: 340, Loss: 0.0287
# Epoch: 9, Batch: 350, Loss: 0.0197
# Epoch: 9, Batch: 360, Loss: 0.0188
# Epoch: 9, Batch: 370, Loss: 0.0232
# Epoch: 9, Batch: 380, Loss: 0.0270
# Epoch: 9, Batch: 390, Loss: 0.0169
# Epoch: 9, Batch: 400, Loss: 0.0251
# Epoch: 9, Batch: 410, Loss: 0.0217
# Epoch: 9, Batch: 420, Loss: 0.0247
# Epoch: 9, Batch: 430, Loss: 0.0256
# Epoch: 9, Batch: 440, Loss: 0.0251
# Epoch: 9, Batch: 450, Loss: 0.0201
# Epoch: 9, Batch: 460, Loss: 0.0214
# Epoch: 9, Batch: 470, Loss: 0.0208
# Epoch: 9, Batch: 480, Loss: 0.0269
# Epoch: 9, Batch: 490, Loss: 0.0189
# Epoch: 9, Batch: 500, Loss: 0.0213
# Epoch: 9, Batch: 510, Loss: 0.0297
# Epoch: 9, Batch: 520, Loss: 0.0248
# Epoch: 9, Batch: 530, Loss: 0.0274
# Epoch: 9, Batch: 540, Loss: 0.0221
# Epoch: 9, Batch: 550, Loss: 0.0197
# Epoch: 9, Batch: 560, Loss: 0.0257
# Epoch: 9, Batch: 570, Loss: 0.0240
# Epoch: 9, Batch: 580, Loss: 0.0271
# Epoch: 9, Batch: 590, Loss: 0.0217
# Epoch: 9, Batch: 600, Loss: 0.0208
# Epoch: 9, Batch: 610, Loss: 0.0191
# Epoch: 9, Batch: 620, Loss: 0.0216
# Epoch: 9, Batch: 630, Loss: 0.0255
# Epoch: 9, Batch: 640, Loss: 0.0234
# Epoch: 9, Batch: 650, Loss: 0.0193
# Epoch: 9, Batch: 660, Loss: 0.0287
# Epoch: 9, Batch: 670, Loss: 0.0187
# Epoch: 9, Batch: 680, Loss: 0.0233
# Epoch: 9, Batch: 690, Loss: 0.0349
# Epoch: 9, Batch: 700, Loss: 0.0221
# Epoch: 9, Batch: 710, Loss: 0.0217
# Epoch: 9, Batch: 720, Loss: 0.0245
# Epoch: 9, Batch: 730, Loss: 0.0188
# Epoch: 9, Batch: 740, Loss: 0.0246
# Epoch: 9, Batch: 750, Loss: 0.0256
# Epoch: 9, Batch: 760, Loss: 0.0234
# Epoch: 9, Batch: 770, Loss: 0.0206
# Epoch: 9, Batch: 780, Loss: 0.0229
# Epoch: 9, Batch: 790, Loss: 0.0260
# Epoch: 9, Batch: 800, Loss: 0.0236
# Epoch: 9, Batch: 810, Loss: 0.0247
# Epoch: 9, Batch: 820, Loss: 0.0221
# Epoch: 9, Batch: 830, Loss: 0.0279
# Epoch: 9, Batch: 840, Loss: 0.0221
# Epoch: 9, Batch: 850, Loss: 0.0209
# Epoch: 9, Batch: 860, Loss: 0.0221
# Epoch: 9, Batch: 870, Loss: 0.0246
# Epoch: 9, Batch: 880, Loss: 0.0203
# Epoch: 9, Batch: 890, Loss: 0.0250
# Epoch: 9, Batch: 900, Loss: 0.0166
# Epoch: 9, Batch: 910, Loss: 0.0203
# Epoch: 9, Batch: 920, Loss: 0.0268
# Epoch: 9, Batch: 930, Loss: 0.0268
# Epoch: 9, Batch: 940, Loss: 0.0390
# Epoch: 9, Batch: 950, Loss: 0.0249
# Epoch: 9, Batch: 960, Loss: 0.0202
# Epoch: 9, Batch: 970, Loss: 0.0246
# Epoch: 9, Batch: 980, Loss: 0.0230
# Epoch: 9, Batch: 990, Loss: 0.0229
# Epoch: 9, Batch: 1000, Loss: 0.0195
# Epoch: 9, Batch: 1010, Loss: 0.0233
# Epoch: 9, Batch: 1020, Loss: 0.0209
# Epoch: 9, Batch: 1030, Loss: 0.0221
# Epoch: 9, Batch: 1040, Loss: 0.0294
# Epoch: 9, Batch: 1050, Loss: 0.0241
# Epoch: 9, Batch: 1060, Loss: 0.0202
# Epoch: 9, Batch: 1070, Loss: 0.0313
# Epoch: 9, Batch: 1080, Loss: 0.0202
# Epoch: 9, Batch: 1090, Loss: 0.0231
# Epoch: 9, Batch: 1100, Loss: 0.0237
# Epoch: 9, Batch: 1110, Loss: 0.0298
# Epoch: 9, Batch: 1120, Loss: 0.0179
# Epoch: 9, Batch: 1130, Loss: 0.0216
# Epoch: 9, Batch: 1140, Loss: 0.0178
# Epoch: 9, Batch: 1150, Loss: 0.0221
# Epoch: 9, Batch: 1160, Loss: 0.0248
# Epoch: 9, Batch: 1170, Loss: 0.0238
# Epoch: 9, Batch: 1180, Loss: 0.0252
# Epoch: 9, Batch: 1190, Loss: 0.0221
# Epoch: 9, Batch: 1200, Loss: 0.0243
# Epoch: 9, Batch: 1210, Loss: 0.0263
# Epoch: 9, Batch: 1220, Loss: 0.0238
# Epoch: 9, Batch: 1230, Loss: 0.0251
# Epoch: 9, Batch: 1240, Loss: 0.0257
# Epoch: 9, Train Loss: 0.0231, Val Loss: 0.0290
# Epoch: 10, Batch: 0, Loss: 0.0198
# Epoch: 10, Batch: 10, Loss: 0.0174
# Epoch: 10, Batch: 20, Loss: 0.0202
# Epoch: 10, Batch: 30, Loss: 0.0238
# Epoch: 10, Batch: 40, Loss: 0.0202
# Epoch: 10, Batch: 50, Loss: 0.0199
# Epoch: 10, Batch: 60, Loss: 0.0124
# Epoch: 10, Batch: 70, Loss: 0.0158
# Epoch: 10, Batch: 80, Loss: 0.0199
# Epoch: 10, Batch: 90, Loss: 0.0179
# Epoch: 10, Batch: 100, Loss: 0.0249
# Epoch: 10, Batch: 110, Loss: 0.0205
# Epoch: 10, Batch: 120, Loss: 0.0239
# Epoch: 10, Batch: 130, Loss: 0.0192
# Epoch: 10, Batch: 140, Loss: 0.0180
# Epoch: 10, Batch: 150, Loss: 0.0262
# Epoch: 10, Batch: 160, Loss: 0.0232
# Epoch: 10, Batch: 170, Loss: 0.0143
# Epoch: 10, Batch: 180, Loss: 0.0246
# Epoch: 10, Batch: 190, Loss: 0.0168
# Epoch: 10, Batch: 200, Loss: 0.0143
# Epoch: 10, Batch: 210, Loss: 0.0173
# Epoch: 10, Batch: 220, Loss: 0.0152
# Epoch: 10, Batch: 230, Loss: 0.0185
# Epoch: 10, Batch: 240, Loss: 0.0153
# Epoch: 10, Batch: 250, Loss: 0.0219
# Epoch: 10, Batch: 260, Loss: 0.0210
# Epoch: 10, Batch: 270, Loss: 0.0173
# Epoch: 10, Batch: 280, Loss: 0.0249
# Epoch: 10, Batch: 290, Loss: 0.0188
# Epoch: 10, Batch: 300, Loss: 0.0219
# Epoch: 10, Batch: 310, Loss: 0.0204
# Epoch: 10, Batch: 320, Loss: 0.0232
# Epoch: 10, Batch: 330, Loss: 0.0181
# Epoch: 10, Batch: 340, Loss: 0.0202
# Epoch: 10, Batch: 350, Loss: 0.0252
# Epoch: 10, Batch: 360, Loss: 0.0173
# Epoch: 10, Batch: 370, Loss: 0.0219
# Epoch: 10, Batch: 380, Loss: 0.0280
# Epoch: 10, Batch: 390, Loss: 0.0232
# Epoch: 10, Batch: 400, Loss: 0.0163
# Epoch: 10, Batch: 410, Loss: 0.0235
# Epoch: 10, Batch: 420, Loss: 0.0188
# Epoch: 10, Batch: 430, Loss: 0.0231
# Epoch: 10, Batch: 440, Loss: 0.0151
# Epoch: 10, Batch: 450, Loss: 0.0245
# Epoch: 10, Batch: 460, Loss: 0.0194
# Epoch: 10, Batch: 470, Loss: 0.0232
# Epoch: 10, Batch: 480, Loss: 0.0165
# Epoch: 10, Batch: 490, Loss: 0.0198
# Epoch: 10, Batch: 500, Loss: 0.0196
# Epoch: 10, Batch: 510, Loss: 0.0152
# Epoch: 10, Batch: 520, Loss: 0.0170
# Epoch: 10, Batch: 530, Loss: 0.0184
# Epoch: 10, Batch: 540, Loss: 0.0209
# Epoch: 10, Batch: 550, Loss: 0.0161
# Epoch: 10, Batch: 560, Loss: 0.0227
# Epoch: 10, Batch: 570, Loss: 0.0190
# Epoch: 10, Batch: 580, Loss: 0.0179
# Epoch: 10, Batch: 590, Loss: 0.0221
# Epoch: 10, Batch: 600, Loss: 0.0266
# Epoch: 10, Batch: 610, Loss: 0.0199
# Epoch: 10, Batch: 620, Loss: 0.0175
# Epoch: 10, Batch: 630, Loss: 0.0200
# Epoch: 10, Batch: 640, Loss: 0.0223
# Epoch: 10, Batch: 650, Loss: 0.0152
# Epoch: 10, Batch: 660, Loss: 0.0262
# Epoch: 10, Batch: 670, Loss: 0.0165
# Epoch: 10, Batch: 680, Loss: 0.0244
# Epoch: 10, Batch: 690, Loss: 0.0188
# Epoch: 10, Batch: 700, Loss: 0.0175
# Epoch: 10, Batch: 710, Loss: 0.0124
# Epoch: 10, Batch: 720, Loss: 0.0224
# Epoch: 10, Batch: 730, Loss: 0.0146
# Epoch: 10, Batch: 740, Loss: 0.0223
# Epoch: 10, Batch: 750, Loss: 0.0163
# Epoch: 10, Batch: 760, Loss: 0.0290
# Epoch: 10, Batch: 770, Loss: 0.0188
# Epoch: 10, Batch: 780, Loss: 0.0162
# Epoch: 10, Batch: 790, Loss: 0.0200
# Epoch: 10, Batch: 800, Loss: 0.0222
# Epoch: 10, Batch: 810, Loss: 0.0237
# Epoch: 10, Batch: 820, Loss: 0.0183
# Epoch: 10, Batch: 830, Loss: 0.0232
# Epoch: 10, Batch: 840, Loss: 0.0229
# Epoch: 10, Batch: 850, Loss: 0.0217
# Epoch: 10, Batch: 860, Loss: 0.0213
# Epoch: 10, Batch: 870, Loss: 0.0266
# Epoch: 10, Batch: 880, Loss: 0.0168
# Epoch: 10, Batch: 890, Loss: 0.0280
# Epoch: 10, Batch: 900, Loss: 0.0194
# Epoch: 10, Batch: 910, Loss: 0.0233
# Epoch: 10, Batch: 920, Loss: 0.0228
# Epoch: 10, Batch: 930, Loss: 0.0269
# Epoch: 10, Batch: 940, Loss: 0.0235
# Epoch: 10, Batch: 950, Loss: 0.0178
# Epoch: 10, Batch: 960, Loss: 0.0222
# Epoch: 10, Batch: 970, Loss: 0.0219
# Epoch: 10, Batch: 980, Loss: 0.0198
# Epoch: 10, Batch: 990, Loss: 0.0192
# Epoch: 10, Batch: 1000, Loss: 0.0187
# Epoch: 10, Batch: 1010, Loss: 0.0218
# Epoch: 10, Batch: 1020, Loss: 0.0209
# Epoch: 10, Batch: 1030, Loss: 0.0228
# Epoch: 10, Batch: 1040, Loss: 0.0258
# Epoch: 10, Batch: 1050, Loss: 0.0167
# Epoch: 10, Batch: 1060, Loss: 0.0140
# Epoch: 10, Batch: 1070, Loss: 0.0238
# Epoch: 10, Batch: 1080, Loss: 0.0225
# Epoch: 10, Batch: 1090, Loss: 0.0206
# Epoch: 10, Batch: 1100, Loss: 0.0220
# Epoch: 10, Batch: 1110, Loss: 0.0217
# Epoch: 10, Batch: 1120, Loss: 0.0184
# Epoch: 10, Batch: 1130, Loss: 0.0264
# Epoch: 10, Batch: 1140, Loss: 0.0209
# Epoch: 10, Batch: 1150, Loss: 0.0199
# Epoch: 10, Batch: 1160, Loss: 0.0238
# Epoch: 10, Batch: 1170, Loss: 0.0149
# Epoch: 10, Batch: 1180, Loss: 0.0214
# Epoch: 10, Batch: 1190, Loss: 0.0165
# Epoch: 10, Batch: 1200, Loss: 0.0189
# Epoch: 10, Batch: 1210, Loss: 0.0187
# Epoch: 10, Batch: 1220, Loss: 0.0225
# Epoch: 10, Batch: 1230, Loss: 0.0228
# Epoch: 10, Batch: 1240, Loss: 0.0213
# Epoch: 10, Train Loss: 0.0211, Val Loss: 0.0281
# Epoch: 11, Batch: 0, Loss: 0.0155
# Epoch: 11, Batch: 10, Loss: 0.0173
# Epoch: 11, Batch: 20, Loss: 0.0217
# Epoch: 11, Batch: 30, Loss: 0.0183
# Epoch: 11, Batch: 40, Loss: 0.0149
# Epoch: 11, Batch: 50, Loss: 0.0146
# Epoch: 11, Batch: 60, Loss: 0.0212
# Epoch: 11, Batch: 70, Loss: 0.0187
# Epoch: 11, Batch: 80, Loss: 0.0203
# Epoch: 11, Batch: 90, Loss: 0.0190
# Epoch: 11, Batch: 100, Loss: 0.0143
# Epoch: 11, Batch: 110, Loss: 0.0200
# Epoch: 11, Batch: 120, Loss: 0.0132
# Epoch: 11, Batch: 130, Loss: 0.0179
# Epoch: 11, Batch: 140, Loss: 0.0184
# Epoch: 11, Batch: 150, Loss: 0.0223
# Epoch: 11, Batch: 160, Loss: 0.0167
# Epoch: 11, Batch: 170, Loss: 0.0215
# Epoch: 11, Batch: 180, Loss: 0.0175
# Epoch: 11, Batch: 190, Loss: 0.0170
# Epoch: 11, Batch: 200, Loss: 0.0295
# Epoch: 11, Batch: 210, Loss: 0.0182
# Epoch: 11, Batch: 220, Loss: 0.0139
# Epoch: 11, Batch: 230, Loss: 0.0201
# Epoch: 11, Batch: 240, Loss: 0.0128
# Epoch: 11, Batch: 250, Loss: 0.0174
# Epoch: 11, Batch: 260, Loss: 0.0207
# Epoch: 11, Batch: 270, Loss: 0.0120
# Epoch: 11, Batch: 280, Loss: 0.0186
# Epoch: 11, Batch: 290, Loss: 0.0137
# Epoch: 11, Batch: 300, Loss: 0.0191
# Epoch: 11, Batch: 310, Loss: 0.0159
# Epoch: 11, Batch: 320, Loss: 0.0156
# Epoch: 11, Batch: 330, Loss: 0.0187
# Epoch: 11, Batch: 340, Loss: 0.0167
# Epoch: 11, Batch: 350, Loss: 0.0121
# Epoch: 11, Batch: 360, Loss: 0.0222
# Epoch: 11, Batch: 370, Loss: 0.0210
# Epoch: 11, Batch: 380, Loss: 0.0134
# Epoch: 11, Batch: 390, Loss: 0.0176
# Epoch: 11, Batch: 400, Loss: 0.0233
# Epoch: 11, Batch: 410, Loss: 0.0180
# Epoch: 11, Batch: 420, Loss: 0.0183
# Epoch: 11, Batch: 430, Loss: 0.0235
# Epoch: 11, Batch: 440, Loss: 0.0147
# Epoch: 11, Batch: 450, Loss: 0.0179
# Epoch: 11, Batch: 460, Loss: 0.0224
# Epoch: 11, Batch: 470, Loss: 0.0219
# Epoch: 11, Batch: 480, Loss: 0.0185
# Epoch: 11, Batch: 490, Loss: 0.0201
# Epoch: 11, Batch: 500, Loss: 0.0172
# Epoch: 11, Batch: 510, Loss: 0.0287
# Epoch: 11, Batch: 520, Loss: 0.0190
# Epoch: 11, Batch: 530, Loss: 0.0184
# Epoch: 11, Batch: 540, Loss: 0.0167
# Epoch: 11, Batch: 550, Loss: 0.0203
# Epoch: 11, Batch: 560, Loss: 0.0210
# Epoch: 11, Batch: 570, Loss: 0.0182
# Epoch: 11, Batch: 580, Loss: 0.0205
# Epoch: 11, Batch: 590, Loss: 0.0165
# Epoch: 11, Batch: 600, Loss: 0.0194
# Epoch: 11, Batch: 610, Loss: 0.0145
# Epoch: 11, Batch: 620, Loss: 0.0242
# Epoch: 11, Batch: 630, Loss: 0.0240
# Epoch: 11, Batch: 640, Loss: 0.0209
# Epoch: 11, Batch: 650, Loss: 0.0229
# Epoch: 11, Batch: 660, Loss: 0.0189
# Epoch: 11, Batch: 670, Loss: 0.0213
# Epoch: 11, Batch: 680, Loss: 0.0185
# Epoch: 11, Batch: 690, Loss: 0.0186
# Epoch: 11, Batch: 700, Loss: 0.0188
# Epoch: 11, Batch: 710, Loss: 0.0162
# Epoch: 11, Batch: 720, Loss: 0.0212
# Epoch: 11, Batch: 730, Loss: 0.0211
# Epoch: 11, Batch: 740, Loss: 0.0176
# Epoch: 11, Batch: 750, Loss: 0.0135
# Epoch: 11, Batch: 760, Loss: 0.0184
# Epoch: 11, Batch: 770, Loss: 0.0162
# Epoch: 11, Batch: 780, Loss: 0.0186
# Epoch: 11, Batch: 790, Loss: 0.0203
# Epoch: 11, Batch: 800, Loss: 0.0248
# Epoch: 11, Batch: 810, Loss: 0.0195
# Epoch: 11, Batch: 820, Loss: 0.0211
# Epoch: 11, Batch: 830, Loss: 0.0174
# Epoch: 11, Batch: 840, Loss: 0.0166
# Epoch: 11, Batch: 850, Loss: 0.0204
# Epoch: 11, Batch: 860, Loss: 0.0228
# Epoch: 11, Batch: 870, Loss: 0.0277
# Epoch: 11, Batch: 880, Loss: 0.0174
# Epoch: 11, Batch: 890, Loss: 0.0240
# Epoch: 11, Batch: 900, Loss: 0.0136
# Epoch: 11, Batch: 910, Loss: 0.0206
# Epoch: 11, Batch: 920, Loss: 0.0170
# Epoch: 11, Batch: 930, Loss: 0.0161
# Epoch: 11, Batch: 940, Loss: 0.0163
# Epoch: 11, Batch: 950, Loss: 0.0178
# Epoch: 11, Batch: 960, Loss: 0.0194
# ...
# Epoch: 27, Batch: 640, Loss: 0.0074
# Epoch: 27, Batch: 650, Loss: 0.0085
# Epoch: 27, Batch: 660, Loss: 0.0086
# Epoch: 27, Batch: 670, Loss: 0.0107
# Epoch: 27, Batch: 680, Loss: 0.0084
# Epoch: 27, Batch: 690, Loss: 0.0073
# Epoch: 27, Batch: 700, Loss: 0.0053
# Epoch: 27, Batch: 710, Loss: 0.0054
# Epoch: 27, Batch: 720, Loss: 0.0050
# Epoch: 27, Batch: 730, Loss: 0.0059
# Epoch: 27, Batch: 740, Loss: 0.0076
# Epoch: 27, Batch: 750, Loss: 0.0080
# Epoch: 27, Batch: 760, Loss: 0.0077
# Epoch: 27, Batch: 770, Loss: 0.0094
# Epoch: 27, Batch: 780, Loss: 0.0066
# Epoch: 27, Batch: 790, Loss: 0.0059
# Epoch: 27, Batch: 800, Loss: 0.0125
# Epoch: 27, Batch: 810, Loss: 0.0097
# Epoch: 27, Batch: 820, Loss: 0.0051
# Epoch: 27, Batch: 830, Loss: 0.0085
# Epoch: 27, Batch: 840, Loss: 0.0093
# Epoch: 27, Batch: 850, Loss: 0.0114
# Epoch: 27, Batch: 860, Loss: 0.0084
# Epoch: 27, Batch: 870, Loss: 0.0067
# Epoch: 27, Batch: 880, Loss: 0.0042
# Epoch: 27, Batch: 890, Loss: 0.0067
# Epoch: 27, Batch: 900, Loss: 0.0057
# Epoch: 27, Batch: 910, Loss: 0.0074
# Epoch: 27, Batch: 920, Loss: 0.0097
# Epoch: 27, Batch: 930, Loss: 0.0070
# Epoch: 27, Batch: 940, Loss: 0.0057
# Epoch: 27, Batch: 950, Loss: 0.0067
# Epoch: 27, Batch: 960, Loss: 0.0087
# Epoch: 27, Batch: 970, Loss: 0.0049
# Epoch: 27, Batch: 980, Loss: 0.0062
# Epoch: 27, Batch: 990, Loss: 0.0072
# Epoch: 27, Batch: 1000, Loss: 0.0095
# Epoch: 27, Batch: 1010, Loss: 0.0054
# Epoch: 27, Batch: 1020, Loss: 0.0066
# Epoch: 27, Batch: 1030, Loss: 0.0055
# Epoch: 27, Batch: 1040, Loss: 0.0056
# Epoch: 27, Batch: 1050, Loss: 0.0056
# Epoch: 27, Batch: 1060, Loss: 0.0065
# Epoch: 27, Batch: 1070, Loss: 0.0054
# Epoch: 27, Batch: 1080, Loss: 0.0152
# Epoch: 27, Batch: 1090, Loss: 0.0089
# Epoch: 27, Batch: 1100, Loss: 0.0120
# Epoch: 27, Batch: 1110, Loss: 0.0063
# Epoch: 27, Batch: 1120, Loss: 0.0057
# Epoch: 27, Batch: 1130, Loss: 0.0114
# Epoch: 27, Batch: 1140, Loss: 0.0069
# Epoch: 27, Batch: 1150, Loss: 0.0059
# Epoch: 27, Batch: 1160, Loss: 0.0088
# Epoch: 27, Batch: 1170, Loss: 0.0068
# Epoch: 27, Batch: 1180, Loss: 0.0059
# Epoch: 27, Batch: 1190, Loss: 0.0060
# Epoch: 27, Batch: 1200, Loss: 0.0061
# Epoch: 27, Batch: 1210, Loss: 0.0070
# Epoch: 27, Batch: 1220, Loss: 0.0095
# Epoch: 27, Batch: 1230, Loss: 0.0089
# Epoch: 27, Batch: 1240, Loss: 0.0055
# Epoch: 27, Train Loss: 0.0072, Val Loss: 0.0329
# Epoch: 28, Batch: 0, Loss: 0.0040
# Epoch: 28, Batch: 10, Loss: 0.0058
# Epoch: 28, Batch: 20, Loss: 0.0049
# Epoch: 28, Batch: 30, Loss: 0.0036
# Epoch: 28, Batch: 40, Loss: 0.0053
# Epoch: 28, Batch: 50, Loss: 0.0052
# Epoch: 28, Batch: 60, Loss: 0.0062
# Epoch: 28, Batch: 70, Loss: 0.0057
# Epoch: 28, Batch: 80, Loss: 0.0076
# Epoch: 28, Batch: 90, Loss: 0.0084
# Epoch: 28, Batch: 100, Loss: 0.0040
# Epoch: 28, Batch: 110, Loss: 0.0047
# Epoch: 28, Batch: 120, Loss: 0.0049
# Epoch: 28, Batch: 130, Loss: 0.0096
# Epoch: 28, Batch: 140, Loss: 0.0051
# Epoch: 28, Batch: 150, Loss: 0.0052
# Epoch: 28, Batch: 160, Loss: 0.0066
# Epoch: 28, Batch: 170, Loss: 0.0054
# Epoch: 28, Batch: 180, Loss: 0.0099
# Epoch: 28, Batch: 190, Loss: 0.0065
# Epoch: 28, Batch: 200, Loss: 0.0053
# Epoch: 28, Batch: 210, Loss: 0.0042
# Epoch: 28, Batch: 220, Loss: 0.0078
# Epoch: 28, Batch: 230, Loss: 0.0075
# Epoch: 28, Batch: 240, Loss: 0.0066
# Epoch: 28, Batch: 250, Loss: 0.0076
# Epoch: 28, Batch: 260, Loss: 0.0108
# Epoch: 28, Batch: 270, Loss: 0.0041
# Epoch: 28, Batch: 280, Loss: 0.0048
# Epoch: 28, Batch: 290, Loss: 0.0077
# Epoch: 28, Batch: 300, Loss: 0.0043
# Epoch: 28, Batch: 310, Loss: 0.0049
# Epoch: 28, Batch: 320, Loss: 0.0053
# Epoch: 28, Batch: 330, Loss: 0.0045
# Epoch: 28, Batch: 340, Loss: 0.0040
# Epoch: 28, Batch: 350, Loss: 0.0058
# Epoch: 28, Batch: 360, Loss: 0.0074
# Epoch: 28, Batch: 370, Loss: 0.0105
# Epoch: 28, Batch: 380, Loss: 0.0102
# Epoch: 28, Batch: 390, Loss: 0.0086
# Epoch: 28, Batch: 400, Loss: 0.0061
# Epoch: 28, Batch: 410, Loss: 0.0066
# Epoch: 28, Batch: 420, Loss: 0.0037
# Epoch: 28, Batch: 430, Loss: 0.0056
# Epoch: 28, Batch: 440, Loss: 0.0051
# Epoch: 28, Batch: 450, Loss: 0.0065
# Epoch: 28, Batch: 460, Loss: 0.0094
# Epoch: 28, Batch: 470, Loss: 0.0041
# Epoch: 28, Batch: 480, Loss: 0.0078
# Epoch: 28, Batch: 490, Loss: 0.0065
# Epoch: 28, Batch: 500, Loss: 0.0037
# Epoch: 28, Batch: 510, Loss: 0.0046
# Epoch: 28, Batch: 520, Loss: 0.0065
# Epoch: 28, Batch: 530, Loss: 0.0039
# Epoch: 28, Batch: 540, Loss: 0.0072
# Epoch: 28, Batch: 550, Loss: 0.0056
# Epoch: 28, Batch: 560, Loss: 0.0091
# Epoch: 28, Batch: 570, Loss: 0.0079
# Epoch: 28, Batch: 580, Loss: 0.0071
# Epoch: 28, Batch: 590, Loss: 0.0085
# Epoch: 28, Batch: 600, Loss: 0.0069
# Epoch: 28, Batch: 610, Loss: 0.0078
# Epoch: 28, Batch: 620, Loss: 0.0099
# Epoch: 28, Batch: 630, Loss: 0.0095
# Epoch: 28, Batch: 640, Loss: 0.0086
# Epoch: 28, Batch: 650, Loss: 0.0056
# Epoch: 28, Batch: 660, Loss: 0.0051
# Epoch: 28, Batch: 670, Loss: 0.0051
# Epoch: 28, Batch: 680, Loss: 0.0070
# Epoch: 28, Batch: 690, Loss: 0.0077
# Epoch: 28, Batch: 700, Loss: 0.0047
# Epoch: 28, Batch: 710, Loss: 0.0092
# Epoch: 28, Batch: 720, Loss: 0.0060
# Epoch: 28, Batch: 730, Loss: 0.0062
# Epoch: 28, Batch: 740, Loss: 0.0111
# Epoch: 28, Batch: 750, Loss: 0.0088
# Epoch: 28, Batch: 760, Loss: 0.0093
# Epoch: 28, Batch: 770, Loss: 0.0077
# Epoch: 28, Batch: 780, Loss: 0.0132
# Epoch: 28, Batch: 790, Loss: 0.0119
# Epoch: 28, Batch: 800, Loss: 0.0068
# Epoch: 28, Batch: 810, Loss: 0.0085
# Epoch: 28, Batch: 820, Loss: 0.0081
# Epoch: 28, Batch: 830, Loss: 0.0062
# Epoch: 28, Batch: 840, Loss: 0.0079
# Epoch: 28, Batch: 850, Loss: 0.0108
# Epoch: 28, Batch: 860, Loss: 0.0115
# Epoch: 28, Batch: 870, Loss: 0.0070
# Epoch: 28, Batch: 880, Loss: 0.0066
# Epoch: 28, Batch: 890, Loss: 0.0085
# Epoch: 28, Batch: 900, Loss: 0.0070
# Epoch: 28, Batch: 910, Loss: 0.0060
# Epoch: 28, Batch: 920, Loss: 0.0058
# Epoch: 28, Batch: 930, Loss: 0.0049
# Epoch: 28, Batch: 940, Loss: 0.0131
# Epoch: 28, Batch: 950, Loss: 0.0054
# Epoch: 28, Batch: 960, Loss: 0.0073
# Epoch: 28, Batch: 970, Loss: 0.0111
# Epoch: 28, Batch: 980, Loss: 0.0076
# Epoch: 28, Batch: 990, Loss: 0.0084
# Epoch: 28, Batch: 1000, Loss: 0.0062
# Epoch: 28, Batch: 1010, Loss: 0.0045
# Epoch: 28, Batch: 1020, Loss: 0.0063
# Epoch: 28, Batch: 1030, Loss: 0.0060
# Epoch: 28, Batch: 1040, Loss: 0.0045
# Epoch: 28, Batch: 1050, Loss: 0.0054
# Epoch: 28, Batch: 1060, Loss: 0.0065
# Epoch: 28, Batch: 1070, Loss: 0.0093
# Epoch: 28, Batch: 1080, Loss: 0.0053
# Epoch: 28, Batch: 1090, Loss: 0.0078
# Epoch: 28, Batch: 1100, Loss: 0.0078
# Epoch: 28, Batch: 1110, Loss: 0.0061
# Epoch: 28, Batch: 1120, Loss: 0.0121
# Epoch: 28, Batch: 1130, Loss: 0.0048
# Epoch: 28, Batch: 1140, Loss: 0.0042
# Epoch: 28, Batch: 1150, Loss: 0.0087
# Epoch: 28, Batch: 1160, Loss: 0.0091
# Epoch: 28, Batch: 1170, Loss: 0.0070
# Epoch: 28, Batch: 1180, Loss: 0.0076
# Epoch: 28, Batch: 1190, Loss: 0.0063
# Epoch: 28, Batch: 1200, Loss: 0.0071
# Epoch: 28, Batch: 1210, Loss: 0.0056
# Epoch: 28, Batch: 1220, Loss: 0.0040
# Epoch: 28, Batch: 1230, Loss: 0.0109
# Epoch: 28, Batch: 1240, Loss: 0.0073
# Epoch: 28, Train Loss: 0.0069, Val Loss: 0.0349
# Epoch: 29, Batch: 0, Loss: 0.0074
# Epoch: 29, Batch: 10, Loss: 0.0049
# Epoch: 29, Batch: 20, Loss: 0.0066
# Epoch: 29, Batch: 30, Loss: 0.0044
# Epoch: 29, Batch: 40, Loss: 0.0063
# Epoch: 29, Batch: 50, Loss: 0.0032
# Epoch: 29, Batch: 60, Loss: 0.0049
# Epoch: 29, Batch: 70, Loss: 0.0051
# Epoch: 29, Batch: 80, Loss: 0.0055
# Epoch: 29, Batch: 90, Loss: 0.0054
# Epoch: 29, Batch: 100, Loss: 0.0117
# Epoch: 29, Batch: 110, Loss: 0.0058
# Epoch: 29, Batch: 120, Loss: 0.0046
# Epoch: 29, Batch: 130, Loss: 0.0067
# Epoch: 29, Batch: 140, Loss: 0.0035
# Epoch: 29, Batch: 150, Loss: 0.0071
# Epoch: 29, Batch: 160, Loss: 0.0066
# Epoch: 29, Batch: 170, Loss: 0.0069
# Epoch: 29, Batch: 180, Loss: 0.0067
# Epoch: 29, Batch: 190, Loss: 0.0098
# Epoch: 29, Batch: 200, Loss: 0.0058
# Epoch: 29, Batch: 210, Loss: 0.0032
# Epoch: 29, Batch: 220, Loss: 0.0036
# Epoch: 29, Batch: 230, Loss: 0.0032
# Epoch: 29, Batch: 240, Loss: 0.0062
# Epoch: 29, Batch: 250, Loss: 0.0056
# Epoch: 29, Batch: 260, Loss: 0.0082
# Epoch: 29, Batch: 270, Loss: 0.0039
# Epoch: 29, Batch: 280, Loss: 0.0067
# Epoch: 29, Batch: 290, Loss: 0.0046
# Epoch: 29, Batch: 300, Loss: 0.0058
# Epoch: 29, Batch: 310, Loss: 0.0051
# Epoch: 29, Batch: 320, Loss: 0.0094
# Epoch: 29, Batch: 330, Loss: 0.0088
# Epoch: 29, Batch: 340, Loss: 0.0084
# Epoch: 29, Batch: 350, Loss: 0.0112
# Epoch: 29, Batch: 360, Loss: 0.0057
# Epoch: 29, Batch: 370, Loss: 0.0050
# Epoch: 29, Batch: 380, Loss: 0.0062
# Epoch: 29, Batch: 390, Loss: 0.0059
# Epoch: 29, Batch: 400, Loss: 0.0054
# Epoch: 29, Batch: 410, Loss: 0.0038
# Epoch: 29, Batch: 420, Loss: 0.0077
# Epoch: 29, Batch: 430, Loss: 0.0083
# Epoch: 29, Batch: 440, Loss: 0.0045
# Epoch: 29, Batch: 450, Loss: 0.0043
# Epoch: 29, Batch: 460, Loss: 0.0058
# Epoch: 29, Batch: 470, Loss: 0.0065
# Epoch: 29, Batch: 480, Loss: 0.0078
# Epoch: 29, Batch: 490, Loss: 0.0079
# Epoch: 29, Batch: 500, Loss: 0.0060
# Epoch: 29, Batch: 510, Loss: 0.0055
# Epoch: 29, Batch: 520, Loss: 0.0069
# Epoch: 29, Batch: 530, Loss: 0.0031
# Epoch: 29, Batch: 540, Loss: 0.0064
# Epoch: 29, Batch: 550, Loss: 0.0083
# Epoch: 29, Batch: 560, Loss: 0.0077
# Epoch: 29, Batch: 570, Loss: 0.0081
# Epoch: 29, Batch: 580, Loss: 0.0053
# Epoch: 29, Batch: 590, Loss: 0.0055
# Epoch: 29, Batch: 600, Loss: 0.0038
# Epoch: 29, Batch: 610, Loss: 0.0076
# Epoch: 29, Batch: 620, Loss: 0.0082
# Epoch: 29, Batch: 630, Loss: 0.0100
# Epoch: 29, Batch: 640, Loss: 0.0049
# Epoch: 29, Batch: 650, Loss: 0.0047
# Epoch: 29, Batch: 660, Loss: 0.0064
# Epoch: 29, Batch: 670, Loss: 0.0103
# Epoch: 29, Batch: 680, Loss: 0.0088
# Epoch: 29, Batch: 690, Loss: 0.0064
# Epoch: 29, Batch: 700, Loss: 0.0093
# Epoch: 29, Batch: 710, Loss: 0.0067
# Epoch: 29, Batch: 720, Loss: 0.0094
# Epoch: 29, Batch: 730, Loss: 0.0091
# Epoch: 29, Batch: 740, Loss: 0.0100
# Epoch: 29, Batch: 750, Loss: 0.0080
# Epoch: 29, Batch: 760, Loss: 0.0102
# Epoch: 29, Batch: 770, Loss: 0.0071
# Epoch: 29, Batch: 780, Loss: 0.0075
# Epoch: 29, Batch: 790, Loss: 0.0110
# Epoch: 29, Batch: 800, Loss: 0.0109
# Epoch: 29, Batch: 810, Loss: 0.0056
# Epoch: 29, Batch: 820, Loss: 0.0066
# Epoch: 29, Batch: 830, Loss: 0.0056
# Epoch: 29, Batch: 840, Loss: 0.0053
# Epoch: 29, Batch: 850, Loss: 0.0104
# Epoch: 29, Batch: 860, Loss: 0.0068
# Epoch: 29, Batch: 870, Loss: 0.0063
# Epoch: 29, Batch: 880, Loss: 0.0059
# Epoch: 29, Batch: 890, Loss: 0.0065
# Epoch: 29, Batch: 900, Loss: 0.0064
# Epoch: 29, Batch: 910, Loss: 0.0080
# Epoch: 29, Batch: 920, Loss: 0.0092
# Epoch: 29, Batch: 930, Loss: 0.0085
# Epoch: 29, Batch: 940, Loss: 0.0067
# Epoch: 29, Batch: 950, Loss: 0.0090
# Epoch: 29, Batch: 960, Loss: 0.0069
# Epoch: 29, Batch: 970, Loss: 0.0085
# Epoch: 29, Batch: 980, Loss: 0.0064
# Epoch: 29, Batch: 990, Loss: 0.0079
# Epoch: 29, Batch: 1000, Loss: 0.0059
# Epoch: 29, Batch: 1010, Loss: 0.0063
# Epoch: 29, Batch: 1020, Loss: 0.0087
# Epoch: 29, Batch: 1030, Loss: 0.0077
# Epoch: 29, Batch: 1040, Loss: 0.0133
# Epoch: 29, Batch: 1050, Loss: 0.0070
# Epoch: 29, Batch: 1060, Loss: 0.0048
# Epoch: 29, Batch: 1070, Loss: 0.0057
# Epoch: 29, Batch: 1080, Loss: 0.0045
# Epoch: 29, Batch: 1090, Loss: 0.0075
# Epoch: 29, Batch: 1100, Loss: 0.0070
# Epoch: 29, Batch: 1110, Loss: 0.0100
# Epoch: 29, Batch: 1120, Loss: 0.0088
# Epoch: 29, Batch: 1130, Loss: 0.0134
# Epoch: 29, Batch: 1140, Loss: 0.0087
# Epoch: 29, Batch: 1150, Loss: 0.0061
# Epoch: 29, Batch: 1160, Loss: 0.0072
# Epoch: 29, Batch: 1170, Loss: 0.0064
# Epoch: 29, Batch: 1180, Loss: 0.0075
# Epoch: 29, Batch: 1190, Loss: 0.0068
# Epoch: 29, Batch: 1200, Loss: 0.0086
# Epoch: 29, Batch: 1210, Loss: 0.0078
# Epoch: 29, Batch: 1220, Loss: 0.0062
# Epoch: 29, Batch: 1230, Loss: 0.0100
# Epoch: 29, Batch: 1240, Loss: 0.0050
# Epoch: 29, Train Loss: 0.0067, Val Loss: 0.0327
# Epoch: 30, Batch: 0, Loss: 0.0044
# Epoch: 30, Batch: 10, Loss: 0.0040
# Epoch: 30, Batch: 20, Loss: 0.0071
# Epoch: 30, Batch: 30, Loss: 0.0013
# Epoch: 30, Batch: 40, Loss: 0.0059
# Epoch: 30, Batch: 50, Loss: 0.0043
# Epoch: 30, Batch: 60, Loss: 0.0062
# Epoch: 30, Batch: 70, Loss: 0.0055
# Epoch: 30, Batch: 80, Loss: 0.0065
# Epoch: 30, Batch: 90, Loss: 0.0074
# Epoch: 30, Batch: 100, Loss: 0.0056
# Epoch: 30, Batch: 110, Loss: 0.0056
# Epoch: 30, Batch: 120, Loss: 0.0069
# Epoch: 30, Batch: 130, Loss: 0.0082
# Epoch: 30, Batch: 140, Loss: 0.0049
# Epoch: 30, Batch: 150, Loss: 0.0084
# Epoch: 30, Batch: 160, Loss: 0.0072
# Epoch: 30, Batch: 170, Loss: 0.0086
# Epoch: 30, Batch: 180, Loss: 0.0045
# Epoch: 30, Batch: 190, Loss: 0.0055
# Epoch: 30, Batch: 200, Loss: 0.0046
# Epoch: 30, Batch: 210, Loss: 0.0051
# Epoch: 30, Batch: 220, Loss: 0.0072
# Epoch: 30, Batch: 230, Loss: 0.0062
# Epoch: 30, Batch: 240, Loss: 0.0064
# Epoch: 30, Batch: 250, Loss: 0.0039
# Epoch: 30, Batch: 260, Loss: 0.0040
# Epoch: 30, Batch: 270, Loss: 0.0085
# Epoch: 30, Batch: 280, Loss: 0.0063
# Epoch: 30, Batch: 290, Loss: 0.0045
# Epoch: 30, Batch: 300, Loss: 0.0038
# Epoch: 30, Batch: 310, Loss: 0.0042
# Epoch: 30, Batch: 320, Loss: 0.0061
# Epoch: 30, Batch: 330, Loss: 0.0046
# Epoch: 30, Batch: 340, Loss: 0.0043
# Epoch: 30, Batch: 350, Loss: 0.0056
# Epoch: 30, Batch: 360, Loss: 0.0059
# Epoch: 30, Batch: 370, Loss: 0.0060
# Epoch: 30, Batch: 380, Loss: 0.0062
# Epoch: 30, Batch: 390, Loss: 0.0081
# Epoch: 30, Batch: 400, Loss: 0.0063
# Epoch: 30, Batch: 410, Loss: 0.0056
# Epoch: 30, Batch: 420, Loss: 0.0038
# Epoch: 30, Batch: 430, Loss: 0.0058
# Epoch: 30, Batch: 440, Loss: 0.0055
# Epoch: 30, Batch: 450, Loss: 0.0056
# Epoch: 30, Batch: 460, Loss: 0.0046
# Epoch: 30, Batch: 470, Loss: 0.0077
# Epoch: 30, Batch: 480, Loss: 0.0049
# Epoch: 30, Batch: 490, Loss: 0.0048
# Epoch: 30, Batch: 500, Loss: 0.0063
# Epoch: 30, Batch: 510, Loss: 0.0076
# Epoch: 30, Batch: 520, Loss: 0.0058
# Epoch: 30, Batch: 530, Loss: 0.0033
# Epoch: 30, Batch: 540, Loss: 0.0054
# Epoch: 30, Batch: 550, Loss: 0.0252
# Epoch: 30, Batch: 560, Loss: 0.0060
# Epoch: 30, Batch: 570, Loss: 0.0070
# Epoch: 30, Batch: 580, Loss: 0.0055
# Epoch: 30, Batch: 590, Loss: 0.0060
# Epoch: 30, Batch: 600, Loss: 0.0073
# Epoch: 30, Batch: 610, Loss: 0.0071
# Epoch: 30, Batch: 620, Loss: 0.0080
# Epoch: 30, Batch: 630, Loss: 0.0039
# Epoch: 30, Batch: 640, Loss: 0.0065
# Epoch: 30, Batch: 650, Loss: 0.0075
# Epoch: 30, Batch: 660, Loss: 0.0066
# Epoch: 30, Batch: 670, Loss: 0.0045
# Epoch: 30, Batch: 680, Loss: 0.0042
# Epoch: 30, Batch: 690, Loss: 0.0063
# Epoch: 30, Batch: 700, Loss: 0.0077
# Epoch: 30, Batch: 710, Loss: 0.0041
# Epoch: 30, Batch: 720, Loss: 0.0038
# Epoch: 30, Batch: 730, Loss: 0.0112
# Epoch: 30, Batch: 740, Loss: 0.0074
# Epoch: 30, Batch: 750, Loss: 0.0090
# Epoch: 30, Batch: 760, Loss: 0.0064
# Epoch: 30, Batch: 770, Loss: 0.0079
# Epoch: 30, Batch: 780, Loss: 0.0083
# Epoch: 30, Batch: 790, Loss: 0.0099
# Epoch: 30, Batch: 800, Loss: 0.0038
# Epoch: 30, Batch: 810, Loss: 0.0108
# Epoch: 30, Batch: 820, Loss: 0.0100
# Epoch: 30, Batch: 830, Loss: 0.0074
# Epoch: 30, Batch: 840, Loss: 0.0109
# Epoch: 30, Batch: 850, Loss: 0.0054
# Epoch: 30, Batch: 860, Loss: 0.0047
# Epoch: 30, Batch: 870, Loss: 0.0054
# Epoch: 30, Batch: 880, Loss: 0.0058
# Epoch: 30, Batch: 890, Loss: 0.0036
# Epoch: 30, Batch: 900, Loss: 0.0054
# Epoch: 30, Batch: 910, Loss: 0.0098
# Epoch: 30, Batch: 920, Loss: 0.0061
# Epoch: 30, Batch: 930, Loss: 0.0071
# Epoch: 30, Batch: 940, Loss: 0.0072
# Epoch: 30, Batch: 950, Loss: 0.0042
# Epoch: 30, Batch: 960, Loss: 0.0052
# Epoch: 30, Batch: 970, Loss: 0.0067
# Epoch: 30, Batch: 980, Loss: 0.0083
# Epoch: 30, Batch: 990, Loss: 0.0025
# Epoch: 30, Batch: 1000, Loss: 0.0064
# Epoch: 30, Batch: 1010, Loss: 0.0073
# Epoch: 30, Batch: 1020, Loss: 0.0036
# Epoch: 30, Batch: 1030, Loss: 0.0082
# Epoch: 30, Batch: 1040, Loss: 0.0140
# Epoch: 30, Batch: 1050, Loss: 0.0054
# Epoch: 30, Batch: 1060, Loss: 0.0066
# Epoch: 30, Batch: 1070, Loss: 0.0055
# Epoch: 30, Batch: 1080, Loss: 0.0041
# Epoch: 30, Batch: 1090, Loss: 0.0077
# Epoch: 30, Batch: 1100, Loss: 0.0067
# Epoch: 30, Batch: 1110, Loss: 0.0051
# Epoch: 30, Batch: 1120, Loss: 0.0080
# Epoch: 30, Batch: 1130, Loss: 0.0048
# Epoch: 30, Batch: 1140, Loss: 0.0070
# Epoch: 30, Batch: 1150, Loss: 0.0053
# Epoch: 30, Batch: 1160, Loss: 0.0091
# Epoch: 30, Batch: 1170, Loss: 0.0065
# Epoch: 30, Batch: 1180, Loss: 0.0059
# Epoch: 30, Batch: 1190, Loss: 0.0071
# Epoch: 30, Batch: 1200, Loss: 0.0152
# Epoch: 30, Batch: 1210, Loss: 0.0102
# Epoch: 30, Batch: 1220, Loss: 0.0055
# Epoch: 30, Batch: 1230, Loss: 0.0055
# Epoch: 30, Batch: 1240, Loss: 0.0069
# Epoch: 30, Train Loss: 0.0065, Val Loss: 0.0352
# Input: gfbs, Decrypted: ASIN
