# %%
import torch
import torch.nn as nn
import math
import pandas as pd
import string
import numpy as np
from tqdm import tqdm

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# --- Vocabulary Class ---
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        all_chars = list(string.printable)
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        if isinstance(text, float):  # Handle NaN values
            text = str(text)
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# --- Transformer Model ---
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))
        attn_probs = torch.softmax(scores, dim=-1)
        return torch.matmul(attn_probs, V)

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        return self.W_o(self.combine_heads(attn_output))

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super().__init__()
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm2(x + self.dropout(ff_output))

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        return self.norm3(x + self.dropout(ff_output))

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)
        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask
        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        return self.fc(dec_output)

# --- Inference Functions ---
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        return vocab.decode(target[0].cpu().numpy())

def process_and_print_results(model, test_file, vocab, max_length, device, num_samples=4000):
    try:
        df = pd.read_excel(test_file) if test_file.endswith('.xlsx') else pd.read_csv(test_file)
    except Exception as e:
        print(f"Error loading test file: {e}")
        return None

    if len(df) > num_samples:
        df = df.sample(n=num_samples, random_state=42)

    results = []
    total_correct = 0
    total_chars_correct = 0
    total_chars = 0

    print("\n=== Starting Inference ===")
    print(f"Processing {len(df)} test cases...\n")

    for idx, row in df.iterrows():
        try:
            input_text = str(row['input'])
            expected = str(row['output'])

            # Decrypt the text
            decrypted = decrypt_text(model, input_text, vocab, max_length, device)
            decrypted_clean = decrypted.replace('<SOS>', '').replace('<EOS>', '').strip()

            # Calculate metrics
            full_match = decrypted_clean == expected
            total_correct += int(full_match)

            min_len = min(len(decrypted_clean), len(expected))
            char_matches = sum(1 for a, b in zip(decrypted_clean[:min_len], expected[:min_len]) if a == b)
            total_chars_correct += char_matches
            total_chars += max(len(decrypted_clean), len(expected))

            # Print detailed results for each case
            print(f"\n--- Case {idx+1} ---")
            print(f"Input:     {input_text}")
            print(f"Decrypted: {decrypted_clean}")
            print(f"Expected:  {expected}")
            print(f"Match:     {'✅' if full_match else '❌'}")
            print(f"Char Accuracy: {char_matches}/{max(len(decrypted_clean), len(expected))} ({(char_matches/max(len(decrypted_clean), len(expected)))*100:.1f}%)")

            results.append({
                'Case #': idx+1,
                'Input': input_text,
                'Decrypted': decrypted_clean,
                'Expected': expected,
                'Full Match': 'Yes' if full_match else 'No',
                'Char Matches': f"{char_matches}/{max(len(decrypted_clean), len(expected))}",
                'Char Accuracy': f"{(char_matches/max(len(decrypted_clean), len(expected)))*100:.2f}%"
            })

        except Exception as e:
            print(f"\nError processing case {idx+1}: {e}")
            continue

    # Create results DataFrame
    results_df = pd.DataFrame(results)

    # Add summary
    full_acc = (total_correct/len(results))*100 if results else 0
    char_acc = (total_chars_correct/total_chars)*100 if total_chars > 0 else 0

    summary = pd.DataFrame([{
        'Case #': 'SUMMARY',
        'Input': f"Total Cases: {len(results)}",
        'Decrypted': f"Full Accuracy: {full_acc:.2f}%",
        'Expected': f"Char Accuracy: {char_acc:.2f}%",
        'Full Match': f"{total_correct}/{len(results)}",
        'Char Matches': f"{total_chars_correct}/{total_chars}",
        'Char Accuracy': f"{char_acc:.2f}%"
    }])

    return pd.concat([results_df, summary], ignore_index=True)

# --- Main Execution ---
if __name__ == "__main__":
    # Configuration
    MODEL_PATH = '/content/drive/MyDrive/mono_vanilla_5_keys.pth'
    TEST_FILE = '/content/Full_testing_mono_5.xlsx'
    OUTPUT_FILE = '/content/drive/MyDrive/inference_mono_five_vanilla.xlsx'
    MAX_LENGTH = 256

    # Initialize vocabulary and model
    vocab = Vocabulary()
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=2,
        num_layers=6,
        d_ff=256,
        max_seq_length=MAX_LENGTH,
        dropout=0.21983729110648678
    ).to(device)

    # Load trained model
    try:
        model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
        model.eval()
        print("Model loaded successfully")
    except Exception as e:
        print(f"Error loading model: {e}")
        exit()

    # Process test cases and print all results
    results = process_and_print_results(model, TEST_FILE, vocab, MAX_LENGTH, device)

    # Save to Excel
    if results is not None:
        try:
            results.to_excel(OUTPUT_FILE, index=False)
            print(f"\nFull results saved to {OUTPUT_FILE}")

            # Print final summary
            print("\n=== Final Summary ===")
            print(f"Full-match accuracy: {results.iloc[-1]['Full Match']}")
            print(f"Character-level accuracy: {results.iloc[-1]['Char Matches']} ({results.iloc[-1]['Char Accuracy']})")
        except Exception as e:
            print(f"\nError saving results: {e}")
    else:
        print("\nNo results were generated")
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected:  TOM HAS BEEN MAKING THREATS.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 17926 ---
# Input:     S JESIOTZ CFT XESZT.
# Decrypted: I CLIMBED THE SLIDE.
# Expected:  I CLIMBED THE SLIDE.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 13299 ---
# Input:     DEPEJJK
# Decrypted: REBECCA
# Expected:  REBECCA
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 5606 ---
# Input:     CYI JFRXTZ IT.
# Decrypted: TOM CHASED ME.
# Expected:  TOM CHASED ME.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 10870 ---
# Input:     XD QRBYDF GLQSB QXH.
# Decrypted: WE TALKED UNTIL TWO.
# Expected:  WE TALKED UNTIL TWO.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 7357 ---
# Input:     KXSEPKZS
# Decrypted: ADEQUATE
# Expected:  ADEQUATE
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 18005 ---
# Input:     S QHHY R PTRLPD RLF RPPDJQDF TSZ PTRBBDLND.
# Decrypted: I TOOK A CHANCE AND ACCEPTED HIS CHALLENGE.
# Expected:  I TOOK A CHANCE AND ACCEPTED HIS CHALLENGE.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 7221 ---
# Input:     CTR JRA VRSC.
# Decrypted: TEA CAN WAIT.
# Expected:  TEA CAN WAIT.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 484 ---
# Input:     Q YCFO VKCRHEX QO ITT.
# Decrypted: I JUST LAUGHED IT OFF.
# Expected:  I JUST LAUGHED IT OFF.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 19135 ---
# Input:     WADLPT JRARQAHHJDAZ JDAWHAKDF RQAHPSHGZ QHAQGADZ QH RBNDASRLZ FGASLN QTD BSUDARQSHL XRA.
# Decrypted: FRENCH PARATROOPERS PERFORMED ATROCIOUS TORTURES TO ALGERIANS DURING THE LIBERATION WAR.
# Expected:  FRENCH PARATROOPERS PERFORMED ATROCIOUS TORTURES TO ALGERIANS DURING THE LIBERATION WAR.
# Match:     ✅
# Char Accuracy: 88/88 (100.0%)
#
# --- Case 1316 ---
# Input:     OYCF CYI RAZ S RNT SA R FUNNG.
# Decrypted: BOTH TOM AND I ARE IN A HURRY.
# Expected:  BOTH TOM AND I ARE IN A HURRY.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 3016 ---
# Input:     ARLYGR SX QRIYUX QYN SCX JRXCET.
# Decrypted: NAGOYA IS FAMOUS FOR ITS CASTLE.
# Expected:  NAGOYA IS FAMOUS FOR ITS CASTLE.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 13440 ---
# Input:     SQ XRZ ADCDRBDF QTRQ KRAV XRZ JADNLRLQ.
# Decrypted: IT WAS REVEALED THAT MARY WAS PREGNANT.
# Expected:  IT WAS REVEALED THAT MARY WAS PREGNANT.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 18576 ---
# Input:     ONYVXT
# Decrypted: BROWSE
# Expected:  BROWSE
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 9098 ---
# Input:     QIZI BVF RDZW BLZZIDC.
# Decrypted: ZIRI WAS VERY WORRIED.
# Expected:  ZIRI WAS VERY WORRIED.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 12770 ---
# Input:     WVHFHA SZ NHSLN QH ZSLN.
# Decrypted: FYODOR IS GOING TO SING.
# Expected:  FYODOR IS GOING TO SING.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 9900 ---
# Input:     URPYDF
# Decrypted: BACKED
# Expected:  BACKED
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 4227 ---
# Input:     QTSDSKL
# Decrypted: WHEREAS
# Expected:  WHEREAS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 18404 ---
# Input:     OIU QF K NDEOOZ RIIX XEOEJOQSE.
# Decrypted: TOM IS A PRETTY GOOD DETECTIVE.
# Expected:  TOM IS A PRETTY GOOD DETECTIVE.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 18676 ---
# Input:     S LYC LYYZ LNRZTX RAZ S DRXXTZ.
# Decrypted: I GOT GOOD GRADES AND I PASSED.
# Expected:  I GOT GOOD GRADES AND I PASSED.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 16006 ---
# Input:     FROSCRC
# Decrypted: HABITAT
# Expected:  HABITAT
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 2486 ---
# Input:     JREE UD SX R DFNRXT CFRC ITRAX CY CTETDFYAT.
# Decrypted: CALL UP IS A PHRASE THAT MEANS TO TELEPHONE.
# Expected:  CALL UP IS A PHRASE THAT MEANS TO TELEPHONE.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 18433 ---
# Input:     HLT FMLSUC MVRD BVIHDC JLZ SF HL ADH HMDZD.
# Decrypted: TOM SHOULD HAVE WAITED FOR US TO GET THERE.
# Expected:  TOM SHOULD HAVE WAITED FOR US TO GET THERE.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 8666 ---
# Input:     RACYASY FSZ SAXSZT R XFSDDSAL JYACRSATN.
# Decrypted: ANTONIO HID INSIDE A SHIPPING CONTAINER.
# Expected:  ANTONIO HID INSIDE A SHIPPING CONTAINER.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 19589 ---
# Input:     TIIOWIOEF HKSE PEEW NDISQXEX.
# Decrypted: FOOTNOTES HAVE BEEN PROVIDED.
# Expected:  FOOTNOTES HAVE BEEN PROVIDED.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 10216 ---
# Input:     DNYDYXT
# Decrypted: PROPOSE
# Expected:  PROPOSE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 908 ---
# Input:     BD VZD V FSIXICD PZDRDNHILN LZAVNIQVHILN.
# Decrypted: WE ARE A SUICIDE PREVENTION ORGANIZATION.
# Expected:  WE ARE A SUICIDE PREVENTION ORGANIZATION.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 1577 ---
# Input:     ATUHHUAL
# Decrypted: PHILLIPS
# Expected:  PHILLIPS
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 14176 ---
# Input:     LNYUD
# Decrypted: GROUP
# Expected:  GROUP
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 14884 ---
# Input:     TZIXID RKSE K FOKOEUEWO.
# Decrypted: FYODOR GAVE A STATEMENT.
# Expected:  FYODOR GAVE A STATEMENT.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 10361 ---
# Input:     DETRXT ZY AYC QYNLTC CY LTC IT RC CFT XCRCSYA.
# Decrypted: PLEASE DO NOT FORGET TO GET ME AT THE STATION.
# Expected:  PLEASE DO NOT FORGET TO GET ME AT THE STATION.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 1340 ---
# Input:     ZRKS SZ YSLF HW UGZV LHX.
# Decrypted: SAMI IS KIND OF BUSY NOW.
# Expected:  SAMI IS KIND OF BUSY NOW.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 11721 ---
# Input:     ITIYNG SX AYC XCROET.
# Decrypted: MEMORY IS NOT STABLE.
# Expected:  MEMORY IS NOT STABLE.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 15858 ---
# Input:     HMD AIZU FHVZINA GVXY VH TD BVF VNAZW.
# Decrypted: THE GIRL STARING BACK AT ME WAS ANGRY.
# Expected:  THE GIRL STARING BACK AT ME WAS ANGRY.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 8686 ---
# Input:     GRAAS XFYVTZ CFT DSJCUNT CY CFT VRSCNTXX.
# Decrypted: YANNI SHOWED THE PICTURE TO THE WAITRESS.
# Expected:  YANNI SHOWED THE PICTURE TO THE WAITRESS.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 5385 ---
# Input:     KV WRQTDA SZ NDQQSLN UDQQDA RLF UDQQDA.
# Decrypted: MY FATHER IS GETTING BETTER AND BETTER.
# Expected:  MY FATHER IS GETTING BETTER AND BETTER.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 18833 ---
# Input:     HMIF IF HMD BLZFH HMINA IN HMD BLZUC.
# Decrypted: THIS IS THE WORST THING IN THE WORLD.
# Expected:  THIS IS THE WORST THING IN THE WORLD.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 6133 ---
# Input:     VTGVFFVCLZ
# Decrypted: AMBASSADOR
# Expected:  AMBASSADOR
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 11161 ---
# Input:     ETAZ IT R BASQT VSCF VFSJF CY DTTE CFSX DTRN.
# Decrypted: LEND ME A KNIFE WITH WHICH TO PEEL THIS PEAR.
# Expected:  LEND ME A KNIFE WITH WHICH TO PEEL THIS PEAR.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 1990 ---
# Input:     S JBRL QH PHLQRPQ KRAV UV JTHLD QHKHAAHX RLF RZY TDA QH TDBJ GZ.
# Decrypted: I PLAN TO CONTACT MARY BY PHONE TOMORROW AND ASK HER TO HELP US.
# Expected:  I PLAN TO CONTACT MARY BY PHONE TOMORROW AND ASK HER TO HELP US.
# Match:     ✅
# Char Accuracy: 64/64 (100.0%)
#
# --- Case 14726 ---
# Input:     ITNJUNG FRX R WTNG VTRB IRLATCSJ QSTEZ.
# Decrypted: MERCURY HAS A VERY WEAK MAGNETIC FIELD.
# Expected:  MERCURY HAS A VERY WEAK MAGNETIC FIELD.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 7062 ---
# Input:     XIXL
# Decrypted: CICO
# Expected:  DVDS
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 16777 ---
# Input:     KHRJLZ KHH RF DSGJDXL QSDS URAJDZSX WDJR BSDRKNF.
# Decrypted: ALMOST ALL MY RECORDS WERE IMPORTED FROM GERMANY.
# Expected:  ALMOST ALL MY RECORDS WERE IMPORTED FROM GERMANY.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 15793 ---
# Input:     I MDVZC WLS BDZD MVRINA PZLGUDTF VH FXMLLU.
# Decrypted: I HEARD YOU WERE HAVING PROBLEMS AT SCHOOL.
# Expected:  I HEARD YOU WERE HAVING PROBLEMS AT SCHOOL.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 16093 ---
# Input:     HLT MVF INFLTNIV.
# Decrypted: TOM HAS INSOMNIA.
# Expected:  TOM HAS INSOMNIA.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 6873 ---
# Input:     I MDVZC HLT IN HMD YIHXMDN.
# Decrypted: I HEARD TOM IN THE KITCHEN.
# Expected:  I HEARD TOM IN THE KITCHEN.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 15256 ---
# Input:     S ATTZ R LYYZ QNTAJF ZSJCSYARNG.
# Decrypted: I NEED A GOOD FRENCH DICTIONARY.
# Expected:  I NEED A GOOD FRENCH DICTIONARY.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 4986 ---
# Input:     CYI BAYVX CFRC IRNG ESBTX NTLLRT.
# Decrypted: TOM KNOWS THAT MARY LIKES REGGAE.
# Expected:  TOM KNOWS THAT MARY LIKES REGGAE.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 14817 ---
# Input:     ZTS WKGZ ZTKZ ZJR NJ HJNBSD ZDPLZL RS QJDDUSL RS.
# Decrypted: THE FACT THAT TOM NO LONGER TRUSTS ME WORRIES ME.
# Expected:  THE FACT THAT TOM NO LONGER TRUSTS ME WORRIES ME.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 122 ---
# Input:     FJP NSSX ZJ MS RJDS KZZSNZUIS UN GHKLL.
# Decrypted: YOU NEED TO BE MORE ATTENTIVE IN CLASS.
# Expected:  YOU NEED TO BE MORE ATTENTIVE IN CLASS.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 2610 ---
# Input:     QHK ZTHGBF UD RUHGQ TRBWXRV THKD UV LHX.
# Decrypted: TOM SHOULD BE ABOUT HALFWAY HOME BY NOW.
# Expected:  TOM SHOULD BE ABOUT HALFWAY HOME BY NOW.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 15868 ---
# Input:     BIHM HDVXMINA VNC FHSCWINA VUU LJ TW HITD IF HVYDN SP.
# Decrypted: WITH TEACHING AND STUDYING ALL OF MY TIME IS TAKEN UP.
# Expected:  WITH TEACHING AND STUDYING ALL OF MY TIME IS TAKEN UP.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 19512 ---
# Input:     ZJR LKUX ZTKZ TS TKX ZDJPMHS XJUNB ZTKZ.
# Decrypted: TOM SAID THAT HE HAD TROUBLE DOING THAT.
# Expected:  TOM SAID THAT HE HAD TROUBLE DOING THAT.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 15759 ---
# Input:     PEVVE
# Decrypted: BELLE
# Expected:  BELLE
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 6219 ---
# Input:     JIUNVEOEVZ
# Decrypted: COMPLETELY
# Expected:  COMPLETELY
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 7173 ---
# Input:     MD GLBDC.
# Decrypted: HE BOWED.
# Expected:  HE BOWED.
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 13458 ---
# Input:     MD XVTD LSH LJ HMD GVHMZLLT.
# Decrypted: HE CAME OUT OF THE BATHROOM.
# Expected:  HE CAME OUT OF THE BATHROOM.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 954 ---
# Input:     FKUQ HKF PEEW OHEDE ISED FQM HICDF.
# Decrypted: SAMI HAS BEEN THERE OVER SIX HOURS.
# Expected:  SAMI HAS BEEN THERE OVER SIX HOURS.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 16367 ---
# Input:     ZTUL AKUNZSD GKDSWPHHF GTJJLSL ZTS RJLZ IUIUX GJHJPDL.
# Decrypted: THIS PAINTER CAREFULLY CHOOSES THE MOST VIVID COLOURS.
# Expected:  THIS PAINTER CAREFULLY CHOOSES THE MOST VIVID COLOURS.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 16692 ---
# Input:     LJRSMJXF GKRS.
# Decrypted: SOMEBODY CAME.
# Expected:  SOMEBODY CAME.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 4194 ---
# Input:     HE LKF K WCDFE.
# Decrypted: HE WAS A NURSE.
# Expected:  HE WAS A NURSE.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 6699 ---
# Input:     Q AWIL OIU HKF KVDEKXZ VETO TID PIFOIW.
# Decrypted: I KNOW TOM HAS ALREADY LEFT FOR BOSTON.
# Expected:  I KNOW TOM HAS ALREADY LEFT FOR BOSTON.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 15495 ---
# Input:     GQSBZ
# Decrypted: UTILS
# Expected:  UTILS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 8158 ---
# Input:     ULXY
# Decrypted: LOCK
# Expected:  LOCK
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 4822 ---
# Input:     WJDZPNS
# Decrypted: FORTUNE
# Expected:  FORTUNE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 10326 ---
# Input:     S ATTZ CY ETC FSI BAYV.
# Decrypted: I NEED TO LET HIM KNOW.
# Expected:  I NEED TO LET HIM KNOW.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 11766 ---
# Input:     CYI XRSZ FT VRX ESWSAL SA RUXCNRESR RC CFT CSIT.
# Decrypted: TOM SAID HE WAS LIVING IN AUSTRALIA AT THE TIME.
# Expected:  TOM SAID HE WAS LIVING IN AUSTRALIA AT THE TIME.
# Match:     ✅
# Char Accuracy: 48/48 (100.0%)
#
# --- Case 2541 ---
# Input:     CYI RAZ S ESWT SA CFT XRIT ZYNI.
# Decrypted: TOM AND I LIVE IN THE SAME DORM.
# Expected:  TOM AND I LIVE IN THE SAME DORM.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 5307 ---
# Input:     KRSDUGKNL KDS UXUJZL.
# Decrypted: AMERICANS ARE IDIOTS.
# Expected:  AMERICANS ARE IDIOTS.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 1271 ---
# Input:     S CFYULFC SC VRX UAATJTXXRNG QYN UX CY ZY RAGCFSAL ROYUC CFRC CYZRG.
# Decrypted: I THOUGHT IT WAS UNNECESSARY FOR US TO DO ANYTHING ABOUT THAT TODAY.
# Expected:  I THOUGHT IT WAS UNNECESSARY FOR US TO DO ANYTHING ABOUT THAT TODAY.
# Match:     ✅
# Char Accuracy: 68/68 (100.0%)
#
# --- Case 5246 ---
# Input:     XCNUJCUNTX
# Decrypted: STRUCTURES
# Expected:  STRUCTURES
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 16291 ---
# Input:     S CUNATZ CFT DRLT.
# Decrypted: I TURNED THE PAGE.
# Expected:  I TURNED THE PAGE.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 1692 ---
# Input:     ZJR TSHAL KNFJNS QTJ KLVL WJD TSHA.
# Decrypted: TOM HELPS ANYONE WHO ASKS FOR HELP.
# Expected:  TOM HELPS ANYONE WHO ASKS FOR HELP.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 19669 ---
# Input:     BQDQ OIIA K VIWR FHILED QW OHE PKOHDIIU.
# Decrypted: ZIRI TOOK A LONG SHOWER IN THE BATHROOM.
# Expected:  ZIRI TOOK A LONG SHOWER IN THE BATHROOM.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 18051 ---
# Input:     CYI FRX IRZT FSX XFRNT YQ ISXCRBTX.
# Decrypted: TOM HAS MADE HIS SHARE OF MISTAKES.
# Expected:  TOM HAS MADE HIS SHARE OF MISTAKES.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 16161 ---
# Input:     FT ORASXFTZ CFRC ZSXCUNOSAL CFYULFC.
# Decrypted: HE BANISHED THAT DISTURBING THOUGHT.
# Expected:  HE BANISHED THAT DISTURBING THOUGHT.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 2728 ---
# Input:     QIZI RIFIHDC HMVH JVTLSF JLZDFH.
# Decrypted: ZIRI VISITED THAT FAMOUS FOREST.
# Expected:  ZIRI VISITED THAT FAMOUS FOREST.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 9602 ---
# Input:     HUVS VNJQL HUVS.
# Decrypted: LIKE KNOWS LIKE.
# Expected:  LIKE KNOWS LIKE.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 18617 ---
# Input:     RJMUHSL
# Decrypted: MOBILES
# Expected:  MOBILES
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 14432 ---
# Input:     FKNNU DSKHUOSX ZTS QKL LJRSZTUNB SHLS MSTUNX ZTS MKDDSHL.
# Decrypted: YANNI REALIZED THE WAS SOMETHING ELSE BEHIND THE BARRELS.
# Expected:  YANNI REALIZED THE WAS SOMETHING ELSE BEHIND THE BARRELS.
# Match:     ✅
# Char Accuracy: 57/57 (100.0%)
#
# --- Case 13766 ---
# Input:     S BAYV R EYC.
# Decrypted: I KNOW A LOT.
# Expected:  I KNOW A LOT.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 14069 ---
# Input:     QXEWOQTQJKOQIW
# Decrypted: IDENTIFICATION
# Expected:  IDENTIFICATION
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 2975 ---
# Input:     AGPTDB SZ R JHBSZT EDX.
# Decrypted: RUCHEL IS A POLISH JEW.
# Expected:  RUCHEL IS A POLISH JEW.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 7370 ---
# Input:     QHK QTHGNTQ KRAV XHGBF UD TDAD QHFRV.
# Decrypted: TOM THOUGHT MARY WOULD BE HERE TODAY.
# Expected:  TOM THOUGHT MARY WOULD BE HERE TODAY.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 7975 ---
# Input:     S QTSLY ZHKDQTSLN URF SZ RUHGQ QH TRJJDL.
# Decrypted: I THINK SOMETHING BAD IS ABOUT TO HAPPEN.
# Expected:  I THINK SOMETHING BAD IS ABOUT TO HAPPEN.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 17185 ---
# Input:     ZGJJHAQDAZ HW QTD JAHEDPQ ZRV SQ XSBB NDLDARQD URFBV LDDFDF EHUZ RLF ADZJDPQ BHPRB ZDLZSQSCSQSDZ.
# Decrypted: SUPPORTERS OF THE PROJECT SAY IT WILL GENERATE BADLY NEEDED JOBS AND RESPECT LOCAL SENSITIVITIES.
# Expected:  SUPPORTERS OF THE PROJECT SAY IT WILL GENERATE BADLY NEEDED JOBS AND RESPECT LOCAL SENSITIVITIES.
# Match:     ✅
# Char Accuracy: 97/97 (100.0%)
#
# --- Case 2046 ---
# Input:     OUEB
# Decrypted: BULK
# Expected:  BULK
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 4978 ---
# Input:     GLZIF FUDPH LN HMD AZLSNC BIHM GSAF.
# Decrypted: BORIS SLEPT ON THE GROUND WITH BUGS.
# Expected:  BORIS SLEPT ON THE GROUND WITH BUGS.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 7122 ---
# Input:     NSBJZUKZUJN
# Decrypted: NEGOTIATION
# Expected:  NEGOTIATION
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 13632 ---
# Input:     ZJR XDJIS LHJQHF XJQN ZTS LZDSSZ.
# Decrypted: TOM DROVE SLOWLY DOWN THE STREET.
# Expected:  TOM DROVE SLOWLY DOWN THE STREET.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 15547 ---
# Input:     RF TJRS UL WKD KQKF.
# Decrypted: MY HOME IS FAR AWAY.
# Expected:  MY HOME IS FAR AWAY.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 2737 ---
# Input:     MPDLZ
# Decrypted: BURST
# Expected:  BURST
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 17585 ---
# Input:     ZRKS SZ WBSAQSLN XSQT HQTDA NSABZ.
# Decrypted: SAMI IS FLIRTING WITH OTHER GIRLS.
# Expected:  SAMI IS FLIRTING WITH OTHER GIRLS.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 1209 ---
# Input:     JIWFCVOQWR
# Decrypted: CONSULTING
# Expected:  CONSULTING
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 17061 ---
# Input:     CYI DNRGTZ CY LYZ QYN FTED.
# Decrypted: TOM PRAYED TO GOD FOR HELP.
# Expected:  TOM PRAYED TO GOD FOR HELP.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 8328 ---
# Input:     FMVNAMVI
# Decrypted: SHANGHAI
# Expected:  SHANGHAI
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 6849 ---
# Input:     KWOIWQI AQVVEX OHE XIR KF LEVV.
# Decrypted: ANTONIO KILLED THE DOG AS WELL.
# Expected:  ANTONIO KILLED THE DOG AS WELL.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 14637 ---
# Input:     XSLSDIS
# Decrypted: DESERVE
# Expected:  DESERVE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 10419 ---
# Input:     UKDAEOF
# Decrypted: MARKETS
# Expected:  MARKETS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 10600 ---
# Input:     QHK XRSQDF WHA KRAV WHA QTADD THGAZ.
# Decrypted: TOM WAITED FOR MARY FOR THREE HOURS.
# Expected:  TOM WAITED FOR MARY FOR THREE HOURS.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 15506 ---
# Input:     RFTRZ
# Decrypted: AHEAD
# Expected:  AHEAD
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 13069 ---
# Input:     HE KDUEX HQUFEVT LQOH K RCW KWX LEWO OI TKJE OHE EWEUZ JKUN.
# Decrypted: HE ARMED HIMSELF WITH A GUN AND WENT TO FACE THE ENEMY CAMP.
# Expected:  HE ARMED HIMSELF WITH A GUN AND WENT TO FACE THE ENEMY CAMP.
# Match:     ✅
# Char Accuracy: 60/60 (100.0%)
#
# --- Case 1091 ---
# Input:     NROOSC
# Decrypted: RABBIT
# Expected:  RABBIT
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 3121 ---
# Input:     QTWTN
# Decrypted: FEVER
# Expected:  FEVER
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 12767 ---
# Input:     WFJXJD UL BJUNB ZJ LUNB.
# Decrypted: FYODOR IS GOING TO SING.
# Expected:  FYODOR IS GOING TO SING.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 10481 ---
# Input:     CFYXT VFY JRIT YA CFT QYEEYVSAL ZRG VTNT SA ZRALTN.
# Decrypted: THOSE WHO CAME ON THE FOLLOWING DAY WERE IN DANGER.
# Expected:  THOSE WHO CAME ON THE FOLLOWING DAY WERE IN DANGER.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 11545 ---
# Input:     QTRS
# Decrypted: THAI
# Expected:  THAI
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 1534 ---
# Input:     FKUQ XEJQXEX OI PCZ K UKWFQIW.
# Decrypted: SAMI DECIDED TO BUY A MANSION.
# Expected:  SAMI DECIDED TO BUY A MANSION.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 8064 ---
# Input:     XKWQEV HKX KWIOHED XQTTQJCVO OKFA KHEKX IT HQU.
# Decrypted: DANIEL HAD ANOTHER DIFFICULT TASK AHEAD OF HIM.
# Expected:  DANIEL HAD ANOTHER DIFFICULT TASK AHEAD OF HIM.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 1412 ---
# Input:     U QJDVSX KZ K MKNV.
# Decrypted: I WORKED AT A BANK.
# Expected:  I WORKED AT A BANK.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 9991 ---
# Input:     IRNG OYULFC R OTTN QYN FTNXTEQ.
# Decrypted: MARY BOUGHT A BEER FOR HERSELF.
# Expected:  MARY BOUGHT A BEER FOR HERSELF.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 7922 ---
# Input:     U TKX K MKX LPRRSD.
# Decrypted: I HAD A BAD SUMMER.
# Expected:  I HAD A BAD SUMMER.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 3201 ---
# Input:     S OYULFC CFSX SA RUXCNRESR.
# Decrypted: I BOUGHT THIS IN AUSTRALIA.
# Expected:  I BOUGHT THIS IN AUSTRALIA.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 11051 ---
# Input:     CFT YAEG YATX VFY JRA CTEE UX VFRC VT ATTZ CY BAYV RNT CYI RAZ IRNG.
# Decrypted: THE ONLY ONES WHO CAN TELL US WHAT WE NEED TO KNOW ARE TOM AND MARY.
# Expected:  THE ONLY ONES WHO CAN TELL US WHAT WE NEED TO KNOW ARE TOM AND MARY.
# Match:     ✅
# Char Accuracy: 68/68 (100.0%)
#
# --- Case 2615 ---
# Input:     ZRKS CSZSQDF BRVBR RNRSL.
# Decrypted: SAMI VISITED LAYLA AGAIN.
# Expected:  SAMI VISITED LAYLA AGAIN.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 13720 ---
# Input:     ADCDRBDF
# Decrypted: REVEALED
# Expected:  REVEALED
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 16934 ---
# Input:     FKUQ KVLKZF HKF KW EMJCFE.
# Decrypted: SAMI ALWAYS HAS AN EXCUSE.
# Expected:  SAMI ALWAYS HAS AN EXCUSE.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 2547 ---
# Input:     ZKZZJJ
# Decrypted: TATTOO
# Expected:  TATTOO
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 12595 ---
# Input:     QTD QGKHA SZ NAHXSLN SL ZSID.
# Decrypted: THE TUMOR IS GROWING IN SIZE.
# Expected:  THE TUMOR IS GROWING IN SIZE.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 9738 ---
# Input:     HLT IF MLPINA MD XVN CL HMVH BIHM TVZW.
# Decrypted: TOM IS HOPING HE CAN DO THAT WITH MARY.
# Expected:  TOM IS HOPING HE CAN DO THAT WITH MARY.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 16399 ---
# Input:     HE LKF HKSQWR K HKDX OQUE LQOH HQF FOCXQEF.
# Decrypted: HE WAS HAVING A HARD TIME WITH HIS STUDIES.
# Expected:  HE WAS HAVING A HARD TIME WITH HIS STUDIES.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 11546 ---
# Input:     S QSAZ SC ZSQQSJUEC CY VNRD IG FTRZ RNYUAZ CFT AYCSYA YQ AYNIRESCG.
# Decrypted: I FIND IT DIFFICULT TO WRAP MY HEAD AROUND THE NOTION OF NORMALITY.
# Expected:  I FIND IT DIFFICULT TO WRAP MY HEAD AROUND THE NOTION OF NORMALITY.
# Match:     ✅
# Char Accuracy: 67/67 (100.0%)
#
# --- Case 2665 ---
# Input:     QHK XRZ ASNTQ LHQ QH FH QTRQ.
# Decrypted: TOM WAS RIGHT NOT TO DO THAT.
# Expected:  TOM WAS RIGHT NOT TO DO THAT.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 14302 ---
# Input:     ZJR LZKFL KZ TJRS JN QSSVSNXL.
# Decrypted: TOM STAYS AT HOME ON WEEKENDS.
# Expected:  TOM STAYS AT HOME ON WEEKENDS.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 13207 ---
# Input:     ZJR UL ZTS JNHF RKN UN ZTS QJDHX ZTKZ GKN APHH ZTUL JWW.
# Decrypted: TOM IS THE ONLY MAN IN THE WORLD THAT CAN PULL THIS OFF.
# Expected:  TOM IS THE ONLY MAN IN THE WORLD THAT CAN PULL THIS OFF.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 10269 ---
# Input:     KVVIL OHDEE LEEAF TID XEVQSEDZ.
# Decrypted: ALLOW THREE WEEKS FOR DELIVERY.
# Expected:  ALLOW THREE WEEKS FOR DELIVERY.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 1458 ---
# Input:     MIHVXMI
# Decrypted: HITACHI
# Expected:  HITACHI
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 3589 ---
# Input:     FACDK KWX UQDK DEKX K JIUQJ PIIA.
# Decrypted: SKURA AND MIRA READ A COMIC BOOK.
# Expected:  SKURA AND MIRA READ A COMIC BOOK.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 7703 ---
# Input:     I ZDVUUW VPPZDXIVHD BMVH WLS CIC JLZ TD.
# Decrypted: I REALLY APPRECIATE WHAT YOU DID FOR ME.
# Expected:  I REALLY APPRECIATE WHAT YOU DID FOR ME.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 16355 ---
# Input:     ZJDRY QH QTD KRLRNDA.
# Decrypted: SPEAK TO THE MANAGER.
# Expected:  SPEAK TO THE MANAGER.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 5549 ---
# Input:     VJX
# Decrypted: WCC
# Expected:  LCD
# Match:     ❌
# Char Accuracy: 1/3 (33.3%)
#
# --- Case 19722 ---
# Input:     KLVSX
# Decrypted: ASKED
# Expected:  ASKED
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 6053 ---
# Input:     HLT PVIC FLTDLND HL MDUP MIT TLRD HMD PIVNL.
# Decrypted: TOM PAID SOMEONE TO HELP HIM MOVE THE PIANO.
# Expected:  TOM PAID SOMEONE TO HELP HIM MOVE THE PIANO.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 10697 ---
# Input:     U KR NJZ K RSRMSD JW ZTS GHPM.
# Decrypted: I AM NOT A MEMBER OF THE CLUB.
# Expected:  I AM NOT A MEMBER OF THE CLUB.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 13618 ---
# Input:     HLT GZLSAMH HMZDD GLHHUDF LJ BVHDZ BIHM MIT.
# Decrypted: TOM BROUGHT THREE BOTTLES OF WATER WITH HIM.
# Expected:  TOM BROUGHT THREE BOTTLES OF WATER WITH HIM.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 12043 ---
# Input:     FTLYINA IF V CVNADZ HL WLSZ MDVUHM.
# Decrypted: SMOKING IS A DANGER TO YOUR HEALTH.
# Expected:  SMOKING IS A DANGER TO YOUR HEALTH.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 17285 ---
# Input:     S ZKDBBDF URPHL.
# Decrypted: I SMELLED BACON.
# Expected:  I SMELLED BACON.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 10533 ---
# Input:     I BVNH HL HVUY HL HLT NLB.
# Decrypted: I WANT TO TALK TO TOM NOW.
# Expected:  I WANT TO TALK TO TOM NOW.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 18779 ---
# Input:     FJKW
# Decrypted: SCAN
# Expected:  SCAN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 2951 ---
# Input:     CFSX SX BSAZ YQ R ZNRL.
# Decrypted: THIS IS KIND OF A DRAG.
# Expected:  THIS IS KIND OF A DRAG.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 7860 ---
# Input:     S RK WSWQV.
# Decrypted: I AM FIFTY.
# Expected:  I AM FIFTY.
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 1394 ---
# Input:     JIIV QO XILW.
# Decrypted: COOL IT DOWN.
# Expected:  COOL IT DOWN.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 13145 ---
# Input:     DAJ
# Decrypted: ERP
# Expected:  ERP
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 16932 ---
# Input:     LKRU KHQKFL TKL KN SYGPLS.
# Decrypted: SAMI ALWAYS HAS AN EXCUSE.
# Expected:  SAMI ALWAYS HAS AN EXCUSE.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 12105 ---
# Input:     ZTD FDPSFDF QH NH RTDRF BDQ TSK TRCD TSZ XRV.
# Decrypted: SHE DECIDED TO GO AHEAD LET HIM HAVE HIS WAY.
# Expected:  SHE DECIDED TO GO AHEAD LET HIM HAVE HIS WAY.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 6848 ---
# Input:     VNHLNIL YIUUDC HMD CLA VF BDUU.
# Decrypted: ANTONIO KILLED THE DOG AS WELL.
# Expected:  ANTONIO KILLED THE DOG AS WELL.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 7078 ---
# Input:     VPPZDXIVHDC
# Decrypted: APPRECIATED
# Expected:  APPRECIATED
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 3015 ---
# Input:     NH QH XHAY.
# Decrypted: GO TO WORK.
# Expected:  GO TO WORK.
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 17383 ---
# Input:     FVTI BVNHDC HL GSW V BVHXM.
# Decrypted: SAMI WANTED TO BUY A WATCH.
# Expected:  SAMI WANTED TO BUY A WATCH.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 16633 ---
# Input:     BIXYDC
# Decrypted: WICKED
# Expected:  WICKED
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 12278 ---
# Input:     GSYYVYD
# Decrypted: BUKKAKE
# Expected:  BUKKAKE
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 18634 ---
# Input:     OIU OKVAF OI UE K VIO.
# Decrypted: TOM TALKS TO ME A LOT.
# Expected:  TOM TALKS TO ME A LOT.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 16182 ---
# Input:     ZJR DSKHUOSX ZTKZ ZTSDS QKL NJ ZJUHSZ AKASD.
# Decrypted: TOM REALIZED THAT THERE WAS NO TOILET PAPER.
# Expected:  TOM REALIZED THAT THERE WAS NO TOILET PAPER.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 5643 ---
# Input:     MD HLLY VUU HMD ZDFPLNFIGIUIHIDF.
# Decrypted: HE TOOK ALL THE RESPONSIBILITIES.
# Expected:  HE TOOK ALL THE RESPONSIBILITIES.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 13060 ---
# Input:     XD XDLQ QH QTD WGLWRSA VDZQDAFRV RLF TRF R NH HL QTD USN XTDDB.
# Decrypted: WE WENT TO THE FUNFAIR YESTERDAY AND HAD A GO ON THE BIG WHEEL.
# Expected:  WE WENT TO THE FUNFAIR YESTERDAY AND HAD A GO ON THE BIG WHEEL.
# Match:     ✅
# Char Accuracy: 63/63 (100.0%)
#
# --- Case 5113 ---
# Input:     HLT VNC TVZW VZD DEHZDTDUW PZLSC LJ HMDIZ FLN.
# Decrypted: TOM AND MARY ARE EXTREMELY PROUD OF THEIR SON.
# Expected:  TOM AND MARY ARE EXTREMELY PROUD OF THEIR SON.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 13120 ---
# Input:     ISAS TDBJDF ASKR DZPRJD XSQT QTD URUV.
# Decrypted: ZIRI HELPED RIMA ESCAPE WITH THE BABY.
# Expected:  ZIRI HELPED RIMA ESCAPE WITH THE BABY.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 1768 ---
# Input:     ZDXIPIDNH
# Decrypted: RECIPIENT
# Expected:  RECIPIENT
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 7901 ---
# Input:     CYI SX YUN ATV RXXSXCRAC IRARLTN.
# Decrypted: TOM IS OUR NEW ASSISTANT MANAGER.
# Expected:  TOM IS OUR NEW ASSISTANT MANAGER.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 17268 ---
# Input:     TLLNUIAMH BLN HMD LFXVZ JLZ GDFH PIXHSZD.
# Decrypted: MOONLIGHT WON THE OSCAR FOR BEST PICTURE.
# Expected:  MOONLIGHT WON THE OSCAR FOR BEST PICTURE.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 19877 ---
# Input:     HKLZ NUBTZ TS LKQ KN PNUXSNZUWUSX WHFUNB JMCSGZ UN ZTS LVF.
# Decrypted: LAST NIGHT HE SAW AN UNIDENTIFIED FLYING OBJECT IN THE SKY.
# Expected:  LAST NIGHT HE SAW AN UNIDENTIFIED FLYING OBJECT IN THE SKY.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 10625 ---
# Input:     FRXL
# Decrypted: DAWN
# Expected:  DAWN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 10449 ---
# Input:     OHE JIKJH JKVVEX ITT OHE RKUE PEJKCFE UKWZ IT OHE NVKZEDF LEDE XILW LQOH OHE TVC.
# Decrypted: THE COACH CALLED OFF THE GAME BECAUSE MANY OF THE PLAYERS WERE DOWN WITH THE FLU.
# Expected:  THE COACH CALLED OFF THE GAME BECAUSE MANY OF THE PLAYERS WERE DOWN WITH THE FLU.
# Match:     ✅
# Char Accuracy: 81/81 (100.0%)
#
# --- Case 15492 ---
# Input:     PZUHL
# Decrypted: UTILS
# Expected:  UTILS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 15905 ---
# Input:     ZTD AGUUDF TDA PTSL.
# Decrypted: SHE RUBBED HER CHIN.
# Expected:  SHE RUBBED HER CHIN.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 10580 ---
# Input:     PTASZQHJTDA
# Decrypted: CHRISTOPHER
# Expected:  CHRISTOPHER
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 17762 ---
# Input:     QS QULT FJP K TKAAF GTDULZRKL KNX K TKAAF NSQ FSKD.
# Decrypted: WE WISH YOU A HAPPY CHRISTMAS AND A HAPPY NEW YEAR.
# Expected:  WE WISH YOU A HAPPY CHRISTMAS AND A HAPPY NEW YEAR.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 16369 ---
# Input:     OHQF NKQWOED JKDETCVVZ JHIIFEF OHE UIFO SQSQX JIVICDF.
# Decrypted: THIS PAINTER CAREFULLY CHOOSES THE MOST VIVID COLOURS.
# Expected:  THIS PAINTER CAREFULLY CHOOSES THE MOST VIVID COLOURS.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 19437 ---
# Input:     WJDRUNB
# Decrypted: FORMING
# Expected:  FORMING
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 9708 ---
# Input:     XMDT
# Decrypted: CHEM
# Expected:  CHEM
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 5467 ---
# Input:     ZJR QKL KWDKUX ZJ KLV WJD TSHA.
# Decrypted: TOM WAS AFRAID TO ASK FOR HELP.
# Expected:  TOM WAS AFRAID TO ASK FOR HELP.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 17922 ---
# Input:     FJP LTJPHX TUDS RS MSGKPLS U KR ZTS MSLZ RKN WJD ZTS CJM
# Decrypted: YOU SHOULD HIRE ME BECAUSE I AM THE BEST MAN FOR THE JOB
# Expected:  YOU SHOULD HIRE ME BECAUSE I AM THE BEST MAN FOR THE JOB
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 16181 ---
# Input:     CYI NTRESPTZ CFRC CFTNT VRX AY CYSETC DRDTN.
# Decrypted: TOM REALIZED THAT THERE WAS NO TOILET PAPER.
# Expected:  TOM REALIZED THAT THERE WAS NO TOILET PAPER.
# Match:     ✅
# Char Accuracy: 44/44 (100.0%)
#
# --- Case 19519 ---
# Input:     ICD KPQVQOZ OI JIUUCWQJKOE KPICO OHEFE UKOOEDF EWXEX K LHQVE KRI.
# Decrypted: OUR ABILITY TO COMMUNICATE ABOUT THESE MATTERS ENDED A WHILE AGO.
# Expected:  OUR ABILITY TO COMMUNICATE ABOUT THESE MATTERS ENDED A WHILE AGO.
# Match:     ✅
# Char Accuracy: 65/65 (100.0%)
#
# --- Case 17757 ---
# Input:     OUDU APLTSX DURK KQKF KNX LTS WSHH JN ZTS BDJPNX.
# Decrypted: ZIRI PUSHED RIMA AWAY AND SHE FELL ON THE GROUND.
# Expected:  ZIRI PUSHED RIMA AWAY AND SHE FELL ON THE GROUND.
# Match:     ✅
# Char Accuracy: 49/49 (100.0%)
#
# --- Case 15304 ---
# Input:     JQDJCVKD
# Decrypted: CIRCULAR
# Expected:  CIRCULAR
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 17863 ---
# Input:     XVNCUD
# Decrypted: CANDLE
# Expected:  CANDLE
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 13109 ---
# Input:     UQDIFVKS UKXE QO OI OHE IVZUNQJF.
# Decrypted: MIROSLAV MADE IT TO THE OLYMPICS.
# Expected:  MIROSLAV MADE IT TO THE OLYMPICS.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 4689 ---
# Input:     Q HKX OHE NVEKFCDE IT VEKDWQWR OHKO ZIC DEJEWOVZ PEJKUE OHE UKWKRED IT OHE NDIXCJOQIW XQSQFQIW.
# Decrypted: I HAD THE PLEASURE OF LEARNING THAT YOU RECENTLY BECAME THE MANAGER OF THE PRODUCTION DIVISION.
# Expected:  I HAD THE PLEASURE OF LEARNING THAT YOU RECENTLY BECAME THE MANAGER OF THE PRODUCTION DIVISION.
# Match:     ✅
# Char Accuracy: 95/95 (100.0%)
#
# --- Case 3985 ---
# Input:     TD FAHJJDF TSZ NBRZZ.
# Decrypted: HE DROPPED HIS GLASS.
# Expected:  HE DROPPED HIS GLASS.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 19395 ---
# Input:     S XSBB XRSQ HGQZSFD.
# Decrypted: I WILL WAIT OUTSIDE.
# Expected:  I WILL WAIT OUTSIDE.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 1003 ---
# Input:     I HMLSAMH HLT VNC TVZW BDZD DUDXHZIXIVNF.
# Decrypted: I THOUGHT TOM AND MARY WERE ELECTRICIANS.
# Expected:  I THOUGHT TOM AND MARY WERE ELECTRICIANS.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 1062 ---
# Input:     APZ ZTS XIXL MKGV UN ZTSUD ADJASD AHKGS KWZSD QKZGTUNB ZTSR.
# Decrypted: PUT THE DVDS BACK IN THEIR PROPER PLACE AFTER WATCHING THEM.
# Expected:  PUT THE DVDS BACK IN THEIR PROPER PLACE AFTER WATCHING THEM.
# Match:     ✅
# Char Accuracy: 60/60 (100.0%)
#
# --- Case 8622 ---
# Input:     TS KNX U QSDS MJZT RKDDUSX.
# Decrypted: HE AND I WERE BOTH MARRIED.
# Expected:  HE AND I WERE BOTH MARRIED.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 14122 ---
# Input:     ATUHJLJATF
# Decrypted: PHILOSOPHY
# Expected:  PHILOSOPHY
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 18035 ---
# Input:     PDLQGAV
# Decrypted: CENTURY
# Expected:  CENTURY
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 13798 ---
# Input:     I BLNCDZ IJ HLT VNC TVZW VZD FHIUU ULNDUW.
# Decrypted: I WONDER IF TOM AND MARY ARE STILL LONELY.
# Expected:  I WONDER IF TOM AND MARY ARE STILL LONELY.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 7140 ---
# Input:     ZTD BSYDZ DCDAVQTSLN RUHGQ TSK.
# Decrypted: SHE LIKES EVERYTHING ABOUT HIM.
# Expected:  SHE LIKES EVERYTHING ABOUT HIM.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 5171 ---
# Input:     S CYEZ CFTI CFT XCYNG YQ CFT CFNTT ESCCET DSLX.
# Decrypted: I TOLD THEM THE STORY OF THE THREE LITTLE PIGS.
# Expected:  I TOLD THEM THE STORY OF THE THREE LITTLE PIGS.
# Match:     ✅
# Char Accuracy: 47/47 (100.0%)
#
# --- Case 9694 ---
# Input:     PEQWRF
# Decrypted: BEINGS
# Expected:  BEINGS
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 13797 ---
# Input:     U QJNXSD UW ZJR KNX RKDF KDS LZUHH HJNSHF.
# Decrypted: I WONDER IF TOM AND MARY ARE STILL LONELY.
# Expected:  I WONDER IF TOM AND MARY ARE STILL LONELY.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 11645 ---
# Input:     RBNDASR TRZ NHHF ADBRQSHLZ XSQT QTD LRQH RBBSRLPD.
# Decrypted: ALGERIA HAS GOOD RELATIONS WITH THE NATO ALLIANCE.
# Expected:  ALGERIA HAS GOOD RELATIONS WITH THE NATO ALLIANCE.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 4672 ---
# Input:     U QKL UN KPLZDKHUK WJD K WSQ QSSVL.
# Decrypted: I WAS IN AUSTRALIA FOR A FEW WEEKS.
# Expected:  I WAS IN AUSTRALIA FOR A FEW WEEKS.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 10787 ---
# Input:     ZJR LZKDZSX RJKNUNB UN AKUN.
# Decrypted: TOM STARTED MOANING IN PAIN.
# Expected:  TOM STARTED MOANING IN PAIN.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 4294 ---
# Input:     NDIUIOQIWKV
# Decrypted: PROMOTIONAL
# Expected:  PROMOTIONAL
# Match:     ✅
# Char Accuracy: 11/11 (100.0%)
#
# --- Case 4166 ---
# Input:     CFT OYGX XJRIDTNTZ SA REE ZSNTJCSYAX RC CFT XSLFC YQ CFTSN CTRJFTN.
# Decrypted: THE BOYS SCAMPERED IN ALL DIRECTIONS AT THE SIGHT OF THEIR TEACHER.
# Expected:  THE BOYS SCAMPERED IN ALL DIRECTIONS AT THE SIGHT OF THEIR TEACHER.
# Match:     ✅
# Char Accuracy: 67/67 (100.0%)
#
# --- Case 15623 ---
# Input:     HLT VNC TVZW GSIUH HMD CLAMLSFD HLADHMDZ.
# Decrypted: TOM AND MARY BUILT THE DOGHOUSE TOGETHER.
# Expected:  TOM AND MARY BUILT THE DOGHOUSE TOGETHER.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 11831 ---
# Input:     GYU ZTXTNWT CFRC.
# Decrypted: YOU DESERVE THAT.
# Expected:  YOU DESERVE THAT.
# Match:     ✅
# Char Accuracy: 17/17 (100.0%)
#
# --- Case 10744 ---
# Input:     XEJKXEF
# Decrypted: DECADES
# Expected:  DECADES
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 8930 ---
# Input:     QTRQ XRZ R CDAV USN ZGAJASZD.
# Decrypted: THAT WAS A VERY BIG SURPRISE.
# Expected:  THAT WAS A VERY BIG SURPRISE.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 10430 ---
# Input:     LDSNTUHA
# Decrypted: NEIGHBOR
# Expected:  NEIGHBOR
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 2147 ---
# Input:     U QKNZ ZJ MS RJDS UNXSASNXSNZ.
# Decrypted: I WANT TO BE MORE INDEPENDENT.
# Expected:  I WANT TO BE MORE INDEPENDENT.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 5735 ---
# Input:     S TDBJDF QHK NDQ HGQ HW QTRQ KDZZ.
# Decrypted: I HELPED TOM GET OUT OF THAT MESS.
# Expected:  I HELPED TOM GET OUT OF THAT MESS.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 19898 ---
# Input:     BD UIRD LSZ UITIHDC UIJD IN HMD XLLZCINVHD FWFHDT LJ HITD VNC TLNDW.
# Decrypted: WE LIVE OUR LIMITED LIFE IN THE COORDINATE SYSTEM OF TIME AND MONEY.
# Expected:  WE LIVE OUR LIMITED LIFE IN THE COORDINATE SYSTEM OF TIME AND MONEY.
# Match:     ✅
# Char Accuracy: 68/68 (100.0%)
#
# --- Case 2663 ---
# Input:     HLT BVF ZIAMH NLH HL CL HMVH.
# Decrypted: TOM WAS RIGHT NOT TO DO THAT.
# Expected:  TOM WAS RIGHT NOT TO DO THAT.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 14606 ---
# Input:     XRIS VRX ZYAT DTTSAL.
# Decrypted: SAMI WAS DONE PEEING.
# Expected:  SAMI WAS DONE PEEING.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 19279 ---
# Input:     DEVESKWO
# Decrypted: RELEVANT
# Expected:  RELEVANT
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 19033 ---
# Input:     UVBN
# Decrypted: LAWN
# Expected:  LAWN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 19408 ---
# Input:     HLT BVNHF TD HL BVIH JLZ TVZW.
# Decrypted: TOM WANTS ME TO WAIT FOR MARY.
# Expected:  TOM WANTS ME TO WAIT FOR MARY.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 8361 ---
# Input:     DRWSESYA
# Decrypted: PAVILION
# Expected:  PAVILION
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 587 ---
# Input:     ZJR QKNZL ZJ MS K XKNGSD.
# Decrypted: TOM WANTS TO BE A DANCER.
# Expected:  TOM WANTS TO BE A DANCER.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 10106 ---
# Input:     PSNS VTAC SA.
# Decrypted: ZIRI WENT IN.
# Expected:  ZIRI WENT IN.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 17002 ---
# Input:     U TKX ZJ DPN KQKF WDJR SNDKBSX ZJR.
# Decrypted: I HAD TO RUN AWAY FROM ENRAGED TOM.
# Expected:  I HAD TO RUN AWAY FROM ENRAGED TOM.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 3195 ---
# Input:     XD WSLSZTDF QTD KRQPT.
# Decrypted: WE FINISHED THE MATCH.
# Expected:  WE FINISHED THE MATCH.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 17227 ---
# Input:     ZTKZ QKL K EPSLZUJN ZJR LSSRSX DSKXF WJD.
# Decrypted: THAT WAS A QUESTION TOM SEEMED READY FOR.
# Expected:  THAT WAS A QUESTION TOM SEEMED READY FOR.
# Match:     ✅
# Char Accuracy: 41/41 (100.0%)
#
# --- Case 2954 ---
# Input:     OHQF QF AQWX IT K XDKR.
# Decrypted: THIS IS KIND OF A DRAG.
# Expected:  THIS IS KIND OF A DRAG.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 2267 ---
# Input:     DJHS
# Decrypted: ROLE
# Expected:  ROLE
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 9445 ---
# Input:     FSZPGZZSHL ZTDF BSNTQ HL QTD ZHBGQSHL.
# Decrypted: DISCUSSION SHED LIGHT ON THE SOLUTION.
# Expected:  DISCUSSION SHED LIGHT ON THE SOLUTION.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 6179 ---
# Input:     OHE UKVVF QW OHE CWQSEDFQOZ LEDE VQWEX LQOH ODEEF.
# Decrypted: THE MALLS IN THE UNIVERSITY WERE LINED WITH TREES.
# Expected:  THE MALLS IN THE UNIVERSITY WERE LINED WITH TREES.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 11305 ---
# Input:     QHK XRLQZ QH QRBY QH KD RNRSL.
# Decrypted: TOM WANTS TO TALK TO ME AGAIN.
# Expected:  TOM WANTS TO TALK TO ME AGAIN.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 11633 ---
# Input:     HLT HZIDC.
# Decrypted: TOM TRIED.
# Expected:  TOM TRIED.
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 5533 ---
# Input:     ZDPSGUIX
# Decrypted: REPUBLIC
# Expected:  REPUBLIC
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 11344 ---
# Input:     PDCWI UISEX IW OI OHE WEMO DIIU.
# Decrypted: BRUNO MOVED ON TO THE NEXT ROOM.
# Expected:  BRUNO MOVED ON TO THE NEXT ROOM.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 4510 ---
# Input:     FDWDPQZ
# Decrypted: DEFECTS
# Expected:  DEFECTS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 9056 ---
# Input:     CFT VFYET CFSAL VRX JRULFC YA JJCW.
# Decrypted: THE WHOLE THING WAS CAUGHT ON CCTV.
# Expected:  THE WHOLE THING WAS CAUGHT ON CCTV.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 19553 ---
# Input:     AFT
# Decrypted: NHE
# Expected:  GSM
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 4047 ---
# Input:     ZJR QKNZL ZJ MPF K AJNF WJD TUL LJN.
# Decrypted: TOM WANTS TO BUY A PONY FOR HIS SON.
# Expected:  TOM WANTS TO BUY A PONY FOR HIS SON.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 13142 ---
# Input:     SDA
# Decrypted: IPN
# Expected:  ERP
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 1281 ---
# Input:     JFTJB IG QRJTOYYB DRLT.
# Decrypted: CHECK MY FACEBOOK PAGE.
# Expected:  CHECK MY FACEBOOK PAGE.
# Match:     ✅
# Char Accuracy: 23/23 (100.0%)
#
# --- Case 5218 ---
# Input:     FSPDZRIFLZ
# Decrypted: SUPERVISOR
# Expected:  SUPERVISOR
# Match:     ✅
# Char Accuracy: 10/10 (100.0%)
#
# --- Case 14760 ---
# Input:     NSCD QTRQ UHHY QH RLVHLD XTH XRLQZ SQ.
# Decrypted: GIVE THAT BOOK TO ANYONE WHO WANTS IT.
# Expected:  GIVE THAT BOOK TO ANYONE WHO WANTS IT.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 4922 ---
# Input:     ZJR KNX RKDF LKUX ZTKZ ZTSF ZTUNV QS GJPHX XJ ZTKZ.
# Decrypted: TOM AND MARY SAID THAT THEY THINK WE COULD DO THAT.
# Expected:  TOM AND MARY SAID THAT THEY THINK WE COULD DO THAT.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 9876 ---
# Input:     EYNTAPY DTTBTZ UAZTN CFT JNRJB RC CFT OYCCYI YQ CFT OESAZX.
# Decrypted: LORENZO PEEKED UNDER THE CRACK AT THE BOTTOM OF THE BLINDS.
# Expected:  LORENZO PEEKED UNDER THE CRACK AT THE BOTTOM OF THE BLINDS.
# Match:     ✅
# Char Accuracy: 59/59 (100.0%)
#
# --- Case 8604 ---
# Input:     Q LQVV PE KO HIUE LHEW HE JIUEF WEMO.
# Decrypted: I WILL BE AT HOME WHEN HE COMES NEXT.
# Expected:  I WILL BE AT HOME WHEN HE COMES NEXT.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 10819 ---
# Input:     FKUQ HEVNEX VKZVK TQWX TKDQX.
# Decrypted: SAMI HELPED LAYLA FIND FARID.
# Expected:  SAMI HELPED LAYLA FIND FARID.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 14215 ---
# Input:     ZRJ
# Decrypted: DAC
# Expected:  SAP
# Match:     ❌
# Char Accuracy: 1/3 (33.3%)
#
# --- Case 13547 ---
# Input:     QS QUHH APNULT ZTSR.
# Decrypted: WE WILL PUNISH THEM.
# Expected:  WE WILL PUNISH THEM.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 2639 ---
# Input:     FQWRKNIDE
# Decrypted: SINGAPORE
# Expected:  SINGAPORE
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 3546 ---
# Input:     NYWTN
# Decrypted: ROVER
# Expected:  ROVER
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 9667 ---
# Input:     QS QSNZ JPZ WJD K QTUHS.
# Decrypted: WE WENT OUT FOR A WHILE.
# Expected:  WE WENT OUT FOR A WHILE.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 15358 ---
# Input:     TW CZDVT BDNH SP IN FTLYD.
# Decrypted: MY DREAM WENT UP IN SMOKE.
# Expected:  MY DREAM WENT UP IN SMOKE.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 15257 ---
# Input:     U NSSX K BJJX WDSNGT XUGZUJNKDF.
# Decrypted: I NEED A GOOD FRENCH DICTIONARY.
# Expected:  I NEED A GOOD FRENCH DICTIONARY.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 5169 ---
# Input:     HE LKF LHKJAEX ICO.
# Decrypted: HE WAS WHACKED OUT.
# Expected:  HE WAS WHACKED OUT.
# Match:     ✅
# Char Accuracy: 19/19 (100.0%)
#
# --- Case 9499 ---
# Input:     XYQPICOQ QF KW KDKP JICWODZ.
# Decrypted: DJIBOUTI IS AN ARAB COUNTRY.
# Expected:  DJIBOUTI IS AN ARAB COUNTRY.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 14101 ---
# Input:     VT XRV R OUAJF YQ OSNZX.
# Decrypted: WE SAW A BUNCH OF BIRDS.
# Expected:  WE SAW A BUNCH OF BIRDS.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 6333 ---
# Input:     TVNW DSZLPDVNF VZD TSUHIUINASVU.
# Decrypted: MANY EUROPEANS ARE MULTILINGUAL.
# Expected:  MANY EUROPEANS ARE MULTILINGUAL.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 11001 ---
# Input:     IRNG CFYULFC XFT VRX CFT YAEG YAT VFY BATV FYV CY ZY CFRC.
# Decrypted: MARY THOUGHT SHE WAS THE ONLY ONE WHO KNEW HOW TO DO THAT.
# Expected:  MARY THOUGHT SHE WAS THE ONLY ONE WHO KNEW HOW TO DO THAT.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 16613 ---
# Input:     HMDFD VZD HMD BLZCF HL UDVZN.
# Decrypted: THESE ARE THE WORDS TO LEARN.
# Expected:  THESE ARE THE WORDS TO LEARN.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 18136 ---
# Input:     VSXZYI FTEDX UX ARWSLRCT JFRALT.
# Decrypted: WISDOM HELPS US NAVIGATE CHANGE.
# Expected:  WISDOM HELPS US NAVIGATE CHANGE.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 8876 ---
# Input:     REOTNCY QTEC ESBT SXROTEER VRX EYYBSAL RC FSI.
# Decrypted: ALBERTO FELT LIKE ISABELLA WAS LOOKING AT HIM.
# Expected:  ALBERTO FELT LIKE ISABELLA WAS LOOKING AT HIM.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 2443 ---
# Input:     BD AVRD FVZVM HMD VPPUD.
# Decrypted: WE GAVE SARAH THE APPLE.
# Expected:  WE GAVE SARAH THE APPLE.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 6075 ---
# Input:     ZTD BHZQ QTD DBDPQSHL.
# Decrypted: SHE LOST THE ELECTION.
# Expected:  SHE LOST THE ELECTION.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 13239 ---
# Input:     OIU FKQX OHKO UKDZ QF NDEOOZ RIIX KO NVKZQWR OHE NQKWI.
# Decrypted: TOM SAID THAT MARY IS PRETTY GOOD AT PLAYING THE PIANO.
# Expected:  TOM SAID THAT MARY IS PRETTY GOOD AT PLAYING THE PIANO.
# Match:     ✅
# Char Accuracy: 55/55 (100.0%)
#
# --- Case 8104 ---
# Input:     XIIU
# Decrypted: CIIL
# Expected:  DOOM
# Match:     ❌
# Char Accuracy: 0/4 (0.0%)
#
# --- Case 14990 ---
# Input:     VRLLS ZRQ LDRA QTD FHHA.
# Decrypted: YANNI SAT NEAR THE DOOR.
# Expected:  YANNI SAT NEAR THE DOOR.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 1571 ---
# Input:     LSWT CYI CFT IYATG CFRC GYU YVT FSI.
# Decrypted: GIVE TOM THE MONEY THAT YOU OWE HIM.
# Expected:  GIVE TOM THE MONEY THAT YOU OWE HIM.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 1399 ---
# Input:     XQX
# Decrypted: DID
# Expected:  DID
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 2282 ---
# Input:     LSZPA
# Decrypted: SETUP
# Expected:  SETUP
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 8652 ---
# Input:     TS ZJHX RS ZTKZ TS QKL WDUBTZSNSX.
# Decrypted: HE TOLD ME THAT HE WAS FRIGHTENED.
# Expected:  HE TOLD ME THAT HE WAS FRIGHTENED.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 9247 ---
# Input:     U QJPHX HUVS ZJ LASNX ZTS DSLZ JW RF HUWS QUZT FJP.
# Decrypted: I WOULD LIKE TO SPEND THE REST OF MY LIFE WITH YOU.
# Expected:  I WOULD LIKE TO SPEND THE REST OF MY LIFE WITH YOU.
# Match:     ✅
# Char Accuracy: 51/51 (100.0%)
#
# --- Case 17307 ---
# Input:     TS GKPBTZ K BHURALS JW ZTS XDUISD KL ZTS ZDKUN DKGSX AKLZ.
# Decrypted: HE CAUGHT A GLIMPSE OF THE DRIVER AS THE TRAIN RACED PAST.
# Expected:  HE CAUGHT A GLIMPSE OF THE DRIVER AS THE TRAIN RACED PAST.
# Match:     ✅
# Char Accuracy: 58/58 (100.0%)
#
# --- Case 2022 ---
# Input:     FJP LTJPHX GJNLUXSD ZKVUNB K IKGKZUJN.
# Decrypted: YOU SHOULD CONSIDER TAKING A VACATION.
# Expected:  YOU SHOULD CONSIDER TAKING A VACATION.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 18708 ---
# Input:     HLT XLSUC CL DRDZWHMINA MD MVC HL CL.
# Decrypted: TOM COULD DO EVERYTHING HE HAD TO DO.
# Expected:  TOM COULD DO EVERYTHING HE HAD TO DO.
# Match:     ✅
# Char Accuracy: 37/37 (100.0%)
#
# --- Case 17133 ---
# ...
#
# --- Case 1826 ---
# Input:     EUBRX JYUEZ ORNTEG IYWT.
# Decrypted: LUKAS COULD BARELY MOVE.
# Expected:  LUKAS COULD BARELY MOVE.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 15973 ---
# Input:     TVZW HLUC HLT HMVH FMD BVF HMZLSAM CLINA HMVH.
# Decrypted: MARY TOLD TOM THAT SHE WAS THROUGH DOING THAT.
# Expected:  MARY TOLD TOM THAT SHE WAS THROUGH DOING THAT.
# Match:     ✅
# Char Accuracy: 46/46 (100.0%)
#
# --- Case 9316 ---
# Input:     IRNG EYYBTZ SACY FTN ORL RAZ NTRESPTZ CFRC FTN JYIDUCTN FRZ OTTA XCYETA.
# Decrypted: MARY LOOKED INTO HER BAG AND REALIZED THAT HER COMPUTER HAD BEEN STOLEN.
# Expected:  MARY LOOKED INTO HER BAG AND REALIZED THAT HER COMPUTER HAD BEEN STOLEN.
# Match:     ✅
# Char Accuracy: 72/72 (100.0%)
#
# --- Case 4011 ---
# Input:     XFT BTDC LYSAL.
# Decrypted: SHE KEPT GOING.
# Expected:  SHE KEPT GOING.
# Match:     ✅
# Char Accuracy: 15/15 (100.0%)
#
# --- Case 340 ---
# Input:     QTRQ XRZ FDJADZZSLN.
# Decrypted: THAT WAS DEPRESSING.
# Expected:  THAT WAS DEPRESSING.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 13755 ---
# Input:     DCDAV ZDRQ XRZ WGBB.
# Decrypted: EVERY SEAT WAS FULL.
# Expected:  EVERY SEAT WAS FULL.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 4418 ---
# Input:     HMD AVZGVAD CIFPLFVU SNIH XLNNDXHDC HL MDZ YIHXMDN FINY FHLPPDC BLZYINA.
# Decrypted: THE GARBAGE DISPOSAL UNIT CONNECTED TO HER KITCHEN SINK STOPPED WORKING.
# Expected:  THE GARBAGE DISPOSAL UNIT CONNECTED TO HER KITCHEN SINK STOPPED WORKING.
# Match:     ✅
# Char Accuracy: 72/72 (100.0%)
#
# --- Case 11321 ---
# Input:     CFTNT RNT XCUZTACX LYSAL CY XJFYYE.
# Decrypted: THERE ARE STUDENTS GOING TO SCHOOL.
# Expected:  THERE ARE STUDENTS GOING TO SCHOOL.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 15721 ---
# Input:     OYEZS JRA ZY RAGCFSAL FT VRACX.
# Decrypted: BOLDI CAN DO ANYTHING HE WANTS.
# Expected:  BOLDI CAN DO ANYTHING HE WANTS.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 14245 ---
# Input:     BRVBR XRZ ADRFV QH WSNTQ WHA QTD PRGZD.
# Decrypted: LAYLA WAS READY TO FIGHT FOR THE CAUSE.
# Expected:  LAYLA WAS READY TO FIGHT FOR THE CAUSE.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 14721 ---
# Input:     S ATWTN UAZTNXCYYZ CFSX.
# Decrypted: I NEVER UNDERSTOOD THIS.
# Expected:  I NEVER UNDERSTOOD THIS.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 8139 ---
# Input:     WIWE IT OHEFE KNNVEF KDE DQNE ZEO.
# Decrypted: NONE OF THESE APPLES ARE RIPE YET.
# Expected:  NONE OF THESE APPLES ARE RIPE YET.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 4129 ---
# Input:     OIU KWX UKDZ PICRHO FIUE WEL TCDWQOCDE.
# Decrypted: TOM AND MARY BOUGHT SOME NEW FURNITURE.
# Expected:  TOM AND MARY BOUGHT SOME NEW FURNITURE.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 6742 ---
# Input:     LPUZL
# Decrypted: SUITS
# Expected:  SUITS
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 17669 ---
# Input:     JIVVEJO ZICD REKD.
# Decrypted: COLLECT YOUR GEAR.
# Expected:  COLLECT YOUR GEAR.
# Match:     ✅
# Char Accuracy: 18/18 (100.0%)
#
# --- Case 15463 ---
# Input:     HLT VNC TVZW VZD ADHHINA V CIRLZXD.
# Decrypted: TOM AND MARY ARE GETTING A DIVORCE.
# Expected:  TOM AND MARY ARE GETTING A DIVORCE.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 2217 ---
# Input:     RKDF ZDUSX NJZ ZJ HSZ TSD RUNX QKNXSD.
# Decrypted: MARY TRIED NOT TO LET HER MIND WANDER.
# Expected:  MARY TRIED NOT TO LET HER MIND WANDER.
# Match:     ✅
# Char Accuracy: 38/38 (100.0%)
#
# --- Case 9001 ---
# Input:     CYI EYYBTZ RNYUAZ RX SQ VRSCSAL QYN XYITCFSAL CY FRDDTA.
# Decrypted: TOM LOOKED AROUND AS IF WAITING FOR SOMETHING TO HAPPEN.
# Expected:  TOM LOOKED AROUND AS IF WAITING FOR SOMETHING TO HAPPEN.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 2996 ---
# Input:     RUZ
# Decrypted: AUD
# Expected:  AUD
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 15121 ---
# Input:     ZTIYJNRCX
# Decrypted: DEMOCRATS
# Expected:  DEMOCRATS
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 12430 ---
# Input:     S FSF DLHGNT WHA QHK.
# Decrypted: I DID ENOUGH FOR TOM.
# Expected:  I DID ENOUGH FOR TOM.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 19062 ---
# Input:     TS QJPHX NJZ HULZSN ZJ RF KXIUGS.
# Decrypted: HE WOULD NOT LISTEN TO MY ADVICE.
# Expected:  HE WOULD NOT LISTEN TO MY ADVICE.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 11115 ---
# Input:     KHLZQDA
# Decrypted: MONSTER
# Expected:  MONSTER
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 6504 ---
# Input:     IUKW
# Decrypted: OMAN
# Expected:  OMAN
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 19203 ---
# Input:     VNAUD
# Decrypted: ANGLE
# Expected:  ANGLE
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 12335 ---
# Input:     QTSZ SZ KV TGKUBD THGZD.
# Decrypted: THIS IS MY HUMBLE HOUSE.
# Expected:  THIS IS MY HUMBLE HOUSE.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 9452 ---
# Input:     U TJAS ZTKZ QS QUN ZTS GTKRAUJNLTUA.
# Decrypted: I HOPE THAT WE WIN THE CHAMPIONSHIP.
# Expected:  I HOPE THAT WE WIN THE CHAMPIONSHIP.
# Match:     ✅
# Char Accuracy: 36/36 (100.0%)
#
# --- Case 5084 ---
# Input:     NVEKFE JIWWEJO K JIWODIVVED.
# Decrypted: PLEASE CONNECT A CONTROLLER.
# Expected:  PLEASE CONNECT A CONTROLLER.
# Match:     ✅
# Char Accuracy: 28/28 (100.0%)
#
# --- Case 12315 ---
# Input:     QHK ZRSF QTRQ TD TRF QH QDBB ZHKDHLD RUHGQ TSZ JAHUBDKZ.
# Decrypted: TOM SAID THAT HE HAD TO TELL SOMEONE ABOUT HIS PROBLEMS.
# Expected:  TOM SAID THAT HE HAD TO TELL SOMEONE ABOUT HIS PROBLEMS.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 8479 ---
# Input:     ZKWWQ AWILF KVREDQK SEDZ LEVV.
# Decrypted: YANNI KNOWS ALGERIA VERY WELL.
# Expected:  YANNI KNOWS ALGERIA VERY WELL.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 15957 ---
# Input:     KLV ZJR NJZ ZJ QKUZ WJD RS.
# Decrypted: ASK TOM NOT TO WAIT FOR ME.
# Expected:  ASK TOM NOT TO WAIT FOR ME.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 16232 ---
# Input:     LJHUX
# Decrypted: SOLID
# Expected:  SOLID
# Match:     ✅
# Char Accuracy: 5/5 (100.0%)
#
# --- Case 9625 ---
# Input:     KRAV TRZ QHBF QHK ZTD TRZ QH BDRCD.
# Decrypted: MARY HAS TOLD TOM SHE HAS TO LEAVE.
# Expected:  MARY HAS TOLD TOM SHE HAS TO LEAVE.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 656 ---
# Input:     RCCTACSYA
# Decrypted: ATTENTION
# Expected:  ATTENTION
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 18964 ---
# Input:     SEVIJQOZ
# Decrypted: VELOCITY
# Expected:  VELOCITY
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 15419 ---
# Input:     OIU NDETEDF FKCFKRE KWX UKFHEX NIOKOIEF.
# Decrypted: TOM PREFERS SAUSAGE AND MASHED POTATOES.
# Expected:  TOM PREFERS SAUSAGE AND MASHED POTATOES.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 2590 ---
# Input:     ZRKS NHDZ HGQ DCDAV ZRQGAFRV LSNTQ.
# Decrypted: SAMI GOES OUT EVERY SATURDAY NIGHT.
# Expected:  SAMI GOES OUT EVERY SATURDAY NIGHT.
# Match:     ✅
# Char Accuracy: 35/35 (100.0%)
#
# --- Case 15403 ---
# Input:     I VCTIZD MIF HVUDNH.
# Decrypted: I ADMIRE HIS TALENT.
# Expected:  I ADMIRE HIS TALENT.
# Match:     ✅
# Char Accuracy: 20/20 (100.0%)
#
# --- Case 5981 ---
# Input:     ZYEERN
# Decrypted: DOLLAR
# Expected:  DOLLAR
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 7827 ---
# Input:     KHBUSDL NSSXL ZJ CJUN ZTS DKNV JW ZTS RJLZ RJXSDN GUZUSL UN ZTS QJDHX.
# Decrypted: ALGIERS NEEDS TO JOIN THE RANK OF THE MOST MODERN CITIES IN THE WORLD.
# Expected:  ALGIERS NEEDS TO JOIN THE RANK OF THE MOST MODERN CITIES IN THE WORLD.
# Match:     ✅
# Char Accuracy: 70/70 (100.0%)
#
# --- Case 3351 ---
# Input:     CNSUIDF
# Decrypted: DNULIES
# Expected:  TRIUMPH
# Match:     ❌
# Char Accuracy: 0/7 (0.0%)
#
# --- Case 11734 ---
# Input:     NHN
# Decrypted: GOG
# Expected:  PHP
# Match:     ❌
# Char Accuracy: 0/3 (0.0%)
#
# --- Case 8417 ---
# Input:     XPNB MSSZHSL XSASNX JN ZTS GJQL ZJ AJJA LJ ZTKZ ZTSF GKN BSZ ZTSUD WJJX.
# Decrypted: DUNG BEETLES DEPEND ON THE COWS TO POOP SO THAT THEY CAN GET THEIR FOOD.
# Expected:  DUNG BEETLES DEPEND ON THE COWS TO POOP SO THAT THEY CAN GET THEIR FOOD.
# Match:     ✅
# Char Accuracy: 72/72 (100.0%)
#
# --- Case 6088 ---
# Input:     VXND
# Decrypted: ACNE
# Expected:  ACNE
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 3224 ---
# Input:     ZIC FHKDNEWEX OHE AWQSEF.
# Decrypted: YOU SHARPENED THE KNIVES.
# Expected:  YOU SHARPENED THE KNIVES.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 12884 ---
# Input:     HCWO
# Decrypted: HUNT
# Expected:  HUNT
# Match:     ✅
# Char Accuracy: 4/4 (100.0%)
#
# --- Case 12336 ---
# Input:     SC VRX RA RVQUE IYWST.
# Decrypted: IT WAS AN AWFUL MOVIE.
# Expected:  IT WAS AN AWFUL MOVIE.
# Match:     ✅
# Char Accuracy: 22/22 (100.0%)
#
# --- Case 8366 ---
# Input:     CYI RXBTZ IT SQ FT JYUEZ LY FYIT TRNEG CYZRG.
# Decrypted: TOM ASKED ME IF HE COULD GO HOME EARLY TODAY.
# Expected:  TOM ASKED ME IF HE COULD GO HOME EARLY TODAY.
# Match:     ✅
# Char Accuracy: 45/45 (100.0%)
#
# --- Case 11079 ---
# Input:     XIQWR OHKO LICVX PE XQTTQJCVO WIL.
# Decrypted: DOING THAT WOULD BE DIFFICULT NOW.
# Expected:  DOING THAT WOULD BE DIFFICULT NOW.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3616 ---
# Input:     CYI RAZ IRNG LYC IRNNSTZ VFTA CFTG VTNT XCSEE CTTARLTNX.
# Decrypted: TOM AND MARY GOT MARRIED WHEN THEY WERE STILL TEENAGERS.
# Expected:  TOM AND MARY GOT MARRIED WHEN THEY WERE STILL TEENAGERS.
# Match:     ✅
# Char Accuracy: 56/56 (100.0%)
#
# --- Case 17786 ---
# Input:     S LNTV UD VSCF CFTXT CW XFYVX.
# Decrypted: I GREW UP WITH THESE TV SHOWS.
# Expected:  I GREW UP WITH THESE TV SHOWS.
# Match:     ✅
# Char Accuracy: 30/30 (100.0%)
#
# --- Case 450 ---
# Input:     UADRYFHXL
# Decrypted: BREAKDOWN
# Expected:  BREAKDOWN
# Match:     ✅
# Char Accuracy: 9/9 (100.0%)
#
# --- Case 14862 ---
# Input:     ZTUL GKZ VNJGVSX JISD ZTS GKN JW GKNNSX WULT LJ ZTKZ UZ GJPHX SKZ UZ.
# Decrypted: THIS CAT KNOCKED OVER THE CAN OF CANNED FISH SO THAT IT COULD EAT IT.
# Expected:  THIS CAT KNOCKED OVER THE CAN OF CANNED FISH SO THAT IT COULD EAT IT.
# Match:     ✅
# Char Accuracy: 69/69 (100.0%)
#
# --- Case 10045 ---
# Input:     QHK ZQSBB TRZ ZHKD GLWSLSZTDF UGZSLDZZ.
# Decrypted: TOM STILL HAS SOME UNFINISHED BUSINESS.
# Expected:  TOM STILL HAS SOME UNFINISHED BUSINESS.
# Match:     ✅
# Char Accuracy: 39/39 (100.0%)
#
# --- Case 11419 ---
# Input:     FCNNVQEX
# Decrypted: SUPPLIED
# Expected:  SUPPLIED
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 15619 ---
# Input:     PDILFEDF
# Decrypted: BROWSERS
# Expected:  BROWSERS
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 6408 ---
# Input:     IH VUFL FVWF HMVH XLTPVNIDF DEIFHINA JLZ V ULNA HITD VZD RDZW ZDUIVGUD.
# Decrypted: IT ALSO SAYS THAT COMPANIES EXISTING FOR A LONG TIME ARE VERY RELIABLE.
# Expected:  IT ALSO SAYS THAT COMPANIES EXISTING FOR A LONG TIME ARE VERY RELIABLE.
# Match:     ✅
# Char Accuracy: 71/71 (100.0%)
#
# --- Case 8697 ---
# Input:     FKNNU QUHH MS UN KHBUSDL.
# Decrypted: YANNI WILL BE IN ALGIERS.
# Expected:  YANNI WILL BE IN ALGIERS.
# Match:     ✅
# Char Accuracy: 25/25 (100.0%)
#
# --- Case 19475 ---
# Input:     S PRL QDBB VHG PRADF RUHGQ QTDK.
# Decrypted: I CAN TELL YOU CARED ABOUT THEM.
# Expected:  I CAN TELL YOU CARED ABOUT THEM.
# Match:     ✅
# Char Accuracy: 32/32 (100.0%)
#
# --- Case 11077 ---
# Input:     XJUNB ZTKZ QJPHX MS XUWWUGPHZ NJQ.
# Decrypted: DOING THAT WOULD BE DIFFICULT NOW.
# Expected:  DOING THAT WOULD BE DIFFICULT NOW.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 5816 ---
# Input:     CFT OTCNRGRE YQ R QNSTAZ SX R NTRE CNRLTZG.
# Decrypted: THE BETRAYAL OF A FRIEND IS A REAL TRAGEDY.
# Expected:  THE BETRAYAL OF A FRIEND IS A REAL TRAGEDY.
# Match:     ✅
# Char Accuracy: 43/43 (100.0%)
#
# --- Case 536 ---
# Input:     S XRV GYU CREBSAL VSCF CYI.
# Decrypted: I SAW YOU TALKING WITH TOM.
# Expected:  I SAW YOU TALKING WITH TOM.
# Match:     ✅
# Char Accuracy: 27/27 (100.0%)
#
# --- Case 9235 ---
# Input:     ZTD XRZ WHAPDF SLQH KRAASRND.
# Decrypted: SHE WAS FORCED INTO MARRIAGE.
# Expected:  SHE WAS FORCED INTO MARRIAGE.
# Match:     ✅
# Char Accuracy: 29/29 (100.0%)
#
# --- Case 14621 ---
# Input:     CFRC CFT VTO SX QUEE YQ DSCQREEX SX JYIIYA BAYVETZLT.
# Decrypted: THAT THE WEB IS FULL OF PITFALLS IS COMMON KNOWLEDGE.
# Expected:  THAT THE WEB IS FULL OF PITFALLS IS COMMON KNOWLEDGE.
# Match:     ✅
# Char Accuracy: 53/53 (100.0%)
#
# --- Case 5427 ---
# Input:     QS PALSZ ZJR.
# Decrypted: WE UPSET TOM.
# Expected:  WE UPSET TOM.
# Match:     ✅
# Char Accuracy: 13/13 (100.0%)
#
# --- Case 11021 ---
# Input:     FTRWTA JRA VRSC.
# Decrypted: HEAVEN CAN WAIT.
# Expected:  HEAVEN CAN WAIT.
# Match:     ✅
# Char Accuracy: 16/16 (100.0%)
#
# --- Case 2426 ---
# Input:     VT RNT TMJSCTZ ROYUC CFT IYWT CY CFT ATV OUSEZSAL.
# Decrypted: WE ARE EXCITED ABOUT THE MOVE TO THE NEW BUILDING.
# Expected:  WE ARE EXCITED ABOUT THE MOVE TO THE NEW BUILDING.
# Match:     ✅
# Char Accuracy: 50/50 (100.0%)
#
# --- Case 1837 ---
# Input:     MKDMKXJL
# Decrypted: BARBADOS
# Expected:  BARBADOS
# Match:     ✅
# Char Accuracy: 8/8 (100.0%)
#
# --- Case 10355 ---
# Input:     BRVBR XRLQDF QH WSLF KA. ASNTQ.
# Decrypted: LAYLA WANTED TO FIND MR. RIGHT.
# Expected:  LAYLA WANTED TO FIND MR. RIGHT.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 4743 ---
# Input:     NLHMINA FDDTF HL MVRD MVPPDNDC.
# Decrypted: NOTHING SEEMS TO HAVE HAPPENED.
# Expected:  NOTHING SEEMS TO HAVE HAPPENED.
# Match:     ✅
# Char Accuracy: 31/31 (100.0%)
#
# --- Case 10464 ---
# Input:     HIDQBIW
# Decrypted: HORIZON
# Expected:  HORIZON
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 7464 ---
# Input:     OIU QF SEDZ EKRED OI RI LQOH ZIC.
# Decrypted: TOM IS VERY EAGER TO GO WITH YOU.
# Expected:  TOM IS VERY EAGER TO GO WITH YOU.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 17299 ---
# Input:     OIU QF ODZQWR OI FEVV HQF IVX JKD.
# Decrypted: TOM IS TRYING TO SELL HIS OLD CAR.
# Expected:  TOM IS TRYING TO SELL HIS OLD CAR.
# Match:     ✅
# Char Accuracy: 34/34 (100.0%)
#
# --- Case 3464 ---
# Input:     Q FKL HED IWVZ K LEEA KRI.
# Decrypted: I SAW HER ONLY A WEEK AGO.
# Expected:  I SAW HER ONLY A WEEK AGO.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 14635 ---
# Input:     TD XRZ RKRIDF.
# Decrypted: HE WAS AMAZED.
# Expected:  HE WAS AMAZED.
# Match:     ✅
# Char Accuracy: 14/14 (100.0%)
#
# --- Case 2681 ---
# Input:     RXF
# Decrypted: ASH
# Expected:  ASH
# Match:     ✅
# Char Accuracy: 3/3 (100.0%)
#
# --- Case 10120 ---
# Input:     ERPY SLZSZQZ QTRQ TD TRZ LHQTSLN QH FH XSQT QTD PASKD.
# Decrypted: JACK INSISTS THAT HE HAS NOTHING TO DO WITH THE CRIME.
# Expected:  JACK INSISTS THAT HE HAS NOTHING TO DO WITH THE CRIME.
# Match:     ✅
# Char Accuracy: 54/54 (100.0%)
#
# --- Case 6374 ---
# Input:     FHE LKF PIDW QWOI K SEDZ DEVQRQICF TKUQVZ.
# Decrypted: SHE WAS BORN INTO A VERY RELIGIOUS FAMILY.
# Expected:  SHE WAS BORN INTO A VERY RELIGIOUS FAMILY.
# Match:     ✅
# Char Accuracy: 42/42 (100.0%)
#
# --- Case 1891 ---
# Input:     XTJCYNX
# Decrypted: SECTORS
# Expected:  SECTORS
# Match:     ✅
# Char Accuracy: 7/7 (100.0%)
#
# --- Case 1039 ---
# Input:     DEFIDO
# Decrypted: RESORT
# Expected:  RESORT
# Match:     ✅
# Char Accuracy: 6/6 (100.0%)
#
# --- Case 17605 ---
# Input:     S TRCD LH ADNADQZ RUHGQ ADQSASLN.
# Decrypted: I HAVE NO REGRETS ABOUT RETIRING.
# Expected:  I HAVE NO REGRETS ABOUT RETIRING.
# Match:     ✅
# Char Accuracy: 33/33 (100.0%)
#
# --- Case 12558 ---
# Input:     HLT HLUC TD MD HMLSAMH TVZW ULLYDC PVUD.
# Decrypted: TOM TOLD ME HE THOUGHT MARY LOOKED PALE.
# Expected:  TOM TOLD ME HE THOUGHT MARY LOOKED PALE.
# Match:     ✅
# Char Accuracy: 40/40 (100.0%)
#
# --- Case 4074 ---
# Input:     OHEZ KDE TQVOHZ DQJH.
# Decrypted: THEY ARE FILTHY RICH.
# Expected:  THEY ARE FILTHY RICH.
# Match:     ✅
# Char Accuracy: 21/21 (100.0%)
#
# --- Case 7443 ---
# Input:     TVZW BVNHF MDZ TLNDW GVXY.
# Decrypted: MARY WANTS HER MONEY BACK.
# Expected:  MARY WANTS HER MONEY BACK.
# Match:     ✅
# Char Accuracy: 26/26 (100.0%)
#
# --- Case 10000 ---
# Input:     KRAV PBDRADF TDA QTAHRQ.
# Decrypted: MARY CLEARED HER THROAT.
# Expected:  MARY CLEARED HER THROAT.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 1871 ---
# Input:     FT VRX XVTRCSAL OUEETCX.
# Decrypted: HE WAS SWEATING BULLETS.
# Expected:  HE WAS SWEATING BULLETS.
# Match:     ✅
# Char Accuracy: 24/24 (100.0%)
#
# --- Case 15197 ---
# Input:     TFMDUX
# Decrypted: EHXPUS
# Expected:  HYBRID
# Match:     ❌
# Char Accuracy: 0/6 (0.0%)
#
# Full results saved to /content/drive/MyDrive/inference_mono_five_vanilla.xlsx
#
# === Final Summary ===
# Full-match accuracy: 3890/4000
# Character-level accuracy: 113304/113734 (99.62%)
