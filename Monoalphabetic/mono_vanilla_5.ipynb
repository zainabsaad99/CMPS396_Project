# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import Counter
import string

# Data Preparation
def load_data(file_path):
    df = pd.read_excel(file_path)

    df = df[df['output'].str.len() <= 200]

    # Get the count of such rows
    count_filtered = len(df)

    if count_filtered > 400000:
        df = df.sample(n=400000, random_state=42)
    print(len(df))
    inputs = df['input'].astype(str).tolist()
    outputs = df['output'].astype(str).tolist()


    return inputs, outputs

# Tokenization and Vocabulary
class Vocabulary:
    def __init__(self):
        self.char2idx = {}
        self.idx2char = {}
        self.pad_token = 0
        self.sos_token = 1
        self.eos_token = 2
        self.unk_token = 3
        self._build_vocab()

    def _build_vocab(self):
        # Special tokens
        special_tokens = ['<PAD>', '<SOS>', '<EOS>', '<UNK>']
        # All printable characters
        all_chars = list(string.printable)

        # Create vocabulary
        self.char2idx = {token: idx for idx, token in enumerate(special_tokens)}
        self.char2idx.update({char: idx+len(special_tokens) for idx, char in enumerate(all_chars)})

        # Reverse mapping
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def __len__(self):
        return len(self.char2idx)

    def encode(self, text):
        return [self.char2idx.get(char, self.unk_token) for char in text]

    def decode(self, indices):
        return ''.join([self.idx2char.get(idx, '<UNK>') for idx in indices if idx not in {self.pad_token, self.sos_token, self.eos_token}])

# Dataset Class
class CipherDataset(data.Dataset):
    def __init__(self, inputs, outputs, vocab, max_length):
        self.inputs = inputs
        self.outputs = outputs
        self.vocab = vocab
        self.max_length = max_length

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_text = self.inputs[idx]
        output_text = self.outputs[idx]

        # Encode with SOS and EOS tokens
        input_encoded = [self.vocab.sos_token] + self.vocab.encode(input_text) + [self.vocab.eos_token]
        output_encoded = [self.vocab.sos_token] + self.vocab.encode(output_text) + [self.vocab.eos_token]

        # Pad sequences
        input_padded = input_encoded + [self.vocab.pad_token] * (self.max_length - len(input_encoded))
        output_padded = output_encoded + [self.vocab.pad_token] * (self.max_length - len(output_encoded))

        # Truncate if necessary
        input_padded = input_padded[:self.max_length]
        output_padded = output_padded[:self.max_length]

        return torch.tensor(input_padded), torch.tensor(output_padded)

# Transformer Model (same as your implementation)
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Q, K, V shapes: (batch_size, num_heads, seq_len, d_k)
        d_k = Q.size(-1)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, float('-inf'))

        attn_probs = torch.softmax(scores, dim=-1)
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        output = self.W_o(self.combine_heads(attn_output))
        return output

class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        # Source mask
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, src_len)

        # Target mask
        tgt_pad_mask = (tgt != 0).unsqueeze(1).unsqueeze(2)  # (batch_size, 1, 1, tgt_len)
        tgt_len = tgt.size(1)
        tgt_sub_mask = torch.tril(torch.ones((tgt_len, tgt_len), device=tgt.device)).bool()
        tgt_mask = tgt_pad_mask & tgt_sub_mask  # (batch_size, 1, tgt_len, tgt_len)

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# Training Function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        total_loss = 0
        for batch_idx, (src, tgt) in enumerate(train_loader):
            src, tgt = src.to(device), tgt.to(device)

            optimizer.zero_grad()
            output = model(src, tgt[:, :-1])

            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if batch_idx % 10 == 0:
                print(f'Epoch: {epoch+1}, Batch: {batch_idx}, Loss: {loss.item():.4f}')

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        val_loss = evaluate_model(model, val_loader, criterion, device)
        print(f'Epoch: {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}')

        # Save best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), '/content/drive/MyDrive/mono_vanilla_5_keys.pth')

    return model

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for src, tgt in data_loader:
            src, tgt = src.to(device), tgt.to(device)
            output = model(src, tgt[:, :-1])
            loss = criterion(output.contiguous().view(-1, len(vocab)),
                           tgt[:, 1:].contiguous().view(-1))
            total_loss += loss.item()

    return total_loss / len(data_loader)

# Inference Function
def decrypt_text(model, text, vocab, max_length, device):
    model.eval()
    with torch.no_grad():
        # Encode the input text
        encoded = [vocab.sos_token] + vocab.encode(text) + [vocab.eos_token]
        encoded = encoded + [vocab.pad_token] * (max_length - len(encoded))
        encoded = torch.tensor(encoded[:max_length]).unsqueeze(0).to(device)

        # Initialize target with SOS token
        target = torch.tensor([[vocab.sos_token]]).to(device)

        for _ in range(max_length - 1):
            output = model(encoded, target)
            next_token = output.argmax(2)[:, -1].item()
            if next_token == vocab.eos_token:
                break
            target = torch.cat([target, torch.tensor([[next_token]]).to(device)], dim=1)

        # Decode the output
        decrypted = vocab.decode(target[0].cpu().numpy())
        return decrypted

# Main Execution
if __name__ == "__main__":
    # Load and prepare data
    inputs, outputs = load_data('/content/Full_training_mono_5.xlsx')

    # Create vocabulary
    vocab = Vocabulary()

    # Split data into train and validation
    train_inputs, val_inputs, train_outputs, val_outputs = train_test_split(
        inputs, outputs, test_size=0.2, random_state=42
    )

    # Create datasets
    max_length = 256
    train_dataset = CipherDataset(train_inputs, train_outputs, vocab, max_length)
    val_dataset = CipherDataset(val_inputs, val_outputs, vocab, max_length)

    # Create data loaders
    batch_size = 400
    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size)

    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Transformer(
        src_vocab_size=len(vocab),
        tgt_vocab_size=len(vocab),
        d_model=512,
        num_heads=2,
        num_layers=6,
        d_ff=256,
        max_seq_length=max_length,
        dropout=0.21983729110648678
    ).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss(ignore_index=vocab.pad_token)
    optimizer = optim.Adam(model.parameters(), lr=0.0003134263502032441, betas=(0.9, 0.98), eps=1e-9)

    # Train the model
    num_epochs = 30
    trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

    # Test the model
    test_text = "gfbs"  # Should decrypt to "fear"
    decrypted = decrypt_text(trained_model, test_text, vocab, max_length, device)
    print(f"Input: {test_text}, Decrypted: {decrypted}")
# Out:
# 179975
# Epoch: 1, Batch: 0, Loss: 4.8508
# Epoch: 1, Batch: 10, Loss: 3.0696
# Epoch: 1, Batch: 20, Loss: 3.0071
# Epoch: 1, Batch: 30, Loss: 2.9803
# Epoch: 1, Batch: 40, Loss: 2.9353
# Epoch: 1, Batch: 50, Loss: 2.7303
# Epoch: 1, Batch: 60, Loss: 2.4757
# Epoch: 1, Batch: 70, Loss: 2.3388
# Epoch: 1, Batch: 80, Loss: 2.2905
# Epoch: 1, Batch: 90, Loss: 2.2547
# Epoch: 1, Batch: 100, Loss: 2.2250
# Epoch: 1, Batch: 110, Loss: 2.1415
# Epoch: 1, Batch: 120, Loss: 2.1120
# Epoch: 1, Batch: 130, Loss: 2.0529
# Epoch: 1, Batch: 140, Loss: 2.0581
# Epoch: 1, Batch: 150, Loss: 1.9666
# Epoch: 1, Batch: 160, Loss: 1.9313
# Epoch: 1, Batch: 170, Loss: 1.8837
# Epoch: 1, Batch: 180, Loss: 1.8205
# Epoch: 1, Batch: 190, Loss: 1.6939
# Epoch: 1, Batch: 200, Loss: 1.6540
# Epoch: 1, Batch: 210, Loss: 1.5173
# Epoch: 1, Batch: 220, Loss: 1.4308
# Epoch: 1, Batch: 230, Loss: 1.3354
# Epoch: 1, Batch: 240, Loss: 1.2374
# Epoch: 1, Batch: 250, Loss: 1.0747
# Epoch: 1, Batch: 260, Loss: 0.9727
# Epoch: 1, Batch: 270, Loss: 0.7758
# Epoch: 1, Batch: 280, Loss: 0.6807
# Epoch: 1, Batch: 290, Loss: 0.5847
# Epoch: 1, Batch: 300, Loss: 0.5107
# Epoch: 1, Batch: 310, Loss: 0.4335
# Epoch: 1, Batch: 320, Loss: 0.4076
# Epoch: 1, Batch: 330, Loss: 0.3386
# Epoch: 1, Batch: 340, Loss: 0.3384
# Epoch: 1, Batch: 350, Loss: 0.2966
# Epoch: 1, Train Loss: 1.6595, Val Loss: 0.1793
# Epoch: 2, Batch: 0, Loss: 0.1983
# Epoch: 2, Batch: 10, Loss: 0.1599
# Epoch: 2, Batch: 20, Loss: 0.1515
# Epoch: 2, Batch: 30, Loss: 0.1115
# Epoch: 2, Batch: 40, Loss: 0.0932
# Epoch: 2, Batch: 50, Loss: 0.0983
# Epoch: 2, Batch: 60, Loss: 0.0721
# Epoch: 2, Batch: 70, Loss: 0.1379
# Epoch: 2, Batch: 80, Loss: 0.0860
# Epoch: 2, Batch: 90, Loss: 0.1148
# Epoch: 2, Batch: 100, Loss: 0.0741
# Epoch: 2, Batch: 110, Loss: 0.0526
# Epoch: 2, Batch: 120, Loss: 0.0397
# Epoch: 2, Batch: 130, Loss: 0.0642
# Epoch: 2, Batch: 140, Loss: 0.0516
# Epoch: 2, Batch: 150, Loss: 0.0345
# Epoch: 2, Batch: 160, Loss: 0.0462
# Epoch: 2, Batch: 170, Loss: 0.0499
# Epoch: 2, Batch: 180, Loss: 0.0337
# Epoch: 2, Batch: 190, Loss: 0.9038
# Epoch: 2, Batch: 200, Loss: 0.1418
# Epoch: 2, Batch: 210, Loss: 0.0698
# Epoch: 2, Batch: 220, Loss: 0.0365
# Epoch: 2, Batch: 230, Loss: 0.0454
# Epoch: 2, Batch: 240, Loss: 0.0781
# Epoch: 2, Batch: 250, Loss: 0.0235
# Epoch: 2, Batch: 260, Loss: 0.0414
# Epoch: 2, Batch: 270, Loss: 0.0285
# Epoch: 2, Batch: 280, Loss: 0.0392
# Epoch: 2, Batch: 290, Loss: 0.0360
# Epoch: 2, Batch: 300, Loss: 0.0544
# Epoch: 2, Batch: 310, Loss: 0.0678
# Epoch: 2, Batch: 320, Loss: 0.0287
# Epoch: 2, Batch: 330, Loss: 0.0316
# Epoch: 2, Batch: 340, Loss: 0.0322
# Epoch: 2, Batch: 350, Loss: 0.0211
# Epoch: 2, Train Loss: 0.0744, Val Loss: 0.0419
# Epoch: 3, Batch: 0, Loss: 0.0559
# Epoch: 3, Batch: 10, Loss: 0.0557
# Epoch: 3, Batch: 20, Loss: 0.0775
# Epoch: 3, Batch: 30, Loss: 0.0379
# Epoch: 3, Batch: 40, Loss: 0.0271
# Epoch: 3, Batch: 50, Loss: 0.0231
# Epoch: 3, Batch: 60, Loss: 0.0224
# Epoch: 3, Batch: 70, Loss: 0.0306
# Epoch: 3, Batch: 80, Loss: 0.0316
# Epoch: 3, Batch: 90, Loss: 0.0181
# Epoch: 3, Batch: 100, Loss: 0.0216
# Epoch: 3, Batch: 110, Loss: 0.0290
# Epoch: 3, Batch: 120, Loss: 0.0322
# Epoch: 3, Batch: 130, Loss: 0.0341
# Epoch: 3, Batch: 140, Loss: 0.0314
# Epoch: 3, Batch: 150, Loss: 0.0314
# Epoch: 3, Batch: 160, Loss: 0.0268
# Epoch: 3, Batch: 170, Loss: 0.0195
# Epoch: 3, Batch: 180, Loss: 0.0294
# Epoch: 3, Batch: 190, Loss: 0.0291
# Epoch: 3, Batch: 200, Loss: 0.0377
# Epoch: 3, Batch: 210, Loss: 0.0241
# Epoch: 3, Batch: 220, Loss: 0.0288
# Epoch: 3, Batch: 230, Loss: 0.0312
# Epoch: 3, Batch: 240, Loss: 0.0231
# Epoch: 3, Batch: 250, Loss: 0.0141
# Epoch: 3, Batch: 260, Loss: 0.0170
# Epoch: 3, Batch: 270, Loss: 0.0269
# Epoch: 3, Batch: 280, Loss: 0.0142
# Epoch: 3, Batch: 290, Loss: 0.0209
# Epoch: 3, Batch: 300, Loss: 0.1216
# Epoch: 3, Batch: 310, Loss: 0.0392
# Epoch: 3, Batch: 320, Loss: 0.0203
# Epoch: 3, Batch: 330, Loss: 0.0247
# Epoch: 3, Batch: 340, Loss: 0.0194
# Epoch: 3, Batch: 350, Loss: 0.0134
# Epoch: 3, Train Loss: 0.0311, Val Loss: 0.0193
# Epoch: 4, Batch: 0, Loss: 0.0134
# Epoch: 4, Batch: 10, Loss: 0.0093
# Epoch: 4, Batch: 20, Loss: 0.0187
# Epoch: 4, Batch: 30, Loss: 0.0174
# Epoch: 4, Batch: 40, Loss: 0.0130
# Epoch: 4, Batch: 50, Loss: 0.0147
# Epoch: 4, Batch: 60, Loss: 0.0174
# Epoch: 4, Batch: 70, Loss: 0.0197
# Epoch: 4, Batch: 80, Loss: 0.0187
# Epoch: 4, Batch: 90, Loss: 0.0194
# Epoch: 4, Batch: 100, Loss: 0.0168
# Epoch: 4, Batch: 110, Loss: 0.0271
# Epoch: 4, Batch: 120, Loss: 0.0224
# Epoch: 4, Batch: 130, Loss: 0.0354
# Epoch: 4, Batch: 140, Loss: 0.0207
# Epoch: 4, Batch: 150, Loss: 0.0321
# Epoch: 4, Batch: 160, Loss: 0.0150
# Epoch: 4, Batch: 170, Loss: 0.0124
# Epoch: 4, Batch: 180, Loss: 0.0150
# Epoch: 4, Batch: 190, Loss: 0.0333
# Epoch: 4, Batch: 200, Loss: 0.0212
# Epoch: 4, Batch: 210, Loss: 0.0178
# Epoch: 4, Batch: 220, Loss: 0.0202
# Epoch: 4, Batch: 230, Loss: 0.0136
# Epoch: 4, Batch: 240, Loss: 0.0155
# Epoch: 4, Batch: 250, Loss: 0.0313
# Epoch: 4, Batch: 260, Loss: 0.0348
# Epoch: 4, Batch: 270, Loss: 0.0237
# Epoch: 4, Batch: 280, Loss: 0.0312
# Epoch: 4, Batch: 290, Loss: 0.0116
# Epoch: 4, Batch: 300, Loss: 0.0158
# Epoch: 4, Batch: 310, Loss: 0.0120
# Epoch: 4, Batch: 320, Loss: 0.0239
# Epoch: 4, Batch: 330, Loss: 0.0114
# Epoch: 4, Batch: 340, Loss: 0.0129
# Epoch: 4, Batch: 350, Loss: 0.0145
# Epoch: 4, Train Loss: 0.0178, Val Loss: 0.0175
# Epoch: 5, Batch: 0, Loss: 0.0138
# Epoch: 5, Batch: 10, Loss: 0.0269
# Epoch: 5, Batch: 20, Loss: 0.0156
# Epoch: 5, Batch: 30, Loss: 0.0113
# Epoch: 5, Batch: 40, Loss: 0.0086
# Epoch: 5, Batch: 50, Loss: 0.0195
# Epoch: 5, Batch: 60, Loss: 0.0143
# Epoch: 5, Batch: 70, Loss: 0.0194
# Epoch: 5, Batch: 80, Loss: 0.0124
# Epoch: 5, Batch: 90, Loss: 0.0081
# Epoch: 5, Batch: 100, Loss: 0.0117
# Epoch: 5, Batch: 110, Loss: 0.0062
# Epoch: 5, Batch: 120, Loss: 0.0127
# Epoch: 5, Batch: 130, Loss: 0.0151
# Epoch: 5, Batch: 140, Loss: 0.0290
# Epoch: 5, Batch: 150, Loss: 0.0137
# Epoch: 5, Batch: 160, Loss: 0.0186
# Epoch: 5, Batch: 170, Loss: 0.0111
# Epoch: 5, Batch: 180, Loss: 0.0148
# Epoch: 5, Batch: 190, Loss: 0.0121
# Epoch: 5, Batch: 200, Loss: 0.0074
# Epoch: 5, Batch: 210, Loss: 0.0094
# Epoch: 5, Batch: 220, Loss: 0.0235
# Epoch: 5, Batch: 230, Loss: 0.0110
# Epoch: 5, Batch: 240, Loss: 0.0140
# Epoch: 5, Batch: 250, Loss: 0.0082
# Epoch: 5, Batch: 260, Loss: 0.0163
# Epoch: 5, Batch: 270, Loss: 0.0112
# Epoch: 5, Batch: 280, Loss: 0.0089
# Epoch: 5, Batch: 290, Loss: 0.0282
# Epoch: 5, Batch: 300, Loss: 0.0406
# Epoch: 5, Batch: 310, Loss: 0.0360
# Epoch: 5, Batch: 320, Loss: 0.0173
# Epoch: 5, Batch: 330, Loss: 0.0077
# Epoch: 5, Batch: 340, Loss: 0.0086
# Epoch: 5, Batch: 350, Loss: 0.0067
# Epoch: 5, Train Loss: 0.0156, Val Loss: 0.0096
# Epoch: 6, Batch: 0, Loss: 0.0059
# Epoch: 6, Batch: 10, Loss: 0.0073
# Epoch: 6, Batch: 20, Loss: 0.0060
# Epoch: 6, Batch: 30, Loss: 0.0071
# Epoch: 6, Batch: 40, Loss: 0.0050
# Epoch: 6, Batch: 50, Loss: 0.0082
# Epoch: 6, Batch: 60, Loss: 0.0068
# Epoch: 6, Batch: 70, Loss: 0.0077
# Epoch: 6, Batch: 80, Loss: 0.0060
# Epoch: 6, Batch: 90, Loss: 0.0115
# Epoch: 6, Batch: 100, Loss: 0.0091
# Epoch: 6, Batch: 110, Loss: 0.0066
# Epoch: 6, Batch: 120, Loss: 0.0109
# Epoch: 6, Batch: 130, Loss: 0.0072
# Epoch: 6, Batch: 140, Loss: 0.0140
# Epoch: 6, Batch: 150, Loss: 0.0100
# Epoch: 6, Batch: 160, Loss: 0.0093
# Epoch: 6, Batch: 170, Loss: 0.0091
# Epoch: 6, Batch: 180, Loss: 0.0145
# Epoch: 6, Batch: 190, Loss: 0.0098
# Epoch: 6, Batch: 200, Loss: 0.0126
# Epoch: 6, Batch: 210, Loss: 0.0152
# Epoch: 6, Batch: 220, Loss: 0.0173
# Epoch: 6, Batch: 230, Loss: 0.0105
# Epoch: 6, Batch: 240, Loss: 0.0092
# Epoch: 6, Batch: 250, Loss: 0.0090
# Epoch: 6, Batch: 260, Loss: 0.0063
# Epoch: 6, Batch: 270, Loss: 0.0099
# Epoch: 6, Batch: 280, Loss: 0.0122
# Epoch: 6, Batch: 290, Loss: 0.0109
# Epoch: 6, Batch: 300, Loss: 0.0110
# Epoch: 6, Batch: 310, Loss: 0.0070
# Epoch: 6, Batch: 320, Loss: 0.0079
# Epoch: 6, Batch: 330, Loss: 0.0092
# Epoch: 6, Batch: 340, Loss: 0.0068
# Epoch: 6, Batch: 350, Loss: 0.0135
# Epoch: 6, Train Loss: 0.0102, Val Loss: 0.0107
# Epoch: 7, Batch: 0, Loss: 0.0153
# Epoch: 7, Batch: 10, Loss: 0.0080
# Epoch: 7, Batch: 20, Loss: 0.0210
# Epoch: 7, Batch: 30, Loss: 0.0137
# Epoch: 7, Batch: 40, Loss: 0.0104
# Epoch: 7, Batch: 50, Loss: 0.0066
# Epoch: 7, Batch: 60, Loss: 0.0091
# Epoch: 7, Batch: 70, Loss: 0.0092
# Epoch: 7, Batch: 80, Loss: 0.0085
# Epoch: 7, Batch: 90, Loss: 0.0085
# Epoch: 7, Batch: 100, Loss: 0.0063
# Epoch: 7, Batch: 110, Loss: 0.0045
# Epoch: 7, Batch: 120, Loss: 0.0105
# Epoch: 7, Batch: 130, Loss: 0.0082
# Epoch: 7, Batch: 140, Loss: 0.0060
# Epoch: 7, Batch: 150, Loss: 0.0077
# Epoch: 7, Batch: 160, Loss: 0.0072
# Epoch: 7, Batch: 170, Loss: 0.0067
# Epoch: 7, Batch: 180, Loss: 0.0061
# Epoch: 7, Batch: 190, Loss: 0.0092
# Epoch: 7, Batch: 200, Loss: 0.0069
# Epoch: 7, Batch: 210, Loss: 0.0165
# Epoch: 7, Batch: 220, Loss: 0.0086
# Epoch: 7, Batch: 230, Loss: 0.0105
# Epoch: 7, Batch: 240, Loss: 0.0104
# Epoch: 7, Batch: 250, Loss: 0.0080
# Epoch: 7, Batch: 260, Loss: 0.0116
# Epoch: 7, Batch: 270, Loss: 0.0195
# Epoch: 7, Batch: 280, Loss: 0.0152
# Epoch: 7, Batch: 290, Loss: 0.0104
# Epoch: 7, Batch: 300, Loss: 0.0086
# Epoch: 7, Batch: 310, Loss: 0.0073
# Epoch: 7, Batch: 320, Loss: 0.0167
# Epoch: 7, Batch: 330, Loss: 0.0100
# Epoch: 7, Batch: 340, Loss: 0.0239
# Epoch: 7, Batch: 350, Loss: 0.0081
# Epoch: 7, Train Loss: 0.0094, Val Loss: 0.0107
# Epoch: 8, Batch: 0, Loss: 0.0085
# Epoch: 8, Batch: 10, Loss: 0.0066
# Epoch: 8, Batch: 20, Loss: 0.0108
# Epoch: 8, Batch: 30, Loss: 0.0058
# Epoch: 8, Batch: 40, Loss: 0.0076
# Epoch: 8, Batch: 50, Loss: 0.0088
# Epoch: 8, Batch: 60, Loss: 0.0103
# Epoch: 8, Batch: 70, Loss: 0.0062
# Epoch: 8, Batch: 80, Loss: 0.0056
# Epoch: 8, Batch: 90, Loss: 0.0072
# Epoch: 8, Batch: 100, Loss: 0.0069
# Epoch: 8, Batch: 110, Loss: 0.0096
# Epoch: 8, Batch: 120, Loss: 0.0103
# Epoch: 8, Batch: 130, Loss: 0.0108
# Epoch: 8, Batch: 140, Loss: 0.0091
# Epoch: 8, Batch: 150, Loss: 0.0073
# Epoch: 8, Batch: 160, Loss: 0.0047
# Epoch: 8, Batch: 170, Loss: 0.0088
# Epoch: 8, Batch: 180, Loss: 0.0077
# Epoch: 8, Batch: 190, Loss: 0.0075
# Epoch: 8, Batch: 200, Loss: 0.0058
# Epoch: 8, Batch: 210, Loss: 0.0063
# Epoch: 8, Batch: 220, Loss: 0.0093
# Epoch: 8, Batch: 230, Loss: 0.0105
# Epoch: 8, Batch: 240, Loss: 0.0067
# Epoch: 8, Batch: 250, Loss: 0.0063
# Epoch: 8, Batch: 260, Loss: 0.0068
# Epoch: 8, Batch: 270, Loss: 0.0160
# Epoch: 8, Batch: 280, Loss: 0.0072
# Epoch: 8, Batch: 290, Loss: 0.0088
# Epoch: 8, Batch: 300, Loss: 0.0077
# Epoch: 8, Batch: 310, Loss: 0.0055
# Epoch: 8, Batch: 320, Loss: 0.0050
# Epoch: 8, Batch: 330, Loss: 0.0063
# Epoch: 8, Batch: 340, Loss: 0.0068
# Epoch: 8, Batch: 350, Loss: 0.0073
# Epoch: 8, Train Loss: 0.0079, Val Loss: 0.0077
# Epoch: 9, Batch: 0, Loss: 0.0069
# Epoch: 9, Batch: 10, Loss: 0.0058
# Epoch: 9, Batch: 20, Loss: 0.0099
# Epoch: 9, Batch: 30, Loss: 0.0045
# Epoch: 9, Batch: 40, Loss: 0.0095
# Epoch: 9, Batch: 50, Loss: 0.0032
# Epoch: 9, Batch: 60, Loss: 0.0043
# Epoch: 9, Batch: 70, Loss: 0.0056
# Epoch: 9, Batch: 80, Loss: 0.0069
# Epoch: 9, Batch: 90, Loss: 0.0049
# Epoch: 9, Batch: 100, Loss: 0.0079
# Epoch: 9, Batch: 110, Loss: 0.0127
# Epoch: 9, Batch: 120, Loss: 0.0101
# Epoch: 9, Batch: 130, Loss: 0.0044
# Epoch: 9, Batch: 140, Loss: 0.0095
# Epoch: 9, Batch: 150, Loss: 0.0042
# Epoch: 9, Batch: 160, Loss: 0.0050
# Epoch: 9, Batch: 170, Loss: 0.0054
# Epoch: 9, Batch: 180, Loss: 0.0047
# Epoch: 9, Batch: 190, Loss: 0.0079
# Epoch: 9, Batch: 200, Loss: 0.0056
# Epoch: 9, Batch: 210, Loss: 0.0045
# Epoch: 9, Batch: 220, Loss: 0.0067
# Epoch: 9, Batch: 230, Loss: 0.0054
# Epoch: 9, Batch: 240, Loss: 0.0069
# Epoch: 9, Batch: 250, Loss: 0.0045
# Epoch: 9, Batch: 260, Loss: 0.0048
# Epoch: 9, Batch: 270, Loss: 0.0067
# Epoch: 9, Batch: 280, Loss: 0.0112
# Epoch: 9, Batch: 290, Loss: 0.0049
# Epoch: 9, Batch: 300, Loss: 0.0104
# Epoch: 9, Batch: 310, Loss: 0.0091
# Epoch: 9, Batch: 320, Loss: 0.0054
# Epoch: 9, Batch: 330, Loss: 0.0097
# Epoch: 9, Batch: 340, Loss: 0.0074
# Epoch: 9, Batch: 350, Loss: 0.0041
# Epoch: 9, Train Loss: 0.0069, Val Loss: 0.0072
# Epoch: 10, Batch: 0, Loss: 0.0049
# Epoch: 10, Batch: 10, Loss: 0.0052
# Epoch: 10, Batch: 20, Loss: 0.0040
# Epoch: 10, Batch: 30, Loss: 0.0025
# Epoch: 10, Batch: 40, Loss: 0.0051
# Epoch: 10, Batch: 50, Loss: 0.0043
# Epoch: 10, Batch: 60, Loss: 0.0047
# Epoch: 10, Batch: 70, Loss: 0.0070
# Epoch: 10, Batch: 80, Loss: 0.0061
# Epoch: 10, Batch: 90, Loss: 0.0050
# Epoch: 10, Batch: 100, Loss: 0.0034
# Epoch: 10, Batch: 110, Loss: 0.0022
# Epoch: 10, Batch: 120, Loss: 0.0061
# Epoch: 10, Batch: 130, Loss: 0.0046
# Epoch: 10, Batch: 140, Loss: 0.0048
# Epoch: 10, Batch: 150, Loss: 0.0046
# Epoch: 10, Batch: 160, Loss: 0.0056
# Epoch: 10, Batch: 170, Loss: 0.0039
# Epoch: 10, Batch: 180, Loss: 0.0047
# Epoch: 10, Batch: 190, Loss: 0.0039
# Epoch: 10, Batch: 200, Loss: 0.0063
# Epoch: 10, Batch: 210, Loss: 0.0059
# Epoch: 10, Batch: 220, Loss: 0.0093
# Epoch: 10, Batch: 230, Loss: 0.0073
# Epoch: 10, Batch: 240, Loss: 0.0050
# Epoch: 10, Batch: 250, Loss: 0.0066
# Epoch: 10, Batch: 260, Loss: 0.0068
# Epoch: 10, Batch: 270, Loss: 0.0091
# Epoch: 10, Batch: 280, Loss: 0.0056
# Epoch: 10, Batch: 290, Loss: 0.0056
# Epoch: 10, Batch: 300, Loss: 0.0048
# Epoch: 10, Batch: 310, Loss: 0.0040
# Epoch: 10, Batch: 320, Loss: 0.0064
# Epoch: 10, Batch: 330, Loss: 0.0096
# Epoch: 10, Batch: 340, Loss: 0.0070
# Epoch: 10, Batch: 350, Loss: 0.0038
# Epoch: 10, Train Loss: 0.0060, Val Loss: 0.0065
# Epoch: 11, Batch: 0, Loss: 0.0045
# Epoch: 11, Batch: 10, Loss: 0.0039
# Epoch: 11, Batch: 20, Loss: 0.0063
# Epoch: 11, Batch: 30, Loss: 0.0050
# Epoch: 11, Batch: 40, Loss: 0.0047
# Epoch: 11, Batch: 50, Loss: 0.0043
# Epoch: 11, Batch: 60, Loss: 0.0064
# Epoch: 11, Batch: 70, Loss: 0.0047
# Epoch: 11, Batch: 80, Loss: 0.0037
# Epoch: 11, Batch: 90, Loss: 0.0058
# Epoch: 11, Batch: 100, Loss: 0.0063
# Epoch: 11, Batch: 110, Loss: 0.0050
# Epoch: 11, Batch: 120, Loss: 0.0049
# Epoch: 11, Batch: 130, Loss: 0.0062
# Epoch: 11, Batch: 140, Loss: 0.0067
# Epoch: 11, Batch: 150, Loss: 0.0061
# Epoch: 11, Batch: 160, Loss: 0.0049
# Epoch: 11, Batch: 170, Loss: 0.0057
# Epoch: 11, Batch: 180, Loss: 0.0050
# Epoch: 11, Batch: 190, Loss: 0.0039
# Epoch: 11, Batch: 200, Loss: 0.0085
# Epoch: 11, Batch: 210, Loss: 0.0132
# Epoch: 11, Batch: 220, Loss: 0.0044
# Epoch: 11, Batch: 230, Loss: 0.0050
# Epoch: 11, Batch: 240, Loss: 0.0068
# Epoch: 11, Batch: 250, Loss: 0.0052
# Epoch: 11, Batch: 260, Loss: 0.0074
# Epoch: 11, Batch: 270, Loss: 0.0062
# Epoch: 11, Batch: 280, Loss: 0.0051
# Epoch: 11, Batch: 290, Loss: 0.0056
# Epoch: 11, Batch: 300, Loss: 0.0039
# Epoch: 11, Batch: 310, Loss: 0.0080
# Epoch: 11, Batch: 320, Loss: 0.0046
# Epoch: 11, Batch: 330, Loss: 0.0054
# Epoch: 11, Batch: 340, Loss: 0.0055
# Epoch: 11, Batch: 350, Loss: 0.0059
# Epoch: 11, Train Loss: 0.0054, Val Loss: 0.0061
# Epoch: 12, Batch: 0, Loss: 0.0059
# Epoch: 12, Batch: 10, Loss: 0.0020
# Epoch: 12, Batch: 20, Loss: 0.0063
# Epoch: 12, Batch: 30, Loss: 0.0058
# Epoch: 12, Batch: 40, Loss: 0.0048
# Epoch: 12, Batch: 50, Loss: 0.0043
# Epoch: 12, Batch: 60, Loss: 0.0045
# Epoch: 12, Batch: 70, Loss: 0.0037
# Epoch: 12, Batch: 80, Loss: 0.0078
# Epoch: 12, Batch: 90, Loss: 0.0042
# Epoch: 12, Batch: 100, Loss: 0.0037
# Epoch: 12, Batch: 110, Loss: 0.0051
# Epoch: 12, Batch: 120, Loss: 0.0079
# Epoch: 12, Batch: 130, Loss: 0.0068
# Epoch: 12, Batch: 140, Loss: 0.0051
# Epoch: 12, Batch: 150, Loss: 0.0064
# Epoch: 12, Batch: 160, Loss: 0.0031
# Epoch: 12, Batch: 170, Loss: 0.0060
# Epoch: 12, Batch: 180, Loss: 0.0029
# Epoch: 12, Batch: 190, Loss: 0.0035
# Epoch: 12, Batch: 200, Loss: 0.0057
# Epoch: 12, Batch: 210, Loss: 0.0060
# Epoch: 12, Batch: 220, Loss: 0.0033
# Epoch: 12, Batch: 230, Loss: 0.0029
# Epoch: 12, Batch: 240, Loss: 0.0049
# Epoch: 12, Batch: 250, Loss: 0.0039
# Epoch: 12, Batch: 260, Loss: 0.0034
# Epoch: 12, Batch: 270, Loss: 0.0028
# Epoch: 12, Batch: 280, Loss: 0.0045
# Epoch: 12, Batch: 290, Loss: 0.0067
# Epoch: 12, Batch: 300, Loss: 0.0048
# Epoch: 12, Batch: 310, Loss: 0.0040
# Epoch: 12, Batch: 320, Loss: 0.0022
# Epoch: 12, Batch: 330, Loss: 0.0038
# Epoch: 12, Batch: 340, Loss: 0.0066
# Epoch: 12, Batch: 350, Loss: 0.0061
# Epoch: 12, Train Loss: 0.0051, Val Loss: 0.0053
# Epoch: 13, Batch: 0, Loss: 0.0035
# Epoch: 13, Batch: 10, Loss: 0.0033
# Epoch: 13, Batch: 20, Loss: 0.0046
# Epoch: 13, Batch: 30, Loss: 0.0047
# Epoch: 13, Batch: 40, Loss: 0.0030
# Epoch: 13, Batch: 50, Loss: 0.0043
# Epoch: 13, Batch: 60, Loss: 0.0030
# Epoch: 13, Batch: 70, Loss: 0.0032
# Epoch: 13, Batch: 80, Loss: 0.0043
# Epoch: 13, Batch: 90, Loss: 0.0035
# Epoch: 13, Batch: 100, Loss: 0.0045
# Epoch: 13, Batch: 110, Loss: 0.0073
# Epoch: 13, Batch: 120, Loss: 0.0060
# Epoch: 13, Batch: 130, Loss: 0.0042
# Epoch: 13, Batch: 140, Loss: 0.0062
# Epoch: 13, Batch: 150, Loss: 0.0063
# Epoch: 13, Batch: 160, Loss: 0.0043
# Epoch: 13, Batch: 170, Loss: 0.0064
# Epoch: 13, Batch: 180, Loss: 0.0043
# Epoch: 13, Batch: 190, Loss: 0.0039
# Epoch: 13, Batch: 200, Loss: 0.0049
# Epoch: 13, Batch: 210, Loss: 0.0036
# Epoch: 13, Batch: 220, Loss: 0.0043
# Epoch: 13, Batch: 230, Loss: 0.0039
# Epoch: 13, Batch: 240, Loss: 0.0029
# Epoch: 13, Batch: 250, Loss: 0.0025
# Epoch: 13, Batch: 260, Loss: 0.0044
# Epoch: 13, Batch: 270, Loss: 0.0030
# Epoch: 13, Batch: 280, Loss: 0.0052
# Epoch: 13, Batch: 290, Loss: 0.0033
# Epoch: 13, Batch: 300, Loss: 0.0056
# Epoch: 13, Batch: 310, Loss: 0.0045
# Epoch: 13, Batch: 320, Loss: 0.0038
# Epoch: 13, Batch: 330, Loss: 0.0048
# Epoch: 13, Batch: 340, Loss: 0.0044
# Epoch: 13, Batch: 350, Loss: 0.0074
# Epoch: 13, Train Loss: 0.0047, Val Loss: 0.0051
# Epoch: 14, Batch: 0, Loss: 0.0026
# Epoch: 14, Batch: 10, Loss: 0.0059
# Epoch: 14, Batch: 20, Loss: 0.0041
# Epoch: 14, Batch: 30, Loss: 0.0043
# Epoch: 14, Batch: 40, Loss: 0.0047
# Epoch: 14, Batch: 50, Loss: 0.0023
# Epoch: 14, Batch: 60, Loss: 0.0028
# Epoch: 14, Batch: 70, Loss: 0.0044
# Epoch: 14, Batch: 80, Loss: 0.0063
# Epoch: 14, Batch: 90, Loss: 0.0046
# Epoch: 14, Batch: 100, Loss: 0.0033
# Epoch: 14, Batch: 110, Loss: 0.0048
# Epoch: 14, Batch: 120, Loss: 0.0043
# Epoch: 14, Batch: 130, Loss: 0.0053
# Epoch: 14, Batch: 140, Loss: 0.0053
# Epoch: 14, Batch: 150, Loss: 0.0050
# Epoch: 14, Batch: 160, Loss: 0.0071
# Epoch: 14, Batch: 170, Loss: 0.0031
# Epoch: 14, Batch: 180, Loss: 0.0057
# Epoch: 14, Batch: 190, Loss: 0.0044
# Epoch: 14, Batch: 200, Loss: 0.0025
# Epoch: 14, Batch: 210, Loss: 0.0050
# Epoch: 14, Batch: 220, Loss: 0.0039
# Epoch: 14, Batch: 230, Loss: 0.0058
# Epoch: 14, Batch: 240, Loss: 0.0053
# Epoch: 14, Batch: 250, Loss: 0.0060
# Epoch: 14, Batch: 260, Loss: 0.0023
# Epoch: 14, Batch: 270, Loss: 0.0029
# Epoch: 14, Batch: 280, Loss: 0.0021
# Epoch: 14, Batch: 290, Loss: 0.0048
# Epoch: 14, Batch: 300, Loss: 0.0058
# Epoch: 14, Batch: 310, Loss: 0.0019
# Epoch: 14, Batch: 320, Loss: 0.0043
# Epoch: 14, Batch: 330, Loss: 0.0049
# Epoch: 14, Batch: 340, Loss: 0.0040
# Epoch: 14, Batch: 350, Loss: 0.0034
# Epoch: 14, Train Loss: 0.0044, Val Loss: 0.0049
# Epoch: 15, Batch: 0, Loss: 0.0023
# Epoch: 15, Batch: 10, Loss: 0.0036
# Epoch: 15, Batch: 20, Loss: 0.0022
# Epoch: 15, Batch: 30, Loss: 0.0045
# Epoch: 15, Batch: 40, Loss: 0.0024
# Epoch: 15, Batch: 50, Loss: 0.0023
# Epoch: 15, Batch: 60, Loss: 0.0046
# Epoch: 15, Batch: 70, Loss: 0.0040
# Epoch: 15, Batch: 80, Loss: 0.0057
# Epoch: 15, Batch: 90, Loss: 0.0026
# Epoch: 15, Batch: 100, Loss: 0.0039
# Epoch: 15, Batch: 110, Loss: 0.0041
# Epoch: 15, Batch: 120, Loss: 0.0032
# Epoch: 15, Batch: 130, Loss: 0.0138
# Epoch: 15, Batch: 140, Loss: 0.0032
# Epoch: 15, Batch: 150, Loss: 0.0024
# Epoch: 15, Batch: 160, Loss: 0.0055
# Epoch: 15, Batch: 170, Loss: 0.0050
# Epoch: 15, Batch: 180, Loss: 0.0029
# Epoch: 15, Batch: 190, Loss: 0.0039
# Epoch: 15, Batch: 200, Loss: 0.0059
# Epoch: 15, Batch: 210, Loss: 0.0057
# Epoch: 15, Batch: 220, Loss: 0.0025
# Epoch: 15, Batch: 230, Loss: 0.0043
# Epoch: 15, Batch: 240, Loss: 0.0027
# Epoch: 15, Batch: 250, Loss: 0.0043
# Epoch: 15, Batch: 260, Loss: 0.0054
# Epoch: 15, Batch: 270, Loss: 0.0051
# Epoch: 15, Batch: 280, Loss: 0.0068
# Epoch: 15, Batch: 290, Loss: 0.0036
# Epoch: 15, Batch: 300, Loss: 0.0038
# Epoch: 15, Batch: 310, Loss: 0.0027
# Epoch: 15, Batch: 320, Loss: 0.0034
# Epoch: 15, Batch: 330, Loss: 0.0030
# Epoch: 15, Batch: 340, Loss: 0.0035
# Epoch: 15, Batch: 350, Loss: 0.0062
# Epoch: 15, Train Loss: 0.0043, Val Loss: 0.0061
# Epoch: 16, Batch: 0, Loss: 0.0035
# Epoch: 16, Batch: 10, Loss: 0.0046
# Epoch: 16, Batch: 20, Loss: 0.0037
# Epoch: 16, Batch: 30, Loss: 0.0026
# Epoch: 16, Batch: 40, Loss: 0.0027
# Epoch: 16, Batch: 50, Loss: 0.0049
# Epoch: 16, Batch: 60, Loss: 0.0025
# Epoch: 16, Batch: 70, Loss: 0.0024
# Epoch: 16, Batch: 80, Loss: 0.0031
# Epoch: 16, Batch: 90, Loss: 0.0039
# Epoch: 16, Batch: 100, Loss: 0.0036
# Epoch: 16, Batch: 110, Loss: 0.0042
# Epoch: 16, Batch: 120, Loss: 0.0042
# Epoch: 16, Batch: 130, Loss: 0.0021
# Epoch: 16, Batch: 140, Loss: 0.0035
# Epoch: 16, Batch: 150, Loss: 0.0057
# Epoch: 16, Batch: 160, Loss: 0.0053
# Epoch: 16, Batch: 170, Loss: 0.0067
# Epoch: 16, Batch: 180, Loss: 0.0052
# Epoch: 16, Batch: 190, Loss: 0.0032
# Epoch: 16, Batch: 200, Loss: 0.0037
# Epoch: 16, Batch: 210, Loss: 0.0032
# Epoch: 16, Batch: 220, Loss: 0.0053
# Epoch: 16, Batch: 230, Loss: 0.0031
# Epoch: 16, Batch: 240, Loss: 0.0023
# Epoch: 16, Batch: 250, Loss: 0.0048
# Epoch: 16, Batch: 260, Loss: 0.0062
# Epoch: 16, Batch: 270, Loss: 0.0034
# Epoch: 16, Batch: 280, Loss: 0.0049
# Epoch: 16, Batch: 290, Loss: 0.0027
# Epoch: 16, Batch: 300, Loss: 0.0049
# Epoch: 16, Batch: 310, Loss: 0.0027
# Epoch: 16, Batch: 320, Loss: 0.0046
# Epoch: 16, Batch: 330, Loss: 0.0031
# Epoch: 16, Batch: 340, Loss: 0.0049
# Epoch: 16, Batch: 350, Loss: 0.0042
# Epoch: 16, Train Loss: 0.0042, Val Loss: 0.0056
# Epoch: 17, Batch: 0, Loss: 0.0026
# Epoch: 17, Batch: 10, Loss: 0.0036
# Epoch: 17, Batch: 20, Loss: 0.0054
# Epoch: 17, Batch: 30, Loss: 0.0039
# Epoch: 17, Batch: 40, Loss: 0.0037
# Epoch: 17, Batch: 50, Loss: 0.0031
# Epoch: 17, Batch: 60, Loss: 0.0047
# Epoch: 17, Batch: 70, Loss: 0.0026
# Epoch: 17, Batch: 80, Loss: 0.0030
# Epoch: 17, Batch: 90, Loss: 0.0024
# Epoch: 17, Batch: 100, Loss: 0.0027
# Epoch: 17, Batch: 110, Loss: 0.0013
# Epoch: 17, Batch: 120, Loss: 0.0023
# Epoch: 17, Batch: 130, Loss: 0.0031
# Epoch: 17, Batch: 140, Loss: 0.0043
# Epoch: 17, Batch: 150, Loss: 0.0029
# Epoch: 17, Batch: 160, Loss: 0.0044
# Epoch: 17, Batch: 170, Loss: 0.0043
# Epoch: 17, Batch: 180, Loss: 0.0031
# Epoch: 17, Batch: 190, Loss: 0.0050
# Epoch: 17, Batch: 200, Loss: 0.0037
# Epoch: 17, Batch: 210, Loss: 0.0058
# Epoch: 17, Batch: 220, Loss: 0.0041
# Epoch: 17, Batch: 230, Loss: 0.0042
# Epoch: 17, Batch: 240, Loss: 0.0034
# Epoch: 17, Batch: 250, Loss: 0.0020
# Epoch: 17, Batch: 260, Loss: 0.0039
# Epoch: 17, Batch: 270, Loss: 0.0040
# Epoch: 17, Batch: 280, Loss: 0.0040
# Epoch: 17, Batch: 290, Loss: 0.0051
# Epoch: 17, Batch: 300, Loss: 0.0057
# Epoch: 17, Batch: 310, Loss: 0.0072
# Epoch: 17, Batch: 320, Loss: 0.0020
# Epoch: 17, Batch: 330, Loss: 0.0020
# Epoch: 17, Batch: 340, Loss: 0.0034
# Epoch: 17, Batch: 350, Loss: 0.0037
# Epoch: 17, Train Loss: 0.0041, Val Loss: 0.0042
# Epoch: 18, Batch: 0, Loss: 0.0018
# Epoch: 18, Batch: 10, Loss: 0.0027
# Epoch: 18, Batch: 20, Loss: 0.0048
# Epoch: 18, Batch: 30, Loss: 0.0041
# Epoch: 18, Batch: 40, Loss: 0.0036
# Epoch: 18, Batch: 50, Loss: 0.0025
# Epoch: 18, Batch: 60, Loss: 0.0032
# Epoch: 18, Batch: 70, Loss: 0.0044
# Epoch: 18, Batch: 80, Loss: 0.0044
# Epoch: 18, Batch: 90, Loss: 0.0043
# Epoch: 18, Batch: 100, Loss: 0.0034
# Epoch: 18, Batch: 110, Loss: 0.0030
# Epoch: 18, Batch: 120, Loss: 0.0032
# Epoch: 18, Batch: 130, Loss: 0.0030
# Epoch: 18, Batch: 140, Loss: 0.0025
# Epoch: 18, Batch: 150, Loss: 0.0047
# Epoch: 18, Batch: 160, Loss: 0.0036
# Epoch: 18, Batch: 170, Loss: 0.0025
# Epoch: 18, Batch: 180, Loss: 0.0046
# Epoch: 18, Batch: 190, Loss: 0.0032
# Epoch: 18, Batch: 200, Loss: 0.0044
# Epoch: 18, Batch: 210, Loss: 0.0070
# Epoch: 18, Batch: 220, Loss: 0.0039
# Epoch: 18, Batch: 230, Loss: 0.0056
# Epoch: 18, Batch: 240, Loss: 0.0022
# Epoch: 18, Batch: 250, Loss: 0.0047
# Epoch: 18, Batch: 260, Loss: 0.0018
# Epoch: 18, Batch: 270, Loss: 0.0026
# Epoch: 18, Batch: 280, Loss: 0.0026
# Epoch: 18, Batch: 290, Loss: 0.0038
# Epoch: 18, Batch: 300, Loss: 0.0045
# Epoch: 18, Batch: 310, Loss: 0.0039
# Epoch: 18, Batch: 320, Loss: 0.0031
# Epoch: 18, Batch: 330, Loss: 0.0042
# Epoch: 18, Batch: 340, Loss: 0.0041
# Epoch: 18, Batch: 350, Loss: 0.0041
# Epoch: 18, Train Loss: 0.0036, Val Loss: 0.0040
# Epoch: 19, Batch: 0, Loss: 0.0016
# Epoch: 19, Batch: 10, Loss: 0.0029
# Epoch: 19, Batch: 20, Loss: 0.0018
# Epoch: 19, Batch: 30, Loss: 0.0055
# Epoch: 19, Batch: 40, Loss: 0.0043
# Epoch: 19, Batch: 50, Loss: 0.0030
# Epoch: 19, Batch: 60, Loss: 0.0034
# Epoch: 19, Batch: 70, Loss: 0.0037
# Epoch: 19, Batch: 80, Loss: 0.0029
# Epoch: 19, Batch: 90, Loss: 0.0022
# Epoch: 19, Batch: 100, Loss: 0.0028
# Epoch: 19, Batch: 110, Loss: 0.0042
# Epoch: 19, Batch: 120, Loss: 0.0046
# Epoch: 19, Batch: 130, Loss: 0.0029
# Epoch: 19, Batch: 140, Loss: 0.0044
# Epoch: 19, Batch: 150, Loss: 0.0045
# Epoch: 19, Batch: 160, Loss: 0.0039
# Epoch: 19, Batch: 170, Loss: 0.0017
# Epoch: 19, Batch: 180, Loss: 0.0029
# Epoch: 19, Batch: 190, Loss: 0.0027
# Epoch: 19, Batch: 200, Loss: 0.0018
# Epoch: 19, Batch: 210, Loss: 0.0031
# Epoch: 19, Batch: 220, Loss: 0.0027
# Epoch: 19, Batch: 230, Loss: 0.0045
# Epoch: 19, Batch: 240, Loss: 0.0048
# Epoch: 19, Batch: 250, Loss: 0.0023
# Epoch: 19, Batch: 260, Loss: 0.0052
# Epoch: 19, Batch: 270, Loss: 0.0029
# Epoch: 19, Batch: 280, Loss: 0.0050
# Epoch: 19, Batch: 290, Loss: 0.0027
# Epoch: 19, Batch: 300, Loss: 0.0027
# Epoch: 19, Batch: 310, Loss: 0.0104
# Epoch: 19, Batch: 320, Loss: 0.0032
# Epoch: 19, Batch: 330, Loss: 0.0074
# Epoch: 19, Batch: 340, Loss: 0.0073
# Epoch: 19, Batch: 350, Loss: 0.0035
# Epoch: 19, Train Loss: 0.0036, Val Loss: 0.0056
# Epoch: 20, Batch: 0, Loss: 0.0041
# Epoch: 20, Batch: 10, Loss: 0.0033
# Epoch: 20, Batch: 20, Loss: 0.0024
# Epoch: 20, Batch: 30, Loss: 0.0025
# Epoch: 20, Batch: 40, Loss: 0.0040
# Epoch: 20, Batch: 50, Loss: 0.0013
# Epoch: 20, Batch: 60, Loss: 0.0022
# Epoch: 20, Batch: 70, Loss: 0.0026
# Epoch: 20, Batch: 80, Loss: 0.0030
# Epoch: 20, Batch: 90, Loss: 0.0041
# Epoch: 20, Batch: 100, Loss: 0.0035
# Epoch: 20, Batch: 110, Loss: 0.0031
# Epoch: 20, Batch: 120, Loss: 0.0065
# Epoch: 20, Batch: 130, Loss: 0.0044
# Epoch: 20, Batch: 140, Loss: 0.0025
# Epoch: 20, Batch: 150, Loss: 0.0030
# Epoch: 20, Batch: 160, Loss: 0.0037
# Epoch: 20, Batch: 170, Loss: 0.0025
# Epoch: 20, Batch: 180, Loss: 0.0037
# Epoch: 20, Batch: 190, Loss: 0.0056
# Epoch: 20, Batch: 200, Loss: 0.0052
# Epoch: 20, Batch: 210, Loss: 0.0034
# Epoch: 20, Batch: 220, Loss: 0.0032
# Epoch: 20, Batch: 230, Loss: 0.0020
# Epoch: 20, Batch: 240, Loss: 0.0037
# Epoch: 20, Batch: 250, Loss: 0.0027
# Epoch: 20, Batch: 260, Loss: 0.0025
# Epoch: 20, Batch: 270, Loss: 0.0040
# Epoch: 20, Batch: 280, Loss: 0.0041
# Epoch: 20, Batch: 290, Loss: 0.0037
# Epoch: 20, Batch: 300, Loss: 0.0038
# Epoch: 20, Batch: 310, Loss: 0.0023
# Epoch: 20, Batch: 320, Loss: 0.0032
# Epoch: 20, Batch: 330, Loss: 0.0031
# Epoch: 20, Batch: 340, Loss: 0.0033
# Epoch: 20, Batch: 350, Loss: 0.0018
# Epoch: 20, Train Loss: 0.0035, Val Loss: 0.0042
# Epoch: 21, Batch: 0, Loss: 0.0029
# Epoch: 21, Batch: 10, Loss: 0.0014
# Epoch: 21, Batch: 20, Loss: 0.0038
# Epoch: 21, Batch: 30, Loss: 0.0049
# Epoch: 21, Batch: 40, Loss: 0.0058
# Epoch: 21, Batch: 50, Loss: 0.0055
# Epoch: 21, Batch: 60, Loss: 0.0058
# Epoch: 21, Batch: 70, Loss: 0.0028
# Epoch: 21, Batch: 80, Loss: 0.0055
# Epoch: 21, Batch: 90, Loss: 0.0031
# Epoch: 21, Batch: 100, Loss: 0.0037
# Epoch: 21, Batch: 110, Loss: 0.0030
# Epoch: 21, Batch: 120, Loss: 0.0027
# Epoch: 21, Batch: 130, Loss: 0.0046
# Epoch: 21, Batch: 140, Loss: 0.0032
# Epoch: 21, Batch: 150, Loss: 0.0013
# Epoch: 21, Batch: 160, Loss: 0.0021
# Epoch: 21, Batch: 170, Loss: 0.0030
# Epoch: 21, Batch: 180, Loss: 0.0029
# Epoch: 21, Batch: 190, Loss: 0.0044
# Epoch: 21, Batch: 200, Loss: 0.0019
# Epoch: 21, Batch: 210, Loss: 0.0025
# Epoch: 21, Batch: 220, Loss: 0.0035
# Epoch: 21, Batch: 230, Loss: 0.0038
# Epoch: 21, Batch: 240, Loss: 0.0027
# Epoch: 21, Batch: 250, Loss: 0.0045
# Epoch: 21, Batch: 260, Loss: 0.0031
# Epoch: 21, Batch: 270, Loss: 0.0037
# Epoch: 21, Batch: 280, Loss: 0.0049
# Epoch: 21, Batch: 290, Loss: 0.0031
# Epoch: 21, Batch: 300, Loss: 0.0044
# Epoch: 21, Batch: 310, Loss: 0.0033
# Epoch: 21, Batch: 320, Loss: 0.0026
# Epoch: 21, Batch: 330, Loss: 0.0035
# Epoch: 21, Batch: 340, Loss: 0.0025
# Epoch: 21, Batch: 350, Loss: 0.0026
# Epoch: 21, Train Loss: 0.0037, Val Loss: 0.0042
# Epoch: 22, Batch: 0, Loss: 0.0027
# Epoch: 22, Batch: 10, Loss: 0.0040
# Epoch: 22, Batch: 20, Loss: 0.0029
# Epoch: 22, Batch: 30, Loss: 0.0039
# Epoch: 22, Batch: 40, Loss: 0.0035
# Epoch: 22, Batch: 50, Loss: 0.0037
# Epoch: 22, Batch: 60, Loss: 0.0036
# Epoch: 22, Batch: 70, Loss: 0.0020
# Epoch: 22, Batch: 80, Loss: 0.0041
# Epoch: 22, Batch: 90, Loss: 0.0033
# Epoch: 22, Batch: 100, Loss: 0.0026
# Epoch: 22, Batch: 110, Loss: 0.0024
# Epoch: 22, Batch: 120, Loss: 0.0028
# Epoch: 22, Batch: 130, Loss: 0.0036
# Epoch: 22, Batch: 140, Loss: 0.0040
# Epoch: 22, Batch: 150, Loss: 0.0029
# Epoch: 22, Batch: 160, Loss: 0.0019
# Epoch: 22, Batch: 170, Loss: 0.0056
# Epoch: 22, Batch: 180, Loss: 0.0024
# Epoch: 22, Batch: 190, Loss: 0.0033
# Epoch: 22, Batch: 200, Loss: 0.0054
# Epoch: 22, Batch: 210, Loss: 0.0032
# Epoch: 22, Batch: 220, Loss: 0.0022
# Epoch: 22, Batch: 230, Loss: 0.0033
# Epoch: 22, Batch: 240, Loss: 0.0016
# Epoch: 22, Batch: 250, Loss: 0.0033
# Epoch: 22, Batch: 260, Loss: 0.0028
# Epoch: 22, Batch: 270, Loss: 0.0020
# Epoch: 22, Batch: 280, Loss: 0.0042
# Epoch: 22, Batch: 290, Loss: 0.0064
# Epoch: 22, Batch: 300, Loss: 0.0027
# Epoch: 22, Batch: 310, Loss: 0.0100
# Epoch: 22, Batch: 320, Loss: 0.0037
# Epoch: 22, Batch: 330, Loss: 0.0075
# Epoch: 22, Batch: 340, Loss: 0.0046
# Epoch: 22, Batch: 350, Loss: 0.0033
# Epoch: 22, Train Loss: 0.0037, Val Loss: 0.0041
# Epoch: 23, Batch: 0, Loss: 0.0024
# Epoch: 23, Batch: 10, Loss: 0.0023
# Epoch: 23, Batch: 20, Loss: 0.0035
# Epoch: 23, Batch: 30, Loss: 0.0032
# Epoch: 23, Batch: 40, Loss: 0.0021
# Epoch: 23, Batch: 50, Loss: 0.0036
# Epoch: 23, Batch: 60, Loss: 0.0026
# Epoch: 23, Batch: 70, Loss: 0.0038
# Epoch: 23, Batch: 80, Loss: 0.0018
# Epoch: 23, Batch: 90, Loss: 0.0056
# Epoch: 23, Batch: 100, Loss: 0.0019
# Epoch: 23, Batch: 110, Loss: 0.0025
# Epoch: 23, Batch: 120, Loss: 0.0015
# Epoch: 23, Batch: 130, Loss: 0.0031
# Epoch: 23, Batch: 140, Loss: 0.0030
# Epoch: 23, Batch: 150, Loss: 0.0029
# Epoch: 23, Batch: 160, Loss: 0.0027
# Epoch: 23, Batch: 170, Loss: 0.0045
# Epoch: 23, Batch: 180, Loss: 0.0023
# Epoch: 23, Batch: 190, Loss: 0.0050
# Epoch: 23, Batch: 200, Loss: 0.0042
# Epoch: 23, Batch: 210, Loss: 0.0034
# Epoch: 23, Batch: 220, Loss: 0.0032
# Epoch: 23, Batch: 230, Loss: 0.0041
# Epoch: 23, Batch: 240, Loss: 0.0059
# Epoch: 23, Batch: 250, Loss: 0.0027
# Epoch: 23, Batch: 260, Loss: 0.0019
# Epoch: 23, Batch: 270, Loss: 0.0027
# Epoch: 23, Batch: 280, Loss: 0.0034
# Epoch: 23, Batch: 290, Loss: 0.0038
# Epoch: 23, Batch: 300, Loss: 0.0025
# Epoch: 23, Batch: 310, Loss: 0.0048
# Epoch: 23, Batch: 320, Loss: 0.0104
# Epoch: 23, Batch: 330, Loss: 0.0017
# Epoch: 23, Batch: 340, Loss: 0.0030
# Epoch: 23, Batch: 350, Loss: 0.0033
# Epoch: 23, Train Loss: 0.0034, Val Loss: 0.0040
# Epoch: 24, Batch: 0, Loss: 0.0014
# Epoch: 24, Batch: 10, Loss: 0.0039
# Epoch: 24, Batch: 20, Loss: 0.0012
# Epoch: 24, Batch: 30, Loss: 0.0017
# Epoch: 24, Batch: 40, Loss: 0.0046
# Epoch: 24, Batch: 50, Loss: 0.0020
# Epoch: 24, Batch: 60, Loss: 0.0053
# Epoch: 24, Batch: 70, Loss: 0.0059
# Epoch: 24, Batch: 80, Loss: 0.0028
# Epoch: 24, Batch: 90, Loss: 0.0023
# Epoch: 24, Batch: 100, Loss: 0.0026
# Epoch: 24, Batch: 110, Loss: 0.0028
# Epoch: 24, Batch: 120, Loss: 0.0034
# Epoch: 24, Batch: 130, Loss: 0.0025
# Epoch: 24, Batch: 140, Loss: 0.0045
# Epoch: 24, Batch: 150, Loss: 0.0030
# Epoch: 24, Batch: 160, Loss: 0.0032
# Epoch: 24, Batch: 170, Loss: 0.0017
# Epoch: 24, Batch: 180, Loss: 0.0015
# Epoch: 24, Batch: 190, Loss: 0.0009
# Epoch: 24, Batch: 200, Loss: 0.0038
# Epoch: 24, Batch: 210, Loss: 0.0038
# Epoch: 24, Batch: 220, Loss: 0.0024
# Epoch: 24, Batch: 230, Loss: 0.0050
# Epoch: 24, Batch: 240, Loss: 0.0031
# Epoch: 24, Batch: 250, Loss: 0.0039
# Epoch: 24, Batch: 260, Loss: 0.0018
# Epoch: 24, Batch: 270, Loss: 0.0042
# Epoch: 24, Batch: 280, Loss: 0.0029
# Epoch: 24, Batch: 290, Loss: 0.0036
# Epoch: 24, Batch: 300, Loss: 0.0051
# Epoch: 24, Batch: 310, Loss: 0.0045
# Epoch: 24, Batch: 320, Loss: 0.0029
# Epoch: 24, Batch: 330, Loss: 0.0033
# Epoch: 24, Batch: 340, Loss: 0.0044
# Epoch: 24, Batch: 350, Loss: 0.0026
# Epoch: 24, Train Loss: 0.0033, Val Loss: 0.0036
# Epoch: 25, Batch: 0, Loss: 0.0050
# Epoch: 25, Batch: 10, Loss: 0.0027
# Epoch: 25, Batch: 20, Loss: 0.0024
# Epoch: 25, Batch: 30, Loss: 0.0044
# Epoch: 25, Batch: 40, Loss: 0.0030
# Epoch: 25, Batch: 50, Loss: 0.0022
# Epoch: 25, Batch: 60, Loss: 0.0032
# Epoch: 25, Batch: 70, Loss: 0.0022
# Epoch: 25, Batch: 80, Loss: 0.0035
# Epoch: 25, Batch: 90, Loss: 0.0011
# Epoch: 25, Batch: 100, Loss: 0.0041
# Epoch: 25, Batch: 110, Loss: 0.0032
# Epoch: 25, Batch: 120, Loss: 0.0034
# Epoch: 25, Batch: 130, Loss: 0.0031
# Epoch: 25, Batch: 140, Loss: 0.0025
# Epoch: 25, Batch: 150, Loss: 0.0039
# Epoch: 25, Batch: 160, Loss: 0.0030
# Epoch: 25, Batch: 170, Loss: 0.0038
# Epoch: 25, Batch: 180, Loss: 0.0023
# Epoch: 25, Batch: 190, Loss: 0.0019
# Epoch: 25, Batch: 200, Loss: 0.0030
# Epoch: 25, Batch: 210, Loss: 0.0024
# Epoch: 25, Batch: 220, Loss: 0.0025
# Epoch: 25, Batch: 230, Loss: 0.0037
# Epoch: 25, Batch: 240, Loss: 0.0025
# Epoch: 25, Batch: 250, Loss: 0.0025
# Epoch: 25, Batch: 260, Loss: 0.0028
# Epoch: 25, Batch: 270, Loss: 0.0017
# Epoch: 25, Batch: 280, Loss: 0.0021
# Epoch: 25, Batch: 290, Loss: 0.0026
# Epoch: 25, Batch: 300, Loss: 0.0063
# Epoch: 25, Batch: 310, Loss: 0.0040
# Epoch: 25, Batch: 320, Loss: 0.0024
# Epoch: 25, Batch: 330, Loss: 0.0061
# Epoch: 25, Batch: 340, Loss: 0.0033
# Epoch: 25, Batch: 350, Loss: 0.0032
# Epoch: 25, Train Loss: 0.0032, Val Loss: 0.0040
# Epoch: 26, Batch: 0, Loss: 0.0013
# Epoch: 26, Batch: 10, Loss: 0.0024
# Epoch: 26, Batch: 20, Loss: 0.0022
# Epoch: 26, Batch: 30, Loss: 0.0024
# Epoch: 26, Batch: 40, Loss: 0.0030
# Epoch: 26, Batch: 50, Loss: 0.0038
# Epoch: 26, Batch: 60, Loss: 0.0026
# Epoch: 26, Batch: 70, Loss: 0.0018
# Epoch: 26, Batch: 80, Loss: 0.0029
# Epoch: 26, Batch: 90, Loss: 0.0091
# Epoch: 26, Batch: 100, Loss: 0.0040
# Epoch: 26, Batch: 110, Loss: 0.0032
# Epoch: 26, Batch: 120, Loss: 0.0023
# Epoch: 26, Batch: 130, Loss: 0.0026
# Epoch: 26, Batch: 140, Loss: 0.0037
# Epoch: 26, Batch: 150, Loss: 0.0027
# Epoch: 26, Batch: 160, Loss: 0.0036
# Epoch: 26, Batch: 170, Loss: 0.0014
# Epoch: 26, Batch: 180, Loss: 0.0027
# Epoch: 26, Batch: 190, Loss: 0.0022
# Epoch: 26, Batch: 200, Loss: 0.0037
# Epoch: 26, Batch: 210, Loss: 0.0037
# Epoch: 26, Batch: 220, Loss: 0.0042
# Epoch: 26, Batch: 230, Loss: 0.0023
# Epoch: 26, Batch: 240, Loss: 0.0048
# Epoch: 26, Batch: 250, Loss: 0.0043
# Epoch: 26, Batch: 260, Loss: 0.0042
# Epoch: 26, Batch: 270, Loss: 0.0058
# Epoch: 26, Batch: 280, Loss: 0.0034
# Epoch: 26, Batch: 290, Loss: 0.0031
# Epoch: 26, Batch: 300, Loss: 0.0030
# Epoch: 26, Batch: 310, Loss: 0.0033
# Epoch: 26, Batch: 320, Loss: 0.0017
# Epoch: 26, Batch: 330, Loss: 0.0042
# Epoch: 26, Batch: 340, Loss: 0.0046
# Epoch: 26, Batch: 350, Loss: 0.0019
# Epoch: 26, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch: 27, Batch: 0, Loss: 0.0021
# Epoch: 27, Batch: 10, Loss: 0.0011
# Epoch: 27, Batch: 20, Loss: 0.0082
# Epoch: 27, Batch: 30, Loss: 0.0036
# Epoch: 27, Batch: 40, Loss: 0.0024
# Epoch: 27, Batch: 50, Loss: 0.0038
# Epoch: 27, Batch: 60, Loss: 0.0026
# Epoch: 27, Batch: 70, Loss: 0.0026
# Epoch: 27, Batch: 80, Loss: 0.0030
# Epoch: 27, Batch: 90, Loss: 0.0018
# Epoch: 27, Batch: 100, Loss: 0.0063
# Epoch: 27, Batch: 110, Loss: 0.0040
# Epoch: 27, Batch: 120, Loss: 0.0027
# Epoch: 27, Batch: 130, Loss: 0.0037
# Epoch: 27, Batch: 140, Loss: 0.0043
# Epoch: 27, Batch: 150, Loss: 0.0046
# Epoch: 27, Batch: 160, Loss: 0.0014
# Epoch: 27, Batch: 170, Loss: 0.0019
# Epoch: 27, Batch: 180, Loss: 0.0034
# Epoch: 27, Batch: 190, Loss: 0.0027
# Epoch: 27, Batch: 200, Loss: 0.0039
# Epoch: 27, Batch: 210, Loss: 0.0021
# Epoch: 27, Batch: 220, Loss: 0.0057
# Epoch: 27, Batch: 230, Loss: 0.0025
# Epoch: 27, Batch: 240, Loss: 0.0047
# Epoch: 27, Batch: 250, Loss: 0.0016
# Epoch: 27, Batch: 260, Loss: 0.0027
# Epoch: 27, Batch: 270, Loss: 0.0066
# Epoch: 27, Batch: 280, Loss: 0.0018
# Epoch: 27, Batch: 290, Loss: 0.0023
# Epoch: 27, Batch: 300, Loss: 0.0039
# Epoch: 27, Batch: 310, Loss: 0.0078
# Epoch: 27, Batch: 320, Loss: 0.0044
# Epoch: 27, Batch: 330, Loss: 0.0024
# Epoch: 27, Batch: 340, Loss: 0.0033
# Epoch: 27, Batch: 350, Loss: 0.0026
# Epoch: 27, Train Loss: 0.0033, Val Loss: 0.0037
# Epoch: 28, Batch: 0, Loss: 0.0018
# Epoch: 28, Batch: 10, Loss: 0.0027
# Epoch: 28, Batch: 20, Loss: 0.0014
# Epoch: 28, Batch: 30, Loss: 0.0032
# Epoch: 28, Batch: 40, Loss: 0.0013
# Epoch: 28, Batch: 50, Loss: 0.0023
# Epoch: 28, Batch: 60, Loss: 0.0028
# Epoch: 28, Batch: 70, Loss: 0.0023
# Epoch: 28, Batch: 80, Loss: 0.0031
# Epoch: 28, Batch: 90, Loss: 0.0016
# Epoch: 28, Batch: 100, Loss: 0.0030
# Epoch: 28, Batch: 110, Loss: 0.0040
# Epoch: 28, Batch: 120, Loss: 0.0025
# Epoch: 28, Batch: 130, Loss: 0.0019
# Epoch: 28, Batch: 140, Loss: 0.0024
# Epoch: 28, Batch: 150, Loss: 0.0030
# Epoch: 28, Batch: 160, Loss: 0.0021
# Epoch: 28, Batch: 170, Loss: 0.0043
# Epoch: 28, Batch: 180, Loss: 0.0027
# Epoch: 28, Batch: 190, Loss: 0.0020
# Epoch: 28, Batch: 200, Loss: 0.0049
# Epoch: 28, Batch: 210, Loss: 0.0022
# Epoch: 28, Batch: 220, Loss: 0.0012
# Epoch: 28, Batch: 230, Loss: 0.0016
# Epoch: 28, Batch: 240, Loss: 0.0035
# Epoch: 28, Batch: 250, Loss: 0.0033
# Epoch: 28, Batch: 260, Loss: 0.0034
# Epoch: 28, Batch: 270, Loss: 0.0029
# Epoch: 28, Batch: 280, Loss: 0.0041
# Epoch: 28, Batch: 290, Loss: 0.0054
# Epoch: 28, Batch: 300, Loss: 0.0030
# Epoch: 28, Batch: 310, Loss: 0.0048
# Epoch: 28, Batch: 320, Loss: 0.0043
# Epoch: 28, Batch: 330, Loss: 0.0036
# Epoch: 28, Batch: 340, Loss: 0.0021
# Epoch: 28, Batch: 350, Loss: 0.0033
# Epoch: 28, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch: 29, Batch: 0, Loss: 0.0018
# Epoch: 29, Batch: 10, Loss: 0.0021
# Epoch: 29, Batch: 20, Loss: 0.0027
# Epoch: 29, Batch: 30, Loss: 0.0018
# Epoch: 29, Batch: 40, Loss: 0.0036
# Epoch: 29, Batch: 50, Loss: 0.0019
# Epoch: 29, Batch: 60, Loss: 0.0022
# Epoch: 29, Batch: 70, Loss: 0.0044
# Epoch: 29, Batch: 80, Loss: 0.0047
# Epoch: 29, Batch: 90, Loss: 0.0030
# Epoch: 29, Batch: 100, Loss: 0.0028
# Epoch: 29, Batch: 110, Loss: 0.0043
# Epoch: 29, Batch: 120, Loss: 0.0034
# Epoch: 29, Batch: 130, Loss: 0.0018
# Epoch: 29, Batch: 140, Loss: 0.0034
# Epoch: 29, Batch: 150, Loss: 0.0037
# Epoch: 29, Batch: 160, Loss: 0.0025
# Epoch: 29, Batch: 170, Loss: 0.0026
# Epoch: 29, Batch: 180, Loss: 0.0028
# Epoch: 29, Batch: 190, Loss: 0.0035
# Epoch: 29, Batch: 200, Loss: 0.0027
# Epoch: 29, Batch: 210, Loss: 0.0041
# Epoch: 29, Batch: 220, Loss: 0.0024
# Epoch: 29, Batch: 230, Loss: 0.0024
# Epoch: 29, Batch: 240, Loss: 0.0052
# Epoch: 29, Batch: 250, Loss: 0.0039
# Epoch: 29, Batch: 260, Loss: 0.0023
# Epoch: 29, Batch: 270, Loss: 0.0023
# Epoch: 29, Batch: 280, Loss: 0.0021
# Epoch: 29, Batch: 290, Loss: 0.0044
# Epoch: 29, Batch: 300, Loss: 0.0026
# Epoch: 29, Batch: 310, Loss: 0.0021
# Epoch: 29, Batch: 320, Loss: 0.0026
# Epoch: 29, Batch: 330, Loss: 0.0035
# Epoch: 29, Batch: 340, Loss: 0.0031
# Epoch: 29, Batch: 350, Loss: 0.0040
# Epoch: 29, Train Loss: 0.0029, Val Loss: 0.0049
# Epoch: 30, Batch: 0, Loss: 0.0031
# Epoch: 30, Batch: 10, Loss: 0.0043
# Epoch: 30, Batch: 20, Loss: 0.0069
# Epoch: 30, Batch: 30, Loss: 0.0031
# Epoch: 30, Batch: 40, Loss: 0.0038
# Epoch: 30, Batch: 50, Loss: 0.0058
# Epoch: 30, Batch: 60, Loss: 0.0048
# Epoch: 30, Batch: 70, Loss: 0.0011
# Epoch: 30, Batch: 80, Loss: 0.0029
# Epoch: 30, Batch: 90, Loss: 0.0026
# Epoch: 30, Batch: 100, Loss: 0.0015
# Epoch: 30, Batch: 110, Loss: 0.0029
# Epoch: 30, Batch: 120, Loss: 0.0028
# Epoch: 30, Batch: 130, Loss: 0.0035
# Epoch: 30, Batch: 140, Loss: 0.0033
# Epoch: 30, Batch: 150, Loss: 0.0024
# Epoch: 30, Batch: 160, Loss: 0.0025
# Epoch: 30, Batch: 170, Loss: 0.0032
# Epoch: 30, Batch: 180, Loss: 0.0042
# Epoch: 30, Batch: 190, Loss: 0.0047
# Epoch: 30, Batch: 200, Loss: 0.0023
# Epoch: 30, Batch: 210, Loss: 0.0015
# Epoch: 30, Batch: 220, Loss: 0.0019
# Epoch: 30, Batch: 230, Loss: 0.0019
# Epoch: 30, Batch: 240, Loss: 0.0035
# Epoch: 30, Batch: 250, Loss: 0.0032
# Epoch: 30, Batch: 260, Loss: 0.0017
# Epoch: 30, Batch: 270, Loss: 0.0016
# Epoch: 30, Batch: 280, Loss: 0.0029
# Epoch: 30, Batch: 290, Loss: 0.0031
# Epoch: 30, Batch: 300, Loss: 0.0037
# Epoch: 30, Batch: 310, Loss: 0.0031
# Epoch: 30, Batch: 320, Loss: 0.0027
# Epoch: 30, Batch: 330, Loss: 0.0036
# Epoch: 30, Batch: 340, Loss: 0.0026
# Epoch: 30, Batch: 350, Loss: 0.0019
# Epoch: 30, Train Loss: 0.0031, Val Loss: 0.0033
# Input: gfbs, Decrypted: OZGL
